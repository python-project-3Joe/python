# %%
#!pip install fake-useragent

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import urllib.request as request

from selenium.webdriver.chrome.options import Options
from fake_useragent import UserAgent

# %%
options = Options()
ua = UserAgent(verify_ssl=False)
userAgent = ua.random
print(userAgent)
# Out:
# Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/29.0.1547.2 Safari/537.36

# %%
options.add_argument(f'user-agent={userAgent}')
# chrome_options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)
driver.get('https://www.melon.com/genre/song_list.htm#params%5BgnrCode%5D=GN0100&params%5BdtlGnrCode%5D=&params%5BorderBy%5D=POP&params%5BsteadyYn%5D=N&po=pageObj&startIndex=501')
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 103.0.5060
# [WDM] - Get LATEST chromedriver version for 103.0.5060 google-chrome
# [WDM] - Driver [/Users/tj/.wdm/drivers/chromedriver/mac64/103.0.5060.134/chromedriver] found in cache

# %%
page_source = driver.page_source
soup = BeautifulSoup(page_source, "html.parser")

# %%
import time

total_lists = []
for page in list(range(501,1000, 50)):

  driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)
  driver.get('https://www.melon.com/genre/song_list.htm#params%5BgnrCode%5D=GN0100&params%5BdtlGnrCode%5D=&params%5BorderBy%5D=POP&params%5BsteadyYn%5D=N&po=pageObj&startIndex='+ str(page))

  time.sleep(1)

  page_source = driver.page_source
  soup = BeautifulSoup(page_source, "html.parser")

  time.sleep(1)

  songIds = soup.select("#frm > div > table > tbody td:nth-child(4) > div > a")
  total_lists = total_lists + songIds

  time.sleep(1)
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 103.0.5060
# [WDM] - Get LATEST chromedriver version for 103.0.5060 google-chrome
# [WDM] - Driver [/Users/tj/.wdm/drivers/chromedriver/mac64/103.0.5060.134/chromedriver] found in cache
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 103.0.5060
# [WDM] - Get LATEST chromedriver version for 103.0.5060 google-chrome
# [WDM] - Driver [/Users/tj/.wdm/drivers/chromedriver/mac64/103.0.5060.134/chromedriver] found in cache
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 103.0.5060
# [WDM] - Get LATEST chromedriver version for 103.0.5060 google-chrome
# [WDM] - Driver [/Users/tj/.wdm/drivers/chromedriver/mac64/103.0.5060.134/chromedriver] found in cache
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 103.0.5060
# [WDM] - Get LATEST chromedriver version for 103.0.5060 google-chrome
# [WDM] - Driver [/Users/tj/.wdm/drivers/chromedriver/mac64/103.0.5060.134/chromedriver] found in cache
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 103.0.5060
# [WDM] - Get LATEST chromedriver version for 103.0.5060 google-chrome
# [WDM] - Driver [/Users/tj/.wdm/drivers/chromedriver/mac64/103.0.5060.134/chromedriver] found in cache
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 103.0.5060
# [WDM] - Get LATEST chromedriver version for 103.0.5060 google-chrome
# [WDM] - Driver [/Users/tj/.wdm/drivers/chromedriver/mac64/103.0.5060.134/chromedriver] found in cache
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 103.0.5060
# [WDM] - Get LATEST chromedriver version for 103.0.5060 google-chrome
# [WDM] - Driver [/Users/tj/.wdm/drivers/chromedriver/mac64/103.0.5060.134/chromedriver] found in cache
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 103.0.5060
# [WDM] - Get LATEST chromedriver version for 103.0.5060 google-chrome
# [WDM] - Driver [/Users/tj/.wdm/drivers/chromedriver/mac64/103.0.5060.134/chromedriver] found in cache
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 103.0.5060
# [WDM] - Get LATEST chromedriver version for 103.0.5060 google-chrome
# [WDM] - Driver [/Users/tj/.wdm/drivers/chromedriver/mac64/103.0.5060.134/chromedriver] found in cache
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 103.0.5060
# [WDM] - Get LATEST chromedriver version for 103.0.5060 google-chrome
# [WDM] - Driver [/Users/tj/.wdm/drivers/chromedriver/mac64/103.0.5060.134/chromedriver] found in cache

# %%
# songId 가져오기
songId_list = []
for songId in total_lists:
    songId_list.append(songId['href'].split('\'')[1])

len(songId_list)
# Out:
# 500

# %%
song_title = []
for i in range(len(songId_list)):
    song_title.append(total_lists[i]['title'].replace(" 곡정보",""))

# %%
song_title
# Out:
# ['세 사람 (With 성시경)',
#  '너를 위해',
#  'TV를 껐네... (Feat. t윤미래, 권정열 Of 10cm)',
#  '오랜만이야',
#  '나에게 그대만이',
#  '사랑했던 우리가 어떻게 친구가 되니',
#  '잘가요',
#  '넌 좋은 사람',
#  '사계 (四季)',
#  '잊었니',
#  '혼자가 아닌 나',
#  '텔레파시 (상수리나무 아래 X 양요섭 X 은하)',
#  '감사',
#  '너의 눈에 별이 떠 있어',
#  '가수가 된 이유',
#  '바보에게 바보가',
#  '그녀를 찾아주세요',
#  '해요',
#  '언제나 사랑해',
#  '첫 눈',
#  'Gravity',
#  '운명이 우릴 갈라놓아도',
#  '제자리 걸음',
#  '잘 된 일이야',
#  '오늘부터 1일 (Day 1)',
#  '이별주',
#  'illa illa (일라 일라)',
#  '중독된 사랑',
#  '날 닮은 너',
#  '내 안부',
#  '사랑 참...',
#  'Melody',
#  '그대 에너지',
#  '다시 사랑 할 수 있을까 (Feat. 다비치)',
#  'I Miss You',
#  '소주한잔',
#  'Higher (Feat. 이루마)',
#  '잘 살고 있다',
#  '유난히 지치는 그런 날이 있잖아',
#  '길',
#  '여기까지 해요',
#  'BAD BOY',
#  '다시 만날까 봐',
#  'Goodbye Summer (f(Amber+Luna+Krystal) (Feat. D.O. Of EXO-K)',
#  '그XX',
#  '안녕, 오늘의 그대에게',
#  '못해준 게 많아서',
#  '깊은 밤을 날아서',
#  '연애소설',
#  '봄 안녕 봄',
#  'Stay Alive (Prod. SUGA of BTS)',
#  '넌 내가 보고 싶지 않나 봐',
#  '그녀를 찾아주세요',
#  'Here We Are',
#  '꿈에',
#  '뭔가 잘못됐어',
#  '그대 고운 내사랑',
#  '이별택시',
#  '우리의 밤을 외워요',
#  '나를 잊지 말아요',
#  '나의 사랑아 (Prod. 정현욱)',
#  '나의 첫사랑',
#  '언제나',
#  '안녕',
#  '하염없이 (Feat. 정동원)',
#  '하지 못한 말',
#  '별',
#  '우린 제법 잘 어울려요',
#  '바래',
#  '둘이서 떠나요',
#  '그땐 미처 알지 못했지',
#  '구르미 그린 달빛',
#  '오늘도 난 봄을 기다려',
#  '그녀가 웃잖아....',
#  '봄인가 봐 (Spring Love)',
#  '아로하',
#  '너도 아는',
#  "이러지마 제발 (Please Don't...)",
#  '좋아',
#  '8번 연습실',
#  'Perhaps Love (사랑인가요) (Prod.By 박근태)',
#  '불러봐도',
#  '나만 몰랐던 이야기',
#  '가진다는 말은 좀 그렇지?',
#  '물론',
#  '너무 보고싶어',
#  '모르시나요',
#  '살다가 한번쯤',
#  '다시 사랑한다 말할까',
#  '사랑한 후에',
#  '에필로그',
#  '12시 30분',
#  '그대네요',
#  '바람의 노래',
#  '힙합보단 사랑, 사랑보단 돈 (Feat. 베이식)',
#  "Don't Cry",
#  '처음 그 자리에',
#  '사랑이었다 (Feat. 루나 of f(x))',
#  '구두',
#  '빌려줄게',
#  '사랑하기 참 좋은 날',
#  '가질 수 없는 너',
#  '사랑의 시작은 고백에서부터',
#  '사랑은 언제나 목마르다',
#  '기다릴게',
#  '별, 바람, 햇살 그리고 사랑',
#  '요즘',
#  '마음이 다쳐서 (Feat. Crown J)',
#  '내 눈물 모아',
#  '가슴 시린 이야기 (Feat. 용준형 Of Beast)',
#  '찬찬히 (Take It Slow)',
#  'Parade',
#  '모노드라마 (With 유승우)',
#  '잔소리',
#  '나는 어떡해',
#  '흑백사진',
#  '더 보고 싶고 미안하고 그래',
#  '한계',
#  '한 남자',
#  'Done For Me',
#  '사랑이 술을 가르쳐 (Feat. 백찬 From 8eight)',
#  '기댈곳',
#  '가슴이 뛴다',
#  '행복한 나를 (Feat. 존박)',
#  '내 눈물 모아',
#  '사랑하지 말아요 (Prod. 로코베리)',
#  'My Destiny',
#  '최고의 행운',
#  '자기야 여보야 사랑아',
#  '부디',
#  '그리워해요',
#  '돌아올순 없나요',
#  '하루',
#  '한잔이면 지워질까',
#  '밤새 서로 미루다',
#  '내 목소리 들리니',
#  '내가 너의 곁에 잠시 살았다는 걸',
#  '그런가 봐요...',
#  'Blue',
#  'Starlight (Feat. DEAN)',
#  '이런 남자',
#  '사실 나는 (남자 Ver.)',
#  '바람',
#  '사랑은 눈꽃처럼',
#  '이 번호로 전화해줘',
#  '언제나',
#  '아무렇지 않은 척',
#  '체념',
#  '니가 필요해 (I Need You)',
#  '너 하나야 (낮에 뜨는 달 X 길구봉구)',
#  'You',
#  'Someday',
#  '그랬나봐',
#  'Lonely Night',
#  '여행자',
#  '잘 가',
#  '사월의 눈',
#  'About You',
#  'Like a Star',
#  '지우개',
#  '1월부터 6월까지',
#  '오르막길',
#  '너에게 난, 나에게 넌',
#  '다시 너를',
#  '버릇처럼 셋을 센다',
#  '사랑의 時(시)',
#  '취중진담',
#  '모를까봐서(2021) (Feat.아샤트리)',
#  '마지막 장면 (Feat. 이성경)',
#  '너를 그리는 시간 (Drawing Our Moments)',
#  '사랑은 늘 도망가',
#  '어떤 날엔',
#  '출발',
#  '우주선 (Spaceship)',
#  '혼자 왔어요',
#  '좋은 사람 (2022)',
#  '만약에 말야 (전우성 Solo)',
#  '바라보다',
#  '좋은 날',
#  '그대를 잊는다는 건',
#  '중독된 사랑',
#  '크리스마스니까',
#  '제자리 걸음',
#  '우리 그만하자',
#  '어른',
#  '이별을 노래로 만들어 보았습니다',
#  '술도 못하는데',
#  '술이야',
#  '아내 (My Wife)',
#  '백야',
#  '가시리',
#  '웃으며 안녕',
#  '헤어지기 싫어',
#  '사랑한다는 말로는 (Feat.주시크 (Joosiq))',
#  '죽어도 못 보내',
#  '아프다',
#  '너를 위해',
#  '그 사람',
#  '보고싶은 날엔..',
#  '바람이 분다',
#  '기대',
#  '그때 또 다시 (Again)',
#  '사랑한다는 말로는',
#  '친구로 지내자면서 (Prod. By 전태익)',
#  '그 사람 많이 사랑했나요',
#  'Gift',
#  '나비무덤',
#  '흔한 노래',
#  'Stardust love song',
#  '우리 둘만 아는',
#  '어제보다 오늘 더',
#  '내 마음 내리는 곳에',
#  '비가와 (Rain)',
#  '별이 될께',
#  '다행이다',
#  '두근두근',
#  '부담이 돼 (Feat. 휘인 Of 마마무)',
#  '별',
#  'Another Day',
#  '펑펑',
#  '좋을텐데 (If Only) (Feat. 폴킴)',
#  '그대여',
#  '사랑에 빠지고 싶다',
#  '영원',
#  '차마...',
#  '슬픈 다짐',
#  '난 너에게',
#  '언제라도 어디에서라도',
#  '기억의 습작',
#  '괜찮아요',
#  '당신을 위하여',
#  '굿모닝 (Good Morning)',
#  '내 입술 따뜻한 커피처럼',
#  '제발',
#  '대낮에 한 이별 (Feat. 선예 (Wonder Girls))',
#  '배운게 사랑이라',
#  'To Heaven (천국으로 보낸 편지)',
#  'Touch Love',
#  '거짓말 거짓말 거짓말',
#  '1440',
#  '나와 헤어진 걸 다행이라 생각할 수 있게',
#  '널 그리워하고 있어',
#  '모든 날, 모든 순간',
#  '그럴때마다',
#  '다시 사랑할 수 있을까',
#  '내사랑 내곁에 (응답하라 1988 삽입곡)',
#  '취중고백',
#  '벌써일년',
#  '사랑은 늘 도망가 (로맨틱 흑기사)',
#  '우리라서 참 행복했어',
#  '내입술...따뜻한 커피처럼',
#  '잘할게',
#  '너 없는 시간들',
#  '내 사람입니다',
#  '이미 나에게로',
#  '오늘은 가지마',
#  "넌 나의 전부 (I can't take my eyes off you)",
#  '너 없이 사는 게 (N번째 연애 X 허각)',
#  'When This Rain Stops',
#  '면도',
#  '눈물이 뚝뚝',
#  '가슴아 그만해',
#  '서툰 이별을 하려해',
#  '왜? 날',
#  '안녕이란 (Two Letters)',
#  '난 너를 사랑해',
#  '그 한마디 (바른연애 길잡이 X 이하이)',
#  '첫 눈',
#  '좋아요',
#  'Only One',
#  '얼마나 아파야 잊을까요',
#  '이별길 (GOODBYE ROAD)',
#  'Falling',
#  '바보야',
#  '그 남잔 말야',
#  '별의 조각',
#  '퇴근버스',
#  '어떻게 사랑이 그래요',
#  '여우비',
#  '인형 (Duet. 신혜성)',
#  '함께',
#  '다시 사랑한다 말할까',
#  '걸음이 느린 아이',
#  '사랑은 또',
#  '사랑은 아프려고 하는 거죠',
#  '그대 없이 그대와',
#  '호랑수월가',
#  '사랑지수',
#  '휠릴리',
#  '멋지게 인사하는 법 (Feat. 슬기 of Red Velvet)',
#  '고무신 거꾸로 신지마',
#  '알았다면',
#  '그리워하지도 말고, 찾아오지도 마',
#  '슬픈 혼잣말',
#  "빈칸 (웹툰 '연애의 발견' X OuiOui (위위))",
#  '우연처럼,인연처럼,운명처럼',
#  '너무 보고싶어',
#  'Je T′aime',
#  '참다행이야',
#  '너무 보고싶어',
#  '빨래',
#  '가족사진',
#  'Sweet Dream',
#  '미워도 다시 한번 (Original Ver.)',
#  '화장을 고치고',
#  '꽃이 핀다',
#  'You And I',
#  '아마추어',
#  '서약 (황금무지개 유이&정일우 러브테마)',
#  '고칠게',
#  '위로',
#  '그대는 눈물겹다',
#  '내가 다 미안해',
#  '행복하니',
#  '바래다주던 길',
#  '사랑하는 당신께',
#  'Gloomy Star (Feat. 1ho, Chan)',
#  '안갯길 (Prod. By 진영(B1A4))',
#  '서로 다른 이별',
#  '야상곡(夜想曲)',
#  '해바라기도 가끔 목이 아프죠',
#  '내 안의 그대',
#  '이쁘다니까',
#  '마음 사이',
#  '벌써 일년 (Drama Ver.)',
#  '사랑시 고백구 행복동',
#  '내사랑 울보',
#  '슬픈 언약식',
#  '배반',
#  '같은 시간 같은 자리 (Walk you home)',
#  '그대 손 놓아요',
#  '내 삶의 반',
#  '우리 사랑했잖아',
#  '하염없이 (Prod. 손이삭)',
#  '눈부신 눈물',
#  '오늘까지만',
#  '신촌을 못가',
#  '나란놈이란',
#  '넌 내게 특별하고',
#  '어느 날 우리',
#  '너에게',
#  '보통의 하루',
#  '아름다운 이별',
#  'Bye Bye Bye',
#  '사랑한다는 흔한 말',
#  '해바라기',
#  'If You',
#  "I'm here",
#  '비가 온다',
#  '옛사랑',
#  '밤하늘의 별을... (1992)',
#  '거짓말',
#  '이노래',
#  'LET ME OUT',
#  '겨울사랑',
#  'All For You',
#  '이 밤이 지나면',
#  '녹는 중 (Feat. 버벌진트)',
#  '살아가는 거야',
#  '욕심',
#  '사랑하니까 (2021)',
#  '사랑이 다른 사랑으로 잊혀지네',
#  '안개 속 어디로',
#  '통화 연결음',
#  '얼음꽃 (Feat. 김세황)',
#  '하루의 끝 (End of a day)',
#  '여우야',
#  '롤러코스터 (Feat.예지 of 경서예지)',
#  '뜨거운 안녕 (Vocal 이지형)',
#  '라라라',
#  '사랑해요',
#  'Be With You',
#  '미치고 싶다',
#  'See you again',
#  '태양계',
#  'FOOL',
#  'Goodbye',
#  '소녀',
#  '고백',
#  '오래된 노래',
#  '아무렇지 않은 사람',
#  '결혼할까요',
#  '너를 사랑해',
#  '마음이 다쳐서(2021)',
#  'Belief',
#  '물끄러미',
#  '12월의 어느 겨울…',
#  '마지막이 될 줄 몰랐어',
#  '희재',
#  '전활 받지 않는 너에게',
#  '끝난 사이',
#  'Try Again',
#  '고백',
#  '제목을 몰랐던 노래',
#  '길 (Song by 아이유, 헨리, 조현아, 양다일)',
#  '한숨',
#  'Beautiful',
#  '내겐 너무 멋진 그대',
#  '돌아가고 싶다',
#  '여기까지',
#  '그날들',
#  '붙잡고 싶어도',
#  '여인의 향기',
#  '사랑해 그리고 기억해',
#  '꿈처럼 내린',
#  '말하는 대로',
#  '북두칠성',
#  'Blue & Grey',
#  '그대 나를 일으켜주면',
#  '기억해 줘요',
#  '정류장',
#  '사랑하고 싶지 않아 (바른연애 길잡이 X XIA (준수))',
#  '오늘은 가지마',
#  'Pit a Pat',
#  '녹슨 가슴',
#  'My Love (Duet Ver.)',
#  '어땠을까',
#  '친구',
#  '신부에게',
#  '아시나요',
#  '다시 와주라',
#  'Beautiful Life',
#  '어떤 날, 그럴 때면',
#  'Say I Love You',
#  'Memories... (Smiling Tears)',
#  '아이처럼',
#  '가질수 없는 너',
#  '사진을 보다가',
#  '죽고 싶단 말 밖에',
#  '사랑을 사랑하게 될 때까지',
#  '내일 할 일',
#  '그여자',
#  'My Story',
#  '구애 (求愛)',
#  'Home',
#  'Who Are You',
#  '아파 (Slow)',
#  '울어',
#  '농담처럼 (Prod. Zion.T)',
#  '전 여친',
#  '봄날의 기억',
#  '회상',
#  '미아',
#  '캠프파이어',
#  '이 밤',
#  '이젠 친구에서 연인이 되고 싶어',
#  '둘만의 세상으로 가',
#  '멜로를 좋아해',
#  '왜 변하니',
#  '광(狂)',
#  '만약에',
#  '그때는 이 거리가 아름다웠다',
#  '나의 매일에게',
#  '맨정신에 고백',
#  '오월의 어느 봄날 (Feat. 첸(CHEN))',
#  '목소리',
#  '사랑이 뭔데',
#  '나비야',
#  '다시는 아파하지 않게',
#  '헤어지는 중입니다',
#  '별이될게',
#  '가만히 눈을 감고 (CF - 교토 다원녹차)',
#  '마지막 너의 인사',
#  '흩어져',
#  '겨울..그다음 봄',
#  '안녕과 안녕으로',
#  '뻔한남자',
#  'Happiness',
#  '서울의 달',
#  '제주도의 푸른 밤',
#  '별다를 거 없어',
#  '한 편의 너',
#  '보고싶은 날엔..',
#  '눈꽃',
#  '오늘따라 비가 와서 그런가 봐',
#  '잘 지내요',
#  '향기',
#  '모래성',
#  '선물 (Feat. 은지원)',
#  'LOVE ALL',
#  '오늘도 그대만',
#  '좋아해 (bye)',
#  '너의 바다',
#  '오늘따라 보고싶어서 그래',
#  '이것밖에',
#  '하기 힘든 말',
#  '밤',
#  '가까이 있어서 몰랐어',
#  '미치게 그리워서',
#  '그 사람을 아나요',
#  '처음 만날때처럼',
#  '그녀가 말했다 (With 권진아)',
#  "인연 (드라마 '불새')",
#  'After (다음엔..)',
#  '눈물이 많아서',
#  'Can We? (Feat. J.O.Y, Cindy Zhang)',
#  '그 남자 그 여자',
#  '이런 게 사랑이라면',
#  '회상',
#  '찾았다']

# %%
# 가수명, 노래제목, 발매일, 가사, 좋아요 수 리스트 변수 생성

singer_list = []
singName_list = []
date_list = []
lyrics_list = []
like_list = []

# %%
# for문으로 가수명, 노래제목, 발매일, 가사, 좋아요 수 리스트 변수에 내용 담고 저장하기

chrome_options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)

for songId in songId_list:
    
    driver.get(f'https://www.melon.com/song/detail.htm?songId={songId}')

    page_source = driver.page_source
    soup = BeautifulSoup(page_source, "html.parser")

    time.sleep(2)

    try:
    
        # 가수명 가져오기
        artist_name = soup.select_one('#downloadfrm > div > div > div.entry > div.info > div.artist > a > span:nth-child(1) ')
        singer_list.append(artist_name.string)

        # 노래제목 가져오기
        song_name = soup.select_one("#downloadfrm > div > div > div.entry > div.info > div.song_name ")
        singName_list.append(song_name.text.strip().split('\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t')[1])

        # 발매일 가져오기
        date = soup.select_one('#downloadfrm > div > div > div.entry > div.meta > dl > dd:nth-child(4)')
        date_list.append(date.string)

        # 가사 가져오기
        lyric = soup.select_one('#d_video_summary')
        lyrics_list.append(lyric.text.strip())

        # 좋아요수 가져오기
        like = soup.select_one("#d_like_count")
        like_list.append(like.text)

        time.sleep(2)
    except:
        singer_list.append(0)
        singName_list.append(0)
        date_list.append(0)
        lyrics_list.append(0)
        like_list.append(0)

        time.sleep(1)
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 103.0.5060
# [WDM] - Get LATEST chromedriver version for 103.0.5060 google-chrome
# [WDM] - Driver [/Users/tj/.wdm/drivers/chromedriver/mac64/103.0.5060.134/chromedriver] found in cache

# %%
singer_list
# Out:
# ['토이',
#  '첸 (CHEN)',
#  '리쌍',
#  0,
#  '임창정',
#  '유해준',
#  '송하예',
#  '정재욱',
#  'SG 워너비',
#  '신용재 (2F)',
#  '이승철',
#  '서영은',
#  '양요섭',
#  '김동률',
#  '포맨 (4MEN)',
#  '신용재 (2F)',
#  '지아',
#  '윤민수(바이브)',
#  'INO',
#  '제이세라',
#  '정준일',
#  '태연 (TAEYEON)',
#  '송하예',
#  '김종국',
#  '나비 (Navi)',
#  '케이윌',
#  '황인욱',
#  'JUNIEL',
#  '조장혁',
#  '임창정',
#  '이우',
#  '디셈버',
#  '휘인 (Whee In)',
#  '아샤트리',
#  '포맨 (4MEN)',
#  '소유 (SOYOU)',
#  '임창정',
#  '에일리(Ailee)',
#  'V.O.S',
#  '다비치',
#  'god',
#  '박현규 (VROMANCE)',
#  'BIGBANG (빅뱅)',
#  'V.O.S',
#  'f(x)',
#  'G-DRAGON',
#  0,
#  '임한별',
#  '잠골버스',
#  '이문세',
#  '가비엔제이',
#  '아이유',
#  '정국',
#  '신예영',
#  '더 네임',
#  '김필',
#  '박정현',
#  '권진아',
#  '어반자카파',
#  '김연우',
#  '카더가든',
#  '허각',
#  '김강패',
#  '다비치',
#  '허각',
#  '효린',
#  'T.P RETRO (타디스 프로젝트舊)',
#  '노을',
#  '볼빨간사춘기',
#  '성시경',
#  'HYNN (박혜원)',
#  '다비치',
#  '이적',
#  '거미',
#  '케이시 (Kassy)',
#  '김형중',
#  '에릭남 (Eric Nam)',
#  '쿨 (COOL)',
#  '폴킴',
#  '케이윌',
#  '민서 (MINSEO)',
#  '이무진',
#  '에릭남 (Eric Nam)',
#  '주호',
#  '아이유',
#  '10CM',
#  '지아',
#  '전상근',
#  '다비치',
#  '포맨 (4MEN)',
#  '김동률',
#  '박효신',
#  '아이유',
#  '비스트',
#  '성시경',
#  '소향',
#  '노아주다 (noahjooda)',
#  '더 크로스',
#  '이보람 (씨야)',
#  '지코 (ZICO)',
#  '씨야',
#  '신용재 (2F)',
#  '이진이',
#  '뱅크',
#  '김범수',
#  '유미',
#  '하동균',
#  '김종국',
#  '양다일',
#  '나비 (Navi)',
#  '서지원',
#  '휘성 (Realslow)',
#  '영탁',
#  '윤하 (YOUNHA)',
#  '허각',
#  '더 넛츠 (The NuTs)',
#  '스탠딩 에그',
#  'KCM',
#  '이예준',
#  '백예린 (Yerin Baek)',
#  '김종국',
#  '펀치 (Punch)',
#  '이승기',
#  '싸이 (PSY)',
#  '케이윌',
#  '허각',
#  '휘인 (Whee In)',
#  '이석훈',
#  '린',
#  '첸 (CHEN)',
#  '린',
#  '심규선 (Lucia)',
#  '2NE1',
#  '디셈버',
#  '포지션',
#  '황인욱',
#  '존박',
#  '벤',
#  '토이',
#  'V.One',
#  '태연 (TAEYEON)',
#  '태연 (TAEYEON)',
#  '먼데이 키즈 (Monday Kiz)',
#  '전건호',
#  '최유리',
#  'XIA (준수)',
#  '바이브',
#  '강민경 (다비치)',
#  '빅마마',
#  'MSG워너비(정상동기)',
#  '케이윌',
#  '길구봉구',
#  '김상민',
#  '아이유',
#  '김형중',
#  '권진아',
#  '임재범',
#  '권진아',
#  '허각',
#  'WOODZ (조승연)',
#  '도영 (DOYOUNG)',
#  '알리 (ALi)',
#  '윤종신',
#  '윤종신',
#  '미도와 파라솔',
#  '매드클라운',
#  'KCM',
#  '엠씨더맥스 (M.C the MAX)',
#  '김동률',
#  '경서예지',
#  '싸이 (PSY)',
#  '태연 (TAEYEON)',
#  '이문세',
#  '김재환',
#  '김동률',
#  '영탁',
#  '디셈버',
#  '해찬 (HAECHAN)',
#  '노을',
#  '남혁',
#  '멜로망스',
#  '다비치',
#  '윤도 (YoonDo)',
#  '성시경',
#  'V.O.S',
#  '로이킴',
#  'Sondia',
#  '정동하',
#  '주호',
#  '바이브',
#  '영탁',
#  '엠씨더맥스 (M.C the MAX)',
#  'SG 워너비',
#  '이석훈',
#  '신예영',
#  '피아노맨',
#  '2am',
#  '지코 (ZICO)',
#  '임재범',
#  '이승철',
#  'V.O.S',
#  '이소라',
#  '나윤권',
#  '임창정',
#  '피아노맨',
#  '황인욱',
#  '정창룡',
#  '박효신',
#  '테이크 (TAKE)',
#  '임창정',
#  '지효 (TWICE)',
#  '윤건',
#  '김종국',
#  '케빈오',
#  '소유 (SOYOU)',
#  '디셈버',
#  '이적',
#  '써니힐',
#  '정키',
#  '유미',
#  '먼데이 키즈 (Monday Kiz)',
#  '알리 (ALi)',
#  '조이 (JOY)',
#  '먼데이 키즈 (Monday Kiz)',
#  '정승환',
#  '스카이',
#  '성시경',
#  '다비치',
#  '다비치',
#  '정승환',
#  '김동률',
#  '비투비',
#  '더 크로스',
#  '케이시 (Kassy)',
#  '청하',
#  '김기태',
#  '박진영',
#  '디셈버',
#  '조성모',
#  '윤미래',
#  '이적',
#  '허각',
#  'DK',
#  '양다일',
#  '이찬원',
#  '백예린 (Yerin Baek)',
#  '정준일',
#  '김현식',
#  '필',
#  '반하나',
#  '로이킴',
#  '주호',
#  '샵',
#  '이승기',
#  '다비치',
#  '더 넛츠 (The NuTs)',
#  '임창정',
#  '벤',
#  '임한별',
#  '허각',
#  '웬디 (WENDY)',
#  'V.One',
#  '케이윌',
#  '엠씨더맥스 (M.C the MAX)',
#  '문별 (마마무)',
#  '백예린 (Yerin Baek)',
#  '황치열',
#  'MSG워너비',
#  '이하이',
#  'EXO',
#  '방탄소년단',
#  '보아 (BoA)',
#  '알리 (ALi)',
#  'iKON',
#  '존박',
#  '허각',
#  '엠씨더맥스 (M.C the MAX)',
#  '윤하 (YOUNHA)',
#  '전상근',
#  '이승환',
#  '이선희',
#  '이지훈',
#  '노을',
#  '김동률',
#  '고유진 (플라워)',
#  '이석훈',
#  '엠씨더맥스 (M.C the MAX)',
#  'HYNN (박혜원)',
#  '유주',
#  '제이세라',
#  '이수영',
#  'Zion.T',
#  '포스트맨(Postmen)',
#  '장덕철',
#  '신예영',
#  '임창정',
#  'OuiOui (위위)',
#  '김기태',
#  '어쿠스틱 콜라보',
#  '조이 (JOY)',
#  'S.Papa',
#  '어쿠스틱 콜라보',
#  '이적',
#  '김진호 (SG워너비)',
#  '장나라',
#  '바이브',
#  '왁스',
#  '케이윌',
#  '2NE1',
#  '이승철',
#  '알리 (ALi)',
#  '진원',
#  '임재범',
#  '엠씨더맥스 (M.C the MAX)',
#  '이진재',
#  '케이시 (Kassy)',
#  '주호',
#  '폴킴',
#  '공기남',
#  '벤',
#  '김도환',
#  '김윤아',
#  '엠씨더맥스 (M.C the MAX)',
#  '서영은',
#  '에디킴',
#  '구원찬',
#  '미도와 파라솔',
#  '제이세라',
#  'SG 워너비',
#  '김정민',
#  '빅마마',
#  'NCT DREAM',
#  '이선희',
#  '한경일',
#  '다비치',
#  '최현준 (V.O.S)',
#  '디셈버',
#  '반하나',
#  '허각',
#  '임창정',
#  '소수빈',
#  '김필',
#  '김민석 (멜로망스)',
#  '정승환',
#  '김건모',
#  '먼데이 키즈 (Monday Kiz)',
#  '김연우',
#  '박상민',
#  '에일리(Ailee)',
#  '이소정',
#  '정승환',
#  '이문세',
#  '양정승',
#  'god',
#  '2am',
#  'HYNN (박혜원)',
#  'The One (더원)',
#  '쿨 (COOL)',
#  '임재범',
#  '다비치',
#  '로이킴',
#  '멜로망스',
#  '이보람 (씨야)',
#  '하림',
#  '가호 (Gaho)',
#  '써니힐',
#  '아이유',
#  '종현 (JONGHYUN)',
#  '조이 (JOY)',
#  '전건호',
#  '토이',
#  '이수영',
#  '김범수',
#  'AKMU (악뮤)',
#  '한동근',
#  '소수빈',
#  '성시경',
#  'WINNER',
#  '웬디 (WENDY)',
#  '이문세',
#  '어반자카파',
#  '김동률',
#  '카더가든',
#  '씨야',
#  '윤미래',
#  '송하예',
#  '정승환',
#  '지아',
#  '윤도 (YoonDo)',
#  '전철민',
#  '임한별',
#  '2am',
#  '보라미유',
#  '디어 (d.ear)',
#  '신용재 (2F)',
#  'DK',
#  'god',
#  '김기태',
#  'Wanna One (워너원)',
#  '씨야',
#  '주호',
#  '권진아',
#  '김기태',
#  '#안녕',
#  '씨야',
#  'god',
#  '다비치',
#  '처진 달팽이 (유재석 & 이적)',
#  '로이킴',
#  '방탄소년단',
#  '카더가든',
#  '다비치',
#  '버스커 버스커',
#  'XIA (준수)',
#  '임세준',
#  '승관 (SEVENTEEN)',
#  '먼데이 키즈 (Monday Kiz)',
#  '이승철',
#  '김나영',
#  '안재욱',
#  '에일리(Ailee)',
#  '조성모',
#  '바이브',
#  'V.O.S',
#  '김찬호',
#  '포맨 (4MEN)',
#  '윤미래',
#  '김동률',
#  '뱅크',
#  '다비치',
#  '허각',
#  '잔나비 최정훈',
#  '윤종신',
#  '백지영',
#  '브라운 아이드 소울',
#  '선우정아',
#  '박효신',
#  '샘김 (Sam Kim)',
#  '2NE1',
#  '한동근',
#  '기리보이',
#  '가비엔제이',
#  '비투비',
#  '정경호',
#  '아이유',
#  '세븐틴',
#  '양다일',
#  '먼데이 키즈 (Monday Kiz)',
#  'Crush',
#  '포맨 (4MEN)',
#  '경서예지',
#  'SG 워너비',
#  'MSG워너비(M.O.M)',
#  '잠골버스',
#  '안녕하신가영',
#  '진민호',
#  '임한별',
#  '노을',
#  '서현진',
#  '하동균',
#  '정동원',
#  '이은미',
#  '제이세라',
#  '정재욱',
#  '헤이즈 (Heize)',
#  '먼데이 키즈 (Monday Kiz)',
#  '로시 (Rothy)',
#  '이예준',
#  '이승기',
#  '가비엔제이',
#  '김건모',
#  '성시경',
#  '손승연',
#  '양다일',
#  '박지헌',
#  '거미',
#  '솔지',
#  '정승환',
#  '샘김 (Sam Kim)',
#  '다비치',
#  '케이윌',
#  'gavy nj project group [H7美人(미인)]',
#  '노을',
#  'CHEEZE (치즈)',
#  '호피폴라',
#  '다비치',
#  '최유리',
#  '이승기',
#  '문성욱',
#  '2am',
#  '유해준',
#  '임창정',
#  '잔나비',
#  '토이',
#  '이승철',
#  '얀',
#  '이두나',
#  '뎁트',
#  '신용재 (2F)',
#  '케이시 (Kassy)',
#  '장범준',
#  '박유천']

# %%
ballad = {'가수명':singer_list, '노래제목':singName_list, '발매일':date_list, '가사':lyrics_list, '좋아요수':like_list}

# %%
# 0값 지워버리기

singer_list.remove(0)

# %%
import pandas as pd

# %%
ballad_top1000 = pd.DataFrame(ballad)
ballad_top1000.head()
# Out:
#         가수명             노래제목         발매일  \
# 0        토이  세 사람 (With 성시경)  2014.11.18
# 1  첸 (CHEN)            너를 위해  2016.08.25
# 2        리쌍                0           0
# 3       임창정            오랜만이야  2009.03.10
# 4       유해준         나에게 그대만이  2009.11.02
#
#                                                   가사     좋아요수
# 0  많은 사람들 분주한 인사우리 모두 모인 게 얼마 만인 건지하얀 드레스멋있어진 녀석정...  113,622
# 1  다른 공간의 다른 시간이지만 내 사랑이 맞을거야 바람에 스치는 너의 향기로도 난 너...  145,852
# 2                                                  0        0
# 3  참 오랜만이란 말로웃으며 인사 하는 너처음 널 만날 때처럼내 가슴이 철없이 또 뛰어...   66,887
# 4  더이상 나에게다른 사랑은 없다는 걸이제 나는 알아요나에게 사랑은항상 하나 뿐 이었다...   44,360

# %%
ballad_top1000.isnull().sum()
# Out:
# 가수명     0
# 노래제목    0
# 발매일     0
# 가사      0
# 좋아요수    0
# dtype: int64

# %%
ballad_top1000['좋아요수'] = ballad_top1000['좋아요수'].str.replace(',','')

# %%
ballad_top1000['발매일'] = ballad_top1000['발매일'].str.replace('.', '-')
# Out:
# /var/folders/51/xmc_l6t13wv1nc5z6qmyg58r0000gn/T/ipykernel_5470/102835891.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   ballad_top1000['발매일'] = ballad_top1000['발매일'].str.replace('.', '-')

# %%
ballad_top1000['발매일'] = pd.to_datetime(ballad_top1000['발매일'])

# %%
ballad_top1000.head()
# Out:
#         가수명             노래제목        발매일  \
# 0        토이  세 사람 (With 성시경) 2014-11-18
# 1  첸 (CHEN)            너를 위해 2016-08-25
# 2        리쌍                0        NaT
# 3       임창정            오랜만이야 2009-03-10
# 4       유해준         나에게 그대만이 2009-11-02
#
#                                                   가사    좋아요수
# 0  많은 사람들 분주한 인사우리 모두 모인 게 얼마 만인 건지하얀 드레스멋있어진 녀석정...  113622
# 1  다른 공간의 다른 시간이지만 내 사랑이 맞을거야 바람에 스치는 너의 향기로도 난 너...  145852
# 2                                                  0     NaN
# 3  참 오랜만이란 말로웃으며 인사 하는 너처음 널 만날 때처럼내 가슴이 철없이 또 뛰어...   66887
# 4  더이상 나에게다른 사랑은 없다는 걸이제 나는 알아요나에게 사랑은항상 하나 뿐 이었다...   44360

# %%
ballad_top1000['순위'] = ballad_top1000.index + 501

# %%
ballad_top1000[ballad_top1000.가수명 == '리쌍'] = [['리쌍','TV를 껐네... (Feat. t윤미래, 권정열 Of 10cm)','2011-08-25',"""널 너무나 사랑해서 난 티비를 껐어
새빨간 니 입술
널 너무나 사랑해서 난 커텐을 쳤어
새빨간 니 입술
널 너무나 사랑해서 난 티비를 껐어
새빨간 니 입술
널 너무나 사랑해서 난 커텐을 쳤어
새빨간 니 입술

내 눈엔 그 어떤 선보다 아름다운 너의 몸매
검은 머리 너만의 향기에 나는 녹네
때론 몰래 응큼한 상상을해 그러다 욕심이 솟네
티비를 보다가도 거리를 걷다가도 시도때도 없이 난 너를 원해
못참아 어떻게 손만잡아 딱딱하게 말하지마 네가 날 딱딱하게 만들었잖아
널 너무 사랑해 내 모든 걸 다 주고 니 모든 걸 다 갖고싶어
더 가까이 널 안고싶어 내 몸을 적시고 엉덩이 토닥토닥 하고싶어

이 밤이 새도록 보여주고 싶어
어제와 또 다른 내 모습에 눈물까지 흘릴꺼야
이 밤이 새도록 보여주고 싶어
넌 너무 사랑스러워 언제나 나를 설레게 만들어 baby

널 너무나 사랑해서 난 티비를 껐어
새빨간 니 입술
널 너무나 사랑해서 난 커텐을 쳤어
새빨간 니 입술

더운데 갑자기 커텐을 왜 쳐
잘 보고 있는 티비는 또 왜꺼
그런 눈으로 왜 또 분위기 잡아
피곤해 피곤해 그냥 난 잘래
니 품에서 꿈꾸고 싶어 밤새
그만 좀 보채 오늘만 날이 아니잖아
좀 참아 착하지 내 남자 그냥 코 자자
삐지지말고 내 손을 잡아
어린애처럼 왜 또 등을 돌려 
못말려 너란 남자 정말 웃겨
생각해볼게 어서 가서 불꺼

이대론 잠 못자요 넌 너무 아름다워
난 오늘 이 밤을 보내기엔 아쉬워요
오늘은 안된단 말 마요 그만 그만 그만

널 너무나 사랑해서 난 티비를 껐어
새빨간 니 입술
널 너무나 사랑해서 난 커텐을 쳤어
새빨간 니 입술
널 너무나 사랑해서 난 티비를 껐어
새빨간 니 입술
널 너무나 사랑해서 난 커텐을 쳤어
새빨간 니 입술

나를 설레게 만들어""".replace("\n"," "),'64287',3]]

# %%
ballad_top1000[ballad_top1000.노래제목 == 0]
# Out:
# Empty DataFrame
# Columns: [가수명, 노래제목, 발매일, 가사, 좋아요수, 순위]
# Index: []

# %%
ballad_top1000[ballad_top1000.가수명 == 'G-DRAGON'] = [['G-DRAGON','그XX','2012-09-15',"""우연히 길을 걷다 네 남잘 봤어 
Yea I saw him
혹시나 했던 내 예감이 맞았어 
I told you
네가 준 반지를 빼고 한쪽엔 
팔짱을 끼고
그냥 여기까지만 말할게 
I don’t wanna hurt you
근데 오히려 너는 내게 화를 내 
Why
그는 절대로 그럴 리가 없대 
Sure you’re right
나는 네 눈칠 살피고 
내가 잘 못 본 거라고
그래 널 위해 거짓말할게
I’m sorry
Oh 날 몰라주는 네가 미워 
이 기다림이 싫어
그 손 이제 놓으라고
네가 슬퍼할 때면 나는 죽을 것만 
같다고 baby
그 새끼보다 내가 못한 게 뭐야
도대체 왜 나는 가질 수 없는 거야
그 새끼는 너를 사랑하는 게 아냐
언제까지 바보같이 울고만 있을 거야
넌 그 사람 얘길 할 땐 
행복해 보여 
You look happy
이렇게라도 웃으니 좋아 보여 
I’m happy
그를 정말 사랑한다고 
마치 영원할거라고
믿는 네 모습이 
I don’t know what to say no more
너의 친구들 모두 그를 잘 알아 
yup they know
뻔히 다 보이는걸 너만 왜 못 봐 
It’s you
They say love is blind Oh baby 
you so blind
제발 헤어지기를 바랄게
Oh 날 몰라주는 네가 미워 
이 기다림이 싫어
그 손 이제 놓으라고
네가 슬퍼할 때면 
나는 죽을 것만 같다고 baby
그 새끼보다 내가 못한 게 뭐야
도대체 왜 나는 가질 수 없는 거야
그 새끼는 너를 사랑하는 게 아냐
언제까지 바보같이 울고만 있을 거야
비싼 차에 예쁜 옷 
고급 레스토랑 
넌 잘 어울려
하지만 네 옆 그 X는 정말 아냐 
너랑은 안 어울려
네 앞에서 거짓미소를 지으며 
네 볼과 머릿결을 만지며
속으론 분명 다른 여자를 생각해 
어쩜 그럴 수 있니 죄 같애
네가 흘린 눈물만큼 내가 더 
잘해줄게 baby
너 혼자 감당할 아픔 내게도 좀 
나눠줄래 baby
나 좀 봐달라고 그대 사랑이 왜 
나란걸 몰라
왜 너만 몰라
그 새끼보다 내가 못한 게 뭐야
도대체 왜 나는 가질 수 없는 거야
그 새끼는 너를 사랑하는 게 아냐
언제까지 바보같이 울고만 있을 거야
그 새끼보다 내가 못한 게 뭐야
도대체 왜 나는 가질 수 없는 거야
그 새끼는 너를 사랑하는 게 아냐
언제까지 바보같이 울고만 있을 거야""".replace("\n"," "),"108,517",45]]

# %%
ballad_top1000.head()
# Out:
#         가수명                                 노래제목        발매일  \
# 0        토이                      세 사람 (With 성시경) 2014-11-18
# 1  첸 (CHEN)                                너를 위해 2016-08-25
# 2        리쌍  TV를 껐네... (Feat. t윤미래, 권정열 Of 10cm) 2011-08-25
# 3       임창정                                오랜만이야 2009-03-10
# 4       유해준                             나에게 그대만이 2009-11-02
#
#                                                   가사    좋아요수   순위
# 0  많은 사람들 분주한 인사우리 모두 모인 게 얼마 만인 건지하얀 드레스멋있어진 녀석정...  113622  501
# 1  다른 공간의 다른 시간이지만 내 사랑이 맞을거야 바람에 스치는 너의 향기로도 난 너...  145852  502
# 2  널 너무나 사랑해서 난 티비를 껐어 새빨간 니 입술 널 너무나 사랑해서 난 커텐을 ...   64287  503
# 3  참 오랜만이란 말로웃으며 인사 하는 너처음 널 만날 때처럼내 가슴이 철없이 또 뛰어...   66887  504
# 4  더이상 나에게다른 사랑은 없다는 걸이제 나는 알아요나에게 사랑은항상 하나 뿐 이었다...   44360  505

# %%
ballad_top1000.tail()
# Out:
#              가수명                                노래제목        발매일  \
# 495           뎁트  Can We? (Feat. J.O.Y, Cindy Zhang) 2022-07-24
# 496     신용재 (2F)                           그 남자 그 여자 2021-12-08
# 497  케이시 (Kassy)                          이런 게 사랑이라면 2020-10-26
# 498          장범준                                  회상 2016-01-30
# 499          박유천                                 찾았다 2010-09-16
#
#                                                     가사   좋아요수    순위
# 495  So can we go back?우리 돌아갈 수 있을까?For a second, m...    259   996
# 496  혹시 네가 다시 돌아올까 봐다른 사랑 절대 못 해남자를 울렸으면 책임져야지네가 뭘 ...   5974   997
# 497  음 니가 떠난 후론밤이 유독 춥고시간은 느리게 흘러음 기다림이 싫어헤어졌던 내가여전...  12841   998
# 498  길을 걸었지 누군가 옆에 있다고느꼈을 때 나는 알아버렸네이미 그대 떠난 후라는 걸나...  60027   999
# 499  솔직히 처음엔 몰랐어우연한 만남 있었지만이제껏 난 기쁨보단아픔을 더 많이 배웠어눈물...  38214  1000

# %%
ballad_top1000.to_csv('../Data/melon_top1000.csv', index=False)

# %%
len(ballad_top1000)
# Out:
# 500
