# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import urllib.request as request

# %%
chrome_options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)
driver.get('https://www.melon.com/genre/song_list.htm?gnrCode=GN0100#params%5BgnrCode%5D=GN0100&params%5BdtlGnrCode%5D=&params%5BorderBy%5D=POP&params%5BsteadyYn%5D=N&po=pageObj&startIndex=1')

# %%
page_source = driver.page_source
soup = BeautifulSoup(page_source, "html.parser")

# %%
# songId 가져오기

songIds = soup.select("#frm > div > table > tbody td:nth-child(4) > div > a")

# %%
# songId 가져오기 (한 페이지당 50개)

for songId in songIds:
    print(songId['href'].split('\'')[1])
# Out:
# 35383397
# 34943312
# 34657844
# 34787226
# 34061322
# 34431086
# 34908740
# 33496587
# 35388184
# 35177030
# 34701627
# 4446485
# 35008524
# 35252996
# 35145136
# 35275022
# 34481680
# 33625988
# 34599917
# 3414749
# 35453293
# 33061995
# 30962526
# 35126568
# 35255652
# 34360855
# 35008527
# 34943241
# 32061975
# 34535898
# 33868791
# 35477159
# 35008534
# 34082381
# 35380365
# 34373632
# 34752959
# 35418345
# 33248758
# 31703498
# 32794652
# 32224166
# 30314784
# 30514366
# 34632789
# 34701996
# 35356222
# 35437408
# 35372649
# 35014621

# %%
# songId 키값 갯수 확인
len(songIds)
# Out:
# 50

# %%
chrome_options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)

# 1, 451, 50
# for문으로 인덱스 돌리기

total_lists = []
for page in list(range(1,500, 50)):

  driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)
  driver.get('https://www.melon.com/genre/song_list.htm?gnrCode=GN0100#params%5BgnrCode%5D=GN0100&params%5BdtlGnrCode%5D='\
              +'&params%5BorderBy%5D=POP&params%5BsteadyYn%5D=N&po=pageObj&startIndex='+ str(page))

  page_source = driver.page_source
  soup = BeautifulSoup(page_source, "html.parser")

  songIds = soup.select("#frm > div > table > tbody td:nth-child(4) > div > a")
  total_lists = total_lists + songIds

# %%
# songId 가져오기
songId_list = []
for songId in total_lists:
    songId_list.append(songId['href'].split('\'')[1])

# %%
print(songId_list[:5])
# Out:
# ['35383397', '34943312', '34657844', '34787226', '34061322']

# %%
# 가수명, 노래제목, 발매일, 가사, 좋아요 수 리스트 변수 생성

singer_list = []
singName_list = []
date_list = []
lyrics_list = []
like_list = []

# %%
import time

# %%
# for문으로 가수명, 노래제목, 발매일, 가사, 좋아요 수 리스트 변수에 내용 담고 저장하기

chrome_options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)

for songId in songId_list:
    
    driver.get(f'https://www.melon.com/song/detail.htm?songId={songId}')

    page_source = driver.page_source
    soup = BeautifulSoup(page_source, "html.parser")
    try:
        time.sleep(2)
        # 가수명 가져오기
        artist_name = soup.select_one('#downloadfrm > div > div > div.entry > div.info > div.artist > a > span:nth-child(1) ')
        singer_list.append(artist_name.string)

        # 노래제목 가져오기
        song_name = soup.select_one("#downloadfrm > div > div > div.entry > div.info > div.song_name ")
        singName_list.append(song_name.text.strip().split('\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t')[1])

        # 발매일 가져오기
        date = soup.select_one('#downloadfrm > div > div > div.entry > div.meta > dl > dd:nth-child(4)')
        date_list.append(date.string)

        # 가사 가져오기
        lyric1 = str(soup.select_one('#d_video_summary')).replace('<br/>',' ')\
                                                         .replace('<div class="lyric" id="d_video_summary"><!-- height:auto; 로 변경시, 확장됨 -->','')\
                                                         .replace('</div>','').replace('\t','').replace('\n','')
        lyric = lyric1.replace('  ', ' ')
        lyrics_list.append(lyric)

        # 좋아요수 가져오기
        like = soup.select_one("#d_like_count")
        like_list.append(like.text)
        time.sleep(2)
    except:
        singer_list.append(0)
        singName_list.append(0)
        date_list.append(0)
        lyrics_list.append(0)
        like_list.append(0)
        time.sleep(1)

# %%
# lyrics_list

# %%
# 0값 지워버리기

# singer_list.remove(0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/51/xmc_l6t13wv1nc5z6qmyg58r0000gn/T/ipykernel_5185/1487908544.py in <module>
#       1 # 0값 지워버리기
#       2
# ----> 3 singer_list.remove(0)
#
# ValueError: list.remove(x): x not in list

# %%
len(singer_list)
# Out:
# 500

# %%
len(singName_list)
# Out:
# 500

# %%
len(date_list)
# Out:
# 500

# %%
len(lyrics_list)
# Out:
# 500

# %%
len(like_list)
# Out:
# 500

# %%
import pandas as pd

# %%
ballad = {'가수명':singer_list, '노래제목':singName_list, '발매일':date_list, '가사':lyrics_list, '좋아요수':like_list}

# %%
ballad
# Out:
# {'가수명': ['WSG워너비 (가야G)',
#   '경서',
#   '멜로망스',
#   '주호',
#   '임영웅',
#   '김민석 (멜로망스)',
#   '임영웅',
#   '경서예지',
#   '이석훈',
#   '케이시 (Kassy)',
#   '임영웅',
#   'MSG워너비(M.O.M)',
#   '#안녕',
#   '성시경',
#   '다비치',
#   '임재현',
#   '아이유',
#   '케이시 (Kassy)',
#   '케이시 (Kassy)',
#   'MSG워너비(M.O.M)',
#   '아이유',
#   '경서',
#   '폴킴',
#   'V.O.S',
#   '주호',
#   '임영웅',
#   '이무진',
#   '탑현',
#   '지민',
#   '멜로망스',
#   'AKMU (악뮤)',
#   '임영웅',
#   '딘딘 (DINDIN)',
#   '세븐틴',
#   '경서예지',
#   '10CM',
#   '한동근',
#   '정동하',
#   '아이유',
#   'HYNN (박혜원)',
#   '#안녕',
#   '김종국',
#   '산들',
#   '멜로망스',
#   '휘인 (Whee In)',
#   '길구봉구',
#   '멜로망스',
#   '폴킴',
#   '조유진 (체리필터)',
#   '하은 (포맨)',
#   '김재환',
#   'SG 워너비',
#   'Sondia',
#   '헤이즈 (Heize)',
#   '성시경',
#   '노을',
#   '씨야',
#   '조정석',
#   '이예준',
#   'WSG워너비 조별경연 (대청봉)',
#   '헤이즈 (Heize)',
#   '엠씨더맥스 (M.C the MAX)',
#   '김필',
#   '폴킴',
#   '케이시 (Kassy)',
#   '다비치',
#   '선우정아',
#   'TOIL',
#   '폴킴',
#   '이홍기 (FT아일랜드)',
#   '에일리(Ailee)',
#   '비비 (BIBI)',
#   '김재환',
# ...

# %%
ballad_top500 = pd.DataFrame(ballad)

ballad_top500.head()
# Out:
#             가수명               노래제목         발매일  \
# 0  WSG워너비 (가야G)  그때 그 순간 그대로 (그그그)  2022.07.09
# 1            경서             나의 X에게  2022.04.24
# 2          멜로망스             사랑인가 봐  2022.02.18
# 3            주호            내가 아니라도  2022.03.25
# 4           임영웅          사랑은 늘 도망가  2021.10.11
#
#                                                   가사     좋아요수
# 0  잘 지냈지? 조금은 어색해 요즘 좋아 보여 인사 나누며 사실 궁금한 게 너무 많았는...   79,774
# 1  우리 다시 만날래 예쁘게 빛나던 모든 추억들이 너무 그리워 너의 품에 안길래 이 밤...  101,199
# 2  너와 함께 하고 싶은 일들을 상상하는 게 요즘 내 일상이 되고 너의 즐거워하는 모습...  146,814
# 3  사랑이었다 별거 없던 내 하루에 빛이 돼준 단한 사람 나보다 나를 더 아껴 주던 너...   50,533
# 4  눈물이 난다 이 길을 걸으면 그 사람 손길이 자꾸 생각이 난다 붙잡지 못하고 가슴만...  169,216

# %%
ballad_top500.isnull().sum()
# Out:
# 가수명     0
# 노래제목    0
# 발매일     0
# 가사      0
# 좋아요수    0
# dtype: int64

# %%
ballad_top500['좋아요수'] = ballad_top500['좋아요수'].str.replace(',','')

# %%
ballad_top500['발매일'] = ballad_top500['발매일'].str.replace('.', '-')
# Out:
# /var/folders/51/xmc_l6t13wv1nc5z6qmyg58r0000gn/T/ipykernel_5185/189548960.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   ballad_top500['발매일'] = ballad_top500['발매일'].str.replace('.', '-')

# %%
ballad_top500['발매일'] = pd.to_datetime(ballad_top500['발매일'])

# %%
ballad_top500.head()
# Out:
#             가수명               노래제목        발매일  \
# 0  WSG워너비 (가야G)  그때 그 순간 그대로 (그그그) 2022-07-09
# 1            경서             나의 X에게 2022-04-24
# 2          멜로망스             사랑인가 봐 2022-02-18
# 3            주호            내가 아니라도 2022-03-25
# 4           임영웅          사랑은 늘 도망가 2021-10-11
#
#                                                   가사    좋아요수
# 0  잘 지냈지? 조금은 어색해 요즘 좋아 보여 인사 나누며 사실 궁금한 게 너무 많았는...   79774
# 1  우리 다시 만날래 예쁘게 빛나던 모든 추억들이 너무 그리워 너의 품에 안길래 이 밤...  101199
# 2  너와 함께 하고 싶은 일들을 상상하는 게 요즘 내 일상이 되고 너의 즐거워하는 모습...  146814
# 3  사랑이었다 별거 없던 내 하루에 빛이 돼준 단한 사람 나보다 나를 더 아껴 주던 너...   50533
# 4  눈물이 난다 이 길을 걸으면 그 사람 손길이 자꾸 생각이 난다 붙잡지 못하고 가슴만...  169216

# %%
ballad_top500['순위'] = ballad_top500.index + 1

# %%
ballad_top500.tail()
# Out:
#      가수명          노래제목        발매일  \
# 495  양다일        소주 한 잔 2022-03-20
# 496   씨야        사랑의 인사 2007-05-25
# 497  다비치      괜찮아 사랑이야 2014-07-30
# 498  이승철           말리꽃 2005-12-20
# 499  권진아  오늘 뭐 했는지 말해봐 2019-02-28
#
#                                                     가사   좋아요수   순위
# 495  술이 한 잔 생각나는 밤 같이 있는 것 같아요 그 좋았던 시절들 이젠 모두 한숨만 ...   6772  496
# 496  비내리는 거릴 좋아 했었죠 우산없이 나와 함께 걸었죠 다시 내리는 비에 그대 생각나...  19335  497
# 497  내 맘이 보이니 왜 사랑인거니 다시는 하지 말자던 사랑 참 많이 바보 같지 왜 행복...  77496  498
# 498  얼마나 더 견뎌야 하는지 짙은 어둠을 헤매고 있어 내가바란 꿈이라는 것은 없는걸까 ...  57643  499
# 499  네가 없는 밤이 너 없이 혼자서 보내는 주말이 이젠 더 편해졌는데 친구를 만나고 새...  52050  500

# %%
# ballad_top500.drop(index=497, inplace=True)

# %%
# ballad_top500.reset_index(drop=True)

# %%
ballad_top500.to_csv('../Data/melon_top500.csv', index=False)

# %%
pd.read_csv("../Data/melon_top500.csv")
# Out:
#               가수명               노래제목         발매일  \
# 0    WSG워너비 (가야G)  그때 그 순간 그대로 (그그그)  2022-07-09
# 1              경서             나의 X에게  2022-04-24
# 2            멜로망스             사랑인가 봐  2022-02-18
# 3              주호            내가 아니라도  2022-03-25
# 4             임영웅          사랑은 늘 도망가  2021-10-11
# ..            ...                ...         ...
# 495           양다일             소주 한 잔  2022-03-20
# 496            씨야             사랑의 인사  2007-05-25
# 497           다비치           괜찮아 사랑이야  2014-07-30
# 498           이승철                말리꽃  2005-12-20
# 499           권진아       오늘 뭐 했는지 말해봐  2019-02-28
#
#                                                     가사    좋아요수   순위
# 0    잘 지냈지? 조금은 어색해 요즘 좋아 보여 인사 나누며 사실 궁금한 게 너무 많았는...   79774    1
# 1    우리 다시 만날래 예쁘게 빛나던 모든 추억들이 너무 그리워 너의 품에 안길래 이 밤...  101199    2
# 2    너와 함께 하고 싶은 일들을 상상하는 게 요즘 내 일상이 되고 너의 즐거워하는 모습...  146814    3
# 3    사랑이었다 별거 없던 내 하루에 빛이 돼준 단한 사람 나보다 나를 더 아껴 주던 너...   50533    4
# ...

# %% [markdown]
# ---
# 멜론 발라드 top1500

# %%
chrome_options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)

# for문으로 인덱스 돌리기

total_lists = []
for page in list(range(1001,1500, 50)):

  driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)
  driver.get('https://www.melon.com/genre/song_list.htm?gnrCode=GN0100#params%5BgnrCode%5D=GN0100&params%5BdtlGnrCode%5D=&params%5BorderBy%5D=POP&params%5BsteadyYn%5D=N&po=pageObj&startIndex='+ str(page))

  page_source = driver.page_source
  soup = BeautifulSoup(page_source, "html.parser")

  songIds = soup.select("#frm > div > table > tbody td:nth-child(4) > div > a")
  total_lists = total_lists + songIds

# %%
# songId 가져오기
songId_list = []
for songId in total_lists:
    songId_list.append(songId['href'].split('\'')[1])

len(songId_list)
# Out:
# 500

# %%
# 가수명, 노래제목, 발매일, 가사, 좋아요 수 리스트 변수 생성

singer_list = []
singName_list = []
date_list = []
lyrics_list = []
like_list = []

# %%
# for문으로 가수명, 노래제목, 발매일, 가사, 좋아요 수 리스트 변수에 내용 담고 저장하기

chrome_options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)

for songId in songId_list:
    
    driver.get(f'https://www.melon.com/song/detail.htm?songId={songId}')

    page_source = driver.page_source
    soup = BeautifulSoup(page_source, "html.parser")
    try:
        time.sleep(2)
        # 가수명 가져오기
        artist_name = soup.select_one('#downloadfrm > div > div > div.entry > div.info > div.artist > a > span:nth-child(1) ')
        singer_list.append(artist_name.string)

        # 노래제목 가져오기
        song_name = soup.select_one("#downloadfrm > div > div > div.entry > div.info > div.song_name ")
        singName_list.append(song_name.text.strip().split('\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t')[1])

        # 발매일 가져오기
        date = soup.select_one('#downloadfrm > div > div > div.entry > div.meta > dl > dd:nth-child(4)')
        date_list.append(date.string)

        # 가사 가져오기
        lyric1 = str(soup.select_one('#d_video_summary')).replace('<br/>',' ').replace('<div class="lyric" id="d_video_summary"><!-- height:auto; 로 변경시, 확장됨 -->','').replace('</div>','').replace('\t','').replace('\n','')
        lyric = lyric1.replace('  ', ' ')
        lyrics_list.append(lyric)

        # 좋아요수 가져오기
        like = soup.select_one("#d_like_count")
        like_list.append(like.text)
        time.sleep(2)
    except:
        singer_list.append(0)
        singName_list.append(0)
        date_list.append(0)
        lyrics_list.append(0)
        like_list.append(0)
        time.sleep(1)

# %%
print(len(singer_list),len(singName_list),len(singName_list),len(lyrics_list),len(like_list))
ballad = {'가수명':singer_list, '노래제목':singName_list, '발매일':date_list, '가사':lyrics_list, '좋아요수':like_list}
# Out:
# 500 500 500 500 500

# %%
ballad_top1500 = pd.DataFrame(ballad)

ballad_top1500.head()
# Out:
#                    가수명                          노래제목         발매일  \
# 0                  정승환                  십이월 이십오일의 고백  2019.12.05
# 1                  임한별                       사랑 이딴 거  2019.01.22
# 2                   지아                      가질 수 없어도  2022.06.01
# 3                  정창룡  익숙함에 속아 소중함을 몰랐다 (Feat. 이지용)  2020.06.30
# 4  엠씨더맥스 (M.C the MAX)                          어김없이  2016.01.28
#
#                                                   가사    좋아요수
# 0  입김처럼 하얀 목소리 닿을 듯하다 사라지고 못내 아쉬운 마음처럼 천천히 걷는 두 사...  75,204
# 1  털썩 주저 앉아버렸어 아무 준비 없이 만난 소나기 예고 없이 찾아오는 겨울 감기처럼...  34,957
# 2  어디서부턴지 멀어지던 네 모습 내 노력으로는 부족했어 끝까지 함께 하자던 얘기들도 ...   1,376
# 3  있을 때 잘해 네가 내게 가끔 했던 말 그땐 그냥 웃으면서 넘겼던 그 말 시간이 흘...   9,112
# 4  아무렇지 않은 듯이  그렇게 천천히 잊어보려 해 붙잡고 싶지만 그대의 마음이 다른 ...  45,647

# %%
ballad_top1500['좋아요수'] = ballad_top1500['좋아요수'].str.replace(',','')
ballad_top1500['발매일'] = ballad_top1500['발매일'].str.replace('.', '-')
ballad_top1500['발매일'] = pd.to_datetime(ballad_top1500['발매일'])
ballad_top1500['순위'] = ballad_top1500.index + 1001
# Out:
# /var/folders/51/xmc_l6t13wv1nc5z6qmyg58r0000gn/T/ipykernel_5185/471228305.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   ballad_top1500['발매일'] = ballad_top1500['발매일'].str.replace('.', '-')

# %%
ballad_top1500.tail()
# Out:
#       가수명                              노래제목        발매일  \
# 495   김건모                           혼자만의 사랑 1993-11-04
# 496   정창룡  그 사람 많이 사랑했나요 Part.2 (Feat. 이지용) 2022-06-19
# 497   한동근             한숨 (어때요 노래 참 쉽죠? 밥로스) 2018-07-01
# 498  럼블피쉬                          그대 내게 다시 2007-07-18
# 499   박효신                           애상 (哀想) 2007-07-30
#
#                                                     가사   좋아요수    순위
# 495  가까이 있어도 널 볼 수가 없어 이별의 큰 벽에 네가 가려져 있어 힘겹게 참아왔던 ...  23862  1496
# 496  정말 사랑했었던 단 한 사람 내가 미칠 듯이 사랑했었다 그런 그 사람이 나를 두고 ...    844  1497
# 497  숨을 크게 쉬어봐요 당신의 가슴 양쪽이 저리게 조금은 아파올 때까지 숨을 더 뱉어봐...  13621  1498
# 498  그대 내게 다시 돌아오려 하나요 내가 그댈 사랑하는지 알 수 없어 헤매이나요 맨 처...  22123  1499
# 499  어느새 또 달려가죠 내 맘이 서둘러 기억을 거슬러 그대 머물던 오래전 그곳으로 나지...  31019  1500

# %%
ballad_top1500[ballad_top1500['가사']==0]
# Out:
# Empty DataFrame
# Columns: [가수명, 노래제목, 발매일, 가사, 좋아요수, 순위]
# Index: []

# %%
ballad_top1500.to_csv('../Data/melon_top1500.csv', index=False)

# %%
pd.read_csv("../Data/melon_top1500.csv").head()
# Out:
#                    가수명                          노래제목         발매일  \
# 0                  정승환                  십이월 이십오일의 고백  2019-12-05
# 1                  임한별                       사랑 이딴 거  2019-01-22
# 2                   지아                      가질 수 없어도  2022-06-01
# 3                  정창룡  익숙함에 속아 소중함을 몰랐다 (Feat. 이지용)  2020-06-30
# 4  엠씨더맥스 (M.C the MAX)                          어김없이  2016-01-28
#
#                                                   가사   좋아요수    순위
# 0  입김처럼 하얀 목소리 닿을 듯하다 사라지고 못내 아쉬운 마음처럼 천천히 걷는 두 사...  75204  1001
# 1  털썩 주저 앉아버렸어 아무 준비 없이 만난 소나기 예고 없이 찾아오는 겨울 감기처럼...  34957  1002
# 2  어디서부턴지 멀어지던 네 모습 내 노력으로는 부족했어 끝까지 함께 하자던 얘기들도 ...   1376  1003
# 3  있을 때 잘해 네가 내게 가끔 했던 말 그땐 그냥 웃으면서 넘겼던 그 말 시간이 흘...   9112  1004
# 4  아무렇지 않은 듯이  그렇게 천천히 잊어보려 해 붙잡고 싶지만 그대의 마음이 다른 ...  45647  1005

# %% [markdown]
# ---
# 멜론 top 2000

# %%
chrome_options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)

# for문으로 인덱스 돌리기

total_lists = []
for page in list(range(1501,2000, 50)):

  driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)
  driver.get('https://www.melon.com/genre/song_list.htm?gnrCode=GN0100#params%5BgnrCode%5D=GN0100&params%5BdtlGnrCode%5D=&params%5BorderBy%5D=POP&params%5BsteadyYn%5D=N&po=pageObj&startIndex='+ str(page))

  page_source = driver.page_source
  soup = BeautifulSoup(page_source, "html.parser")

  songIds = soup.select("#frm > div > table > tbody td:nth-child(4) > div > a")
  total_lists = total_lists + songIds

# %%
# songId 가져오기
songId_list = []
for songId in total_lists:
    songId_list.append(songId['href'].split('\'')[1])

len(songId_list)
# Out:
# 500

# %%
# 가수명, 노래제목, 발매일, 가사, 좋아요 수 리스트 변수 생성

singer_list = []
singName_list = []
date_list = []
lyrics_list = []
like_list = []

# %%
# for문으로 가수명, 노래제목, 발매일, 가사, 좋아요 수 리스트 변수에 내용 담고 저장하기

chrome_options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)

for songId in songId_list:
    
    driver.get(f'https://www.melon.com/song/detail.htm?songId={songId}')

    page_source = driver.page_source
    soup = BeautifulSoup(page_source, "html.parser")
    try:
        time.sleep(2)
        # 가수명 가져오기
        artist_name = soup.select_one('#downloadfrm > div > div > div.entry > div.info > div.artist > a > span:nth-child(1) ')
        singer_list.append(artist_name.string)

        # 노래제목 가져오기
        song_name = soup.select_one("#downloadfrm > div > div > div.entry > div.info > div.song_name ")
        singName_list.append(song_name.text.strip().split('\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t')[1])

        # 발매일 가져오기
        date = soup.select_one('#downloadfrm > div > div > div.entry > div.meta > dl > dd:nth-child(4)')
        date_list.append(date.string)

        # 가사 가져오기
        lyric1 = str(soup.select_one('#d_video_summary')).replace('<br/>',' ').replace('<div class="lyric" id="d_video_summary"><!-- height:auto; 로 변경시, 확장됨 -->','').replace('</div>','').replace('\t','').replace('\n','')
        lyric = lyric1.replace('  ', ' ')
        lyrics_list.append(lyric)

        # 좋아요수 가져오기
        like = soup.select_one("#d_like_count")
        like_list.append(like.text)
        time.sleep(2)
    except:
        singer_list.append(0)
        singName_list.append(0)
        date_list.append(0)
        lyrics_list.append(0)
        like_list.append(0)
        time.sleep(1)

# %%
ballad = {'가수명':singer_list, '노래제목':singName_list, '발매일':date_list, '가사':lyrics_list, '좋아요수':like_list}

# %%
import pandas as pd

# %%
ballad_top2000 = pd.DataFrame(ballad)
ballad_top2000.head()
# Out:
#           가수명                       노래제목         발매일  \
# 0          지아                  술 한잔해요 오늘  2016.12.01
# 1         순순희                  참 많이 사랑했다  2018.04.17
# 2  에일리(Ailee)  슬픈 연극 (금혼령 X 에일리 (Ailee))  2022.02.10
# 3           별         안부 (Duet With 나윤권)  2005.03.17
# 4         KCM           알아요 (드라마 때려 OST)  2014.02.18
#
#                                                   가사    좋아요수
# 0  오늘 한잔할까요 늘 만나던 그곳에서 찬바람이 불면 생각이 나던 골목집에서 추억 한잔...  32,034
# 1  가로등 하나 붙잡아 잠에 취해버린 어두운 골목길 우리의 마지막 밤 맘에도 없는 싫은...  19,396
# 2  별처럼 빛났던 네 기억이 사라지면 그땐 마음껏 웃을 수 있을까 비처럼 쏟아질 아픈 ...   3,289
# 3  이번엔 진짠가요 몇 번을 헤어졌지만 결국엔 다시 또 돌아 왔잖아요 이번엔 진짠가요 ...  18,476
# 4  매일 세상에게 묻곤 했어 너를 사랑해도 되는 건지 내게 그때마다 돌아 온건 이별이란...   7,695

# %%
ballad_top2000.isnull().sum()
# Out:
# 가수명     0
# 노래제목    0
# 발매일     0
# 가사      0
# 좋아요수    0
# dtype: int64

# %%
ballad_top2000['좋아요수'] = ballad_top2000['좋아요수'].str.replace(',','')

# %%
ballad_top2000['발매일'] = ballad_top2000['발매일'].str.replace('.', '-')
# Out:
# /var/folders/51/xmc_l6t13wv1nc5z6qmyg58r0000gn/T/ipykernel_5185/1565362482.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   ballad_top2000['발매일'] = ballad_top2000['발매일'].str.replace('.', '-')

# %%
ballad_top2000['발매일'] = pd.to_datetime(ballad_top2000['발매일'])

# %%
ballad_top2000.head()
# Out:
#           가수명                       노래제목        발매일  \
# 0          지아                  술 한잔해요 오늘 2016-12-01
# 1         순순희                  참 많이 사랑했다 2018-04-17
# 2  에일리(Ailee)  슬픈 연극 (금혼령 X 에일리 (Ailee)) 2022-02-10
# 3           별         안부 (Duet With 나윤권) 2005-03-17
# 4         KCM           알아요 (드라마 때려 OST) 2014-02-18
#
#                                                   가사   좋아요수
# 0  오늘 한잔할까요 늘 만나던 그곳에서 찬바람이 불면 생각이 나던 골목집에서 추억 한잔...  32034
# 1  가로등 하나 붙잡아 잠에 취해버린 어두운 골목길 우리의 마지막 밤 맘에도 없는 싫은...  19396
# 2  별처럼 빛났던 네 기억이 사라지면 그땐 마음껏 웃을 수 있을까 비처럼 쏟아질 아픈 ...   3289
# 3  이번엔 진짠가요 몇 번을 헤어졌지만 결국엔 다시 또 돌아 왔잖아요 이번엔 진짠가요 ...  18476
# 4  매일 세상에게 묻곤 했어 너를 사랑해도 되는 건지 내게 그때마다 돌아 온건 이별이란...   7695

# %%
ballad_top2000.tail()
# Out:
#               가수명            노래제목        발매일  \
# 495          멜로망스              동경 2022-06-08
# 496           곽진언            당신만이 2014-09-20
# 497            허각       비가 내리기 전에 2021-06-20
# 498           김은영  각자의 자리, 각자의 시간 2022-07-21
# 499  태연 (TAEYEON)          그리고 하나 2013-03-13
#
#                                                     가사   좋아요수
# 495  우린 서로 너무도 다른 세상에 살아왔죠 한번 스쳐 지났을 뿐 그 후로 난 멀리서 이...   1218
# 496  눈부신 햇살이 비춰주어도 제게 무슨 소용있겠어요 이토록 아름다운 당신만이 나에게 빛...  58098
# 497  찬란했었던 우리의 사랑이 언제부턴가 어둠을 데려와 자꾸 감추려고 하지 마 너의 얼굴...   6590
# 498  텅 빈 방안에 가만히 누워 한참을 멍하니 바라보았지 홀로 외로이 이 긴 밤에 무너져...    155
# 499  쉽게 상처 받고 쉽게 눈물나고 쉽게 아프던 날 기억하나요 지금도 그래요 여전히 같아...  53028

# %%
ballad_top2000['순위'] = ballad_top2000.index + 1501

# %%
ballad_top2000.to_csv('../Data/melon_top2000.csv', index=False)

# %%
test = pd.read_csv("../Data/melon_top2000.csv")
test.head()
# Out:
#           가수명                       노래제목         발매일  \
# 0          지아                  술 한잔해요 오늘  2016-12-01
# 1         순순희                  참 많이 사랑했다  2018-04-17
# 2  에일리(Ailee)  슬픈 연극 (금혼령 X 에일리 (Ailee))  2022-02-10
# 3           별         안부 (Duet With 나윤권)  2005-03-17
# 4         KCM           알아요 (드라마 때려 OST)  2014-02-18
#
#                                                   가사   좋아요수    순위
# 0  오늘 한잔할까요 늘 만나던 그곳에서 찬바람이 불면 생각이 나던 골목집에서 추억 한잔...  32034  1501
# 1  가로등 하나 붙잡아 잠에 취해버린 어두운 골목길 우리의 마지막 밤 맘에도 없는 싫은...  19396  1502
# 2  별처럼 빛났던 네 기억이 사라지면 그땐 마음껏 웃을 수 있을까 비처럼 쏟아질 아픈 ...   3289  1503
# 3  이번엔 진짠가요 몇 번을 헤어졌지만 결국엔 다시 또 돌아 왔잖아요 이번엔 진짠가요 ...  18476  1504
# 4  매일 세상에게 묻곤 했어 너를 사랑해도 되는 건지 내게 그때마다 돌아 온건 이별이란...   7695  1505

# %%
test.tail()
# Out:
#               가수명            노래제목         발매일  \
# 495          멜로망스              동경  2022-06-08
# 496           곽진언            당신만이  2014-09-20
# 497            허각       비가 내리기 전에  2021-06-20
# 498           김은영  각자의 자리, 각자의 시간  2022-07-21
# 499  태연 (TAEYEON)          그리고 하나  2013-03-13
#
#                                                     가사   좋아요수    순위
# 495  우린 서로 너무도 다른 세상에 살아왔죠 한번 스쳐 지났을 뿐 그 후로 난 멀리서 이...   1218  1996
# 496  눈부신 햇살이 비춰주어도 제게 무슨 소용있겠어요 이토록 아름다운 당신만이 나에게 빛...  58098  1997
# 497  찬란했었던 우리의 사랑이 언제부턴가 어둠을 데려와 자꾸 감추려고 하지 마 너의 얼굴...   6590  1998
# 498  텅 빈 방안에 가만히 누워 한참을 멍하니 바라보았지 홀로 외로이 이 긴 밤에 무너져...    155  1999
# 499  쉽게 상처 받고 쉽게 눈물나고 쉽게 아프던 날 기억하나요 지금도 그래요 여전히 같아...  53028  2000

# %% [markdown]
# ---
# # dataframe 합치기

# %%
top500=pd.read_csv("../Data/melon_top500.csv")
top1000=pd.read_csv("../Data/melon_top1000.csv")
top1500=pd.read_csv("../Data/melon_top1500.csv")
top2000=pd.read_csv("../Data/melon_top2000.csv")

# %%
print(len(top500),len(top1000),len(top1500),len(top2000))
# Out:
# 500 500 500 500

# %%
melon = pd.concat([top500,top1000,top1500,top2000],axis=0,ignore_index=True)
melon.to_csv("../Data/melon.csv", index=False)

# %%
pd.read_csv("../Data/melon.csv").info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   가수명     2000 non-null   object
#  1   노래제목    2000 non-null   object
#  2   발매일     2000 non-null   object
#  3   가사      2000 non-null   object
#  4   좋아요수    2000 non-null   object
#  5   순위      2000 non-null   int64
# dtypes: int64(1), object(5)
# memory usage: 93.9+ KB

# %% [markdown]
# ---
# # traindata_기쁨
# 훈련데이터로 사용할데이터이고, 장르는 발라드만 가져오기위해 가져옴.

# %%
chrome_options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)
driver.get('https://www.melon.com/mymusic/dj/mymusicdjplaylistview_inform.htm?plylstSeq=485961516')
page_source = driver.page_source
soup = BeautifulSoup(page_source, "html.parser")

# songId 가져오기
songIds = soup.select("#frm > div > table > tbody td:nth-child(4) > div > a")

# songId 가져오기
songId_list = []
for songId in songIds:
    songIds = songId['href'].split('\'')[1]
    songId_list.append(songIds)

# %%
len(songId_list)
# Out:
# 50

# %%
chrome_options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)
driver.get('https://www.melon.com/mymusic/dj/mymusicdjplaylistview_inform.htm?plylstSeq=485961516#params%5BplylstSeq%5D=485961516&po=pageObj&startIndex=51')
page_source = driver.page_source
soup = BeautifulSoup(page_source, "html.parser")

# songId 가져오기
songIds = soup.select("#frm > div > table > tbody td:nth-child(4) > div > a")

# songId 가져오기
for songId in songIds:
    songIds = songId['href'].split('\'')[1]
    songId_list.append(songIds)
print(len(songId_list))
# Out:
# 97

# %%
songId_list
# Out:
# ['32243262',
#  '32046508',
#  '3894276',
#  '33077234',
#  '32997758',
#  '33081802',
#  '31615180',
#  '33013877',
#  '32794652',
#  '33084536',
#  '33082573',
#  '32734813',
#  '30290580',
#  '31049643',
#  '8235260',
#  '32075935',
#  '33068027',
#  '30232540',
#  '31803557',
#  '33004733',
#  '33069146',
#  '4451155',
#  '32461675',
#  '33063840',
#  '32637020',
#  '31624517',
#  '8131016',
#  '32764095',
#  '33038587',
#  '33010214',
#  '33064133',
#  '33062466',
#  '30862308',
#  '32999763',
#  '33066531',
#  '33064355',
#  '33043463',
#  '32987478',
#  '31281028',
#  '30118627',
#  '32243273',
#  '32919646',
#  '33062310',
#  '9630257',
#  '32996321',
#  '33061829',
#  '33064572',
#  '30349593',
#  '33029349',
#  '3752434',
#  '33062316',
#  '30383766',
#  '33049291',
#  '33055516',
#  '33059244',
#  '4641057',
#  '33063190',
#  '32979985',
#  '31843000',
#  '3489567',
#  '30948892',
#  '31843004',
#  '30539047',
#  '30616736',
#  '32890305',
#  '31499262',
#  '33049292',
# ...

# %%
# 가수명, 노래제목, 발매일, 가사, 좋아요 수 , 장르 리스트 변수 생성
singer_list = []
singName_list = []
date_list = []
lyrics_list = []
like_list = []
category_list = []

# %%
# for문으로 가수명, 노래제목, 발매일, 가사, 좋아요 수, 장르 리스트 변수에 내용 담고 저장하기

chrome_options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)

for songId in songId_list:
    
    driver.get(f'https://www.melon.com/song/detail.htm?songId={songId}')

    page_source = driver.page_source
    soup = BeautifulSoup(page_source, "html.parser")
    try:
        time.sleep(2)
        # 가수명 가져오기
        artist_name = soup.select_one('#downloadfrm > div > div > div.entry > div.info > div.artist > a > span:nth-child(1) ')
        singer_list.append(artist_name.string)

        # 노래제목 가져오기
        song_name = soup.select_one("#downloadfrm > div > div > div.entry > div.info > div.song_name ")
        singName_list.append(song_name.text.strip().split('\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t')[1])

        # 발매일 가져오기
        date = soup.select_one('#downloadfrm > div > div > div.entry > div.meta > dl > dd:nth-child(4)')
        date_list.append(date.string)

        # 가사 가져오기
        lyric1 = str(soup.select_one('#d_video_summary')).replace('<br/>',' ').replace('<div class="lyric" id="d_video_summary"><!-- height:auto; 로 변경시, 확장됨 -->','').replace('</div>','').replace('\t','').replace('\n','')
        lyric = lyric1.replace('  ', ' ')
        lyrics_list.append(lyric)

        # 좋아요수 가져오기
        like = soup.select_one("#d_like_count")
        like_list.append(like.text)

        # 장르 가져오기
        category = soup.select_one('#downloadfrm > div > div > div.entry > div.meta > dl > dd:nth-child(6)').string
        category_list.append(category)
        
        time.sleep(2)
    except:
        singer_list.append(0)
        singName_list.append(0)
        date_list.append(0)
        lyrics_list.append(0)
        like_list.append(0)
        category_list.append(0)
        time.sleep(1)

# %%
happy = {'가수명':singer_list, '노래제목':singName_list, '발매일':date_list, '가사':lyrics_list, '좋아요수':like_list, '장르':category_list}

# %%
ballad_happy = pd.DataFrame(happy)
ballad_happy.head()
# Out:
#                 가수명                          노래제목         발매일  \
# 0  백예린 (Yerin Baek)  Popo (How deep is our love?)  2019.12.10
# 1               김제훈                    좋은 꿈이었길 바래  2019.09.18
# 2            스탠딩 에그                        오래된 노래  2012.09.04
# 3             방탄소년단                  Life Goes On  2020.11.20
# 4             HONNE        free love (dream edit)  2020.11.12
#
#                                                   가사     좋아요수            장르
# 0  Get away from your own sorrow 슬픔에서 벗어나봐요 Let t...   53,186      R&B/Soul
# 1  만남 이별 짧지 않았던 시간을 지나 뒤돌아보면 그래도 정말 즐거웠었지 널 미워했던 ...      793           발라드
# 2  오래 전에 함께 듣던 노래가 발걸음을 다시 멈춰서게 해 이 거리에서 너를 느낄 수 ...  248,973  인디음악, 포크/블루스
# 3  어느 날 세상이 멈췄어 아무런 예고도 하나 없이 봄은 기다림을 몰라서 눈치 없이 와...  240,502          랩/힙합
# 4  Imagine a house Way up on a hill Dog in the ya...   19,495           POP

# %%
ballad_happy.장르.unique()
# Out:
# array(['R&B/Soul', '발라드', '인디음악, 포크/블루스', '랩/힙합', 'POP', '인디음악, 록/메탈',
#        '포크/블루스, 국내드라마', '발라드, 국내드라마', '랩/힙합, 인디음악', '발라드, 인디음악', '댄스',
#        '포크/블루스', '록/메탈', 'R&B/Soul, 인디음악', '댄스, 인디음악'], dtype=object)

# %%
list = ['발라드, 국내드라마','발라드, 인디음악','발라드']
ballad_happy = ballad_happy[ballad_happy['장르'].isin(list)]

# %%
ballad_happy.reset_index(drop=True, inplace=True)

# %%
ballad_happy = ballad_happy.iloc[:,:-1]

# %%
ballad_happy.to_csv('../Data/ballad_happy.csv', index=False)

# %%
test = pd.read_csv("../Data/ballad_happy.csv")
test.head()
# Out:
#    가수명                   노래제목         발매일  \
# 0  김제훈             좋은 꿈이었길 바래  2019.09.18
# 1  양다일                Darling  2020.11.23
# 2  김제훈                     어때  2019.02.18
# 3  장범준              잠이 오질 않네요  2020.10.24
# 4   산들  취기를 빌려 (취향저격 그녀 X 산들)  2020.07.20
#
#                                                   가사     좋아요수
# 0  만남 이별 짧지 않았던 시간을 지나 뒤돌아보면 그래도 정말 즐거웠었지 널 미워했던 ...      793
# 1  Oh darling 처음 널 만나면 수줍은 대화들로 사랑에 빠질 거야 My darl...   10,907
# 2  머릿속에 맴돌던 생각을 억누른 채 감정을 소비하며 누워서 잠이 들지 뻔한 일상 속에...    1,130
# 3  당신은 날 설레게 만들어 조용한 내 마음 자꾸만 춤추게 해 얼마나 얼마나 날 떨리게...  159,018
# 4  언제부턴가 불쑥 내 습관이 돼버린 너 혹시나 이런 맘이 어쩌면 부담일까 널 주저했어...  218,069

# %%
test['좋아요수'] = test['좋아요수'].str.replace(',','')

# %%
test['발매일'] = test['발매일'].str.replace('.', '-')
# Out:
# /opt/anaconda3/envs/python2/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.

# %%
test['발매일'] = pd.to_datetime(test['발매일'])

# %%
test.to_csv('../Data/ballad_happy.csv', index=False)

# %%
test = pd.read_csv("../Data/ballad_happy.csv")
test.head()
# Out:
#    가수명                   노래제목         발매일  \
# 0  김제훈             좋은 꿈이었길 바래  2019-09-18
# 1  양다일                Darling  2020-11-23
# 2  김제훈                     어때  2019-02-18
# 3  장범준              잠이 오질 않네요  2020-10-24
# 4   산들  취기를 빌려 (취향저격 그녀 X 산들)  2020-07-20
#
#                                                   가사    좋아요수
# 0  만남 이별 짧지 않았던 시간을 지나 뒤돌아보면 그래도 정말 즐거웠었지 널 미워했던 ...     793
# 1  Oh darling 처음 널 만나면 수줍은 대화들로 사랑에 빠질 거야 My darl...   10907
# 2  머릿속에 맴돌던 생각을 억누른 채 감정을 소비하며 누워서 잠이 들지 뻔한 일상 속에...    1130
# 3  당신은 날 설레게 만들어 조용한 내 마음 자꾸만 춤추게 해 얼마나 얼마나 날 떨리게...  159018
# 4  언제부턴가 불쑥 내 습관이 돼버린 너 혹시나 이런 맘이 어쩌면 부담일까 널 주저했어...  218069

# %% [markdown]
# ---
# taindata_무관심

# %%
chrome_options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)
driver.get('https://www.melon.com/mymusic/dj/mymusicdjplaylistview_inform.htm?plylstSeq=479928036')
page_source = driver.page_source
soup = BeautifulSoup(page_source, "html.parser")

# songId 가져오기
songIds = soup.select("#frm > div > table > tbody td:nth-child(4) > div > a")

# songId 가져오기
songId_list = []
for songId in songIds:
    songIds = songId['href'].split('\'')[1]
    songId_list.append(songIds)

# %%
len(songId_list)
# Out:
# 12

# %%
songId_list
# Out:
# ['30011624',
#  '32061981',
#  '30549917',
#  '5493725',
#  '30017605',
#  '31052592',
#  '4369834',
#  '30378164',
#  '32585415',
#  '4276080',
#  '32251432',
#  '8070811']

# %%
# 가수명, 노래제목, 발매일, 가사, 좋아요 수 , 장르 리스트 변수 생성
singer_list = []
singName_list = []
date_list = []
lyrics_list = []
like_list = []
category_list = []

# for문으로 가수명, 노래제목, 발매일, 가사, 좋아요 수, 장르 리스트 변수에 내용 담고 저장하기
import time
chrome_options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)

for songId in songId_list:
    
    driver.get(f'https://www.melon.com/song/detail.htm?songId={songId}')

    page_source = driver.page_source
    soup = BeautifulSoup(page_source, "html.parser")
    try:
        time.sleep(2)
        # 가수명 가져오기
        artist_name = soup.select_one('#downloadfrm > div > div > div.entry > div.info > div.artist > a > span:nth-child(1) ')
        singer_list.append(artist_name.string)

        # 노래제목 가져오기
        song_name = soup.select_one("#downloadfrm > div > div > div.entry > div.info > div.song_name ")
        singName_list.append(song_name.text.strip().split('\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t')[1])

        # 발매일 가져오기
        date = soup.select_one('#downloadfrm > div > div > div.entry > div.meta > dl > dd:nth-child(4)')
        date_list.append(date.string)

        # 가사 가져오기
        lyric1 = str(soup.select_one('#d_video_summary')).replace('<br/>',' ').replace('<div class="lyric" id="d_video_summary"><!-- height:auto; 로 변경시, 확장됨 -->','').replace('</div>','').replace('\t','').replace('\n','')
        lyric = lyric1.replace('  ', ' ')
        lyrics_list.append(lyric)

        # 좋아요수 가져오기
        like = soup.select_one("#d_like_count")
        like_list.append(like.text)

        # 장르 가져오기
        category = soup.select_one('#downloadfrm > div > div > div.entry > div.meta > dl > dd:nth-child(6)').string
        category_list.append(category)
        
        time.sleep(2)
    except:
        singer_list.append(0)
        singName_list.append(0)
        date_list.append(0)
        lyrics_list.append(0)
        like_list.append(0)
        category_list.append(0)
        time.sleep(1)

# %%
calm = {'가수명':singer_list, '노래제목':singName_list, '발매일':date_list, '가사':lyrics_list, '좋아요수':like_list, '장르':category_list}

# %%
import pandas as pd
ballad_calm = pd.DataFrame(calm)
ballad_calm.head()
# Out:
#          가수명                노래제목         발매일  \
# 0        박효신                   숨  2016.10.03
# 1  AKMU (악뮤)               작별 인사  2019.09.25
# 2       드림캐쳐                괜찮아!  2017.07.27
# 3     볼빨간사춘기              가리워진 길  2014.12.05
# 4        박효신  Beautiful Tomorrow  2016.10.03
#
#                                                   가사     좋아요수             장르
# 0  오늘 하루 쉴 숨이 오늘 하루 쉴 곳이 오늘만큼 이렇게 또 한번 살아가 침대 밑에 ...  222,821            발라드
# 1  떠날 때 창틀에 화분이 비었길래 뒤 뜰의 꽃을 옮겨 담았어요 제라늄 꽃을 떠날 때 ...   29,073            발라드
# 2  아직도 난 길을 잃어서 어디로 갈지 몰라 조금도 나아지지가 않아 사실은 나 아직 어...    4,281            발라드
# 3  보일 듯 말 듯 가물거리는 안개 속에 쌓인 길 잡힐 듯 말 듯 멀어져가는 무지개와 ...   33,439  포크/블루스, 국내드라마
# 4  그려지지 않아 눈을 감고 있어도 그렇게나 사랑하고 사랑했었던 너를 너를 몇 번이고 ...   58,852            발라드

# %%
ballad_calm.장르.unique()
# Out:
# array(['발라드', '포크/블루스, 국내드라마', '인디음악, 록/메탈', '록/메탈', 'R&B/Soul',
#        '발라드, 인디음악'], dtype=object)

# %%
list = ['발라드','발라드, 인디음악']
ballad_calm = ballad_calm[ballad_calm['장르'].isin(list)]

# %%
ballad_calm.reset_index(drop=True, inplace=True)
ballad_calm = ballad_calm.iloc[:,:-1]
ballad_calm['좋아요수'] = ballad_calm['좋아요수'].str.replace(',','')
ballad_calm['발매일'] = ballad_calm['발매일'].str.replace('.', '-')
ballad_calm['발매일'] = pd.to_datetime(ballad_calm['발매일'])
ballad_calm.to_csv('../Data/ballad_calm2.csv', index=False)
# Out:
# /var/folders/51/xmc_l6t13wv1nc5z6qmyg58r0000gn/T/ipykernel_2349/2468522225.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   ballad_calm['발매일'] = ballad_calm['발매일'].str.replace('.', '-')

# %%
pd.read_csv('../Data/ballad_calm2.csv')
# Out:
#          가수명                노래제목         발매일  \
# 0        박효신                   숨  2016-10-03
# 1  AKMU (악뮤)               작별 인사  2019-09-25
# 2       드림캐쳐                괜찮아!  2017-07-27
# 3        박효신  Beautiful Tomorrow  2016-10-03
# 4        박효신           별 시 (別 時)  2018-04-30
# 5        아이유                싫은 날  2013-12-20
# 6        아이유                이름에게  2017-04-21
# 7       선우정아                그러려니  2016-02-29
#
#                                                   가사    좋아요수
# 0  오늘 하루 쉴 숨이 오늘 하루 쉴 곳이 오늘만큼 이렇게 또 한번 살아가 침대 밑에 ...  222821
# 1  떠날 때 창틀에 화분이 비었길래 뒤 뜰의 꽃을 옮겨 담았어요 제라늄 꽃을 떠날 때 ...   29073
# 2  아직도 난 길을 잃어서 어디로 갈지 몰라 조금도 나아지지가 않아 사실은 나 아직 어...    4281
# 3  그려지지 않아 눈을 감고 있어도 그렇게나 사랑하고 사랑했었던 너를 너를 몇 번이고 ...   58852
# 4  You are my star 이 노래는 너야 불빛 하나 없는 길을 걷게 해 줄 기나...   61064
# 5  키 큰 전봇대 조명 아래 나 혼자 집에 돌아가는 길 가기 싫다 쓸쓸한 대사 한 마디...   49488
# 6  꿈에서도 그리운 목소리는 이름 불러도 대답을 하지 않아 글썽이는 그 메아리만 돌아와...  213810
# 7  만나는 사람은 줄어들고 그리운 사람은 늘어간다 끊어진 연에 미련은 없더라도 그리운 ...   28333
