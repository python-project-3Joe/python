# %%
import pandas as pd

# %%
ballad = pd.read_csv('../../Data/melon.csv')
ballad.head()

# %%
ballad_happy = pd.read_csv('../../Data/ballad_happy.csv')
ballad_happy.head()

# %%
ballad_anxious = pd.read_csv("../../Data/ballad_anxious.csv")
ballad_anxious.head()

# %%
ballad_sad = pd.read_csv('../../Data/ballad_sad.csv')
ballad_sad.head()

# %%
ballad_sad2 = pd.read_csv('../../Data/ballad_sad2.csv')
ballad_sad2.head()

# %%
ballad_sad = pd.concat([ballad_sad,ballad_sad2],axis=0,ignore_index=True)
ballad_sad.to_csv("../../Data/ballad_sad.csv", index=None)

# %%
ballad_calm1 = pd.read_csv('../../Data/ballad_calm1.csv')
ballad_calm1.head()

# %%
ballad_calm2 = pd.read_csv('../../Data/ballad_calm2.csv')
ballad_calm2.head()

# %%
ballad_calm3 = pd.read_csv('../../Data/ballad_calm3.csv')
ballad_calm3.head()

# %%
# calm1, 2 중복체크
ballad_calm1[ballad_calm1['노래제목'].isin(ballad_calm2['노래제목'])]

# %%
# calm1, 3 중복체크
ballad_calm1[ballad_calm1['노래제목'].isin(ballad_calm3['노래제목'])]

# %%
# calm2, 3 중복체크
ballad_calm2[ballad_calm2['노래제목'].isin(ballad_calm3['노래제목'])]

# %%
#calm2 중복제거
ballad_calm2 = ballad_calm2.iloc[1:,:]

# %%
# ballad_calm 합치기

ballad_calm = pd.concat([ballad_calm1, ballad_calm2, ballad_calm3],axis=0,ignore_index=True)
ballad_calm

# %%
ballad_calm.to_csv("../Data/ballad_calm.csv", index=None)

# %% [markdown]
# ---
# 무관심, 차분함, 관조, 노곤함, 위로 , 평온, 평안, 쓸쓸
#
# 0:위로, 1:위로, 2:위로,  4:관조 , 5:관조, 6:관조, 9:위로, 15:관조 17:평온, 19:덤덤,     20:덤덤, 21:덤덤, 22:차분, 23:차분, 24:위로, 25:관조, 27:쓸쓸 28:쓸쓸 29:쓸쓸, 30:덤덤,    31:관조, 32:쓸쓸, 33:쓸쓸, 34:차분, 36:관조
#
#
# 3:흥분,즐거움, 4:관조,미련(애매), 7:후회, 8:분노 ,10:후회, 11:후회, 12:후회, 13:후회,   14:슬픔, 16:후회, 18:애매, 26:애매, 35:후회, 37:애매 38:후회,복합.
#
# 후회 : [4, 7, 10, 11, 12, 13, 16, 26, 35]
# 무관심 : [0, 1, 2, 5, 6, 8, 9, 15, 17, 18, 19, 20, 21, 22, 23, 24, 25, 27, 28, 29, 30, 31, 32, 33, 34, 36, 37, 38]

# %%
ballad_calm = pd.read_csv("../../Data/ballad_calm.csv")

# %%
reg = [4, 7, 10, 11, 12, 13, 16, 26, 35]
reg_list = ballad_calm.iloc[reg,:]
reg_list
# Out:
#                       가수명                 노래제목         발매일  \
# 4                   어반자카파         아직도 나를 사랑한다면  2016-05-27
# 7                      수지       I Love You Boy  2017-10-11
# 10                    박새별    사랑이 우릴 다시 만나게 한다면  2013-05-28
# 11                     폴킴           사랑 알 수 없나봐  2018-12-16
# 12                   길구봉구               다시, 우리  2018-05-24
# 13             소유 (SOYOU)       길에서 (Feat. 적재)  2019-12-23
# 16  T.P RETRO (타디스 프로젝트舊)  오늘도 그대만 (Feat. 정동원)  2017-02-28
# 26                    박효신            별 시 (別 時)  2018-04-30
# 35                    장나라             그게 정말이니?  2003-12-03
#
#                                                    가사    좋아요수
# 4   노래를 불러요 우릴 헤어지게 만든 그 노래를 이 일만 끝나면 더 잘할 수 있다고 그...    7655
# 7   그댈 보기 위해 먼 길을 건너왔네요 힘든 길인걸 알면서도 그저 걸었죠 I fly f...   33264
# 10  사랑이 우릴 다시 만나게 해준다면 나 그대에게 해주고 싶은 말이 너무 많아요 그댈 ...   12564
# 11  사랑 알 수 없나 봐 어떤 마음인지 자꾸 의심하게 돼 청개구리처럼 반대로 하게 되는...   41914
# 12  뚜루루 온종일 비가 내렸지 눅눅히 젖은 신발을 보다가 엉겨 붙어버린 기억의 먼지 한...   33582
# ...

# %%
indif =[0, 1, 2, 5, 6, 8, 9, 15, 17, 18, 19, 20, 21, 22, 23, 24, 25, 27, 28, 29, 30, 31, 32, 33, 34, 36, 37, 38]
indif_list = ballad_calm.iloc[indif,:]
indif_list
# Out:
#                          가수명                       노래제목         발매일  \
# 0           백예린 (Yerin Baek)                      그럴때마다  2021-09-10
# 1                        권진아                         위로  2019-09-29
# 2                        구원찬     너는 어떻게 (Original ver.)  2018-12-26
# 5   Collective Arts (콜렉티브아츠)                      나의 그늘  2017-07-27
# 6                   첸 (CHEN)  하고 싶던 말 (Sorry not sorry)  2019-04-01
# 8                 훈스 (HOONS)                내가 싫어진 거 알아  2017-02-22
# 9                     Sondia                  Moonlight  2019-12-31
# 15                       윤현상                     잊는다는 게  2015-03-13
# 17                       아이유                        밤편지  2017-03-24
# 18                       곽진언                     택시를 타고  2016-05-10
# 19                       윤종신                        말꼬리  2011-05-31
# 20                       정승환                    숲으로 걷는다  2016-11-29
# 21                        문빛                        끝자락  2017-11-02
# ...

# %%
---
무관심: 차분함, 관조, 노곤함, 위로 , 평온, 평안, 쓸쓸
불안 : 불안 , 긴장, 고민, 우려, 두려움, 과민 , 초조, 잠못드는, 피곤, 의심, 민감, 우려



불안 - [2, 14, 19, 21, 22, 29, 32, 33, 36, 45] 
체념,불안(애매) - [28,]


후회 - [0, 3, 6, 8, 10, 12, 14, 15, 17, 20, 31, 39, 41]

무관심 - [1, 4, 5, 6, 9, 11, 13, 18, 23, 24, 25, 26, 27, 30, 34, 35, 37, 38, 40, 42, 43, 44,]



슬픔 - [7]

# %%
ballad_anxious = pd.read_csv("../../Data/ballad_anxious.csv")
ballad_anxious2 = ballad_anxious.reset_index(drop=True)

# %%
reg2 = [0, 3, 6, 8, 10, 12, 14, 15, 17, 20, 31, 39, 41]
reg_list2 = ballad_anxious.iloc[reg2,:]

# %%
ballad_regret = pd.concat([reg_list, reg_list2], axis=0, ignore_index=True)
ballad_regret.to_csv("../../Data/ballad_regret.csv", index=None)

# %%
pd.read_csv("../../Data/ballad_regret.csv").info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   가수명     22 non-null     object
#  1   노래제목    22 non-null     object
#  2   발매일     22 non-null     object
#  3   가사      22 non-null     object
#  4   좋아요수    22 non-null     int64
# dtypes: int64(1), object(4)
# memory usage: 1008.0+ bytes

# %%
indif2 = [1, 4, 5, 6, 9, 11, 13, 18, 23, 24, 25, 26, 27, 30, 34, 35, 37, 38, 40, 42, 43, 44]
indif_list2 = ballad_anxious.iloc[indif2,:]
indif_list2
# Out:
#                   가수명                          노래제목         발매일  \
# 1                 김나영                    너의 번호를 누르고  2022-04-12
# 4                멜로망스  그게 더 편할 것 같아 (N번째 연애 X 멜로망스)  2021-11-26
# 5                  주호                       내가 아니라도  2022-03-25
# 6                 임영웅                     사랑은 늘 도망가  2021-10-11
# 9                  세윤                    이별을 통보했던 날  2021-11-30
# 11         HYNN (박혜원)                  친구라도 될 걸 그랬어  2022-04-08
# 13                 김필         다시 사랑한다면 (니글니글 버터플라이)  2016-02-21
# 18                김세정                       정인 (情人)  2018-09-16
# 23          AKMU (악뮤)     어떻게 이별까지 사랑하겠어, 널 사랑하는 거지  2019-09-25
# 24                #안녕       너의 번호를 누르고 (Prod. 영화처럼)  2019-11-30
# 25                윤토벤         서툰 이별을 하려해 (Feat.전상근)  2019-08-01
# 26                노형돈          동암역 2번출구 (Feat. 최은설)  2018-08-09
# 27                진민호                            반만  2019-11-30
# 30                 부활            Never Ending Story  2002-09-01
# ...

# %%
ballad_indifference = pd.concat([indif_list, indif_list2], axis=0, ignore_index=True)
ballad_indifference.to_csv("../../Data/ballad_indifference.csv", index=None)

# %%
pd.read_csv("../../Data/ballad_indifference.csv").info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   가수명     50 non-null     object
#  1   노래제목    50 non-null     object
#  2   발매일     50 non-null     object
#  3   가사      50 non-null     object
#  4   좋아요수    50 non-null     int64
# dtypes: int64(1), object(4)
# memory usage: 2.1+ KB
