# %%
import pandas as pd

# %%
ballad = pd.read_csv("../Data/melon_top500.csv")
ballad.tail(50)
# Out:
#                      가수명                                 노래제목         발매일  \
# 449                  임창정                                  되풀이  2021-03-09
# 450                   노을                               살기 위해서  2011-12-05
# 451                  김종국                               바람만바람만  2006-11-15
# 452                  안예은                                   홍연  2016-11-28
# 453                  김세정                   꽃길 (Prod. By ZICO)  2016-11-23
# 454          헤이즈 (Heize)                         내 맘을 볼 수 있나요  2019-07-28
# 455                  정동원                              그대가 살아서  2019-02-02
# 456                  성시경                                  너에게  2013-11-01
# 457                  박효신                                 좋은사람  2002-09-13
# 458                  임한별                    밤하늘의 별을(Original)  2021-11-02
# 459          윤하 (YOUNHA)       서른 밤째 (바른연애 길잡이 X 윤하 (YOUNHA))  2021-02-08
# 460                  정효빈                                처음이라서  2019-04-16
# ...
