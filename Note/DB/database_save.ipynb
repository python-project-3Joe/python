# %%
import pandas as pd

# %%
ballad = pd.read_csv("../../Data/ballad_test.csv")
ballad.head()
# Out:
#             가수명               노래제목         발매일  \
# 0  WSG워너비 (가야G)  그때 그 순간 그대로 (그그그)  2022-07-09
# 1            경서             나의 X에게  2022-04-24
# 2            주호            내가 아니라도  2022-03-25
# 3    김민석 (멜로망스)               취중고백  2021-12-19
# 4           임영웅           우리들의 블루스  2022-05-02
#
#                                                   가사    좋아요수  \
# 0   잘 지냈지? 조금은 어색해 요즘 좋아 보여 인사 나누며 사실 궁금한 게 너무 많았...   88589
# 1   우리 다시 만날래 예쁘게 빛나던 모든 추억들이 너무 그리워 너의 품에 안길래 이 ...  105034
# 2   사랑이었다 별거 없던 내 하루에 빛이 돼준 단한 사람 나보다 나를 더 아껴 주던 ...   52955
# 3   뭐하고 있었니 늦었지만 잠시 나올래 너의 집 골목에 있는 놀이터에 앉아 있어 친구...  137934
# 4   잊지는 말아요 함께 했던 날들 눈물이 날 때면 그대 뒤를 돌아보면 돼요 아프지 말...   71880
#
#                                                 앨범사진    songId  순위
# 0  https://cdnimg.melon.co.kr/cm2/album/images/11...  35383397   1
# 1  https://cdnimg.melon.co.kr/cm2/album/images/10...  34943312   2
# 2  https://cdnimg.melon.co.kr/cm2/album/images/10...  34787226   4
# ...

# %%
ballad.tail()
# Out:
#           가수명                      노래제목         발매일  \
# 1908       터보             회상 (December)  1997-01-01
# 1909      이석훈                        고백  2011-06-02
# 1910      다비치                    나의 첫사랑  2022-05-16
# 1911     미스에스  이 나이 먹고 뭐했길래 (Feat. 정슬기)  2010-09-10
# 1912  하은 (포맨)             혼코노 (Honkono)  2019-10-17
#
#                                                      가사   좋아요수  \
# 1908  겨울 오면은 우리 둘이서 항상 왔었던 바닷가 시린 바람과 하얀 파도는 예전 그대로였...  12742
# 1909  좋은 사람 만나 행복해야 해 너는 웃고 있지만 나는 웃을 수가 없는걸 그래 난 알고...  18569
# 1910  그때의 나는 너를 만나서 하나부터 열까지 모든 순간들이 소중했어 내 첫사랑 잊고 싶...    925
# 1911  다시 처음으로 돌아갈 수 있다면 아마 너를 사랑하는 일은 안했을텐데 그 날밤 그 카...  10416
# 1912  이 동전 하나로 뭘 할 수 있을까 고민 고민하다가 나 혼자 이곳에 왔어 익숙한 번호...  15260
#
#                                                    앨범사진    songId    순위
# 1908  https://cdnimg.melon.co.kr/cm/album/images/003...   1606413  1996
# 1909  https://cdnimg.melon.co.kr/cm/album/images/012...   3426230  1997
# ...

# %%
# 가수명,제목,가사,발매일,이미지,유투브주소,
# m_singer,m_title,m_lyrics,m_date,m_image,m_link

# %%
len(ballad)
# Out:
# 1913

# %%
id_list = pd.DataFrame(list(range(1,1914)),index=None)

# %%
id_list
# Out:
#          0
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
# ...    ...
# 1908  1909
# 1909  1910
# 1910  1911
# 1911  1912
# 1912  1913
#
# [1913 rows x 1 columns]

# %%
ballad_db = ballad[['가수명','노래제목','가사','발매일','앨범사진']]

# %%
ballad_db = pd.DataFrame(ballad_db)

# %%
ballad_db = pd.concat([id_list,ballad_db,id_list,id_list],axis=1)

# %%
column = ['m_id','m_singer','m_title','m_lycrics','m_date','m_image','m_link','d_id']
ballad_db.columns = column
ballad_db.head()
# Out:
#    m_id      m_singer            m_title  \
# 0     1  WSG워너비 (가야G)  그때 그 순간 그대로 (그그그)
# 1     2            경서             나의 X에게
# 2     3            주호            내가 아니라도
# 3     4    김민석 (멜로망스)               취중고백
# 4     5           임영웅           우리들의 블루스
#
#                                            m_lycrics      m_date  \
# 0   잘 지냈지? 조금은 어색해 요즘 좋아 보여 인사 나누며 사실 궁금한 게 너무 많았...  2022-07-09
# 1   우리 다시 만날래 예쁘게 빛나던 모든 추억들이 너무 그리워 너의 품에 안길래 이 ...  2022-04-24
# 2   사랑이었다 별거 없던 내 하루에 빛이 돼준 단한 사람 나보다 나를 더 아껴 주던 ...  2022-03-25
# 3   뭐하고 있었니 늦었지만 잠시 나올래 너의 집 골목에 있는 놀이터에 앉아 있어 친구...  2021-12-19
# 4   잊지는 말아요 함께 했던 날들 눈물이 날 때면 그대 뒤를 돌아보면 돼요 아프지 말...  2022-05-02
#
#                                              m_image  m_link  d_id
# 0  https://cdnimg.melon.co.kr/cm2/album/images/11...       1     1
# 1  https://cdnimg.melon.co.kr/cm2/album/images/10...       2     2
# 2  https://cdnimg.melon.co.kr/cm2/album/images/10...       3     3
# ...

# %%
# !pip install sqlalchemy
# !pip install pymysql

# %%
import pymysql
from sqlalchemy import create_engine

# %%
engine = create_engine("mysql+pymysql://root:qwer1234@127.0.0.1:3306/musik")
conn = engine.connect()

# %%
ballad_db.to_sql(name='music_playlist',con=engine,if_exists='append',index=False)

# %%
balladList = pd.read_sql_table('music_playlist',conn)
balladList
# Out:
#       m_id      m_singer                   m_title  \
# 0        1  WSG워너비 (가야G)         그때 그 순간 그대로 (그그그)
# 1        2            경서                    나의 X에게
# 2        3            주호                   내가 아니라도
# 3        4    김민석 (멜로망스)                      취중고백
# 4        5           임영웅                  우리들의 블루스
# ...    ...           ...                       ...
# 1908  1909            터보             회상 (December)
# 1909  1910           이석훈                        고백
# 1910  1911           다비치                    나의 첫사랑
# 1911  1912          미스에스  이 나이 먹고 뭐했길래 (Feat. 정슬기)
# 1912  1913       하은 (포맨)             혼코노 (Honkono)
#
#                                               m_lycrics     m_date  \
# 0      잘 지냈지? 조금은 어색해 요즘 좋아 보여 인사 나누며 사실 궁금한 게 너무 많았... 2022-07-09
# 1      우리 다시 만날래 예쁘게 빛나던 모든 추억들이 너무 그리워 너의 품에 안길래 이 ... 2022-04-24
# 2      사랑이었다 별거 없던 내 하루에 빛이 돼준 단한 사람 나보다 나를 더 아껴 주던 ... 2022-03-25
# 3      뭐하고 있었니 늦었지만 잠시 나올래 너의 집 골목에 있는 놀이터에 앉아 있어 친구... 2021-12-19
# ...
