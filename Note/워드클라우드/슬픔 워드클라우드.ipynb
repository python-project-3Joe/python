# %% [markdown]
# ---
# ## ballad_sad에서 20개 데이터 추출하기

# %%
import pandas as pd
import numpy as np
import random

# %%
sad = pd.read_csv("../../Data/ballad_sad.csv")
len(sad)
# Out:
# 30

# %%
index_list = range(0,30)

# %%
index = random.sample(index_list,20)
index
# Out:
# [27, 17, 13, 16, 12, 5, 1, 6, 22, 0, 11, 14, 19, 21, 8, 3, 7, 24, 10, 15]

# %%
sad20 = sad.iloc[index,:]

# %%
sad20.reset_index(drop=True,inplace=True)

# %%
sad20.to_csv("../../Data/ballad_sad20.csv",index=False)

# %%
sad20 = pd.read_csv("../../Data/ballad_sad20.csv")
sad20
# Out:
#               가수명                     노래제목         발매일  \
# 0             정효빈                    처음이라서  2019-04-16
# 1       포맨 (4MEN)              눈 떠보니 이별이더라  2017-10-24
# 2              이우                     내 안부  2019-07-16
# 3             윤토벤    서툰 이별을 하려해 (Feat.전상근)  2019-08-01
# 4        사이로(415)                 우리 둘 사이로  2019-08-29
# 5      펀치 (Punch)              안녕 내 전부였던 너  2021-03-10
# 6             주보라      네가 없다 (Without You)  2013-02-19
# 7      펀치 (Punch)              Done For Me  2019-08-18
# 8             송하예                     니 소식  2019-05-11
# 9           V.O.S                  잘 살고 있다  2019-12-02
# 10            황인욱                      이별주  2019-11-01
# 11  MSG워너비(M.O.M)                   바라만 본다  2021-06-26
# 12             이우                     이별행동  2019-10-06
# 13            다비치  마치 우린 없었던 사이 (Prod. 정키)  2018-07-12
# 14            전상근                  너무 보고싶어  2021-07-25
# 15             정키  부담이 돼 (Feat. 휘인 Of 마마무)  2017-03-08
# 16     펀치 (Punch)                   이 밤의 끝  2018-05-31
# 17            아이유                첫 이별 그날 밤  2010-12-09
# 18            빅마마                    하루만 더  2021-06-24
# 19            전상근            오늘따라 더 미운 그대가  2021-06-13
#
#                                                    가사    좋아요수
# 0   떨어질 줄 몰랐던 너의 품도 잡은 손에 스치던 봄바람도 떨리던 입맞춤도 맞춰 걷던 ...   58777
# 1   분명 나는 꿈을 꾼 거다 눈 떠보니 이별이더라 휴대폰을 확인해 봤더니 다시 봐도 이...  115695
# 2   내 소식 들었지 너와 헤어지고 참 많이 울고 힘들게 버티다 이해심이 많은 좋은 사람...   64527
# 3   우리 이제 헤어지기로해 너도 알잖아 우린 충분했다는걸 이별이 무서워 자꾸 피해보지만...   81248
# 4   Forget me close your eyes Forget me close your...    5998
# 5   안녕 안녕 이제 인사를 해야지 너와 나의 이별인데 아니 아니 나는 그게 안될것 같아...   14135
# 6   서툰 작별이었는지 아련한 슬픔 속에 눈물이 멈추질 않아 너무나 어렸던 걸까 내 이기...    2948
# 7   지울게 너에게 남겨줬던 추억까지도 바랄게 너와의 기억도 남지 못하게 더는 다가갈 수...  100916
# 8   그때의 우리 사랑 뜨겁고 치열했는데 끝나보니 남는건 미움뿐 몇번의 계절을 더 보내야...  195103
# 9   한잔 술에 잊자 그만 나도 숨 좀 쉬자 제발 마치 주문처럼 매일 읊조렸던 넌 모르는...   38512
# 10  오늘이 지나면 널 지워야겠지 흔들리는 이 술잔이 너의 마음 같아서 아무 말 안 해도...   60822
# 11  내가 너라면 다 알아볼 텐데 널 위할 사람 찾아낼 텐데 지난 오랜 시간 너의 그 곁...  179238
# 12  자꾸만 연락을 피하고 바쁘다며 약속을 미루고 점점 변해가는 네 모습 무심한 말투 조...   58649
# 13  비 내리는 날 창가에 앉아 서두르던 일상을 달래다 울적해진 마음잡고 써 내려가다 울...   50062
# 14  혼자 이별을 하고 가버리면 난 어떡하라고 너 없는 하루를 살아보고 너 없는 채로 잠...   18728
# 15  더는 할 말이 없어 다른 이유도 어떤 변명도 난 의미 없단 걸 알아 끝이란 게 다 ...  134029
# 16  널 보면 나와 달라 이렇게 난 네 생각뿐인데 널 사랑했던 만큼 아파야 하는 걸까 난...   47764
# 17  멍하니 아무 일도 할 일이 없어 이게 이별인 거니 전화기 가득 찬 너와의 메시지만 ...   93381
# 18  하루만 더 우리 이별을 늦춘다면 어땠을까 그럴 일 없다는 걸 나는 알면서도 아직 널...   58506
# 19  조금은 괜찮다 생각했는데 이제는 잊혀질 때도 됐는데 아무렇지 않다가도 그대가 없단 ...   25819

# %% [markdown]
# ---
# # sad20 wordcloud만들기

# %%
import nltk # national language tool kit
from konlpy.tag import Okt
import matplotlib.pyplot as plt
from wordcloud import WordCloud

t = Okt()

# %%
t.nouns(sad20.loc[0,'가사'])
# Out:
# ['줄',
#  '너',
#  '손',
#  '봄바람',
#  '입맞춤',
#  '걸음',
#  '내겐',
#  '모두',
#  '처음',
#  '고',
#  '하루',
#  '끝',
#  '준',
#  '것',
#  '편지',
#  '눈물',
#  '준',
#  '것',
#  '벚꽃',
#  '여름',
#  '바다',
#  '단풍',
#  '함박눈',
#  '처음',
#  '나',
#  '첫',
#  '사람',
#  '내',
#  '첫사랑',
#  '너',
#  '처음',
#  '시간',
#  '무뎌',
#  '날',
#  '그때',
#  '더',
#  '아파해',
#  '볼',
#  '누군가',
#  '위',
#  '것',
#  '세상',
#  '누군가',
#  '자랑',
#  '것',
#  '너',
#  '게',
#  '게',
#  '나',
#  '첫',
#  '사람',
#  '내',
#  '첫사랑',
#  '너',
#  '처음',
#  '시간',
#  '널',
#  '날',
#  '그때',
#  '더',
#  '아파해',
#  '볼',
#  '사실',
#  '겁',
#  '나',
#  '젠',
#  '가도',
#  '너',
#  '추억',
#  '처음',
#  '거',
#  '더',
#  '거',
#  '처음',
#  '거',
#  '고생',
#  '너',
#  '너',
#  '시간',
#  '추억',
#  '젠',
#  '네',
#  '내',
#  '처음']

# %%
total20 = ""

# %%
for i in range(0, 20):
    total20 += (" " + sad20['가사'][i])

# %%
# 명사 분리
token_ko1 = t.nouns(total20)

# %%
token_ko1
# Out:
# ['줄',
#  '너',
#  '손',
#  '봄바람',
#  '입맞춤',
#  '걸음',
#  '내겐',
#  '모두',
#  '처음',
#  '고',
#  '하루',
#  '끝',
#  '준',
#  '것',
#  '편지',
#  '눈물',
#  '준',
#  '것',
#  '벚꽃',
#  '여름',
#  '바다',
#  '단풍',
#  '함박눈',
#  '처음',
#  '나',
#  '첫',
#  '사람',
#  '내',
#  '첫사랑',
#  '너',
#  '처음',
#  '시간',
#  '무뎌',
#  '날',
#  '그때',
#  '더',
#  '아파해',
#  '볼',
#  '누군가',
#  '위',
#  '것',
#  '세상',
#  '누군가',
#  '자랑',
#  '것',
#  '너',
#  '게',
#  '게',
#  '나',
#  '첫',
#  '사람',
#  '내',
#  '첫사랑',
#  '너',
#  '처음',
#  '시간',
#  '널',
#  '날',
#  '그때',
#  '더',
#  '아파해',
#  '볼',
#  '사실',
#  '겁',
#  '나',
#  '젠',
#  '가도',
#  '너',
#  '추억',
#  '처음',
#  '거',
#  '더',
#  '거',
#  '처음',
#  '거',
#  '고생',
#  '너',
#  '너',
#  '시간',
#  '추억',
#  '젠',
#  '네',
#  '내',
#  '처음',
#  '분명',
#  '나',
#  '꿈',
#  '꾼',
#  '거',
#  '눈',
#  '이별',
#  '더',
#  '휴대폰',
#  '확인',
#  '다시',
#  '이별',
#  '더',
#  '헛웃음',
#  '두',
#  '문득',
#  '네',
#  '얼굴',
#  '눈물',
#  '대체',
#  '무슨',
#  '짓',
#  '엎',
#  '물',
#  '난',
#  '채',
#  '꼼짝',
#  '못',
#  '그',
#  '이별',
#  '뒤',
#  '넌',
#  '사랑',
#  '정말',
#  '내',
#  '옆',
#  '늘',
#  '여기',
#  '네',
#  '날',
#  '그냥',
#  '식이',
#  '나',
#  '눈',
#  '이별',
#  '더',
#  '이건',
#  '절대',
#  '현실',
#  '눈',
#  '꿈',
#  '부정',
#  '이별',
#  '눈물',
#  '네',
#  '이름',
#  '움직',
#  '못',
#  '채',
#  '너',
#  '외치',
#  '그',
#  '이별',
#  '뒤',
#  '넌',
#  '사랑',
#  '정말',
#  '내',
#  '옆',
#  '늘',
#  '여기',
#  '네',
#  '날',
#  '그냥',
#  '식이',
#  '나',
#  '꿈',
#  '사랑',
#  '이별',
#  '현실',
#  '알람',
#  '하나',
#  '번만',
#  '더',
#  '기회',
#  '다시',
#  '내',
#  '바보',
#  '화가',
#  '나',
#  '수가',
#  '그',
#  '이별',
#  '뒤',
#  '이별',
#  '정말',
#  '가슴',
#  '네',
#  '날',
#  '나',
#  '사람과',
#  '평생',
#  '사랑',
#  '나',
#  '너',
#  '평생',
#  '나',
#  '너',
#  '안',
#  '눈',
#  '이별',
#  '더',
#  '내',
#  '소식',
#  '너',
#  '울',
#  '해심',
#  '사람',
#  '나',
#  '넌',
#  '얘길',
#  '전해',
#  '네',
#  '좀',
#  '걱정',
#  '그녀',
#  '자꾸',
#  '네',
#  '네',
#  '안부',
#  '날',
#  '바랬는데',
#  '사랑',
#  '바랬는데',
#  '못',
#  '날',
#  '왜',
#  '너',
#  '안부',
#  '못',
#  '척',
#  '걸',
#  '그게',
#  '지금',
#  '여자친구',
#  '때',
#  '내',
#  '곁',
#  '너',
#  '기억',
#  '하나',
#  '나',
#  '놈',
#  '고작',
#  '너',
#  '안부',
#  '가슴',
#  '왜',
#  '눈물',
#  '나',
#  '날',
#  '바랬는데',
#  '사랑',
#  '바랬는데',
#  '못',
#  '날',
#  '왜',
#  '너',
#  '안부',
#  '못',
#  '척',
#  '걸',
#  '말',
#  '너',
#  '후회',
#  '바랬어',
#  '널',
#  '사랑',
#  '다시',
#  '시작',
#  '생각',
#  '너',
#  '안부',
#  '우리',
#  '이제',
#  '해',
#  '너',
#  '우린',
#  '이별',
#  '자꾸',
#  '피',
#  '젠',
#  '정말',
#  '끝',
#  '우리',
#  '사랑',
#  '우리',
#  '추억',
#  '젠',
#  '기억',
#  '내',
#  '끝',
#  '걸',
#  '알',
#  '끝',
#  '눈',
#  '네',
#  '모습',
#  '날',
#  '나',
#  '이제',
#  '너',
#  '이별',
#  '이제',
#  '정말',
#  '헤어',
#  '가끔',
#  '혼자',
#  '몰래',
#  '널',
#  '그냥',
#  '이별',
#  '혹시',
#  '그때',
#  '서로',
#  '조금',
#  '더',
#  '이해',
#  '우린',
#  '조금',
#  '이제',
#  '내',
#  '기적',
#  '눈',
#  '네',
#  '모습',
#  '날',
#  '나',
#  '이제',
#  '너',
#  '이별',
#  '이제',
#  '정말',
#  '헤어',
#  '가끔',
#  '혼자',
#  '몰래',
#  '널',
#  '그냥',
#  '이별',
#  '우리',
#  '최선',
#  '여기',
#  '수고',
#  '젠',
#  '널',
#  '추억',
#  '속',
#  '우리',
#  '젠',
#  '그냥',
#  '널',
#  '우리',
#  '이제',
#  '정말',
#  '이별',
#  '혹시',
#  '우리',
#  '다시',
#  '날',
#  '그땐',
#  '꼭',
#  '말',
#  '나',
#  '이제',
#  '나',
#  '이제',
#  '우리',
#  '둘',
#  '사이',
#  '너',
#  '이',
#  '맘',
#  '알',
#  '널',
#  '때',
#  '이제',
#  '매일',
#  '밤',
#  '때',
#  '하루',
#  '난',
#  '수백',
#  '번',
#  '고민',
#  '너',
#  '때',
#  '그날',
#  '너',
#  '전',
#  '얘기',
#  '자꾸',
#  '걸',
#  '이면',
#  '젠',
#  '이번',
#  '널',
#  '수',
#  '나',
#  '이제',
#  '우리',
#  '둘',
#  '사이',
#  '네',
#  '나',
#  '하루',
#  '자꾸만',
#  '내',
#  '맘',
#  '걸',
#  '롤',
#  '굴지',
#  '날',
#  '바',
#  '하루',
#  '난',
#  '수백',
#  '번',
#  '고민',
#  '때',
#  '지금',
#  '너',
#  '전',
#  '얘기',
#  '너',
#  '더',
#  '이면',
#  '뒤',
#  '젠',
#  '이번',
#  '널',
#  '수',
#  '나',
#  '이제',
#  '우리',
#  '둘',
#  '사이',
#  '그날',
#  '수',
#  '이제',
#  '수',
#  '날',
#  '시간',
#  '속',
#  '우린',
#  '다른',
#  '룰',
#  '그',
#  '순간',
#  '눈',
#  '우리',
#  '둘',
#  '사이',
#  '안녕',
#  '안녕',
#  '이제',
#  '인사',
#  '너',
#  '나',
#  '이별',
#  '나',
#  '그게',
#  '너',
#  '일',
#  '영활',
#  '보고',
#  '밥',
#  '일도',
#  '손',
#  '잡고',
#  '거릴',
#  '일도',
#  '앞',
#  '혼자',
#  '란',
#  '사실',
#  '그게',
#  '울',
#  '걸',
#  '안녕',
#  '내',
#  '전부',
#  '너',
#  '사랑',
#  '너',
#  '난',
#  '너',
#  '사람',
#  '날수',
#  '사실',
#  '사실',
#  '너',
#  '이별',
#  '말',
#  '조금',
#  '더',
#  '순',
#  '한번',
#  '더',
#  '기횔',
#  '줄',
#  '순',
#  '너',
#  '난',
#  '말',
#  '기억',
#  '마저',
#  '안녕',
#  '내',
#  '전부',
#  '너',
#  '사랑',
#  '너',
#  '난',
#  '너',
#  '사람',
#  '날수',
#  '소리',
#  '낼',
#  '수',
#  '너',
#  '나',
#  '제발',
#  '이',
#  '말',
#  '진심',
#  '다해',
#  '사랑',
#  '말',
#  '건',
#  '난',
#  '그냥',
#  '이',
#  '미안',
#  '내',
#  '사랑',
#  '작별',
#  '슬픔',
#  '속',
#  '눈물',
#  '내',
#  '적임',
#  '너',
#  '우리',
#  '헤어지자',
#  '말',
#  '한지',
#  '하루',
#  '뒤',
#  '잠깐',
#  '실수',
#  '걸',
#  '깨달',
#  '순간',
#  '아침',
#  '네',
#  '목소리',
#  '네',
#  '품',
#  '벌써',
#  '내',
#  '바보',
#  '너',
#  '내',
#  '왜',
#  '이제',
#  '눈물',
#  '내',
#  '마음',
#  '알',
#  '수',
#  '더',
#  '사랑',
#  '나',
#  '항상',
#  '너',
#  '사람',
#  '때',
#  '우리',
#  '헤어지자',
#  '말',
#  '한지',
#  '하루',
#  '뒤',
#  '잠깐',
#  '실수',
#  '걸',
#  '깨달',
#  '순간',
#  '아침',
#  '네',
#  '목소리',
#  '네',
#  '품',
#  '벌써',
#  '내',
#  '바보',
#  '너',
#  '내',
#  '왜',
#  '이제',
#  '눈물',
#  '내',
#  '마음',
#  '알',
#  '수',
#  '더',
#  '작별인사',
#  '안',
#  '우리',
#  '사랑',
#  '그',
#  '기억',
#  '아침',
#  '네',
#  '목',
#  '소린',
#  '이제',
#  '어제',
#  '오늘',
#  '나',
#  '널',
#  '사랑',
#  '것',
#  '바보',
#  '너',
#  '내',
#  '왜',
#  '이제',
#  '눈물',
#  '내',
#  '마음',
#  '알',
#  '수',
#  '더',
#  '너',
#  '추억',
#  '너',
#  '기억',
#  '남지',
#  '더',
#  '수',
#  '네',
#  '마음',
#  '너',
#  '기억',
#  '모두',
#  '수',
#  '널',
#  '수',
#  '사랑',
#  '기억',
#  '낼',
#  '수',
#  '더',
#  '수',
#  '난',
#  '수',
#  '듯이',
#  '너',
#  '곳',
#  '사랑',
#  '추억',
#  '네',
#  '기억',
#  '가시',
#  '해',
#  '모두',
#  '해',
#  '나',
#  '수',
#  '널',
#  '수',
#  '란',
#  '걸',
#  '알',
#  '너',
#  '기억',
#  '모두',
#  '더',
#  '수',
#  '네',
#  '마음',
#  '너',
#  '기억',
#  '모두',
#  '나',
#  '기억',
#  '너',
#  '추억',
#  '너',
#  '그리움',
#  '모든',
#  '순간',
#  '볼',
#  '너',
#  '흔적',
#  '너',
#  '추억',
#  '너',
#  '기억',
#  '남지',
#  '더',
#  '수',
#  '네',
#  '마음',
#  '너',
#  '기억',
#  '모두',
#  '너',
#  '수',
#  '수',
#  '제발',
#  '용서',
#  '우리',
#  '다시',
#  '만날',
#  '수',
#  '그때',
#  '우리',
#  '사랑',
#  '미움',
#  '몇번',
#  '계절',
#  '더',
#  '미련',
#  '듬뿍',
#  '하루',
#  '친구',
#  '통화',
#  '니',
#  '소식',
#  '다른',
#  '사랑',
#  '시작',
#  '땐',
#  '사랑',
#  '우리둘',
#  '젠',
#  '남',
#  '사람',
#  '넌',
#  '넌',
#  '괜',
#  '걱정',
#  '나',
#  '너',
#  '내',
#  '소식',
#  '전해',
#  '은',
#  '좀',
#  '마음',
#  '가끔',
#  '날',
#  '생각',
#  '래야',
#  '내',
#  '맘',
#  '좀',
#  '옆',
#  '다른',
#  '사람',
#  '기적',
#  '땐',
#  '사랑',
#  '우리둘',
#  '젠',
#  '남',
#  '사람',
#  '넌',
#  '넌',
#  '나',
#  '끝',
#  '나',
#  '맘',
#  '말',
#  '사랑',
#  '해',
#  '가슴',
#  '바랬어',
#  '너',
#  '나',
#  '니',
#  '모습',
#  '이제야',
#  '실감',
#  '넌',
#  '날',
#  '난',
#  '니',
#  '사람',
#  '다행',
#  '말',
#  '거짓말',
#  '네',
#  '소식',
#  '그날',
#  '밤',
#  '펑펑',
#  '다가',
#  '밤',
#  '걸',
#  '알',
#  '수',
#  '한잔',
#  '술',
#  '숨',
#  '좀',
#  '제발',
#  '마치',
#  '주문',
#  '매일',
#  '넌',
#  '내',
#  '혼잣말',
#  '친구',
#  '통해',
#  '네',
#  '소식',
#  '살',
#  '날',
#  '만날',
#  '때',
#  '더',
#  '너',
#  '억지로',
#  '밥',
#  '친구',
#  '술',
#  '겨우',
#  '날',
#  '숨',
#  '좀',
#  '쉬',
#  '해',
#  '이제',
#  '네',
#  '얼굴',
#  '살',
#  '너',
#  '듣기',
#  '네',
#  '소식',
#  '막상',
#  '또',
#  '이별',
#  '듯이',
#  '너',
#  '억지로',
#  '밥',
#  '친구',
#  '술',
#  '겨우',
#  '날',
#  '숨',
#  '좀',
#  '쉬',
#  '해',
#  '이제',
#  '네',
#  '얼굴',
#  '너',
#  '너',
#  '밤',
#  '혼자',
#  '날',
#  '가끔',
#  '너',
#  '철',
#  '나',
#  '장난',
#  '입',
#  '꼬리',
#  '그',
#  '미소',
#  '건',
#  '널',
#  '게',
#  '전부',
#  '너',
#  '젠',
#  '나',
#  '사랑',
#  '사람',
#  '살',
#  '너',
#  '수',
#  '오늘이',
#  '널',
#  '이',
#  '술잔',
#  '너',
#  '마음',
#  '아무',
#  '말',
#  '안',
#  '해도',
#  '난',
#  '알',
#  '수가',
#  '오늘',
#  '넌',
#  '이별',
#  '말',
#  '것',
#  '하필',
#  '왜',
#  '이',
#  '포장마차',
#  '우리',
#  '처음',
#  '이',
#  '자리',
#  '왜',
#  '눈물',
#  '해',
#  '이',
#  '술잔',
#  '넌',
#  '이별',
#  '말',
#  '것',
#  '제발',
#  '마',
#  '마',
#  '거',
#  '이',
#  '술잔',
#  '너',
#  '혼자',
#  '끝',
#  '거',
#  '우리',
#  '왜',
#  '해',
#  '이',
#  '술잔',
#  '마',
#  '제발',
#  '하필',
#  '왜',
#  '이',
#  '포장마차',
#  '우리',
#  '매일',
#  '그',
#  '자리',
#  '왜',
#  '눈물',
#  '해',
#  '이',
#  '술잔',
#  '넌',
#  '이별',
#  '말',
#  '것',
#  '제발',
#  '마',
#  '마',
#  '거',
#  '이',
#  '술잔',
#  '너',
#  '혼자',
#  '끝',
#  '거',
#  '우리',
#  '왜',
#  '해',
#  '이',
#  '술잔',
#  '마',
#  '제발',
#  '이',
#  '한잔',
#  '술잔',
#  '난',
#  '너',
#  '수',
#  '이제',
#  '우린',
#  '남',
#  '이',
#  '술잔',
#  '이',
#  '한잔',
#  '거',
#  '라면',
#  '넌',
#  '사랑',
#  '말',
#  '안',
#  '그때',
#  '왜',
#  '날',
#  '왜',
#  '사랑',
#  '어차피',
#  '남',
#  '거',
#  '이',
#  '술잔',
#  '너',
#  '혼자',
#  '끝',
#  ...]

# %%
# 불용어 추가
# 실행해보면서 추가하면서 바꿔야함.
stop_words1 = ["손","고","준","것","첫","더","볼","위","것","게","겁","나","젠","거","줄",\
    "꾼", "거", "눈", "두", "짓", "엎", "물", "채", "뒤", "옆", "늘", "식이", "울", "해심", "척", "왜",\
          "해", "알", "이", "번", "때", "전", "걸", "롤", "굴지", "바", "적임", "수", "듯이", "래야", "쉬", "살", "자리"]
token_ko1 = [each_word for each_word in token_ko1 if each_word not in stop_words1]
print(token_ko1)
# Out:
# ['너', '봄바람', '입맞춤', '걸음', '내겐', '모두', '처음', '하루', '끝', '편지', '눈물', '벚꽃', '여름', '바다', '단풍', '함박눈', '처음', '사람', '내', '첫사랑', '너', '처음', '시간', '무뎌', '날', '그때', '아파해', '누군가', '세상', '누군가', '자랑', '너', '사람', '내', '첫사랑', '너', '처음', '시간', '널', '날', '그때', '아파해', '사실', '가도', '너', '추억', '처음', '처음', '고생', '너', '너', '시간', '추억', '네', '내', '처음', '분명', '꿈', '이별', '휴대폰', '확인', '다시', '이별', '헛웃음', '문득', '네', '얼굴', '눈물', '대체', '무슨', '난', '꼼짝', '못', '그', '이별', '넌', '사랑', '정말', '내', '여기', '네', '날', '그냥', '이별', '이건', '절대', '현실', '꿈', '부정', '이별', '눈물', '네', '이름', '움직', '못', '너', '외치', '그', '이별', '넌', '사랑', '정말', '내', '여기', '네', '날', '그냥', '꿈', '사랑', '이별', '현실', '알람', '하나', '번만', '기회', '다시', '내', '바보', '화가', '수가', '그', '이별', '이별', '정말', '가슴', '네', '날', '사람과', '평생', '사랑', '너', '평생', '너', '안', '이별', '내', '소식', '너', '사람', '넌', '얘길', '전해', '네', '좀', '걱정', '그녀', '자꾸', '네', '네', '안부', '날', '바랬는데', '사랑', '바랬는데', '못', '날', '너', '안부', '못', '그게', '지금', '여자친구', '내', '곁', '너', '기억', '하나', '놈', '고작', '너', '안부', '가슴', '눈물', '날', '바랬는데', '사랑', '바랬는데', '못', '날', '너', '안부', '못', '말', '너', '후회', '바랬어', '널', '사랑', '다시', '시작', '생각', '너', '안부', '우리', '이제', '너', '우린', '이별', '자꾸', '피', '정말', '끝', '우리', '사랑', '우리', '추억', '기억', '내', '끝', '끝', '네', '모습', '날', '이제', '너', '이별', '이제', '정말', '헤어', '가끔', '혼자', '몰래', '널', '그냥', '이별', '혹시', '그때', '서로', '조금', '이해', '우린', '조금', '이제', '내', '기적', '네', '모습', '날', '이제', '너', '이별', '이제', '정말', '헤어', '가끔', '혼자', '몰래', '널', '그냥', '이별', '우리', '최선', '여기', '수고', '널', '추억', '속', '우리', '그냥', '널', '우리', '이제', '정말', '이별', '혹시', '우리', '다시', '날', '그땐', '꼭', '말', '이제', '이제', '우리', '둘', '사이', '너', '맘', '널', '이제', '매일', '밤', '하루', '난', '수백', '고민', '너', '그날', '너', '얘기', '자꾸', '이면', '이번', '널', '이제', '우리', '둘', '사이', '네', '하루', '자꾸만', '내', '맘', '날', '하루', '난', '수백', '고민', '지금', '너', '얘기', '너', '이면', '이번', '널', '이제', '우리', '둘', '사이', '그날', '이제', '날', '시간', '속', '우린', '다른', '룰', '그', '순간', '우리', '둘', '사이', '안녕', '안녕', '이제', '인사', '너', '이별', '그게', '너', '일', '영활', '보고', '밥', '일도', '잡고', '거릴', '일도', '앞', '혼자', '란', '사실', '그게', '안녕', '내', '전부', '너', '사랑', '너', '난', '너', '사람', '날수', '사실', '사실', '너', '이별', '말', '조금', '순', '한번', '기횔', '순', '너', '난', '말', '기억', '마저', '안녕', '내', '전부', '너', '사랑', '너', '난', '너', '사람', '날수', '소리', '낼', '너', '제발', '말', '진심', '다해', '사랑', '말', '건', '난', '그냥', '미안', '내', '사랑', '작별', '슬픔', '속', '눈물', '내', '너', '우리', '헤어지자', '말', '한지', '하루', '잠깐', '실수', '깨달', '순간', '아침', '네', '목소리', '네', '품', '벌써', '내', '바보', '너', '내', '이제', '눈물', '내', '마음', '사랑', '항상', '너', '사람', '우리', '헤어지자', '말', '한지', '하루', '잠깐', '실수', '깨달', '순간', '아침', '네', '목소리', '네', '품', '벌써', '내', '바보', '너', '내', '이제', '눈물', '내', '마음', '작별인사', '안', '우리', '사랑', '그', '기억', '아침', '네', '목', '소린', '이제', '어제', '오늘', '널', '사랑', '바보', '너', '내', '이제', '눈물', '내', '마음', '너', '추억', '너', '기억', '남지', '네', '마음', '너', '기억', '모두', '널', '사랑', '기억', '낼', '난', '너', '곳', '사랑', '추억', '네', '기억', '가시', '모두', '널', '란', '너', '기억', '모두', '네', '마음', '너', '기억', '모두', '기억', '너', '추억', '너', '그리움', '모든', '순간', '너', '흔적', '너', '추억', '너', '기억', '남지', '네', '마음', '너', '기억', '모두', '너', '제발', '용서', '우리', '다시', '만날', '그때', '우리', '사랑', '미움', '몇번', '계절', '미련', '듬뿍', '하루', '친구', '통화', '니', '소식', '다른', '사랑', '시작', '땐', '사랑', '우리둘', '남', '사람', '넌', '넌', '괜', '걱정', '너', '내', '소식', '전해', '은', '좀', '마음', '가끔', '날', '생각', '내', '맘', '좀', '다른', '사람', '기적', '땐', '사랑', '우리둘', '남', '사람', '넌', '넌', '끝', '맘', '말', '사랑', '가슴', '바랬어', '너', '니', '모습', '이제야', '실감', '넌', '날', '난', '니', '사람', '다행', '말', '거짓말', '네', '소식', '그날', '밤', '펑펑', '다가', '밤', '한잔', '술', '숨', '좀', '제발', '마치', '주문', '매일', '넌', '내', '혼잣말', '친구', '통해', '네', '소식', '날', '만날', '너', '억지로', '밥', '친구', '술', '겨우', '날', '숨', '좀', '이제', '네', '얼굴', '너', '듣기', '네', '소식', '막상', '또', '이별', '너', '억지로', '밥', '친구', '술', '겨우', '날', '숨', '좀', '이제', '네', '얼굴', '너', '너', '밤', '혼자', '날', '가끔', '너', '철', '장난', '입', '꼬리', '그', '미소', '건', '널', '전부', '너', '사랑', '사람', '너', '오늘이', '널', '술잔', '너', '마음', '아무', '말', '안', '해도', '난', '수가', '오늘', '넌', '이별', '말', '하필', '포장마차', '우리', '처음', '눈물', '술잔', '넌', '이별', ...

# %%
# 상위 50개 단어 확인
# 이걸보면서 불용어 지우는게 편해 전체는 힘들어
ko1 = nltk.Text(token_ko1)
ko1.vocab().most_common(50)
# Out:
# [('너', 242),
#  ('사랑', 102),
#  ('내', 90),
#  ('네', 90),
#  ('이별', 72),
#  ('난', 68),
#  ('널', 62),
#  ('말', 60),
#  ('그', 58),
#  ('우리', 56),
#  ('날', 54),
#  ('이제', 46),
#  ('보고', 42),
#  ('끝', 38),
#  ('눈물', 38),
#  ('사람', 36),
#  ('넌', 36),
#  ('추억', 32),
#  ('기억', 32),
#  ('혼자', 32),
#  ('밤', 32),
#  ('못', 30),
#  ('하루', 26),
#  ('생각', 24),
#  ('맘', 24),
#  ('오늘', 24),
#  ('술잔', 22),
#  ('그대', 22),
#  ('모두', 20),
#  ('시간', 20),
#  ('다시', 20),
#  ('마', 20),
#  ('처음', 18),
#  ('정말', 18),
#  ('우린', 18),
#  ('순간', 18),
#  ('마음', 18),
#  ('모든', 18),
#  ('니', 18),
#  ('그때', 16),
#  ('지금', 16),
#  ('모습', 16),
#  ('사이', 16),
#  ('제발', 16),
#  ('품', 16),
#  ('또', 16),
#  ('내겐', 14),
#  ('혹시', 14),
#  ('이해', 14),
#  ('그날', 14)]

# %%
# 한글 폰트 문제 해결 
# matplotlib은 한글 폰트를 지원하지 않음
# os정보
import platform

# font_manager : 폰트 관리 모듈
# rc : 폰트 변경 모듈
from matplotlib import font_manager, rc
# unicode 설정
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic') # os가 macos
elif platform.system() == 'Windows':
    path = 'c:/Windows/Fonts/malgun.ttf' # os가 windows
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print("Unknown System")

# %%
# Warning무시
import warnings
warnings.filterwarnings('ignore')

# %%
# 상위 50개의 빈도수 차트 만들기
plt.figure(figsize=(12,6))
ko1.plot(50)
plt.show()

# %%
# 상위 50개만 wordcloud로 그리기
# 구한데이터로 그리기
data = ko1.vocab().most_common(50)

# 딕셔너리로 만들기
tmp_data1 = dict(data)

wordcloud1 = WordCloud(
    background_color='White',
    relative_scaling=0.8,
    font_path="AppleGothic" # 윈도우 => 'c:/Windows/Fonts/malgun.ttf'
).generate_from_frequencies(tmp_data1)

# %%
plt.figure(figsize=(16,8))
plt.imshow(wordcloud1, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# 동사 분리

for word in t.pos(document, stem=True):
    if
# Out:
# [('떨어질', 'Verb'),
#  ('줄', 'Noun'),
#  ('몰랐던', 'Verb'),
#  ('너', 'Noun'),
#  ('의', 'Josa'),
#  ('품도', 'Verb'),
#  ('잡은', 'Verb'),
#  ('손', 'Noun'),
#  ('에', 'Josa'),
#  ('스치던', 'Verb'),
#  ('봄바람', 'Noun'),
#  ('도', 'Josa'),
#  ('떨리던', 'Verb'),
#  ('입맞춤', 'Noun'),
#  ('도', 'Josa'),
#  ('맞춰', 'Verb'),
#  ('걷던', 'Verb'),
#  ('걸음', 'Noun'),
#  ('도', 'Josa'),
#  ('내겐', 'Noun'),
#  ('모두', 'Noun'),
#  ('처음', 'Noun'),
#  ('이라서', 'Josa'),
#  ('고', 'Noun'),
#  ('된', 'Verb'),
#  ('하루', 'Noun'),
#  ('끝', 'Noun'),
#  ('을', 'Josa'),
#  ('토닥여', 'Verb'),
#  ('준', 'Noun'),
#  ('것', 'Noun'),
#  ('도', 'Josa'),
#  ('작은', 'Adjective'),
#  ('편지', 'Noun'),
#  ('로', 'Josa'),
#  ('큰', 'Verb'),
#  ('눈물', 'Noun'),
#  ('을', 'Josa'),
#  ('준', 'Noun'),
#  ('것', 'Noun'),
#  ('도', 'Josa'),
#  ('벚꽃', 'Noun'),
#  ('과', 'Josa'),
#  ('여름', 'Noun'),
#  ('바다', 'Noun'),
#  ('단풍', 'Noun'),
#  ('과', 'Josa'),
#  ('함박눈', 'Noun'),
#  ('이', 'Josa'),
#  ('처음', 'Noun'),
#  ('이라서', 'Josa'),
#  ('힘든가', 'Adjective'),
#  ('봐', 'Verb'),
#  ('나', 'Noun'),
#  ('의', 'Josa'),
#  ('첫', 'Noun'),
#  ('사람', 'Noun'),
#  ('이', 'Josa'),
#  ('내', 'Noun'),
#  ('첫사랑', 'Noun'),
#  ('이', 'Josa'),
#  ('너', 'Noun'),
#  ('라서', 'Josa'),
#  ('처음', 'Noun'),
#  ('이라서', 'Josa'),
#  ('유난히', 'Adverb'),
#  ('아픈가', 'Adjective'),
#  ('봐', 'Verb'),
#  ('시간', 'Noun'),
#  ('이', 'Josa'),
#  ('지나면', 'Verb'),
#  ('다', 'Adverb'),
#  ('무뎌', 'Noun'),
#  ('지는', 'Josa'),
#  ('날', 'Noun'),
#  ('언젠가', 'Adverb'),
#  ('오겠지', 'Verb'),
#  ('그때', 'Noun'),
#  ('까지만', 'Josa'),
#  ('더', 'Noun'),
#  ('아파해', 'Noun'),
#  ('볼', 'Noun'),
#  ('게', 'Josa'),
#  ('누군가', 'Noun'),
#  ('를', 'Josa'),
#  ('위', 'Noun'),
#  ('한', 'Josa'),
#  ('노랠', 'Adjective'),
#  ('부른', 'Verb'),
#  ('것', 'Noun'),
#  ('도', 'Josa'),
#  ('세상', 'Noun'),
#  ('에', 'Josa'),
#  ('누군가', 'Noun'),
#  ('를', 'Josa'),
#  ('자랑', 'Noun'),
#  ('한', 'Josa'),
#  ('것', 'Noun'),
#  ('도', 'Josa'),
#  ('너', 'Noun'),
#  ('를', 'Josa'),
#  ('떠올리는', 'Verb'),
#  ('게', 'Noun'),
#  ('나를', 'Verb'),
#  ('떠올리는', 'Verb'),
#  ('일이', 'Modifier'),
#  ('되는', 'Verb'),
#  ('게', 'Noun'),
#  ('익숙해져', 'Verb'),
#  ('버려서', 'Verb'),
#  ('나', 'Noun'),
#  ('의', 'Josa'),
#  ('첫', 'Noun'),
#  ('사람', 'Noun'),
#  ('이', 'Josa'),
#  ('내', 'Noun'),
#  ('첫사랑', 'Noun'),
#  ('이', 'Josa'),
#  ('너', 'Noun'),
#  ('라서', 'Josa'),
#  ('처음', 'Noun'),
#  ('이라서', 'Josa'),
#  ('유난히', 'Adverb'),
#  ('아픈가', 'Adjective'),
#  ('봐', 'Verb'),
#  ('시간', 'Noun'),
#  ('이', 'Josa'),
#  ('지나면', 'Verb'),
#  ('널', 'Noun'),
#  ('보며', 'Verb'),
#  ('웃는', 'Verb'),
#  ('날', 'Noun'),
#  ('언젠가', 'Adverb'),
#  ('오겠지', 'Verb'),
#  ('그때', 'Noun'),
#  ('까지만', 'Josa'),
#  ('더', 'Noun'),
#  ('아파해', 'Noun'),
#  ('볼', 'Noun'),
#  ('게', 'Josa'),
#  ('사실', 'Noun'),
#  ('은', 'Josa'),
#  ('겁', 'Noun'),
#  ('이', 'Josa'),
#  ('나', 'Noun'),
#  ('이', 'Determiner'),
#  ('젠', 'Noun'),
#  ('어딜', 'Adverb'),
#  ('가도', 'Noun'),
#  ('너', 'Noun'),
#  ('와의', 'Josa'),
#  ('추억', 'Noun'),
#  ('만', 'Josa'),
#  ('있을까', 'Adjective'),
#  ('봐', 'Verb'),
#  ('그래도', 'Adverb'),
#  ('처음', 'Noun'),
#  ('이라', 'Josa'),
#  ('힘든', 'Adjective'),
#  ('거', 'Noun'),
#  ('니까', 'Josa'),
#  ('더', 'Noun'),
#  ('아픈', 'Adjective'),
#  ('거', 'Noun'),
#  ('니까', 'Josa'),
#  ('처음', 'Noun'),
#  ('엔', 'Josa'),
#  ('다', 'Adverb'),
#  ('그런', 'Adjective'),
#  ('거', 'Noun'),
#  ('니까', 'Josa'),
#  ('고생', 'Noun'),
#  ('했어', 'Verb'),
#  ('많이', 'Adverb'),
#  ('행복했었어', 'Adjective'),
#  ('너', 'Noun'),
#  ('라서', 'Josa'),
#  ('다', 'Adverb'),
#  ('너', 'Noun'),
#  ('라서', 'Josa'),
#  ('유난히', 'Adverb'),
#  ('좋았나', 'Adjective'),
#  ('봐', 'Verb'),
#  ('시간', 'Noun'),
#  ('이', 'Josa'),
#  ('지나면', 'Verb'),
#  ('먼', 'Adjective'),
#  ('추억', 'Noun'),
#  ('이', 'Josa'),
#  ('되어', 'Verb'),
#  ('언', 'Modifier'),
#  ('젠', 'Noun'),
#  ('간', 'Suffix'),
#  ('웃겠지', 'Verb'),
#  ('참', 'Verb'),
#  ('좋았어', 'Adjective'),
#  ('네', 'Noun'),
#  ('가', 'Josa'),
#  ('내', 'Noun'),
#  ('처음', 'Noun'),
#  ('이라서', 'Josa'),
#  ('분명', 'Noun'),
#  ('나', 'Noun'),
#  ('는', 'Josa'),
#  ('꿈', 'Noun'),
#  ('을', 'Josa'),
#  ('꾼', 'Noun'),
#  ('거', 'Noun'),
#  ('다', 'Josa'),
#  ('눈', 'Noun'),
#  ('떠보니', 'Verb'),
#  ('이별', 'Noun'),
#  ('이', 'Josa'),
#  ('더', 'Noun'),
#  ('라', 'Josa'),
#  ('휴대폰', 'Noun'),
#  ('을', 'Josa'),
#  ('확인', 'Noun'),
#  ('해', 'Verb'),
#  ('봤더니', 'Verb'),
#  ('다시', 'Noun'),
#  ('봐도', 'Verb'),
#  ('이별', 'Noun'),
#  ('이', 'Josa'),
#  ('더', 'Noun'),
#  ('라', 'Josa'),
#  ('헛웃음', 'Noun'),
#  ('만', 'Josa'),
#  ('흘러나왔고', 'Verb'),
#  ('두', 'Noun'),
#  ('다리는', 'Verb'),
#  ('풀려', 'Verb'),
#  ('버렸고', 'Verb'),
#  ('문득', 'Noun'),
#  ('스친', 'Verb'),
#  ('네', 'Noun'),
#  ('얼굴', 'Noun'),
#  ('생각나', 'Verb'),
#  ('눈물', 'Noun'),
#  ('이', 'Josa'),
#  ('하염없이', 'Adverb'),
#  ('쏟아지는데', 'Verb'),
#  ('대체', 'Noun'),
#  ('무슨', 'Noun'),
#  ('짓', 'Noun'),
#  ('을', 'Josa'),
#  ('한', 'Verb'),
#  ('건데', 'Eomi'),
#  ('엎', 'Noun'),
#  ('질러진', 'Verb'),
#  ('물', 'Noun'),
#  ('에', 'Josa'),
#  ('난', 'Noun'),
#  ('젖은', 'Verb'),
#  ('채', 'Noun'),
#  ('로', 'Josa'),
#  ('꼼짝', 'Noun'),
#  ('못', 'Noun'),
#  ('하고', 'Josa'),
#  ('그', 'Noun'),
#  ('수많은', 'Adjective'),
#  ('이별', 'Noun'),
#  ('뒤', 'Noun'),
#  ('에도', 'Josa'),
#  ('넌', 'Noun'),
#  ('분명히', 'Adjective'),
#  ('사랑', 'Noun'),
#  ('이었다', 'Verb'),
#  ('정말', 'Noun'),
#  ('내', 'Noun'),
#  ('옆', 'Noun'),
#  ('에', 'Josa'),
#  ('있었잖아', 'Adjective'),
#  ('늘', 'Noun'),
#  ('여기', 'Noun'),
#  ('있었잖아', 'Adjective'),
#  ('네', 'Noun'),
#  ('가', 'Josa'),
#  ('날', 'Noun'),
#  ('떠나가면', 'Verb'),
#  ('그냥', 'Noun'),
#  ('가버리면', 'Verb'),
#  ('이런', 'Adjective'),
#  ('식이', 'Noun'),
#  ('면', 'Josa'),
#  ('나', 'Noun'),
#  ('곤란한데', 'Adjective'),
#  ('눈', 'Noun'),
#  ('떠보니', 'Verb'),
#  ('이별', 'Noun'),
#  ('이', 'Josa'),
#  ('더', 'Noun'),
#  ('라', 'Josa'),
#  ('이건', 'Noun'),
#  ('절대', 'Noun'),
#  ('현실', 'Noun'),
#  ('이', 'Josa'),
#  ('아니야', 'Adjective'),
#  ('눈', 'Noun'),
#  ('감으면', 'Verb'),
#  ('꿈', 'Noun'),
#  ('이', 'Josa'),
#  ('될', 'Verb'),
#  ('거야', 'Eomi'),
#  ('애써', 'Verb'),
#  ('부정', 'Noun'),
#  ('해봐도', 'Verb'),
#  ('이별', 'Noun'),
#  ('이', 'Josa'),
#  ('맞잖아', 'Verb'),
#  ('눈물', 'Noun'),
#  ('마저', 'Josa'),
#  ('말라', 'Adjective'),
#  ('버리고', 'Verb'),
#  ('네', 'Noun'),
#  ('이름', 'Noun'),
#  ('만', 'Josa'),
#  ('중얼거리고', 'Verb'),
#  ('움직', 'Noun'),
#  ('이지', 'Josa'),
#  ('못', 'Noun'),
#  ('하고', 'Josa'),
#  ('웅크린', 'Verb'),
#  ('채', 'Noun'),
#  ('너', 'Noun'),
#  ('만', 'Josa'),
#  ('외치', 'Noun'),
#  ('고', 'Josa'),
#  ('그', 'Noun'),
#  ('수많은', 'Adjective'),
#  ('이별', 'Noun'),
#  ('뒤', 'Noun'),
#  ('에도', 'Josa'),
#  ('넌', 'Noun'),
#  ('분명히', 'Adjective'),
#  ('사랑', 'Noun'),
#  ('이었다', 'Verb'),
#  ('정말', 'Noun'),
#  ('내', 'Noun'),
#  ('옆', 'Noun'),
#  ('에', 'Josa'),
#  ('있었잖아', 'Adjective'),
#  ('늘', 'Noun'),
#  ('여기', 'Noun'),
#  ('있었잖아', 'Adjective'),
#  ('네', 'Noun'),
#  ('가', 'Josa'),
#  ('날', 'Noun'),
#  ('떠나가면', 'Verb'),
#  ('그냥', 'Noun'),
#  ('가버리면', 'Verb'),
#  ('이런', 'Adjective'),
#  ('식이', 'Noun'),
#  ('면', 'Josa'),
#  ('나', 'Noun'),
#  ('곤란한데', 'Adjective'),
#  ('꿈', 'Noun'),
#  ('만', 'Josa'),
#  ('같던', 'Adjective'),
#  ('사랑', 'Noun'),
#  ('도', 'Josa'),
#  ('다', 'Adverb'),
#  ('이별', 'Noun'),
#  ('하면', 'Verb'),
#  ('현실', 'Noun'),
#  ('이야', 'Josa'),
#  ('알람', 'Noun'),
#  ('하나', 'Noun'),
#  ('없이', 'Adverb'),
#  ('깨어나', 'Verb'),
#  ('한', 'Verb'),
#  ('번만', 'Noun'),
#  ('더', 'Noun'),
#  ('기회', 'Noun'),
#  ('를', 'Josa'),
#  ('줘', 'Verb'),
#  ('다시', 'Noun'),
#  ('하면', 'Verb'),
#  ('잘', 'VerbPrefix'),
#  ('할', 'Verb'),
#  ('텐데', 'Eomi'),
#  ('내', 'Noun'),
#  ('가', 'Josa'),
#  ('바보', 'Noun'),
#  ('같아', 'Adjective'),
#  ('화가', 'Noun'),
#  ('나', 'Noun'),
#  ('참을', 'Verb'),
#  ('수가', 'Noun'),
#  ('없다', 'Adjective'),
#  ('그', 'Noun'),
#  ('수많은', 'Adjective'),
#  ('이별', 'Noun'),
#  ('뒤', 'Noun'),
#  ('에도', 'Josa'),
#  ('당연하게', 'Adjective'),
#  ('이별', 'Noun'),
#  ('이', 'Josa'),
#  ('온다', 'Verb'),
#  ('정말', 'Noun'),
#  ('가슴', 'Noun'),
#  ('을', 'Josa'),
#  ('찢어', 'Verb'),
#  ('놔도', 'Verb'),
#  ('네', 'Noun'),
#  ('가', 'Josa'),
#  ('날', 'Noun'),
#  ('짓', 'VerbPrefix'),
#  ('밟아도', 'Verb'),
#  ('나', 'Noun'),
#  ('아닌', 'Adjective'),
#  ('딴', 'Verb'),
#  ('사람과', 'Noun'),
#  ('평생', 'Noun'),
#  ('사랑', 'Noun'),
#  ('해도', 'Verb'),
#  ('나', 'Noun'),
#  ('는', 'Josa'),
#  ('너', 'Noun'),
#  ('아니면', 'Adjective'),
#  ('곤란한데', 'Adjective'),
#  ('평생', 'Noun'),
#  ('나', 'Noun'),
#  ('는', 'Josa'),
#  ('너', 'Noun'),
#  ('아니면', 'Adjective'),
#  ('안', 'Noun'),
#  ('되는데', 'Verb'),
#  ('눈', 'Noun'),
#  ('떠보니', 'Verb'),
#  ('이별', 'Noun'),
#  ('이', 'Josa'),
#  ('더', 'Noun'),
#  ('라', 'Josa'),
#  ('내', 'Noun'),
#  ('소식', 'Noun'),
#  ('들었지', 'Verb'),
#  ('너', 'Noun'),
#  ('와', 'Josa'),
#  ('헤어지고', 'Verb'),
#  ('참', 'Verb'),
#  ('많이', 'Adverb'),
#  ('울', 'Noun'),
#  ('고', 'Josa'),
#  ('힘들게', 'Adjective'),
#  ('버티다', 'Verb'),
#  ('이', 'Determiner'),
#  ('해심', 'Noun'),
#  ('이', 'Josa'),
#  ('많은', 'Adjective'),
#  ('좋은', 'Adjective'),
#  ('사람', 'Noun'),
#  ('을', 'Josa'),
#  ('만나서', 'Verb'),
#  ('나', 'Noun'),
#  ('는', 'Josa'),
#  ('잘', 'Verb'),
#  ('지내고', 'Verb'),
#  ('있어', 'Adjective'),
#  ('그런데', 'Conjunction'),
#  ('이상해', 'Adjective'),
#  ('아직', 'Adverb'),
#  ('넌', 'Noun'),
#  ('힘들어', 'Adjective'),
#  ('한다는', 'Modifier'),
#  ('얘길', 'Noun'),
#  ('전해', 'Noun'),
#  ('들으니', 'Verb'),
#  ('네', 'Noun'),
#  ('가', 'Josa'),
#  ('좀', 'Noun'),
#  ('걱정', 'Noun'),
#  ('돼', 'Verb'),
#  ('그녀', 'Noun'),
#  ('에게', 'Josa'),
#  ('미안하지만', 'Adjective'),
#  ('자꾸', 'Noun'),
#  ('네', 'Noun'),
#  ('가', 'Josa'),
#  ('생각나', 'Verb'),
#  ('어떻게', 'Adjective'),
#  ('지내', 'Verb'),
#  ('네', 'Noun'),
#  ('안부', 'Noun'),
#  ('참', 'Verb'),
#  ('궁금한데', 'Adjective'),
#  ('날', 'Noun'),
#  ('잊고', 'Verb'),
#  ('행복하길', 'Adjective'),
#  ('바랬는데', 'Noun'),
#  ('예쁜', 'Adjective'),
#  ('사랑', 'Noun'),
#  ('하기를', 'Verb'),
#  ('바랬는데', 'Noun'),
#  ('잘해주지', 'Verb'),
#  ('못', 'Noun'),
#  ('한', 'Josa'),
#  ('날', 'Noun'),
#  ('왜', 'Noun'),
#  ('잊지', 'Verb'),
#  ('못', 'VerbPrefix'),
#  ('하니', 'Verb'),
#  ('들려오는', 'Verb'),
#  ('너', 'Noun'),
#  ('의', 'Josa'),
#  ('안부', 'Noun'),
#  ('못', 'Noun'),
#  ('들은', 'Verb'),
#  ('척', 'Noun'),
#  ('지나갈', 'Verb'),
#  ('걸', 'Noun'),
#  ('그게', 'Noun'),
#  ('안', 'VerbPrefix'),
#  ('돼', 'Verb'),
#  ('지금', 'Noun'),
#  ('여자친구', 'Noun'),
#  ('힘들', 'Adjective'),
#  ('때', 'Noun'),
#  ('내', 'Noun'),
#  ('곁', 'Noun'),
#  ('으로', 'Josa'),
#  ('와', 'Verb'),
#  ('너', 'Noun'),
#  ('의', 'Josa'),
#  ('기억', 'Noun'),
#  ('을', 'Josa'),
#  ('하나', 'Noun'),
#  ('씩', 'Suffix'),
#  ('지워', 'Verb'),
#  ('줬어', 'Verb'),
#  ('고맙게', 'Adjective'),
#  ('나', 'Noun'),
#  ('는', 'Josa'),
#  ('나쁜', 'Adjective'),
#  ('놈', 'Noun'),
#  ('인', 'Josa'),
#  ('가봐', 'Verb'),
#  ('고작', 'Noun'),
#  ('너', 'Noun'),
#  ('의', 'Josa'),
#  ('안부', 'Noun'),
#  ('에', 'Josa'),
#  ('가슴', 'Noun'),
#  ('이', 'Josa'),
#  ('뛰고', 'Verb'),
#  ('왜', 'Noun'),
#  ('눈물', 'Noun'),
#  ('이', 'Josa'),
#  ('나', 'Noun'),
#  ('는', 'Josa'),
#  ('건데', 'Eomi'),
#  ('날', 'Noun'),
#  ('잊고', 'Verb'),
#  ('행복하길', 'Adjective'),
#  ('바랬는데', 'Noun'),
#  ('예쁜', 'Adjective'),
#  ('사랑', 'Noun'),
#  ('하기를', 'Verb'),
#  ('바랬는데', 'Noun'),
#  ('잘해주지', 'Verb'),
#  ('못', 'Noun'),
#  ('한', 'Josa'),
#  ('날', 'Noun'),
#  ('왜', 'Noun'),
#  ('잊지', 'Verb'),
#  ('못', 'VerbPrefix'),
#  ('하니', 'Verb'),
#  ('들려오는', 'Verb'),
#  ('너', 'Noun'),
#  ('의', 'Josa'),
#  ('안부', 'Noun'),
#  ('못', 'Noun'),
#  ('들은', 'Verb'),
#  ('척', 'Noun'),
#  ('지나갈', 'Verb'),
#  ('걸', 'Noun'),
#  ('헤어짐을', 'Verb'),
#  ('말', 'Noun'),
#  ('한', 'Josa'),
#  ('너', 'Noun'),
#  ('를', 'Josa'),
#  ('미워도', 'Verb'),
#  ('하고', 'Verb'),
#  ('후회', 'Noun'),
#  ('하며', 'Verb'),
#  ('지내기를', 'Verb'),
#  ('바랬어', 'Noun'),
#  ('널', 'Noun'),
#  ('잊고', 'Verb'),
#  ('행복하게', 'Adjective'),
#  ('잘', 'Verb'),
#  ('살았는데', 'Verb'),
#  ('예쁜', 'Adjective'),
#  ('사랑', 'Noun'),
#  ('다시', 'Noun'),
#  ('시작', 'Noun'),
#  ('했는데', 'Verb'),
#  ('다', 'Adverb'),
#  ('잊었다', 'Verb'),
#  ('생각', 'Noun'),
#  ('하고', 'Josa'),
#  ('지내', 'Verb'),
#  ('왔는데', 'Verb'),
#  ('들려오는', 'Verb'),
#  ('너', 'Noun'),
#  ('의', 'Josa'),
#  ('안부', 'Noun'),
#  ('에', 'Josa'),
#  ('결국', 'Adverb'),
#  ('무너졌어', 'Verb'),
#  ('우리', 'Noun'),
#  ('이제', 'Noun'),
#  ('헤어지기로', 'Verb'),
#  ('해', 'Noun'),
#  ('너', 'Noun'),
#  ('도', 'Josa'),
#  ('알잖아', 'Verb'),
#  ('우린', 'Noun'),
#  ('충분했다는걸', 'Adjective'),
#  ('이별', 'Noun'),
#  ('이', 'Josa'),
#  ('무서워', 'Adjective'),
#  ('자꾸', 'Noun'),
#  ('피', 'Noun'),
#  ('해보지만', 'Verb'),
#  ('이', 'Determiner'),
#  ('젠', 'Noun'),
#  ('정말', 'Noun'),
#  ('끝', 'Noun'),
#  ('인걸', 'Josa'),
#  ('우리', 'Noun'),
#  ('사랑', 'Noun'),
#  ('이', 'Josa'),
#  ('우리', 'Noun'),
#  ('추억', 'Noun'),
#  ('이', 'Josa'),
#  ('이', 'Determiner'),
#  ('젠', 'Noun'),
#  ('끝나가지만', 'Verb'),
#  ('함께한', 'Verb'),
#  ('기억', 'Noun'),
#  ('은', 'Josa'),
#  ('내', 'Noun'),
#  ('가', 'Josa'),
#  ('다', 'Adverb'),
#  ('가져갈게', 'Verb'),
#  ('끝', 'Noun'),
#  ('이란', 'Josa'),
#  ('걸', 'Noun'),
#  ('알', 'Noun'),
#  ('지만', 'Josa'),
#  ('끝', 'Noun'),
#  ('이라고', 'Josa'),
#  ('안', 'VerbPrefix'),
#  ('할게', 'Verb'),
#  ('내', 'Determiner'),
#  ('눈', 'Noun'),
#  ('에', 'Josa'),
#  ('비친', 'Verb'),
#  ('네', 'Noun'),
#  ('모습', 'Noun'),
#  ('이', 'Josa'),
#  ('날', 'Noun'),
#  ('나쁘게', 'Adjective'),
#  ('만들어', 'Verb'),
#  ('나', 'Noun'),
#  ('이제', 'Noun'),
#  ('너', 'Noun'),
#  ('와', 'Josa'),
#  ('서툰', 'Adjective'),
#  ('이별', 'Noun'),
#  ('을', 'Josa'),
#  ('하려해', 'Verb'),
#  ('많이', 'Adverb'),
#  ('아프겠지만', 'Adjective'),
#  ('이제', 'Noun'),
#  ('정말', 'Noun'),
#  ('헤어', 'Noun'),
#  ('지려해', 'Verb'),
#  ('가끔', 'Noun'),
#  ('혼자', 'Noun'),
#  ('견디기', 'Verb'),
#  ('힘들어', 'Adjective'),
#  ('나도', 'Verb'),
#  ('몰래', 'Noun'),
#  ('널', 'Noun'),
#  ('부르게', 'Verb'),
#  ('되면', 'Verb'),
#  ('그냥', 'Noun'),
#  ('지나쳐줘', 'Verb'),
#  ('서툰', 'Adjective'),
#  ('이별', 'Noun'),
#  ('이라서', 'Josa'),
#  ('그래', 'Adjective'),
#  ('혹시', 'Noun'),
#  ('그때', 'Noun'),
#  ('의', 'Josa'),
#  ('서로', 'Noun'),
#  ('를', 'Josa'),
#  ('조금', 'Noun'),
#  ('더', 'Noun'),
#  ('이해', 'Noun'),
#  ('했더라면', 'Verb'),
#  ('우린', 'Noun'),
#  ('조금', 'Noun'),
#  ('은', 'Josa'),
#  ('달라졌을까', 'Verb'),
#  ('이제', 'Noun'),
#  ('와', 'Josa'),
#  ('서', 'Verb'),
#  ('이러는', 'Verb'),
#  ('내', 'Noun'),
#  ('가', 'Josa'),
#  ('너무', 'Adverb'),
#  ('이', 'Determiner'),
#  ('기적', 'Noun'),
#  ('인가', 'Josa'),
#  ('봐', 'Verb'),
#  ('내', 'Determiner'),
#  ('눈', 'Noun'),
#  ('에', 'Josa'),
#  ('비친', 'Verb'),
#  ('네', 'Noun'),
#  ('모습', 'Noun'),
#  ('이', 'Josa'),
#  ('날', 'Noun'),
#  ('나쁘게', 'Adjective'),
#  ('만들어', 'Verb'),
#  ('나', 'Noun'),
#  ('이제', 'Noun'),
#  ('너', 'Noun'),
#  ('와', 'Josa'),
#  ('서툰', 'Adjective'),
#  ('이별', 'Noun'),
#  ('을', 'Josa'),
#  ('하려해', 'Verb'),
#  ('많이', 'Adverb'),
#  ('아프겠지만', 'Adjective'),
#  ('이제', 'Noun'),
#  ('정말', 'Noun'),
#  ('헤어', 'Noun'),
#  ('지려해', 'Verb'),
#  ('가끔', 'Noun'),
#  ('혼자', 'Noun'),
#  ('견디기', 'Verb'),
#  ('힘들어', 'Adjective'),
#  ('나도', 'Verb'),
#  ('몰래', 'Noun'),
#  ('널', 'Noun'),
#  ('부르게', 'Verb'),
#  ('되면', 'Verb'),
#  ('그냥', 'Noun'),
#  ('지나쳐줘', 'Verb'),
#  ('서툰', 'Adjective'),
#  ('이별', 'Noun'),
#  ('이라서', 'Josa'),
#  ('그래', 'Adjective'),
#  ('우리', 'Noun'),
#  ('의', 'Josa'),
#  ('최선', 'Noun'),
#  ('은', 'Josa'),
#  ('여기', 'Noun'),
#  ('까지', 'Josa'),
#  ('인거', 'Josa'),
#  ('같아', 'Adjective'),
#  ('수고', 'Noun'),
#  ('많았어', 'Adjective'),
#  ('이', 'Determiner'),
#  ('젠', 'Noun'),
#  ('널', 'Noun'),
#  ('보낼게', 'Verb'),
#  ('같은', 'Adjective'),
#  ('추억', 'Noun'),
#  ('속', 'Noun'),
#  ('에', 'Josa'),
#  ('우리', 'Noun'),
#  ('를', 'Josa'),
#  ('이', 'Determiner'),
#  ('젠', 'Noun'),
#  ('보내줘야해', 'Verb'),
#  ('애써', 'Verb'),
#  ('그냥', 'Noun'),
#  ('웃으며', 'Verb'),
#  ('아무렇지', 'Adjective'),
#  ('않게', 'Verb'),
#  ('널', 'Noun'),
#  ('보낼게', 'Verb'),
#  ('우리', 'Noun'),
#  ('이제', 'Noun'),
#  ('정말', 'Noun'),
#  ('이별', 'Noun'),
#  ('을', 'Josa'),
#  ('하려해', 'Verb'),
#  ('많이', 'Adverb'),
#  ('아프겠지만', 'Adjective'),
#  ('많이', 'Adverb'),
#  ('힘들겠지만', 'Adjective'),
#  ('혹시', 'Noun'),
#  ('우리', 'Noun'),
#  ('가', 'Josa'),
#  ('다시', 'Noun'),
#  ('만나게', 'Verb'),
#  ('되는', 'Verb'),
#  ('날', 'Noun'),
#  ('이', 'Josa'),
#  ('다가오면', 'Verb'),
#  ('그땐', 'Noun'),
#  ('꼭', 'Noun'),
#  ('안아줘', 'Verb'),
#  ('많이', 'Adverb'),
#  ('보고싶었다고', 'Verb'),
#  ('말', 'Noun'),
#  ('해줘', 'Verb'),
#  ('Forget', 'Alpha'),
#  ('me', 'Alpha'),
#  ('close', 'Alpha'),
#  ('your', 'Alpha'),
#  ('eyes', 'Alpha'),
#  ('Forget', 'Alpha'),
#  ('me', 'Alpha'),
#  ('close', 'Alpha'),
#  ('your', 'Alpha'),
#  ('eyes', 'Alpha'),
#  ('돌아보지', 'Verb'),
#  ('않을', 'Verb'),
#  ('거야', 'Eomi'),
#  ('나', 'Noun'),
#  ('이제', 'Noun'),
#  ('Forget', 'Alpha'),
#  ('me', 'Alpha'),
#  ('close', 'Alpha'),
#  ('your', 'Alpha'),
#  ('eyes', 'Alpha'),
#  ('Forget', 'Alpha'),
#  ('me', 'Alpha'),
#  ('close', 'Alpha'),
#  ('your', 'Alpha'),
#  ('eyes', 'Alpha'),
#  ('돌아보지', 'Verb'),
#  ('않을', 'Verb'),
#  ('거야', 'Eomi'),
#  ('나', 'Noun'),
#  ('이제', 'Noun'),
#  ('Forget', 'Alpha'),
#  ('me', 'Alpha'),
#  ('close', 'Alpha'),
#  ('your', 'Alpha'),
#  ('eyes', 'Alpha'),
#  ('Forget', 'Alpha'),
#  ('me', 'Alpha'),
#  ('close', 'Alpha'),
#  ('your', 'Alpha'),
#  ('eyes', 'Alpha'),
#  ('woo', 'Alpha'),
#  ('leak', 'Alpha'),
#  ('out', 'Alpha'),
#  ('우리', 'Noun'),
#  ('둘', 'Noun'),
#  ('사이', 'Noun'),
#  ('로', 'Josa'),
#  ('아무렇지', 'Adjective'),
#  ('않을', 'Verb'),
#  ('너', 'Noun'),
#  ('는', 'Josa'),
#  ('이', 'Noun'),
#  ('맘', 'Noun'),
#  ('알', 'Noun'),
#  ('고', 'Josa'),
#  ('있을까', 'Adjective'),
#  ('두려워', 'Adjective'),
#  ('널', 'Noun'),
#  ('보낼', 'Verb'),
#  ('때', 'Noun'),
#  ('가', 'Josa'),
#  ('돼', 'Verb'),
#  ('버린', 'Verb'),
#  ('걸까', 'Verb'),
#  ('이제', 'Noun'),
#  ('매일', 'Noun'),
#  ('헤매이는', 'Verb'),
#  ('밤', 'Noun'),
#  ('잠들', 'Verb'),
#  ('때', 'Noun'),
#  ('마다', 'Josa'),
#  ('미워지지만', 'Verb'),
#  ('괜찮아', 'Adjective'),
#  ('하루', 'Noun'),
#  ('에도', 'Josa'),
#  ('난', 'Noun'),
#  ('수백', 'Noun'),
#  ('번', 'Noun'),
#  ('고민', 'Noun'),
#  ('해', 'Verb'),
#  ('너', 'Noun'),
#  ('없을', 'Adjective'),
#  ('때', 'Noun'),
#  ('에도', 'Josa'),
#  ('그날', 'Noun'),
#  ('너', 'Noun'),
#  ('에게', 'Josa'),
#  ('전', 'Noun'),
#  ('할', 'Verb'),
#  ('얘기', 'Noun'),
#  ('가', 'Josa'),
#  ('나를', 'Verb'),
#  ('자꾸', 'Noun'),
#  ('괴롭히는', 'Verb'),
#  ('걸', 'Noun'),
#  ('내', 'Determiner'),
#  ('일', 'Modifier'),
#  ('이면', 'Noun'),
#  ('다', 'Adverb'),
#  ('지워', 'Verb'),
#  ('버려야지', 'Verb'),
#  ('이', 'Determiner'),
#  ('젠', 'Noun'),
#  ('이번', 'Noun'),
#  ('에는', 'Josa'),
#  ('널', 'Noun'),
#  ('다', 'Adverb'),
#  ('잊을', 'Verb'),
#  ('수', 'Noun'),
#  ('있을까', 'Adjective'),
#  ('Forget', 'Alpha'),
#  ('me', 'Alpha'),
#  ('close', 'Alpha'),
#  ('your', 'Alpha'),
#  ('eyes', 'Alpha'),
#  ('Forget', 'Alpha'),
#  ('me', 'Alpha'),
#  ('close', 'Alpha'),
#  ('your', 'Alpha'),
#  ('eyes', 'Alpha'),
#  ('돌아보지', 'Verb'),
#  ('않을거야', 'Verb'),
#  ('나', 'Noun'),
#  ('이제', 'Noun'),
#  ('Forget', 'Alpha'),
#  ('me', 'Alpha'),
#  ('close', 'Alpha'),
#  ('your', 'Alpha'),
#  ('eyes', 'Alpha'),
#  ('Forget', 'Alpha'),
#  ('me', 'Alpha'),
#  ('close', 'Alpha'),
#  ('your', 'Alpha'),
#  ('eyes', 'Alpha'),
#  ('woo', 'Alpha'),
#  ('leak', 'Alpha'),
#  ('out', 'Alpha'),
#  ('우리', 'Noun'),
#  ('둘', 'Noun'),
#  ('사이', 'Noun'),
#  ('로', 'Josa'),
#  ('네', 'Noun'),
#  ('가', 'Josa'),
#  ('없는', 'Adjective'),
#  ('나', 'Noun'),
#  ('의', 'Josa'),
#  ('하루', 'Noun'),
#  ('는', 'Josa'),
#  ('어떨진', 'Adjective'),
#  ('몰라', 'Verb'),
#  ('근데', 'Adverb'),
#  ('자꾸만', 'Noun'),
#  ('내', 'Noun'),
#  ('맘', 'Noun'),
#  ('이', 'Josa'),
#  ('조금씩', 'Adverb'),
#  ('나도', 'Verb'),
#  ('모르게', 'Verb'),
#  ('흘러가는', 'Verb'),
#  ('걸', 'Noun'),
#  ('그저', 'Adverb'),
#  ('서', 'Modifier'),
#  ('롤', 'Noun'),
#  ('힘들게', 'Adjective'),
#  ('굴지', 'Noun'),
#  ('않아도', 'Verb'),
#  ('되는', 'Verb'),
#  ('날', 'Noun'),
#  ('에', 'Josa'),
#  ('행복하길', 'Adjective'),
#  ('바', 'Noun'),
#  ('래', 'Josa'),
#  ('하루', 'Noun'),
#  ('에도', 'Josa'),
#  ('난', 'Noun'),
#  ('수백', 'Noun'),
#  ('번', 'Noun'),
#  ('고민', 'Noun'),
#  ('해', 'Verb'),
#  ('같이', 'Adverb'),
#  ('있을', 'Adjective'),
#  ('때', 'Noun'),
#  ('에도', 'Josa'),
#  ('지금', 'Noun'),
#  ('너', 'Noun'),
#  ('에게', 'Josa'),
#  ('전', 'Noun'),
#  ...]
