# %% [markdown]
# ---
# ## ballad_sad에서 20개 데이터 추출하기

# %%
import pandas as pd
import numpy as np
import random

# %%
sad = pd.read_csv("../../Data/ballad_sad.csv")
len(sad)
# Out:
# 30

# %%
index_list = range(0,30)

# %%
index = random.sample(index_list,20)
index
# Out:
# [9, 25, 6, 21, 29, 28, 23, 1, 2, 7, 0, 26, 5, 4, 11, 22, 13, 27, 24, 19]

# %%
sad20 = sad.iloc[index,:]

# %%
sad20.reset_index(drop=True,inplace=True)

# %%
sad20.to_csv("../../Data/ballad_sad20.csv",index=False)

# %%
sad20 = pd.read_csv("../../Data/ballad_sad20.csv")
sad20
# Out:
#             가수명                     노래제목         발매일  \
# 0           강고은      같은 시간 속 우린 여기까지인 거야  2021-07-24
# 1        스웨덴세탁소                우리가 있던 시간  2012-09-07
# 2    펀치 (Punch)              Done For Me  2019-08-18
# 3           다비치  마치 우린 없었던 사이 (Prod. 정키)  2018-07-12
# 4   윤하 (YOUNHA)                 오늘 헤어졌어요  2009-12-11
# 5           아이유               나만 몰랐던 이야기  2011-02-17
# 6           권진아                    이별 뒷면  2018-02-02
# 7           주보라      네가 없다 (Without You)  2013-02-19
# 8   헤이즈 (Heize)          비가 오는 날엔 (2021)  2021-08-04
# 9    펀치 (Punch)                   이 밤의 끝  2018-05-31
# 10        V.O.S                  잘 살고 있다  2019-12-02
# 11    강민경 (다비치)                  사랑해서 그래  2019-02-27
# 12   펀치 (Punch)              안녕 내 전부였던 너  2021-03-10
# 13    나비 (Navi)                  잘 된 일이야  2011-01-19
# 14          황인욱                      이별주  2019-11-01
# 15          송하예                     니 소식  2019-05-11
# 16           이우                     내 안부  2019-07-16
# 17          정효빈                    처음이라서  2019-04-16
# 18          아이유                첫 이별 그날 밤  2010-12-09
# 19           이우                     이별행동  2019-10-06
#
#                                                    가사    좋아요수
# 0   어떻게 말을 꺼 내야 할까 내 하루 속엔 없어 네가 떨어지지 않는 내 마른 입술 끝...    4477
# 1   생각한다 지난 날들 눈이 부시도록 아름다웠던 사라진다 뜨겁게 안아주던 네 손 끝 향...   26459
# 2   지울게 너에게 남겨줬던 추억까지도 바랄게 너와의 기억도 남지 못하게 더는 다가갈 수...  100916
# 3   비 내리는 날 창가에 앉아 서두르던 일상을 달래다 울적해진 마음잡고 써 내려가다 울...   50062
# 4   새하얀 머플러에 얼굴을 묻고 붉어진 눈을 깜빡이며 널 기다렸어 무슨 얘길 하고 픈지...   82634
# 5   정말 넌 다 잊었더라 반갑게 날 보는 너의 얼굴 보니 그제야 어렴풋이 아파오더라 새...  110805
# 6   좁은 골목길은 또 하염없이 멀어져 마주앉은 탁자 반대편마저도 뻗어봐도 맞닿을 수가 ...   58856
# 7   서툰 작별이었는지 아련한 슬픔 속에 눈물이 멈추질 않아 너무나 어렸던 걸까 내 이기...    2948
# 8   세상이 어두워지고 조용히 비가 내리면 여전히 그대로 오늘도 어김없이 난 벗어나질 못...   73229
# 9   널 보면 나와 달라 이렇게 난 네 생각뿐인데 널 사랑했던 만큼 아파야 하는 걸까 난...   47764
# 10  한잔 술에 잊자 그만 나도 숨 좀 쉬자 제발 마치 주문처럼 매일 읊조렸던 넌 모르는...   38512
# 11  잘 있니 잘 지내니 나는 요즘 부쩍 네가 보고 싶어 그래 알아 너는 다신 내가 보기...   32146
# 12  안녕 안녕 이제 인사를 해야지 너와 나의 이별인데 아니 아니 나는 그게 안될것 같아...   14135
# 13  Hello Hello Hello Hello Hello Don't cry Don't ...   42209
# 14  오늘이 지나면 널 지워야겠지 흔들리는 이 술잔이 너의 마음 같아서 아무 말 안 해도...   60822
# 15  그때의 우리 사랑 뜨겁고 치열했는데 끝나보니 남는건 미움뿐 몇번의 계절을 더 보내야...  195103
# 16  내 소식 들었지 너와 헤어지고 참 많이 울고 힘들게 버티다 이해심이 많은 좋은 사람...   64527
# 17  떨어질 줄 몰랐던 너의 품도 잡은 손에 스치던 봄바람도 떨리던 입맞춤도 맞춰 걷던 ...   58777
# 18  멍하니 아무 일도 할 일이 없어 이게 이별인 거니 전화기 가득 찬 너와의 메시지만 ...   93381
# 19  자꾸만 연락을 피하고 바쁘다며 약속을 미루고 점점 변해가는 네 모습 무심한 말투 조...   58649

# %% [markdown]
# ---
# # sad20 wordcloud만들기

# %%
import nltk # national language tool kit
from konlpy.tag import Okt
import matplotlib.pyplot as plt
from wordcloud import WordCloud

t = Okt()

# %%
t.nouns(sad20.loc[0,'가사'])
# Out:
# ['말',
#  '내야',
#  '내',
#  '하루',
#  '속',
#  '네',
#  '내',
#  '입술',
#  '끝',
#  '이',
#  '계절',
#  '난',
#  '해',
#  '시간',
#  '속',
#  '연기',
#  '기억',
#  '너머',
#  '점점',
#  '우리',
#  '내',
#  '마음',
#  '고장',
#  '난',
#  '듯',
#  '넌',
#  '답',
#  '난',
#  '줄',
#  '수가',
#  '시간',
#  '속',
#  '우리',
#  '여기',
#  '그냥',
#  '날',
#  '퍼즐',
#  '속',
#  '조각',
#  '기억',
#  '너머',
#  '점점',
#  '너',
#  '내',
#  '마음',
#  '고장',
#  '난',
#  '듯',
#  '넌',
#  '답',
#  '나',
#  '줄',
#  '수가',
#  '시간',
#  '속',
#  '우리',
#  '여기',
#  '그냥',
#  '날',
#  '가끔',
#  '너',
#  '참고',
#  '말',
#  '기적',
#  '나',
#  '상처',
#  '날',
#  '내',
#  '사랑',
#  '네',
#  '마음',
#  '항상',
#  '답',
#  '넌',
#  '줄',
#  '수가',
#  '시간',
#  '속',
#  '우리',
#  '여기',
#  '날']

# %%
total20 = ""

# %%
for i in range(0, 20):
    total20 += (" " + sad20['가사'][i])

# %%
# 명사 분리
token_ko1 = t.nouns(total20)

# %%
token_ko1
# Out:
# ['말',
#  '내야',
#  '내',
#  '하루',
#  '속',
#  '네',
#  '내',
#  '입술',
#  '끝',
#  '이',
#  '계절',
#  '난',
#  '해',
#  '시간',
#  '속',
#  '연기',
#  '기억',
#  '너머',
#  '점점',
#  '우리',
#  '내',
#  '마음',
#  '고장',
#  '난',
#  '듯',
#  '넌',
#  '답',
#  '난',
#  '줄',
#  '수가',
#  '시간',
#  '속',
#  '우리',
#  '여기',
#  '그냥',
#  '날',
#  '퍼즐',
#  '속',
#  '조각',
#  '기억',
#  '너머',
#  '점점',
#  '너',
#  '내',
#  '마음',
#  '고장',
#  '난',
#  '듯',
#  '넌',
#  '답',
#  '나',
#  '줄',
#  '수가',
#  '시간',
#  '속',
#  '우리',
#  '여기',
#  '그냥',
#  '날',
#  '가끔',
#  '너',
#  '참고',
#  '말',
#  '기적',
#  '나',
#  '상처',
#  '날',
#  '내',
#  '사랑',
#  '네',
#  '마음',
#  '항상',
#  '답',
#  '넌',
#  '줄',
#  '수가',
#  '시간',
#  '속',
#  '우리',
#  '여기',
#  '날',
#  '생각',
#  '지난',
#  '날',
#  '눈',
#  '네',
#  '손',
#  '끝',
#  '향기',
#  '너',
#  '그',
#  '노래',
#  '날',
#  '목소리',
#  '날',
#  '내',
#  '기억',
#  '속',
#  '그',
#  '이름',
#  '하루',
#  '숨',
#  '것',
#  '잔상',
#  '순간',
#  '또',
#  '널',
#  '우리',
#  '시간',
#  '잡지',
#  '뒷모습',
#  '젠',
#  '수가',
#  '하루',
#  '숨',
#  '것',
#  '잔상',
#  '순간',
#  '또',
#  '널',
#  '것',
#  '우리',
#  '시간',
#  '날',
#  '한번',
#  '더',
#  '너',
#  '그',
#  '땐',
#  '우릴',
#  '너',
#  '추억',
#  '너',
#  '기억',
#  '남지',
#  '더',
#  '수',
#  '네',
#  '마음',
#  '너',
#  '기억',
#  '모두',
#  '수',
#  '널',
#  '수',
#  '사랑',
#  '기억',
#  '낼',
#  '수',
#  '더',
#  '수',
#  '난',
#  '수',
#  '듯이',
#  '너',
#  '곳',
#  '사랑',
#  '추억',
#  '네',
#  '기억',
#  '가시',
#  '해',
#  '모두',
#  '해',
#  '나',
#  '수',
#  '널',
#  '수',
#  '란',
#  '걸',
#  '알',
#  '너',
#  '기억',
#  '모두',
#  '더',
#  '수',
#  '네',
#  '마음',
#  '너',
#  '기억',
#  '모두',
#  '나',
#  '기억',
#  '너',
#  '추억',
#  '너',
#  '그리움',
#  '모든',
#  '순간',
#  '볼',
#  '너',
#  '흔적',
#  '너',
#  '추억',
#  '너',
#  '기억',
#  '남지',
#  '더',
#  '수',
#  '네',
#  '마음',
#  '너',
#  '기억',
#  '모두',
#  '너',
#  '수',
#  '수',
#  '제발',
#  '용서',
#  '우리',
#  '다시',
#  '만날',
#  '수',
#  '비',
#  '날',
#  '창가',
#  '일상',
#  '눈물',
#  '게',
#  '해',
#  '하루하루',
#  '누군가',
#  '네',
#  '얘길',
#  '물',
#  '때',
#  '눈물',
#  '밤하늘',
#  '잠시',
#  '혼자',
#  '생각',
#  '밤새',
#  '뒤척',
#  '네',
#  '생각',
#  '잠',
#  '못',
#  '날',
#  '눈물',
#  '다른',
#  '사람',
#  '그땐',
#  '꼭',
#  '나',
#  '너',
#  '더',
#  '이해',
#  '우리',
#  '사랑',
#  '기억',
#  '모두',
#  '만난',
#  '적',
#  '것',
#  '마치',
#  '우린',
#  '사이',
#  '밤하늘',
#  '잠시',
#  '혼자',
#  '생각',
#  '밤새',
#  '뒤척',
#  '네',
#  '생각',
#  '잠',
#  '못',
#  '날',
#  '눈물',
#  '다른',
#  '사람',
#  '그땐',
#  '꼭',
#  '나',
#  '너',
#  '더',
#  '이해',
#  '우리',
#  '사랑',
#  '기억',
#  '모두',
#  '만난',
#  '적',
#  '것',
#  '그',
#  '말',
#  '마치',
#  '우린',
#  '사이',
#  '다른',
#  '사람',
#  '그땐',
#  '꼭',
#  '나',
#  '너',
#  '더',
#  '이해',
#  '우리',
#  '사랑',
#  '기억',
#  '모두',
#  '만난',
#  '적',
#  '것',
#  '마치',
#  '우린',
#  '사이',
#  '새',
#  '머플러',
#  '얼굴',
#  '눈',
#  '깜빡',
#  '널',
#  '무슨',
#  '얘길',
#  '픈',
#  '그',
#  '말',
#  '알',
#  '것',
#  '눈',
#  '인사',
#  '목',
#  '메이',
#  '발',
#  '선',
#  '우리',
#  '둘',
#  '공간',
#  '눈물',
#  '화가',
#  '내',
#  '말',
#  '벌써',
#  '넌',
#  '아주',
#  '멀리',
#  '오늘',
#  '우리',
#  '내',
#  '맘',
#  '알',
#  '것',
#  '옆',
#  '나',
#  '역시',
#  '얼마나',
#  '더',
#  '제대로',
#  '사랑',
#  '요',
#  '귓가',
#  '심장소리',
#  '그대',
#  '니',
#  '번호',
#  '수록',
#  '더욱',
#  '또렷',
#  '해지',
#  '언제',
#  '어디',
#  '어제',
#  '날',
#  '사랑',
#  '오늘',
#  '우리',
#  '내',
#  '맘',
#  '알',
#  '것',
#  '옆',
#  '나',
#  '역시',
#  '얼마나',
#  '더',
#  '제대로',
#  '사랑',
#  '요',
#  '더',
#  '사랑',
#  '또',
#  '속',
#  '내',
#  '그냥',
#  '말',
#  '걸',
#  '그냥',
#  '걸',
#  '우리',
#  '사랑',
#  '기억',
#  '그게',
#  '널',
#  '줄',
#  '너',
#  '내일',
#  '살',
#  '나',
#  '오늘',
#  '살',
#  '아무',
#  '것',
#  '날',
#  '수',
#  '오늘',
#  '우리',
#  '내',
#  '맘',
#  '알',
#  '것',
#  '옆',
#  '나',
#  '역시',
#  '얼마나',
#  '더',
#  '제대로',
#  '사랑',
#  '요',
#  '정말',
#  '넌',
#  '날',
#  '너',
#  '얼굴',
#  '새',
#  '살',
#  '못',
#  '상처',
#  '눈물',
#  '이별',
#  '게',
#  '단치',
#  '것',
#  '이별',
#  '거',
#  '세상',
#  '일이',
#  '걸',
#  '그때',
#  '차라리',
#  '둘',
#  '걸',
#  '그때',
#  '나라',
#  '건',
#  '네겐',
#  '끝',
#  '건',
#  '나',
#  '이야기',
#  '사랑',
#  '내',
#  '곁',
#  '시간',
#  '뿐',
#  '이제야',
#  '알',
#  '것',
#  '왜',
#  '넌',
#  '내',
#  '순간',
#  '기대',
#  '얼마나',
#  '이별',
#  '거',
#  '세상',
#  '일이',
#  '걸',
#  '그때',
#  '차라리',
#  '둘',
#  '걸',
#  '그때',
#  '나라',
#  '건',
#  '네겐',
#  '끝',
#  '건',
#  '나',
#  '이야기',
#  '골목길',
#  '또',
#  '마주',
#  '탁자',
#  '반대편',
#  '수가',
#  '내',
#  '맘',
#  '언제',
#  '그늘',
#  '우리',
#  '서로',
#  '수',
#  '걸',
#  '멀리',
#  '이제',
#  '이별',
#  '면',
#  '우리',
#  '넌',
#  '꿈',
#  '이제',
#  '마지막',
#  '장',
#  '테',
#  '그대',
#  '이유',
#  '거',
#  '얼굴',
#  '우리',
#  '만큼',
#  '더',
#  '아무',
#  '말',
#  '날',
#  '예전',
#  '이제',
#  '이별',
#  '면',
#  '우리',
#  '넌',
#  '꿈',
#  '이제',
#  '마지막',
#  '장',
#  '테',
#  '후회',
#  '마',
#  '우리',
#  '시간',
#  '그',
#  '순간',
#  '의미',
#  '날',
#  '또',
#  '다시',
#  '가도',
#  '일',
#  '테',
#  '이제',
#  '넌',
#  '꿈',
#  '이제',
#  '마지막',
#  '장',
#  '테',
#  '여기',
#  '작별',
#  '슬픔',
#  '속',
#  '눈물',
#  '내',
#  '적임',
#  '너',
#  '우리',
#  '헤어지자',
#  '말',
#  '한지',
#  '하루',
#  '뒤',
#  '잠깐',
#  '실수',
#  '걸',
#  '깨달',
#  '순간',
#  '아침',
#  '네',
#  '목소리',
#  '네',
#  '품',
#  '벌써',
#  '내',
#  '바보',
#  '너',
#  '내',
#  '왜',
#  '이제',
#  '눈물',
#  '내',
#  '마음',
#  '알',
#  '수',
#  '더',
#  '사랑',
#  '나',
#  '항상',
#  '너',
#  '사람',
#  '때',
#  '우리',
#  '헤어지자',
#  '말',
#  '한지',
#  '하루',
#  '뒤',
#  '잠깐',
#  '실수',
#  '걸',
#  '깨달',
#  '순간',
#  '아침',
#  '네',
#  '목소리',
#  '네',
#  '품',
#  '벌써',
#  '내',
#  '바보',
#  '너',
#  '내',
#  '왜',
#  '이제',
#  '눈물',
#  '내',
#  '마음',
#  '알',
#  '수',
#  '더',
#  '작별인사',
#  '안',
#  '우리',
#  '사랑',
#  '그',
#  '기억',
#  '아침',
#  '네',
#  '목',
#  '소린',
#  '이제',
#  '어제',
#  '오늘',
#  '나',
#  '널',
#  '사랑',
#  '것',
#  '바보',
#  '너',
#  '내',
#  '왜',
#  '이제',
#  '눈물',
#  '내',
#  '마음',
#  '알',
#  '수',
#  '더',
#  '세상',
#  '비',
#  '그대로',
#  '오늘',
#  '난',
#  '너',
#  '생각',
#  '안',
#  '이제',
#  '끝',
#  '걸',
#  '알',
#  '미련',
#  '걸',
#  '알',
#  '이제',
#  '걸',
#  '알',
#  '그까짓',
#  '자존심',
#  '널',
#  '잡지',
#  '내',
#  '조금',
#  '뿐',
#  '비',
#  '날',
#  '밤',
#  '비',
#  '너',
#  '따라서',
#  '서서히',
#  '취했',
#  '것',
#  '애',
#  '비',
#  '것',
#  '애',
#  '뭐',
#  '네',
#  '보고',
#  '건',
#  '다만',
#  '우리',
#  '시간',
#  '좀',
#  '뿐',
#  '기억',
#  '추억',
#  '덫',
#  '일부러',
#  '발',
#  '발버둥',
#  '치',
#  '이제',
#  '너',
#  '모두',
#  '비',
#  '너',
#  '모든',
#  '기억',
#  '다시',
#  '널',
#  '비',
#  '날',
#  '밤',
#  '비',
#  '너',
#  '따라서',
#  '서서히',
#  '너',
#  '젠',
#  '지금',
#  '너',
#  '난',
#  '볼',
#  '널',
#  '잡',
#  '수',
#  '힘',
#  '내겐',
#  '어차피',
#  '걸',
#  '이제',
#  '어쩌겠어',
#  '후회',
#  '거지',
#  '덜',
#  '애',
#  '항상',
#  '오',
#  '계속',
#  '반복',
#  '그',
#  '제',
#  '항상',
#  '오',
#  '계속',
#  '반복',
#  '그',
#  '제',
#  '널',
#  '달라',
#  '난',
#  '네',
#  '생각',
#  '널',
#  '사랑',
#  '만큼',
#  '난',
#  '이',
#  '밤',
#  '끝',
#  '잡고',
#  '잠',
#  '못',
#  '드',
#  '시간',
#  '저',
#  '햇살',
#  '날',
#  '우린',
#  '사이',
#  '것',
#  '널',
#  '달라',
#  '왜',
#  '나',
#  '또',
#  '네',
#  '생각',
#  '끝',
#  '보이지',
#  '슬픔',
#  '아들',
#  '난',
#  '이',
#  '밤',
#  '끝',
#  '잡고',
#  '잠',
#  '드',
#  '네',
#  '날',
#  '후회',
#  '지금',
#  '넌',
#  '그',
#  '바람',
#  '게',
#  '난',
#  '다시',
#  '안',
#  '수',
#  '난',
#  '너',
#  '밤',
#  '내',
#  '맘',
#  '널',
#  '널',
#  '달라',
#  '누가',
#  '넌',
#  '끝',
#  '보이지',
#  '슬픔',
#  '아들',
#  '난',
#  '이',
#  '밤',
#  '끝',
#  '잡고',
#  '잠',
#  '못',
#  '드',
#  '추억',
#  '난',
#  '이제',
#  '너',
#  '모두',
#  '내',
#  '맘',
#  '널',
#  '달라',
#  '난',
#  '널',
#  '사랑',
#  '하나',
#  '너',
#  '정말',
#  '난',
#  '이',
#  '밤',
#  '끝',
#  '잡고',
#  '잠',
#  '못',
#  '드',
#  '째깍',
#  '째깍',
#  '초침',
#  '소리',
#  '시간',
#  '또',
#  '넌',
#  '어디',
#  '한잔',
#  '술',
#  '숨',
#  '좀',
#  '제발',
#  '마치',
#  '주문',
#  '매일',
#  '넌',
#  '내',
#  '혼잣말',
#  '친구',
#  '통해',
#  '네',
#  '소식',
#  '살',
#  '날',
#  '만날',
#  '때',
#  '더',
#  '너',
#  '억지로',
#  '밥',
#  '친구',
#  '술',
#  '겨우',
#  '날',
#  '숨',
#  '좀',
#  '쉬',
#  '해',
#  '이제',
#  '네',
#  '얼굴',
#  '살',
#  '너',
#  '듣기',
#  '네',
#  '소식',
#  '막상',
#  '또',
#  '이별',
#  '듯이',
#  '너',
#  '억지로',
#  '밥',
#  '친구',
#  '술',
#  '겨우',
#  '날',
#  '숨',
#  '좀',
#  '쉬',
#  '해',
#  '이제',
#  '네',
#  '얼굴',
#  '너',
#  '너',
#  '밤',
#  '혼자',
#  '날',
#  '가끔',
#  '너',
#  '철',
#  '나',
#  '장난',
#  '입',
#  '꼬리',
#  '그',
#  '미소',
#  '건',
#  '널',
#  '게',
#  '전부',
#  '너',
#  '젠',
#  '나',
#  '사랑',
#  '사람',
#  '살',
#  '너',
#  '수',
#  '나',
#  '요즘',
#  '부쩍',
#  '네',
#  '보고',
#  '알',
#  '너',
#  '내',
#  '보기',
#  '음',
#  '왜',
#  '겁',
#  '사랑',
#  '눈빛',
#  '그게',
#  '난',
#  '숨',
#  '그땐',
#  '나',
#  '날',
#  '이해해',
#  '나',
#  '다시',
#  '너',
#  '또',
#  '이유',
#  '분명',
#  '걸',
#  '알',
#  '수',
#  '널',
#  '날',
#  '나라',
#  '또',
#  '이유',
#  '우리',
#  '걸',
#  '알',
#  '괜',
#  '투정',
#  '말',
#  '너',
#  '젠',
#  '내',
#  '곁',
#  '혼자',
#  '널',
#  '날',
#  '이해해',
#  '나',
#  '다시',
#  '너',
#  '또',
#  '이유',
#  '분명',
#  '걸',
#  '알',
#  '수',
#  '널',
#  '날',
#  '나라',
#  '또',
#  '이유',
#  ...]

# %%
# 불용어 추가
# 실행해보면서 추가하면서 바꿔야함.
stop_words1 = ["손","고","준","것","첫","더","볼","위","것","게","겁","나","젠","거","줄",\
    "꾼", "거", "눈", "두", "짓", "엎", "물", "채", "뒤", "옆", "늘", "식이", "울", "해심", "척", "왜",\
          "해", "알", "이", "번", "때", "전", "걸", "롤", "굴지", "바", "적임", "수", "듯이", "래야", "쉬", "살", "자리"
     "못","좀","다시","마","비","안","건","못","너","널","수가","난","니가","날","넌","내","네","우리","그","우린",\
        "그게","그냥","내겐","누군가","내겐","니","잡고","아무"     
    ]
token_ko1 = [each_word for each_word in token_ko1 if each_word not in stop_words1]
print(token_ko1)
# Out:
# ['말', '내야', '하루', '속', '입술', '끝', '계절', '시간', '속', '연기', '기억', '너머', '점점', '마음', '고장', '듯', '답', '시간', '속', '여기', '퍼즐', '속', '조각', '기억', '너머', '점점', '마음', '고장', '듯', '답', '시간', '속', '여기', '가끔', '참고', '말', '기적', '상처', '사랑', '마음', '항상', '답', '시간', '속', '여기', '생각', '지난', '끝', '향기', '노래', '목소리', '기억', '속', '이름', '하루', '숨', '잔상', '순간', '또', '시간', '잡지', '뒷모습', '하루', '숨', '잔상', '순간', '또', '시간', '한번', '땐', '우릴', '추억', '기억', '남지', '마음', '기억', '모두', '사랑', '기억', '낼', '곳', '사랑', '추억', '기억', '가시', '모두', '란', '기억', '모두', '마음', '기억', '모두', '기억', '추억', '그리움', '모든', '순간', '흔적', '추억', '기억', '남지', '마음', '기억', '모두', '제발', '용서', '만날', '창가', '일상', '눈물', '하루하루', '얘길', '눈물', '밤하늘', '잠시', '혼자', '생각', '밤새', '뒤척', '생각', '잠', '눈물', '다른', '사람', '그땐', '꼭', '이해', '사랑', '기억', '모두', '만난', '적', '마치', '사이', '밤하늘', '잠시', '혼자', '생각', '밤새', '뒤척', '생각', '잠', '눈물', '다른', '사람', '그땐', '꼭', '이해', '사랑', '기억', '모두', '만난', '적', '말', '마치', '사이', '다른', '사람', '그땐', '꼭', '이해', '사랑', '기억', '모두', '만난', '적', '마치', '사이', '새', '머플러', '얼굴', '깜빡', '무슨', '얘길', '픈', '말', '인사', '목', '메이', '발', '선', '둘', '공간', '눈물', '화가', '말', '벌써', '아주', '멀리', '오늘', '맘', '역시', '얼마나', '제대로', '사랑', '요', '귓가', '심장소리', '그대', '번호', '수록', '더욱', '또렷', '해지', '언제', '어디', '어제', '사랑', '오늘', '맘', '역시', '얼마나', '제대로', '사랑', '요', '사랑', '또', '속', '말', '사랑', '기억', '내일', '오늘', '오늘', '맘', '역시', '얼마나', '제대로', '사랑', '요', '정말', '얼굴', '새', '상처', '눈물', '이별', '단치', '이별', '세상', '일이', '그때', '차라리', '둘', '그때', '나라', '네겐', '끝', '이야기', '사랑', '곁', '시간', '뿐', '이제야', '순간', '기대', '얼마나', '이별', '세상', '일이', '그때', '차라리', '둘', '그때', '나라', '네겐', '끝', '이야기', '골목길', '또', '마주', '탁자', '반대편', '맘', '언제', '그늘', '서로', '멀리', '이제', '이별', '면', '꿈', '이제', '마지막', '장', '테', '그대', '이유', '얼굴', '만큼', '말', '예전', '이제', '이별', '면', '꿈', '이제', '마지막', '장', '테', '후회', '시간', '순간', '의미', '또', '가도', '일', '테', '이제', '꿈', '이제', '마지막', '장', '테', '여기', '작별', '슬픔', '속', '눈물', '헤어지자', '말', '한지', '하루', '잠깐', '실수', '깨달', '순간', '아침', '목소리', '품', '벌써', '바보', '이제', '눈물', '마음', '사랑', '항상', '사람', '헤어지자', '말', '한지', '하루', '잠깐', '실수', '깨달', '순간', '아침', '목소리', '품', '벌써', '바보', '이제', '눈물', '마음', '작별인사', '사랑', '기억', '아침', '목', '소린', '이제', '어제', '오늘', '사랑', '바보', '이제', '눈물', '마음', '세상', '그대로', '오늘', '생각', '이제', '끝', '미련', '이제', '그까짓', '자존심', '잡지', '조금', '뿐', '밤', '따라서', '서서히', '취했', '애', '애', '뭐', '보고', '다만', '시간', '뿐', '기억', '추억', '덫', '일부러', '발', '발버둥', '치', '이제', '모두', '모든', '기억', '밤', '따라서', '서서히', '지금', '잡', '힘', '어차피', '이제', '어쩌겠어', '후회', '거지', '덜', '애', '항상', '오', '계속', '반복', '제', '항상', '오', '계속', '반복', '제', '달라', '생각', '사랑', '만큼', '밤', '끝', '잠', '드', '시간', '저', '햇살', '사이', '달라', '또', '생각', '끝', '보이지', '슬픔', '아들', '밤', '끝', '잠', '드', '후회', '지금', '바람', '밤', '맘', '달라', '누가', '끝', '보이지', '슬픔', '아들', '밤', '끝', '잠', '드', '추억', '이제', '모두', '맘', '달라', '사랑', '하나', '정말', '밤', '끝', '잠', '드', '째깍', '째깍', '초침', '소리', '시간', '또', '어디', '한잔', '술', '숨', '제발', '마치', '주문', '매일', '혼잣말', '친구', '통해', '소식', '만날', '억지로', '밥', '친구', '술', '겨우', '숨', '이제', '얼굴', '듣기', '소식', '막상', '또', '이별', '억지로', '밥', '친구', '술', '겨우', '숨', '이제', '얼굴', '밤', '혼자', '가끔', '철', '장난', '입', '꼬리', '미소', '전부', '사랑', '사람', '요즘', '부쩍', '보고', '보기', '음', '사랑', '눈빛', '숨', '그땐', '이해해', '또', '이유', '분명', '나라', '또', '이유', '괜', '투정', '말', '곁', '혼자', '이해해', '또', '이유', '분명', '나라', '또', '이유', '먼저', '후회', '끝내', '말', '마지막', '표정', '얼굴', '전부', '때문', '사랑', '사랑', '가늠', '시간', '변치', '또', '이유', '안녕', '안녕', '이제', '인사', '이별', '일', '영활', '보고', '밥', '일도', '거릴', '일도', '앞', '혼자', '란', '사실', '안녕', '전부', '사랑', '사람', '날수', '사실', '사실', '이별', '말', '조금', '순', '한번', '기횔', '순', '말', '기억', '마저', '안녕', '전부', '사랑', '사람', '날수', '소리', '낼', '제발', '말', '진심', '다해', '사랑', '말', '미안', '사랑', '가슴', '계속', '먼저', '면서', '사랑', '눈물', '대체', '무슨', '죄', '차라리', '일이', '상처', '라면', '지금', '가슴', '사랑', '가라', '사랑', '안녕', '생각', '정말', '마르지', '눈물', '면서', '보고', '대체', '무슨', '죄', '차라리', '일이', '상처', '라면', '지금', '가슴', '사랑', '가라', '사랑', '안녕', '사랑', '아마', '곁', '가슴', '사랑', '가라', '사랑', '안녕', '오늘이', '술잔', '마음', '말', '해도', '오늘', '이별', '말', '하필', '포장마차', '처음', '눈물', '술잔', '이별', '말', '제발', '술잔', '혼자', '끝', '술잔' ...

# %%
# 상위 50개 단어 확인
# 이걸보면서 불용어 지우는게 편해 전체는 힘들어
ko1 = nltk.Text(token_ko1)
ko1.vocab().most_common(50)
# Out:
# [('사랑', 55),
#  ('말', 29),
#  ('기억', 21),
#  ('이제', 19),
#  ('끝', 17),
#  ('눈물', 17),
#  ('이별', 17),
#  ('시간', 15),
#  ('사람', 15),
#  ('생각', 13),
#  ('또', 13),
#  ('밤', 13),
#  ('마음', 11),
#  ('모두', 11),
#  ('술잔', 11),
#  ('속', 9),
#  ('추억', 9),
#  ('그때', 9),
#  ('순간', 8),
#  ('제발', 8),
#  ('혼자', 8),
#  ('맘', 8),
#  ('안녕', 8),
#  ('처음', 8),
#  ('하루', 7),
#  ('오늘', 7),
#  ('숨', 6),
#  ('잠', 6),
#  ('얼굴', 6),
#  ('이유', 6),
#  ('후회', 6),
#  ('소식', 6),
#  ('전부', 6),
#  ('가슴', 6),
#  ('다른', 5),
#  ('꼭', 5),
#  ('마치', 5),
#  ('마지막', 5),
#  ('지금', 5),
#  ('모습', 5),
#  ('안부', 5),
#  ('여기', 4),
#  ('상처', 4),
#  ('항상', 4),
#  ('목소리', 4),
#  ('그땐', 4),
#  ('사이', 4),
#  ('얼마나', 4),
#  ('세상', 4),
#  ('일이', 4)]

# %%
# 한글 폰트 문제 해결 
# matplotlib은 한글 폰트를 지원하지 않음
# os정보
import platform

# font_manager : 폰트 관리 모듈
# rc : 폰트 변경 모듈
from matplotlib import font_manager, rc
# unicode 설정
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic') # os가 macos
elif platform.system() == 'Windows':
    path = 'c:/Windows/Fonts/malgun.ttf' # os가 windows
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print("Unknown System")

# %%
# Warning무시
import warnings
warnings.filterwarnings('ignore')

# %%
# 상위 50개의 빈도수 차트 만들기
plt.figure(figsize=(12,6))
ko1.plot(50)
plt.show()

# %%
# 상위 50개만 wordcloud로 그리기
# 구한데이터로 그리기
data = ko1.vocab().most_common(50)

# 딕셔너리로 만들기
tmp_data1 = dict(data)

wordcloud1 = WordCloud(
    background_color='White',
    relative_scaling=0.8,
    font_path="AppleGothic" # 윈도우 => 'c:/Windows/Fonts/malgun.ttf'
).generate_from_frequencies(tmp_data1)

# %%
plt.figure(figsize=(16,8))
plt.imshow(wordcloud1, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
test = total20

# %%
verb_list = []
for i in range(len(t.pos(test))):
    if t.pos(test)[i][1] == 'Verb':
        verb_list.append(t.pos(test)[i][0])

# %%
verb_list
# Out:
# ['꺼',
#  '할까',
#  '떨어지지',
#  '않는',
#  '끝내려고',
#  '갇혀',
#  '버린',
#  '흩어져',
#  '멀어지는',
#  '소리쳐도',
#  '들리지',
#  '않아',
#  '놓아줘',
#  '맞지',
#  '않는',
#  '흩어져',
#  '멀어지는',
#  '소리쳐도',
#  '들리지',
#  '않아',
#  '쏟아지는',
#  '돌아선',
#  '주는',
#  '들이기에',
#  '망가졌고',
#  '듣지를',
#  '않아',
#  '돼',
#  '놓아줘',
#  '한다',
#  '부시도록',
#  '사라진다',
#  '안아주던',
#  '들려온다',
#  '부르는',
#  '불러',
#  '본다',
#  '맴돌던',
#  '멎을',
#  '밀려오는',
#  '그리던',
#  '기다려',
#  '본다',
#  '흩어진다',
#  '새겨졌던',
#  '해',
#  '작아진',
#  '닿을',
#  '멎을',
#  '밀려오는',
#  '그리던',
#  '기다려',
#  '본다',
#  '사라질',
#  '붙잡고',
#  '담게',
#  '된다면',
#  '놓지',
#  '않을게',
#  '놓지',
#  '않을게',
#  '지울게',
#  '남겨',
#  '줬던',
#  '바랄게',
#  '하게',
#  '다가갈',
#  '가져가',
#  '줘',
#  '지워줘',
#  '지워질',
#  '벗어날',
#  '했던',
#  '비워',
#  '이뤄질',
#  '다가갈',
#  '뛰어가',
#  '가',
#  '갔고',
#  '남겨진',
#  '내게',
#  '남겨',
#  '줬던',
#  '됐고',
#  '사라졌으면',
#  '지워졌으면',
#  '쉴',
#  '떠날게',
#  '가질',
#  '보낼게',
#  '버릴게',
#  '다가갈',
#  '가져가',
#  '줘',
#  '지워줘',
#  '떠나가줘',
#  '가져가',
#  '줘',
#  '지워줘',
#  '그립지는',
#  '않게',
#  '잊어',
#  '잊을게',
#  '지울게',
#  '남겨',
#  '줬던',
#  '바랄게',
#  '하게',
#  '다가갈',
#  '가져가',
#  '줘',
#  '지워줘',
#  '떠날',
#  '멀어질',
#  '나를',
#  '해줘',
#  '는',
#  '내리는',
#  '앉아',
#  '서두르던',
#  '달래다',
#  '마음잡고',
#  '써',
#  '내려가다',
#  '헤어진단',
#  '버티다가',
#  '내게',
#  '어두워지면',
#  '헤매다',
#  '잊었던',
#  '드는',
#  '만난다면',
#  '바랄게',
#  '하길',
#  '했던',
#  '지우고',
#  '어두워지면',
#  '헤매다',
#  '잊었던',
#  '드는',
#  '만난다면',
#  '바랄게',
#  '하길',
#  '했던',
#  '지우고',
#  '뱉어놓은',
#  '만난다면',
#  '바랄게',
#  '하길',
#  '했던',
#  '지우고',
#  '묻고',
#  '기다렸어',
#  '하고',
#  '모르겠어',
#  '한',
#  '물러',
#  '터지고',
#  '나서',
#  '소리치듯',
#  '가란',
#  '달아나',
#  '버렸어',
#  '헤어졌어요',
#  '헤어졌어요',
#  '울어줘요',
#  '봐요',
#  '가봐요',
#  '울어야',
#  '할까',
#  '울리고',
#  '지운',
#  '멀어진',
#  '건지',
#  '했는데',
#  '헤어졌어요',
#  '헤어졌어요',
#  '울어줘요',
#  '봐요',
#  '가봐요',
#  '울어야',
#  '할까',
#  '참',
#  '미워',
#  '나오지',
#  '할',
#  '붙잡아',
#  '웃게',
#  '할',
#  '헤어졌어요',
#  '헤어졌어요',
#  '울어줘요',
#  '봐요',
#  '가봐요',
#  '울어야',
#  '할까',
#  '잊었더라',
#  '보는',
#  '보니',
#  '차오르지',
#  '흐르질',
#  '않더라',
#  '하는',
#  '해서',
#  '보잘',
#  '알았다면',
#  '울어',
#  '이었다는',
#  '몰랐었던',
#  '머물던',
#  '이었을',
#  '했는지',
#  '봐',
#  '떠나는',
#  '했었다니',
#  '알았다면',
#  '울어',
#  '이었다는',
#  '몰랐었던',
#  '멀어져',
#  '앉은',
#  '뻗어',
#  '봐도',
#  '맞닿을',
#  '가',
#  '긴',
#  '드리워',
#  '하는데',
#  '돌아갈',
#  '감았다',
#  '떠보니',
#  '와있어',
#  '서있는',
#  '내게',
#  '넘겨야겠어',
#  '는',
#  '해야겠지',
#  '찾는',
#  '말아요',
#  '할',
#  '했는걸',
#  '말아줘',
#  '보면서',
#  '웃어줘',
#  '서있는',
#  '내게',
#  '넘겨야겠어',
#  '는',
#  '해야겠지',
#  '하지',
#  '나눈',
#  '한',
#  '내게',
#  '넘겨야겠어',
#  '는',
#  '해야겠지',
#  '이었는지',
#  '멈추질',
#  '않아',
#  '어렸던',
#  '걸까',
#  '보내고',
#  '말았던',
#  '걸까',
#  '였단',
#  '버린',
#  '듣던',
#  '버린',
#  '서',
#  '흘리는지',
#  '이었을까',
#  '느껴질',
#  '였단',
#  '버린',
#  '듣던',
#  '버린',
#  '서',
#  '흘리는지',
#  '뱉어',
#  '버린',
#  '했던',
#  '듣던',
#  '한다',
#  '할',
#  '들리지',
#  '않아',
#  '버린',
#  '서',
#  '흘리는걸',
#  '까',
#  '어두워지고',
#  '내리면',
#  '벗어나질',
#  '하네',
#  '했던',
#  '오는',
#  '나를',
#  '찾아와',
#  '새워',
#  '괴롭히다',
#  '그쳐가면',
#  '그쳐가겠지',
#  '봐',
#  '마셔야',
#  '될',
#  '떨어지니까',
#  '나도',
#  '떨어질',
#  '싶다거나',
#  '아냐',
#  '가진',
#  '참',
#  '날이면',
#  '꺼내놓고',
#  '들여놔',
#  '벗어나려고',
#  '않아',
#  '지워',
#  '냈지만',
#  '비워',
#  '냈지만',
#  '내리면',
#  '숨겨놨던',
#  '돌아와',
#  '찾나',
#  '봐',
#  '오는',
#  '나를',
#  '찾아와',
#  '새워',
#  '괴롭히다',
#  '그쳐가면',
#  '그쳐가겠지',
#  '돌아갈',
#  '보며',
#  '웃어',
#  '끝나',
#  '버린',
#  '와',
#  '하는',
#  '떨어진',
#  '비는',
#  '되겠지',
#  '나면',
#  '서야',
#  '나도',
#  '그치겠지',
#  '비는',
#  '되겠지',
#  '나면',
#  '서야',
#  '나도',
#  '그치겠지',
#  '보면',
#  '나와',
#  '했던',
#  '하는',
#  '걸까',
#  '지나가면',
#  '비춰',
#  '줄까',
#  '끝난',
#  '돌아올',
#  '보면',
#  '나와',
#  '않던',
#  '잦',
#  '떠나고',
#  '나잖아',
#  '않을까',
#  '불어오는',
#  '할',
#  '지워가지만',
#  '보면',
#  '나와',
#  '나와',
#  '않던',
#  '잦',
#  '했던',
#  '지울래',
#  '보면',
#  '나와',
#  '봐',
#  '흐르는데',
#  '잊자',
#  '나도',
#  '쉬자',
#  '읊조렸던',
#  '모르는',
#  '들은',
#  '잘',
#  '삼킨',
#  '되어',
#  '줬던',
#  '잊었어',
#  '잘',
#  '듣게',
#  '되니',
#  '삼킨',
#  '되어',
#  '줬던',
#  '잊었어',
#  '잘살고',
#  '버틸',
#  '올라가던',
#  '가진',
#  '가진',
#  '였어',
#  '무너졌나',
#  '봐',
#  '나도',
#  '해줄',
#  '만나',
#  '잘',
#  '싶다',
#  '나도',
#  '잘',
#  '잘',
#  '지내니',
#  '싶어',
#  '다신',
#  '그리',
#  '났었는지',
#  '바라던',
#  '막혔어',
#  '어려서',
#  '몰랐었어',
#  '돌아가지',
#  '하는',
#  '만나면',
#  '멀어질',
#  '참을',
#  '잊지',
#  '해',
#  '잊어',
#  '보내지도',
#  '하는',
#  '알아줘',
#  '바뀌지',
#  '않을',
#  '할',
#  '웃어주던',
#  '미운',
#  '안아주던',
#  '놓칠',
#  '하겠어',
#  '돌아가지',
#  '하는',
#  '만나면',
#  '멀어질',
#  '참을',
#  '잊지',
#  '해',
#  '잊어',
#  '보내지도',
#  '하는',
#  '알아줘',
#  '바뀌지',
#  '않을',
#  '할',
#  '붙잡아줘',
#  '잡아줘',
#  '했었어',
#  '해서',
#  '알기에',
#  '참을',
#  '해서',
#  '해서',
#  '하지',
#  '하는',
#  '지나가도',
#  '않는',
#  '할',
#  '해야지',
#  '보내는',
#  '먹는',
#  '걷는',
#  '나를',
#  '만드는',
#  '였던',
#  '해',
#  '다신',
#  '잘가',
#  '하기',
#  '참을',
#  '하지',
#  '했어',
#  '사라질까봐',
#  '였던',
#  '해',
#  '다신',
#  '잘가',
#  '잊겠니',
#  '듣고',
#  '가',
#  '했단',
#  '잊으라는',
#  '해',
#  '놔줘',
#  '떼어내도',
#  '놔줘',
#  '잘라내도',
#  '돌아설',
#  '하게',
#  '잘',
#  '됐어',
#  '된',
#  '미워지기',
#  '나을지도',
#  '몰라',
#  '하지',
#  '말아줘',
#  '웃고',
#  '싶은데',
#  '잊고',
#  '싶은데',
#  '보내줄게',
#  '잘',
#  '웃으며',
#  '질리지도',
#  '않나',
#  '봐',
#  '않나',
#  '봐',
#  '떠나',
#  '버릴',
#  '싶게',
#  '잘',
#  '됐어',
#  '된',
#  '미워지기',
#  '나을지도',
#  '몰라',
#  '하지',
#  '말아줘',
#  '웃고',
#  '싶은데',
#  '잊고',
#  '싶은데',
#  '보내줄게',
#  '잘',
#  '웃으며',
#  '나를',
#  '떠나도',
#  '웃으며',
#  '놓아줄게',
#  '줬으니',
#  '됐어',
#  '됐어',
#  '는',
#  '올',
#  '우는',
#  '올',
#  '하지',
#  '말아줘',
#  '웃고',
#  '싶은데',
#  '잊고',
#  '싶은데',
#  '보내줄게',
#  '잘',
#  '웃으며',
#  '지나면',
#  '지워야겠지',
#  '흔들리는',
#  '할',
#  '만났던',
#  '나게',
#  '마시고',
#  '나면',
#  '할',
#  '이러지',
#  '나를',
#  '떠나지',
#  '잖아',
#  '마시고',
#  '나면',
#  '잖아',
#  '헤어져야',
#  '비우지',
#  '만났던',
#  '나게',
#  '마시고',
#  '나면',
#  '할',
#  '이러지',
#  '나를',
#  '떠나지',
#  '잖아',
#  '마시고',
#  '나면',
#  '잖아',
#  '헤어져야',
#  '비우지',
#  '마시면',
#  '살아갈',
#  '되겠지',
#  '마시고',
#  '나면',
#  '끝낼',
#  '하면',
#  '되잖아',
#  '했어',
#  '될',
#  '잖아',
#  '마시고',
#  '나면',
#  '잖아',
#  '헤어져야',
#  '비우지',
#  '끝나',
#  '보니',
#  '남는건',
#  '보내야',
#  '질까',
#  '남은',
#  '보내',
#  '들은',
#  '해',
#  '잘',
#  '지낸다고',
#  '했었던',
#  '됐고',
#  '모르는',
#  '잊었나',
#  '봐',
#  '잘사는데',
#  '했나',
#  '봐',
#  '가봐',
#  '들었으면',
#  '갖고',
#  '해줘',
#  '참',
#  '모를',
#  '했었던',
#  '됐고',
#  '모르는',
#  '잊었나',
#  '봐',
#  '잘사는데',
#  '미뤘나',
#  '봐',
#  '봐',
#  '하면',
#  '했으면',
#  '지내길',
#  '웃는',
#  '떠났나',
#  '봐',
#  '떠났나',
#  '봐',
#  '미워져',
#  '말아줘',
#  '지내지',
#  '말아줘',
#  '만나',
#  '들은',
#  '샜어',
#  '늦어',
#  '버린',
#  '봐',
#  '들었지',
#  '헤어지고',
#  '참',
#  '버티다',
#  '만나서',
#  '잘',
#  '지내고',
#  '들으니',
#  '돼',
#  '생각나',
#  '지내',
#  '참',
#  '잊고',
#  '하기를',
#  '잘해주지',
#  '잊지',
#  '하니',
#  '들려오는',
#  '들은',
#  '지나갈',
#  '돼',
#  '와',
#  '지워',
#  '줬어',
#  '가봐',
#  '뛰고',
#  '잊고',
#  '하기를',
#  '잘해주지',
#  '잊지',
#  '하니',
#  '들려오는',
#  '들은',
#  '지나갈',
#  '헤어짐을',
#  '미워도',
#  '하고',
#  '하며',
#  '지내기를',
#  '잊고',
#  '잘',
#  '살았는데',
#  '했는데',
#  '잊었다',
#  '지내',
#  '왔는데',
#  '들려오는',
#  '무너졌어',
#  '떨어질',
#  '몰랐던',
#  '품도',
#  '잡은',
#  '스치던',
#  '떨리던',
#  '맞춰',
#  '걷던',
#  '된',
#  '토닥여',
#  '큰',
#  '봐',
#  '봐',
#  '지나면',
#  '오겠지',
#  '부른',
#  '떠올리는',
#  '나를',
#  '떠올리는',
#  '되는',
#  '익숙해져',
#  '버려서',
#  '봐',
#  '지나면',
#  '보며',
#  '웃는',
#  '오겠지',
#  '봐',
#  '했어',
#  '봐',
#  '지나면',
#  '되어',
#  '웃겠지',
#  '참',
#  '할',
#  '읽다',
#  '읽다',
#  '들린',
#  '둘러보면',
#  '했어',
#  '했지',
#  '했던',
#  '했단',
#  '믿을게',
#  '그리우면',
#  '한',
#  '사라질',
#  '봤어',
#  '떠나면',
#  '들썩여',
#  '우는',
#  '했어',
#  '했지',
#  '했던',
#  '했단',
#  '믿을게',
#  '그리우면',
#  '한',
#  '하지',
#  '나를',
#  '놓친',
#  '딴',
#  '만나면',
#  '내게',
#  '들리도록',
#  '해줘',
#  '서야',
#  '끝낼게',
#  '내게',
#  '돌아올지',
#  '모를',
#  '꿈꾸는',
#  '할말',
#  '미루고',
#  '가고',
#  '웃던',
#  '하면',
#  '했었고',
#  '였는데',
#  '봐',
#  '해',
#  '보낼',
#  '봐',
#  '보이는',
#  '웃고',
#  '잘',
#  '지냈나',
#  '봐',
#  '찾아가지',
#  '믿고',
#  '싶었는데',
#  '봐',
#  '나를',
#  '잊은',
#  '했었고',
#  '였는데',
#  '봐',
#  '해',
#  '보낼',
#  '봐',
#  '보여',
#  '잘',
#  '지내는데',
#  '잊고',
#  '웃으며',
#  '안긴',
#  '보낼']

# %%
# 불용어 추가
# 실행해보면서 추가하면서 바꿔야함.
stop_words2 = ["할","참","한","챌","는제","참","줘","걸까","댄","따라","된","잘","된","는","올","되",\
    "기를","까","큰","갈","건지","하는","이길","딴","서","써","내게","나를","나도","해","봐","나면","잖아",\
    "했어","되겠지","했어","하게","할까","해서","하길","나와","서야","했던","했단","해줘","해야겠지","싶은데",\
    "하던","줬던","하면","않는","들은","듣던","돼","한다","하지","되어","마시고","다신"
    ]
token_ko2 = [each_word for each_word in verb_list if each_word not in stop_words2]
print(token_ko2)
# Out:
# ['꺼', '떨어지지', '끝내려고', '갇혀', '버린', '흩어져', '멀어지는', '소리쳐도', '들리지', '않아', '놓아줘', '맞지', '흩어져', '멀어지는', '소리쳐도', '들리지', '않아', '쏟아지는', '돌아선', '주는', '들이기에', '망가졌고', '듣지를', '않아', '놓아줘', '부시도록', '사라진다', '안아주던', '들려온다', '부르는', '불러', '본다', '맴돌던', '멎을', '밀려오는', '그리던', '기다려', '본다', '흩어진다', '새겨졌던', '작아진', '닿을', '멎을', '밀려오는', '그리던', '기다려', '본다', '사라질', '붙잡고', '담게', '된다면', '놓지', '않을게', '놓지', '않을게', '지울게', '남겨', '바랄게', '다가갈', '가져가', '지워줘', '지워질', '벗어날', '비워', '이뤄질', '다가갈', '뛰어가', '가', '갔고', '남겨진', '남겨', '됐고', '사라졌으면', '지워졌으면', '쉴', '떠날게', '가질', '보낼게', '버릴게', '다가갈', '가져가', '지워줘', '떠나가줘', '가져가', '지워줘', '그립지는', '않게', '잊어', '잊을게', '지울게', '남겨', '바랄게', '다가갈', '가져가', '지워줘', '떠날', '멀어질', '내리는', '앉아', '서두르던', '달래다', '마음잡고', '내려가다', '헤어진단', '버티다가', '어두워지면', '헤매다', '잊었던', '드는', '만난다면', '바랄게', '지우고', '어두워지면', '헤매다', '잊었던', '드는', '만난다면', '바랄게', '지우고', '뱉어놓은', '만난다면', '바랄게', '지우고', '묻고', '기다렸어', '하고', '모르겠어', '물러', '터지고', '나서', '소리치듯', '가란', '달아나', '버렸어', '헤어졌어요', '헤어졌어요', '울어줘요', '봐요', '가봐요', '울어야', '울리고', '지운', '멀어진', '했는데', '헤어졌어요', '헤어졌어요', '울어줘요', '봐요', '가봐요', '울어야', '미워', '나오지', '붙잡아', '웃게', '헤어졌어요', '헤어졌어요', '울어줘요', '봐요', '가봐요', '울어야', '잊었더라', '보는', '보니', '차오르지', '흐르질', '않더라', '보잘', '알았다면', '울어', '이었다는', '몰랐었던', '머물던', '이었을', '했는지', '떠나는', '했었다니', '알았다면', '울어', '이었다는', '몰랐었던', '멀어져', '앉은', '뻗어', '봐도', '맞닿을', '가', '긴', '드리워', '하는데', '돌아갈', '감았다', '떠보니', '와있어', '서있는', '넘겨야겠어', '찾는', '말아요', '했는걸', '말아줘', '보면서', '웃어줘', '서있는', '넘겨야겠어', '나눈', '넘겨야겠어', '이었는지', '멈추질', '않아', '어렸던', '보내고', '말았던', '였단', '버린', '버린', '흘리는지', '이었을까', '느껴질', '였단', '버린', '버린', '흘리는지', '뱉어', '버린', '들리지', '않아', '버린', '흘리는걸', '어두워지고', '내리면', '벗어나질', '하네', '오는', '찾아와', '새워', '괴롭히다', '그쳐가면', '그쳐가겠지', '마셔야', '될', '떨어지니까', '떨어질', '싶다거나', '아냐', '가진', '날이면', '꺼내놓고', '들여놔', '벗어나려고', '않아', '지워', '냈지만', '비워', '냈지만', '내리면', '숨겨놨던', '돌아와', '찾나', '오는', '찾아와', '새워', '괴롭히다', '그쳐가면', '그쳐가겠지', '돌아갈', '보며', '웃어', '끝나', '버린', '와', '떨어진', '비는', '그치겠지', '비는', '그치겠지', '보면', '지나가면', '비춰', '줄까', '끝난', '돌아올', '보면', '않던', '잦', '떠나고', '나잖아', '않을까', '불어오는', '지워가지만', '보면', '않던', '잦', '지울래', '보면', '흐르는데', '잊자', '쉬자', '읊조렸던', '모르는', '삼킨', '잊었어', '듣게', '되니', '삼킨', '잊었어', '잘살고', '버틸', '올라가던', '가진', '가진', '였어', '무너졌나', '해줄', '만나', '싶다', '지내니', '싶어', '그리', '났었는지', '바라던', '막혔어', '어려서', '몰랐었어', '돌아가지', '만나면', '멀어질', '참을', '잊지', '잊어', '보내지도', '알아줘', '바뀌지', '않을', '웃어주던', '미운', '안아주던', '놓칠', '하겠어', '돌아가지', '만나면', '멀어질', '참을', '잊지', '잊어', '보내지도', '알아줘', '바뀌지', '않을', '붙잡아줘', '잡아줘', '했었어', '알기에', '참을', '지나가도', '해야지', '보내는', '먹는', '걷는', '만드는', '였던', '잘가', '하기', '참을', '사라질까봐', '였던', '잘가', '잊겠니', '듣고', '가', '잊으라는', '놔줘', '떼어내도', '놔줘', '잘라내도', '돌아설', '됐어', '미워지기', '나을지도', '몰라', '말아줘', '웃고', '잊고', '보내줄게', '웃으며', '질리지도', '않나', '않나', '떠나', '버릴', '싶게', '됐어', '미워지기', '나을지도', '몰라', '말아줘', '웃고', '잊고', '보내줄게', '웃으며', '떠나도', '웃으며', '놓아줄게', '줬으니', '됐어', '됐어', '우는', '말아줘', '웃고', '잊고', '보내줄게', '웃으며', '지나면', '지워야겠지', '흔들리는', '만났던', '나게', '이러지', '떠나지', '헤어져야', '비우지', '만났던', '나게', '이러지', '떠나지', '헤어져야', '비우지', '마시면', '살아갈', '끝낼', '되잖아', '될', '헤어져야', '비우지', '끝나', '보니', '남는건', '보내야', '질까', '남은', '보내', '지낸다고', '했었던', '됐고', '모르는', '잊었나', '잘사는데', '했나', '가봐', '들었으면', '갖고', '모를', '했었던', '됐고', '모르는', '잊었나', '잘사는데', '미뤘나', '했으면', '지내길', '웃는', '떠났나', '떠났나', '미워져', '말아줘', '지내지', '말아줘', '만나', '샜어', '늦어', '버린', '들었지', '헤어지고', '버티다', '만나서', '지내고', '들으니', '생각나', '지내', '잊고', '하기를', '잘해주지', '잊지', '하니', '들려오는', '지나갈', '와', '지워', '줬어', '가봐', '뛰고', '잊고', '하기를', '잘해주지', '잊지', '하니', '들려오는', '지나갈', '헤어짐을', '미워도', '하고', '하며', '지내기를', '잊고', '살았는데', '했는데', '잊었다', '지내', '왔는데', '들려오는', '무너졌어', '떨어질', '몰랐던', '품도', '잡은', '스치던', '떨리던', '맞춰', '걷던', '토닥여', '지나면', '오겠지', '부른', '떠올리는', '떠올리는', '되는', '익숙해져', '버려서', '지나면', '보며', '웃는', '오겠지', '지나면', '웃겠지', '읽다', '읽다', '들린', '둘러보면', '했지', '믿을게', '그리우면', '사라질', '봤어', '떠나면', '들썩여', '우는', '했지', '믿을게', '그리우면', '놓친', '만나면', '들리도록', '끝낼게', '돌아올지', '모를', '꿈꾸는', '할말', '미루고', '가고', '웃던', '했었고', '였는데', '보낼', '보이는', '웃고', '지냈나', '찾아가지', '믿고', '싶었는데', '잊은', '했었고', '였는데', '보낼', '보여', '지내는데', '잊고', '웃으며', '안긴', '보낼']

# %%
# 상위 50개 단어 확인
# 이걸보면서 불용어 지우는게 편해 전체는 힘들어
ko2 = nltk.Text(token_ko2)
ko2.vocab().most_common(50)
# Out:
# [('버린', 9),
#  ('잊고', 7),
#  ('않아', 6),
#  ('헤어졌어요', 6),
#  ('말아줘', 6),
#  ('바랄게', 5),
#  ('웃으며', 5),
#  ('다가갈', 4),
#  ('가져가', 4),
#  ('지워줘', 4),
#  ('보면', 4),
#  ('참을', 4),
#  ('잊지', 4),
#  ('됐어', 4),
#  ('웃고', 4),
#  ('지나면', 4),
#  ('들리지', 3),
#  ('본다', 3),
#  ('남겨', 3),
#  ('가', 3),
#  ('됐고', 3),
#  ('잊어', 3),
#  ('멀어질', 3),
#  ('만난다면', 3),
#  ('지우고', 3),
#  ('울어줘요', 3),
#  ('봐요', 3),
#  ('가봐요', 3),
#  ('울어야', 3),
#  ('넘겨야겠어', 3),
#  ('가진', 3),
#  ('모르는', 3),
#  ('만나면', 3),
#  ('보내줄게', 3),
#  ('헤어져야', 3),
#  ('비우지', 3),
#  ('들려오는', 3),
#  ('보낼', 3),
#  ('흩어져', 2),
#  ('멀어지는', 2),
#  ('소리쳐도', 2),
#  ('놓아줘', 2),
#  ('안아주던', 2),
#  ('멎을', 2),
#  ('밀려오는', 2),
#  ('그리던', 2),
#  ('기다려', 2),
#  ('사라질', 2),
#  ('놓지', 2),
#  ('않을게', 2)]

# %%
# 상위 50개의 빈도수 차트 만들기
plt.figure(figsize=(12,6))
ko2.plot(50)
plt.show()

# %%
# 상위 50개만 wordcloud로 그리기
# 구한데이터로 그리기
data2 = ko2.vocab().most_common(50)

# 딕셔너리로 만들기
tmp_data2 = dict(data2)

wordcloud2 = WordCloud(
    background_color='White',
    relative_scaling=0.8,
    font_path="AppleGothic" # 윈도우 => 'c:/Windows/Fonts/malgun.ttf'
).generate_from_frequencies(tmp_data2)

# %%
plt.figure(figsize=(16,8))
plt.imshow(wordcloud2, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# 상위 100개만 wordcloud로 그리기
# 구한데이터로 그리기
data2_100 = ko2.vocab().most_common(100)

# 딕셔너리로 만들기
tmp_data2_100 = dict(data2_100)

wordcloud2_100 = WordCloud(
    background_color='White',
    relative_scaling=0.8,
    font_path="AppleGothic" # 윈도우 => 'c:/Windows/Fonts/malgun.ttf'
).generate_from_frequencies(tmp_data2_100)

# %%
plt.figure(figsize=(16,8))
plt.imshow(wordcloud2_100, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
test1 = total20

# %%
t.pos(test1)
# Out:
# [('어떻게', 'Adjective'),
#  ('말', 'Noun'),
#  ('을', 'Josa'),
#  ('꺼', 'Verb'),
#  ('내야', 'Noun'),
#  ('할까', 'Verb'),
#  ('내', 'Noun'),
#  ('하루', 'Noun'),
#  ('속', 'Noun'),
#  ('엔', 'Josa'),
#  ('없어', 'Adjective'),
#  ('네', 'Noun'),
#  ('가', 'Josa'),
#  ('떨어지지', 'Verb'),
#  ('않는', 'Verb'),
#  ('내', 'Noun'),
#  ('마른', 'Adjective'),
#  ('입술', 'Noun'),
#  ('끝', 'Noun'),
#  ('에', 'Josa'),
#  ('이', 'Noun'),
#  ('계절', 'Noun'),
#  ('을', 'Josa'),
#  ('난', 'Noun'),
#  ('끝내려고', 'Verb'),
#  ('해', 'Noun'),
#  ('갇혀', 'Verb'),
#  ('버린', 'Verb'),
#  ('시간', 'Noun'),
#  ('속', 'Noun'),
#  ('연기', 'Noun'),
#  ('처럼', 'Josa'),
#  ('흩어져', 'Verb'),
#  ('기억', 'Noun'),
#  ('너머', 'Noun'),
#  ('점점', 'Noun'),
#  ('멀어지는', 'Verb'),
#  ('우리', 'Noun'),
#  ('내', 'Noun'),
#  ('마음', 'Noun'),
#  ('이', 'Josa'),
#  ('고장', 'Noun'),
#  ('난', 'Noun'),
#  ('듯', 'Noun'),
#  ('소리쳐도', 'Verb'),
#  ('들리지', 'Verb'),
#  ('않아', 'Verb'),
#  ('넌', 'Noun'),
#  ('답', 'Noun'),
#  ('을', 'Josa'),
#  ('원했고', 'Adjective'),
#  ('난', 'Noun'),
#  ('줄', 'Noun'),
#  ('수가', 'Noun'),
#  ('없어', 'Adjective'),
#  ('같은', 'Adjective'),
#  ('시간', 'Noun'),
#  ('속', 'Noun'),
#  ('우리', 'Noun'),
#  ('는', 'Josa'),
#  ('여기', 'Noun'),
#  ('까진', 'Josa'),
#  ('거야', 'Eomi'),
#  ('미안해', 'Adjective'),
#  ('미워해', 'Adjective'),
#  ('그냥', 'Noun'),
#  ('날', 'Noun'),
#  ('놓아줘', 'Verb'),
#  ('맞지', 'Verb'),
#  ('않는', 'Verb'),
#  ('퍼즐', 'Noun'),
#  ('속', 'Noun'),
#  ('조각', 'Noun'),
#  ('처럼', 'Josa'),
#  ('흩어져', 'Verb'),
#  ('기억', 'Noun'),
#  ('너머', 'Noun'),
#  ('점점', 'Noun'),
#  ('멀어지는', 'Verb'),
#  ('너', 'Noun'),
#  ('를', 'Josa'),
#  ('내', 'Noun'),
#  ('마음', 'Noun'),
#  ('이', 'Josa'),
#  ('고장', 'Noun'),
#  ('난', 'Noun'),
#  ('듯', 'Noun'),
#  ('소리쳐도', 'Verb'),
#  ('들리지', 'Verb'),
#  ('않아', 'Verb'),
#  ('넌', 'Noun'),
#  ('답', 'Noun'),
#  ('을', 'Josa'),
#  ('원했고', 'Adjective'),
#  ('나', 'Noun'),
#  ('는', 'Josa'),
#  ('줄', 'Noun'),
#  ('수가', 'Noun'),
#  ('없어', 'Adjective'),
#  ('같은', 'Adjective'),
#  ('시간', 'Noun'),
#  ('속', 'Noun'),
#  ('우리', 'Noun'),
#  ('는', 'Josa'),
#  ('여기', 'Noun'),
#  ('까진', 'Josa'),
#  ('거야', 'Eomi'),
#  ('미안해', 'Adjective'),
#  ('미워해', 'Adjective'),
#  ('그냥', 'Noun'),
#  ('날', 'Noun'),
#  ('가끔', 'Noun'),
#  ('은', 'Josa'),
#  ('울컥', 'Adverb'),
#  ('쏟아지는', 'Verb'),
#  ('너', 'Noun'),
#  ('를', 'Josa'),
#  ('참고', 'Noun'),
#  ('차가운', 'Adjective'),
#  ('말', 'Noun'),
#  ('들', 'Suffix'),
#  ('로', 'Josa'),
#  ('돌아선', 'Verb'),
#  ('이', 'Determiner'),
#  ('기적', 'Noun'),
#  ('인', 'Josa'),
#  ('나', 'Noun'),
#  ('는', 'Josa'),
#  ('상처', 'Noun'),
#  ('만', 'Josa'),
#  ('주는', 'Verb'),
#  ('날', 'Noun'),
#  ('들이기에', 'Verb'),
#  ('내', 'Noun'),
#  ('사랑', 'Noun'),
#  ('은', 'Josa'),
#  ('망가졌고', 'Verb'),
#  ('네', 'Noun'),
#  ('마음', 'Noun'),
#  ('도', 'Josa'),
#  ('듣지를', 'Verb'),
#  ('않아', 'Verb'),
#  ('항상', 'Noun'),
#  ('답', 'Noun'),
#  ('을', 'Josa'),
#  ('원했고', 'Adjective'),
#  ('넌', 'Noun'),
#  ('줄', 'Noun'),
#  ('수가', 'Noun'),
#  ('없어', 'Adjective'),
#  ('같은', 'Adjective'),
#  ('시간', 'Noun'),
#  ('속', 'Noun'),
#  ('우리', 'Noun'),
#  ('는', 'Josa'),
#  ('여기', 'Noun'),
#  ('까진', 'Josa'),
#  ('거야', 'Eomi'),
#  ('미안해', 'Adjective'),
#  ('미워해', 'Adjective'),
#  ('미워해도', 'Adjective'),
#  ('돼', 'Verb'),
#  ('그만', 'Adverb'),
#  ('날', 'Noun'),
#  ('놓아줘', 'Verb'),
#  ('생각', 'Noun'),
#  ('한다', 'Verb'),
#  ('지난', 'Noun'),
#  ('날', 'Noun'),
#  ('들', 'Suffix'),
#  ('눈', 'Noun'),
#  ('이', 'Josa'),
#  ('부시도록', 'Verb'),
#  ('아름다웠던', 'Adjective'),
#  ('사라진다', 'Verb'),
#  ('뜨겁게', 'Adjective'),
#  ('안아주던', 'Verb'),
#  ('네', 'Noun'),
#  ('손', 'Noun'),
#  ('끝', 'Noun'),
#  ('향기', 'Noun'),
#  ('가', 'Josa'),
#  ('들려온다', 'Verb'),
#  ('너', 'Noun'),
#  ('의', 'Josa'),
#  ('그', 'Noun'),
#  ('노래', 'Noun'),
#  ('가', 'Josa'),
#  ('날', 'Noun'),
#  ('부르는', 'Verb'),
#  ('목소리', 'Noun'),
#  ('가', 'Josa'),
#  ('불러', 'Verb'),
#  ('본다', 'Verb'),
#  ('서툴게', 'Adjective'),
#  ('날', 'Noun'),
#  ('맴돌던', 'Verb'),
#  ('내', 'Noun'),
#  ('기억', 'Noun'),
#  ('속', 'Noun'),
#  ('그', 'Noun'),
#  ('이름', 'Noun'),
#  ('을', 'Josa'),
#  ('짧은', 'Adjective'),
#  ('하루', 'Noun'),
#  ('라도', 'Josa'),
#  ('숨', 'Noun'),
#  ('이', 'Josa'),
#  ('멎을', 'Verb'),
#  ('것', 'Noun'),
#  ('같아', 'Adjective'),
#  ('밀려오는', 'Verb'),
#  ('잔상', 'Noun'),
#  ('들', 'Suffix'),
#  ('로', 'Josa'),
#  ('미치도록', 'Adjective'),
#  ('그리던', 'Verb'),
#  ('순간', 'Noun'),
#  ('들', 'Suffix'),
#  ('로', 'Josa'),
#  ('또', 'Noun'),
#  ('널', 'Noun'),
#  ('기다려', 'Verb'),
#  ('본다', 'Verb'),
#  ('흩어진다', 'Verb'),
#  ('깊게', 'Adjective'),
#  ('새겨졌던', 'Verb'),
#  ('우리', 'Noun'),
#  ('의', 'Josa'),
#  ('시간', 'Noun'),
#  ('들', 'Suffix'),
#  ('이', 'Josa'),
#  ('잡지', 'Noun'),
#  ('못', 'VerbPrefix'),
#  ('해', 'Verb'),
#  ('작아진', 'Verb'),
#  ('뒷모습', 'Noun'),
#  ('도', 'Josa'),
#  ('이', 'Determiner'),
#  ('젠', 'Noun'),
#  ('닿을', 'Verb'),
#  ('수가', 'Noun'),
#  ('없잖아', 'Adjective'),
#  ('짧은', 'Adjective'),
#  ('하루', 'Noun'),
#  ('라도', 'Josa'),
#  ('숨', 'Noun'),
#  ('이', 'Josa'),
#  ('멎을', 'Verb'),
#  ('것', 'Noun'),
#  ('같아', 'Adjective'),
#  ('밀려오는', 'Verb'),
#  ('잔상', 'Noun'),
#  ('들', 'Suffix'),
#  ('로', 'Josa'),
#  ('미치도록', 'Adjective'),
#  ('그리던', 'Verb'),
#  ('순간', 'Noun'),
#  ('들', 'Suffix'),
#  ('로', 'Josa'),
#  ('또', 'Noun'),
#  ('널', 'Noun'),
#  ('기다려', 'Verb'),
#  ('본다', 'Verb'),
#  ('사라질', 'Verb'),
#  ('것', 'Noun'),
#  ('같던', 'Adjective'),
#  ('우리', 'Noun'),
#  ('의', 'Josa'),
#  ('시간', 'Noun'),
#  ('들', 'Suffix'),
#  ('이', 'Josa'),
#  ('아직도', 'Adverb'),
#  ('날', 'Noun'),
#  ('붙잡고', 'Verb'),
#  ('한번', 'Noun'),
#  ('만', 'Josa'),
#  ('더', 'Noun'),
#  ('너', 'Noun'),
#  ('를', 'Josa'),
#  ('담게', 'Verb'),
#  ('된다면', 'Verb'),
#  ('그', 'Noun'),
#  ('땐', 'Noun'),
#  ('놓지', 'Verb'),
#  ('않을게', 'Verb'),
#  ('우릴', 'Noun'),
#  ('놓지', 'Verb'),
#  ('않을게', 'Verb'),
#  ('지울게', 'Verb'),
#  ('너', 'Noun'),
#  ('에게', 'Josa'),
#  ('남겨', 'Verb'),
#  ('줬던', 'Verb'),
#  ('추억', 'Noun'),
#  ('까지도', 'Josa'),
#  ('바랄게', 'Verb'),
#  ('너', 'Noun'),
#  ('와의', 'Josa'),
#  ('기억', 'Noun'),
#  ('도', 'Josa'),
#  ('남지', 'Noun'),
#  ('못', 'VerbPrefix'),
#  ('하게', 'Verb'),
#  ('더', 'Noun'),
#  ('는', 'Josa'),
#  ('다가갈', 'Verb'),
#  ('수', 'Noun'),
#  ('없어', 'Adjective'),
#  ('네', 'Noun'),
#  ('게', 'Josa'),
#  ('이런', 'Adjective'),
#  ('마음', 'Noun'),
#  ('이', 'Josa'),
#  ('너무', 'Adverb'),
#  ('두려워', 'Adjective'),
#  ('너', 'Noun'),
#  ('의', 'Josa'),
#  ('기억', 'Noun'),
#  ('모두', 'Noun'),
#  ('가져가', 'Verb'),
#  ('줘', 'Verb'),
#  ('다', 'Adverb'),
#  ('지워줘', 'Verb'),
#  ('done', 'Alpha'),
#  ('for', 'Alpha'),
#  ('me', 'Alpha'),
#  ('깨끗이', 'Adverb'),
#  ('지워질', 'Verb'),
#  ('수', 'Noun'),
#  ('있을까', 'Adjective'),
#  ('널', 'Noun'),
#  ('벗어날', 'Verb'),
#  ('수', 'Noun'),
#  ('있을까', 'Adjective'),
#  ('사랑', 'Noun'),
#  ('했던', 'Verb'),
#  ('기억', 'Noun'),
#  ('도', 'Josa'),
#  ('다', 'Adverb'),
#  ('비워', 'Verb'),
#  ('낼', 'Noun'),
#  ('수', 'Noun'),
#  ('있을까', 'Adjective'),
#  ('더', 'Noun'),
#  ('이뤄질', 'Verb'),
#  ('수', 'Noun'),
#  ('는', 'Josa'),
#  ('없어', 'Adjective'),
#  ('난', 'Noun'),
#  ('다가갈', 'Verb'),
#  ('수', 'Noun'),
#  ('없어', 'Adjective'),
#  ('미친', 'Adjective'),
#  ('듯이', 'Noun'),
#  ('뛰어가', 'Verb'),
#  ('너', 'Noun'),
#  ('없는', 'Adjective'),
#  ('곳', 'Noun'),
#  ('에', 'Josa'),
#  ('가', 'Verb'),
#  ('사랑', 'Noun'),
#  ('은', 'Josa'),
#  ('갔고', 'Verb'),
#  ('남겨진', 'Verb'),
#  ('추억', 'Noun'),
#  ('들', 'Suffix'),
#  ('은', 'Josa'),
#  ('아팠고', 'Adjective'),
#  ('네', 'Noun'),
#  ('가', 'Josa'),
#  ('내게', 'Verb'),
#  ('남겨', 'Verb'),
#  ('줬던', 'Verb'),
#  ('기억', 'Noun'),
#  ('은', 'Josa'),
#  ('가시', 'Noun'),
#  ('가', 'Josa'),
#  ('됐고', 'Verb'),
#  ('다', 'Adverb'),
#  ('사라졌으면', 'Verb'),
#  ('해', 'Noun'),
#  ('모두', 'Noun'),
#  ('지워졌으면', 'Verb'),
#  ('해', 'Noun'),
#  ('나', 'Noun'),
#  ('쉴', 'Verb'),
#  ('수', 'Noun'),
#  ('있게', 'Adjective'),
#  ('널', 'Noun'),
#  ('떠날게', 'Verb'),
#  ('가질', 'Verb'),
#  ('수', 'Noun'),
#  ('없는', 'Adjective'),
#  ('너', 'Modifier'),
#  ('란', 'Noun'),
#  ('걸', 'Noun'),
#  ('알', 'Noun'),
#  ('고', 'Josa'),
#  ('있어', 'Adjective'),
#  ('보낼게', 'Verb'),
#  ('너', 'Noun'),
#  ('와의', 'Josa'),
#  ('기억', 'Noun'),
#  ('모두', 'Noun'),
#  ('다', 'Adverb'),
#  ('버릴게', 'Verb'),
#  ('더', 'Noun'),
#  ('는', 'Josa'),
#  ('다가갈', 'Verb'),
#  ('수', 'Noun'),
#  ('없어', 'Adjective'),
#  ('네', 'Noun'),
#  ('게', 'Josa'),
#  ('이런', 'Adjective'),
#  ('마음', 'Noun'),
#  ('이', 'Josa'),
#  ('너무', 'Adverb'),
#  ('두려워', 'Adjective'),
#  ('너', 'Noun'),
#  ('의', 'Josa'),
#  ('기억', 'Noun'),
#  ('모두', 'Noun'),
#  ('가져가', 'Verb'),
#  ('줘', 'Verb'),
#  ('다', 'Adverb'),
#  ('지워줘', 'Verb'),
#  ('done', 'Alpha'),
#  ('for', 'Alpha'),
#  ('me', 'Alpha'),
#  ('나', 'Noun'),
#  ('의', 'Josa'),
#  ('기억', 'Noun'),
#  ('에서', 'Josa'),
#  ('떠나가줘', 'Verb'),
#  ('너', 'Noun'),
#  ('의', 'Josa'),
#  ('추억', 'Noun'),
#  ('들', 'Suffix'),
#  ('도', 'Josa'),
#  ('가져가', 'Verb'),
#  ('줘', 'Verb'),
#  ('지워줘', 'Verb'),
#  ('너', 'Noun'),
#  ('의', 'Josa'),
#  ('그리움', 'Noun'),
#  ('까지도', 'Josa'),
#  ('그리워도', 'Adjective'),
#  ('그립지는', 'Verb'),
#  ('않게', 'Verb'),
#  ('모든', 'Noun'),
#  ('순간', 'Noun'),
#  ('들', 'Suffix'),
#  ('을', 'Josa'),
#  ('잊어', 'Verb'),
#  ('볼', 'Noun'),
#  ('게', 'Josa'),
#  ('다', 'Adverb'),
#  ('잊을게', 'Verb'),
#  ('너', 'Noun'),
#  ('의', 'Josa'),
#  ('작은', 'Adjective'),
#  ('흔적', 'Noun'),
#  ('까지도', 'Josa'),
#  ('지울게', 'Verb'),
#  ('너', 'Noun'),
#  ('에게', 'Josa'),
#  ('남겨', 'Verb'),
#  ('줬던', 'Verb'),
#  ('추억', 'Noun'),
#  ('까지도', 'Josa'),
#  ('바랄게', 'Verb'),
#  ('너', 'Noun'),
#  ('와의', 'Josa'),
#  ('기억', 'Noun'),
#  ('도', 'Josa'),
#  ('남지', 'Noun'),
#  ('못', 'VerbPrefix'),
#  ('하게', 'Verb'),
#  ('더', 'Noun'),
#  ('는', 'Josa'),
#  ('다가갈', 'Verb'),
#  ('수', 'Noun'),
#  ('없어', 'Adjective'),
#  ('네', 'Noun'),
#  ('게', 'Josa'),
#  ('이런', 'Adjective'),
#  ('마음', 'Noun'),
#  ('이', 'Josa'),
#  ('너무', 'Adverb'),
#  ('두려워', 'Adjective'),
#  ('너', 'Noun'),
#  ('의', 'Josa'),
#  ('기억', 'Noun'),
#  ('모두', 'Noun'),
#  ('가져가', 'Verb'),
#  ('줘', 'Verb'),
#  ('다', 'Adverb'),
#  ('지워줘', 'Verb'),
#  ('done', 'Alpha'),
#  ('for', 'Alpha'),
#  ('me', 'Alpha'),
#  ('너', 'Noun'),
#  ('를', 'Josa'),
#  ('떠날', 'Verb'),
#  ('수', 'Noun'),
#  ('밖에', 'Josa'),
#  ('멀어질', 'Verb'),
#  ('수', 'Noun'),
#  ('밖에', 'Josa'),
#  ('없으니까', 'Adjective'),
#  ('이런', 'Adjective'),
#  ('나를', 'Verb'),
#  ('제발', 'Noun'),
#  ('용서', 'Noun'),
#  ('해줘', 'Verb'),
#  ('언젠가', 'Adverb'),
#  ('는', 'Verb'),
#  ('우리', 'Noun'),
#  ('다시', 'Noun'),
#  ('만날', 'Noun'),
#  ('수', 'Noun'),
#  ('있기를', 'Adjective'),
#  ('done', 'Alpha'),
#  ('for', 'Alpha'),
#  ('me', 'Alpha'),
#  ('done', 'Alpha'),
#  ('for', 'Alpha'),
#  ('me', 'Alpha'),
#  ('비', 'Noun'),
#  ('내리는', 'Verb'),
#  ('날', 'Noun'),
#  ('창가', 'Noun'),
#  ('에', 'Josa'),
#  ('앉아', 'Verb'),
#  ('서두르던', 'Verb'),
#  ('일상', 'Noun'),
#  ('을', 'Josa'),
#  ('달래다', 'Verb'),
#  ('울적해진', 'Adjective'),
#  ('마음잡고', 'Verb'),
#  ('써', 'Verb'),
#  ('내려가다', 'Verb'),
#  ('울컥', 'Adverb'),
#  ('눈물', 'Noun'),
#  ('만', 'Josa'),
#  ('헤어진단', 'Verb'),
#  ('게', 'Noun'),
#  ('낯설기만', 'Adjective'),
#  ('해', 'Noun'),
#  ('하루하루', 'Noun'),
#  ('를', 'Josa'),
#  ('그저', 'Adverb'),
#  ('버티다가', 'Verb'),
#  ('누군가', 'Noun'),
#  ('내게', 'Verb'),
#  ('네', 'Noun'),
#  ('얘길', 'Noun'),
#  ('물', 'Noun'),
#  ('을', 'Josa'),
#  ('때', 'Noun'),
#  ('면', 'Josa'),
#  ('울컥', 'Adverb'),
#  ('눈물', 'Noun'),
#  ('만', 'Josa'),
#  ('어두워지면', 'Verb'),
#  ('밤하늘', 'Noun'),
#  ('을', 'Josa'),
#  ('헤매다', 'Verb'),
#  ('잠시', 'Noun'),
#  ('잊었던', 'Verb'),
#  ('혼자', 'Noun'),
#  ('라는', 'Josa'),
#  ('생각', 'Noun'),
#  ('에', 'Josa'),
#  ('밤새', 'Noun'),
#  ('뒤척', 'Noun'),
#  ('이다', 'Josa'),
#  ('네', 'Noun'),
#  ('생각', 'Noun'),
#  ('에', 'Josa'),
#  ('잠', 'Noun'),
#  ('못', 'Noun'),
#  ('드는', 'Verb'),
#  ('날', 'Noun'),
#  ('엔', 'Josa'),
#  ('그저', 'Adverb'),
#  ('눈물', 'Noun'),
#  ('만', 'Josa'),
#  ('다른', 'Noun'),
#  ('사람', 'Noun'),
#  ('을', 'Josa'),
#  ('만난다면', 'Verb'),
#  ('그땐', 'Noun'),
#  ('꼭', 'Noun'),
#  ('바랄게', 'Verb'),
#  ('나', 'Noun'),
#  ('보단', 'Josa'),
#  ('너', 'Noun'),
#  ('를', 'Josa'),
#  ('더', 'Noun'),
#  ('이해', 'Noun'),
#  ('하길', 'Verb'),
#  ('우리', 'Noun'),
#  ('뜨겁게', 'Adjective'),
#  ('사랑', 'Noun'),
#  ('했던', 'Verb'),
#  ('기억', 'Noun'),
#  ('모두', 'Noun'),
#  ('다', 'Adverb'),
#  ('지우고', 'Verb'),
#  ('만난', 'Noun'),
#  ('적', 'Noun'),
#  ('없었던', 'Adjective'),
#  ('것', 'Noun'),
#  ('처럼', 'Josa'),
#  ('Oh', 'Alpha'),
#  ('You', 'Alpha'),
#  ('Oh', 'Alpha'),
#  ('You', 'Alpha'),
#  ('마치', 'Noun'),
#  ('우린', 'Noun'),
#  ('없었던', 'Adjective'),
#  ('사이', 'Noun'),
#  ('어두워지면', 'Verb'),
#  ('밤하늘', 'Noun'),
#  ('을', 'Josa'),
#  ('헤매다', 'Verb'),
#  ('잠시', 'Noun'),
#  ('잊었던', 'Verb'),
#  ('혼자', 'Noun'),
#  ('라는', 'Josa'),
#  ('생각', 'Noun'),
#  ('에', 'Josa'),
#  ('밤새', 'Noun'),
#  ('뒤척', 'Noun'),
#  ('이다', 'Josa'),
#  ('네', 'Noun'),
#  ('생각', 'Noun'),
#  ('에', 'Josa'),
#  ('잠', 'Noun'),
#  ('못', 'Noun'),
#  ('드는', 'Verb'),
#  ('날', 'Noun'),
#  ('엔', 'Josa'),
#  ('그저', 'Adverb'),
#  ('눈물', 'Noun'),
#  ('만', 'Josa'),
#  ('다른', 'Noun'),
#  ('사람', 'Noun'),
#  ('을', 'Josa'),
#  ('만난다면', 'Verb'),
#  ('그땐', 'Noun'),
#  ('꼭', 'Noun'),
#  ('바랄게', 'Verb'),
#  ('나', 'Noun'),
#  ('보단', 'Josa'),
#  ('너', 'Noun'),
#  ('를', 'Josa'),
#  ('더', 'Noun'),
#  ('이해', 'Noun'),
#  ('하길', 'Verb'),
#  ('우리', 'Noun'),
#  ('뜨겁게', 'Adjective'),
#  ('사랑', 'Noun'),
#  ('했던', 'Verb'),
#  ('기억', 'Noun'),
#  ('모두', 'Noun'),
#  ('다', 'Adverb'),
#  ('지우고', 'Verb'),
#  ('만난', 'Noun'),
#  ('적', 'Noun'),
#  ('없었던', 'Adjective'),
#  ('것', 'Noun'),
#  ('처럼', 'Josa'),
#  ('그렇게', 'Adverb'),
#  ('뱉어놓은', 'Verb'),
#  ('그', 'Noun'),
#  ('많은', 'Adjective'),
#  ('말', 'Noun'),
#  ('들', 'Suffix'),
#  ('은', 'Josa'),
#  ('없어', 'Adjective'),
#  ('마치', 'Noun'),
#  ('우린', 'Noun'),
#  ('없었던', 'Adjective'),
#  ('사이', 'Noun'),
#  ('다른', 'Noun'),
#  ('사람', 'Noun'),
#  ('을', 'Josa'),
#  ('만난다면', 'Verb'),
#  ('그땐', 'Noun'),
#  ('꼭', 'Noun'),
#  ('바랄게', 'Verb'),
#  ('나', 'Noun'),
#  ('보단', 'Josa'),
#  ('너', 'Noun'),
#  ('를', 'Josa'),
#  ('더', 'Noun'),
#  ('이해', 'Noun'),
#  ('하길', 'Verb'),
#  ('우리', 'Noun'),
#  ('뜨겁게', 'Adjective'),
#  ('사랑', 'Noun'),
#  ('했던', 'Verb'),
#  ('기억', 'Noun'),
#  ('모두', 'Noun'),
#  ('다', 'Adverb'),
#  ('지우고', 'Verb'),
#  ('만난', 'Noun'),
#  ('적', 'Noun'),
#  ('없었던', 'Adjective'),
#  ('것', 'Noun'),
#  ('처럼', 'Josa'),
#  ('Oh', 'Alpha'),
#  ('You', 'Alpha'),
#  ('마치', 'Noun'),
#  ('우린', 'Noun'),
#  ('없었던', 'Adjective'),
#  ('사이', 'Noun'),
#  ('새', 'Noun'),
#  ('하얀', 'Adjective'),
#  ('머플러', 'Noun'),
#  ('에', 'Josa'),
#  ('얼굴', 'Noun'),
#  ('을', 'Josa'),
#  ('묻고', 'Verb'),
#  ('붉어진', 'Adjective'),
#  ('눈', 'Noun'),
#  ('을', 'Josa'),
#  ('깜빡', 'Noun'),
#  ('이며', 'Josa'),
#  ('널', 'Noun'),
#  ('기다렸어', 'Verb'),
#  ('무슨', 'Noun'),
#  ('얘길', 'Noun'),
#  ('하고', 'Verb'),
#  ('픈', 'Noun'),
#  ('지', 'Josa'),
#  ('그', 'Noun'),
#  ('말', 'Noun'),
#  ('알', 'Noun'),
#  ('것', 'Noun'),
#  ('도', 'Josa'),
#  ('같은데', 'Adjective'),
#  ('모르겠어', 'Verb'),
#  ('어색한', 'Adjective'),
#  ('눈', 'Noun'),
#  ('인사', 'Noun'),
#  ('에', 'Josa'),
#  ('목', 'Noun'),
#  ('이', 'Josa'),
#  ('메이', 'Noun'),
#  ('고', 'Josa'),
#  ('한', 'Verb'),
#  ('발', 'Noun'),
#  ('물러', 'Verb'),
#  ('선', 'Noun'),
#  ('우리', 'Noun'),
#  ('둘', 'Noun'),
#  ('공간', 'Noun'),
#  ('에', 'Josa'),
#  ('눈물', 'Noun'),
#  ('터지고', 'Verb'),
#  ('화가', 'Noun'),
#  ('나서', 'Verb'),
#  ('소리치듯', 'Verb'),
#  ('가란', 'Verb'),
#  ('내', 'Noun'),
#  ('말', 'Noun'),
#  ('에', 'Josa'),
#  ('벌써', 'Noun'),
#  ('넌', 'Noun'),
#  ('아주', 'Noun'),
#  ('멀리', 'Noun'),
#  ('달아나', 'Verb'),
#  ('버렸어', 'Verb'),
#  ('오늘', 'Noun'),
#  ('헤어졌어요', 'Verb'),
#  ('우리', 'Noun'),
#  ('헤어졌어요', 'Verb'),
#  ('내', 'Noun'),
#  ('맘', 'Noun'),
#  ('알', 'Noun'),
#  ('것', 'Noun'),
#  ('같다면', 'Adjective'),
#  ('옆', 'Noun'),
#  ('에서', 'Josa'),
#  ('같이', 'Adverb'),
#  ('울어줘요', 'Verb'),
#  ('나', 'Noun'),
#  ('는', 'Josa'),
#  ('안되나', 'Adjective'),
#  ('봐요', 'Verb'),
#  ('역시', 'Noun'),
#  ('아닌', 'Adjective'),
#  ('가봐요', 'Verb'),
#  ('얼마나', 'Noun'),
#  ('더', 'Noun'),
#  ('울어야', 'Verb'),
#  ('제대로', 'Noun'),
#  ('사랑', 'Noun'),
#  ('할까', 'Verb'),
#  ('요', 'Noun'),
#  ('귓가', 'Noun'),
#  ('엔', 'Josa'),
#  ('심장소리', 'Noun'),
#  ('그대', 'Noun'),
#  ('울리고', 'Verb'),
#  ('지운', 'Verb'),
#  ('니', 'Noun'),
#  ('번호', 'Noun'),
#  ('지', 'Modifier'),
#  ('울', 'Modifier'),
#  ('수록', 'Noun'),
#  ('더욱', 'Noun'),
#  ('또렷', 'Noun'),
#  ('해지', 'Noun'),
#  ('고', 'Josa'),
#  ('언제', 'Noun'),
#  ('부터', 'Josa'),
#  ('어디', 'Noun'),
#  ('부터', 'Josa'),
#  ('멀어진', 'Verb'),
#  ('건지', 'Verb'),
#  ('분명히', 'Adjective'),
#  ('어제', 'Noun'),
#  ('까진', 'Josa'),
#  ('날', 'Noun'),
#  ('사랑', 'Noun'),
#  ('했는데', 'Verb'),
#  ('오늘', 'Noun'),
#  ('헤어졌어요', 'Verb'),
#  ('우리', 'Noun'),
#  ('헤어졌어요', 'Verb'),
#  ('내', 'Noun'),
#  ('맘', 'Noun'),
#  ('알', 'Noun'),
#  ('것', 'Noun'),
#  ('같다면', 'Adjective'),
#  ('옆', 'Noun'),
#  ('에서', 'Josa'),
#  ('같이', 'Adverb'),
#  ('울어줘요', 'Verb'),
#  ('나', 'Noun'),
#  ('는', 'Josa'),
#  ('안되나', 'Adjective'),
#  ('봐요', 'Verb'),
#  ('역시', 'Noun'),
#  ('아닌', 'Adjective'),
#  ('가봐요', 'Verb'),
#  ('얼마나', 'Noun'),
#  ('더', 'Noun'),
#  ('울어야', 'Verb'),
#  ('제대로', 'Noun'),
#  ('사랑', 'Noun'),
#  ('할까', 'Verb'),
#  ('요', 'Noun'),
#  ('참', 'Verb'),
#  ('좋았어', 'Adjective'),
#  ('너무', 'Adverb'),
#  ('좋아서', 'Adjective'),
#  ('더', 'Noun'),
#  ('아프죠', 'Adjective'),
#  ('사랑', 'Noun'),
#  ('에', 'Josa'),
#  ('또', 'Noun'),
#  ('속', 'Noun'),
#  ('은', 'Josa'),
#  ('내', 'Noun'),
#  ('가', 'Josa'),
#  ('미워', 'Verb'),
#  ('그냥', 'Noun'),
#  ('나오지', 'Verb'),
#  ('말', 'Noun'),
#  ('걸', 'Noun'),
#  ('그냥', 'Noun'),
#  ('아프다', 'Adjective'),
#  ('할', 'Verb'),
#  ('걸', 'Noun'),
#  ('우리', 'Noun'),
#  ('사랑', 'Noun'),
#  ('한', 'Josa'),
#  ('기억', 'Noun'),
#  ('그게', 'Noun'),
#  ('널', 'Noun'),
#  ('붙잡아', 'Verb'),
#  ('줄', 'Noun'),
#  ('텐데', 'Eomi'),
#  ('너', 'Noun'),
#  ('는', 'Josa'),
#  ('내일', 'Noun'),
#  ('을', 'Josa'),
#  ('살', 'Noun'),
#  ('고', 'Josa'),
#  ('나', 'Noun'),
#  ('는', 'Josa'),
#  ('오늘', 'Noun'),
#  ('을', 'Josa'),
#  ('살', 'Noun'),
#  ('아', 'Josa'),
#  ('아무', 'Noun'),
#  ('도', 'Josa'),
#  ('아무', 'Modifier'),
#  ('것', 'Noun'),
#  ('도', 'Josa'),
#  ('날', 'Noun'),
#  ('웃게', 'Verb'),
#  ('할', 'Verb'),
#  ('수', 'Noun'),
#  ('는', 'Josa'),
#  ('없어', 'Adjective'),
#  ('오늘', 'Noun'),
#  ('헤어졌어요', 'Verb'),
#  ('우리', 'Noun'),
#  ('헤어졌어요', 'Verb'),
#  ('내', 'Noun'),
#  ('맘', 'Noun'),
#  ('알', 'Noun'),
#  ('것', 'Noun'),
#  ('같다면', 'Adjective'),
#  ('옆', 'Noun'),
#  ('에서', 'Josa'),
#  ('같이', 'Adverb'),
#  ('울어줘요', 'Verb'),
#  ('나', 'Noun'),
#  ('는', 'Josa'),
#  ('안되나', 'Adjective'),
#  ('봐요', 'Verb'),
#  ('역시', 'Noun'),
#  ('아닌', 'Adjective'),
#  ('가봐요', 'Verb'),
#  ('얼마나', 'Noun'),
#  ('더', 'Noun'),
#  ('울어야', 'Verb'),
#  ('제대로', 'Noun'),
#  ('사랑', 'Noun'),
#  ('할까', 'Verb'),
#  ('요', 'Noun'),
#  ('정말', 'Noun'),
#  ('넌', 'Noun'),
#  ('다', 'Adverb'),
#  ('잊었더라', 'Verb'),
#  ('반갑게', 'Adjective'),
#  ('날', 'Noun'),
#  ('보는', 'Verb'),
#  ('너', 'Noun'),
#  ('의', 'Josa'),
#  ('얼굴', 'Noun'),
#  ('보니', 'Verb'),
#  ('그제야', 'Adverb'),
#  ('어렴풋이', 'Adverb'),
#  ('아파오더라', 'Adjective'),
#  ('새', 'Noun'),
#  ('살', 'Noun'),
#  ('차오르지', 'Verb'),
#  ('못', 'Noun'),
#  ('한', 'Josa'),
#  ('상처', 'Noun'),
#  ('가', 'Josa'),
#  ('눈물', 'Noun'),
#  ('은', 'Josa'),
#  ('흐르질', 'Verb'),
#  ('않더라', 'Verb'),
#  ('이별', 'Noun'),
#  ('이라', 'Josa'),
#  ('하는', 'Verb'),
#  ('게', 'Noun'),
#  ('대', 'Modifier'),
#  ('단치', 'Noun'),
#  ('도', 'Josa'),
#  ('못', 'VerbPrefix'),
#  ('해서', 'Verb'),
#  ('이렇게', 'Adverb'),
#  ('보잘', 'Verb'),
#  ('것', 'Noun'),
#  ('없어서', 'Adjective'),
#  ('좋은', 'Adjective'),
#  ('이별', 'Noun'),
#  ('이란', 'Josa'),
#  ('거', 'Noun'),
#  ('결국', 'Adverb'),
#  ('세상', 'Noun'),
#  ('엔', 'Josa'),
#  ('없는', 'Adjective'),
#  ('일이', 'Noun'),
#  ('라는', 'Josa'),
#  ('걸', 'Noun'),
#  ('알았다면', 'Verb'),
#  ('그때', 'Noun'),
#  ('차라리', 'Noun'),
#  ('다', 'Adverb'),
#  ('울어', 'Verb'),
#  ('둘', 'Noun'),
#  ('걸', 'Noun'),
#  ('그때', 'Noun'),
#  ('이미', 'Adverb'),
#  ('나라', 'Noun'),
#  ('는', 'Josa'),
#  ('건', 'Noun'),
#  ...]

# %%
adjective_list = []
for i in range(len(t.pos(test1))):
    if t.pos(test1)[i][1] == 'Adjective':
        adjective_list.append(t.pos(test1)[i][0])

# %%
adjective_list
# Out:
# ['어떻게',
#  '없어',
#  '마른',
#  '원했고',
#  '없어',
#  '같은',
#  '미안해',
#  '미워해',
#  '원했고',
#  '없어',
#  '같은',
#  '미안해',
#  '미워해',
#  '차가운',
#  '원했고',
#  '없어',
#  '같은',
#  '미안해',
#  '미워해',
#  '미워해도',
#  '아름다웠던',
#  '뜨겁게',
#  '서툴게',
#  '짧은',
#  '같아',
#  '미치도록',
#  '깊게',
#  '없잖아',
#  '짧은',
#  '같아',
#  '미치도록',
#  '같던',
#  '없어',
#  '이런',
#  '두려워',
#  '있을까',
#  '있을까',
#  '있을까',
#  '없어',
#  '없어',
#  '미친',
#  '없는',
#  '아팠고',
#  '있게',
#  '없는',
#  '있어',
#  '없어',
#  '이런',
#  '두려워',
#  '그리워도',
#  '작은',
#  '없어',
#  '이런',
#  '두려워',
#  '없으니까',
#  '이런',
#  '있기를',
#  '울적해진',
#  '낯설기만',
#  '뜨겁게',
#  '없었던',
#  '없었던',
#  '뜨겁게',
#  '없었던',
#  '많은',
#  '없어',
#  '없었던',
#  '뜨겁게',
#  '없었던',
#  '없었던',
#  '하얀',
#  '붉어진',
#  '같은데',
#  '어색한',
#  '같다면',
#  '안되나',
#  '아닌',
#  '분명히',
#  '같다면',
#  '안되나',
#  '아닌',
#  '좋았어',
#  '좋아서',
#  '아프죠',
#  '아프다',
#  '없어',
#  '같다면',
#  '안되나',
#  '아닌',
#  '반갑게',
#  '아파오더라',
#  '없어서',
#  '좋은',
#  '없는',
#  '아니었더라',
#  '같아',
#  '미안했어야만',
#  '들떴었나',
#  '우스웠던',
#  '좋은',
#  '없는',
#  '좁은',
#  '없어서',
#  '괜찮다',
#  '완전히',
#  '없는',
#  '벅차도록',
#  '행복했던',
#  '아플',
#  '같은',
#  '충분히',
#  '그러니',
#  '벅차도록',
#  '행복했던',
#  '아플',
#  '없는',
#  '없었고',
#  '벅차도록',
#  '행복했던',
#  '아플',
#  '고마웠어',
#  '서툰',
#  '아련한',
#  '뒤늦게',
#  '따스한',
#  '그리운',
#  '싫어져',
#  '없는게',
#  '아파',
#  '서툰',
#  '없는',
#  '많았어',
#  '뒤늦게',
#  '따스한',
#  '그리운',
#  '싫어져',
#  '없는게',
#  '아파',
#  '같은데',
#  '없는게',
#  '아파',
#  '조용히',
#  '여전히',
#  '아닐',
#  '아쉬울',
#  '같',
#  '같',
#  '그런',
#  '날카로울',
#  '좋아했었던',
#  '이런',
#  '생생한',
#  '힘들게',
#  '길은',
#  '없지만',
#  '행복한',
#  '있었던',
#  '없었으니까',
#  '뒤늦게',
#  '아파야',
#  '차가웠던',
#  '따스한',
#  '같았어',
#  '아무렇지',
#  '차가운',
#  '무서워',
#  '있다면',
#  '없는',
#  '아프게',
#  '그리워해',
#  '그래',
#  '같다고',
#  '아파서',
#  '그래',
#  '행복하면',
#  '좋겠어',
#  '있니',
#  '슬픈',
#  '있어',
#  '없었지만',
#  '까마득해',
#  '있다',
#  '두려워',
#  '싫던',
#  '아파',
#  '없었지만',
#  '까마득해',
#  '있다',
#  '없는',
#  '많은',
#  '많은데',
#  '없던',
#  '그리워',
#  '없지만',
#  '없었으니까',
#  '그럴',
#  '있을까',
#  '있니',
#  '그래',
#  '싫지',
#  '영원한',
#  '미안해서',
#  '미안해서',
#  '이런',
#  '같은',
#  '있어',
#  '어떻게',
#  '이런',
#  '같은',
#  '아파',
#  '있으니',
#  '없는데',
#  '미안해서',
#  '미안해서',
#  '이런',
#  '같은',
#  '있어',
#  '어떻게',
#  '이런',
#  '같은',
#  '아파',
#  '있으니',
#  '슬픈',
#  '같은',
#  '영원히',
#  '그리워',
#  '같아',
#  '아니',
#  '아니',
#  '안될것',
#  '같아',
#  '좋았어',
#  '같은',
#  '없을거야',
#  '고마워',
#  '힘들었겠지',
#  '없었니',
#  '없니',
#  '좋은',
#  '좋았어',
#  '같은',
#  '없을거야',
#  '고마워',
#  '아파서',
#  '없어',
#  '어떻게',
#  '편해',
#  '아프게',
#  '힘들기',
#  '아파도',
#  '아프게',
#  '힘들기',
#  '아파도',
#  '괜찮아',
#  '그리워',
#  '아파',
#  '슬퍼도',
#  '같아서',
#  '있어',
#  '같아',
#  '같아',
#  '소용없는',
#  '같아',
#  '소용없는',
#  '있을까',
#  '그랬어',
#  '뜨겁고',
#  '치열했는데',
#  '괜찮아',
#  '소중했었고',
#  '완벽히',
#  '힘든',
#  '좋겠어',
#  '힘들어',
#  '미안한',
#  '편할거',
#  '같아',
#  '있다는게',
#  '낯설어',
#  '서운함은',
#  '소중했었고',
#  '완벽히',
#  '그랬나',
#  '솔직한',
#  '좋은',
#  '아프게',
#  '행복하겠지',
#  '설레이겠지',
#  '없이도',
#  '완벽히',
#  '확실히',
#  '행복하지',
#  '좋은',
#  '없나',
#  '힘들게',
#  '많은',
#  '좋은',
#  '있어',
#  '이상해',
#  '힘들어',
#  '미안하지만',
#  '어떻게',
#  '궁금한데',
#  '행복하길',
#  '예쁜',
#  '힘들',
#  '고맙게',
#  '나쁜',
#  '행복하길',
#  '예쁜',
#  '행복하게',
#  '예쁜',
#  '작은',
#  '힘든가',
#  '아픈가',
#  '노랠',
#  '아픈가',
#  '있을까',
#  '힘든',
#  '아픈',
#  '그런',
#  '행복했었어',
#  '좋았나',
#  '먼',
#  '좋았어',
#  '없어',
#  '같아',
#  '궁금해',
#  '싫어서',
#  '궁금해',
#  '예뻐져도',
#  '세련되져도',
#  '바쁘다며',
#  '변해가는',
#  '무심한',
#  '있어',
#  '다급했던',
#  '같아서',
#  '아름답게',
#  '없다고',
#  '미칠',
#  '아픈데',
#  '그런',
#  '있나',
#  '없단',
#  '그리워서',
#  '없나',
#  '있는',
#  '그랬어',
#  '같은',
#  '없나',
#  '그런',
#  '있나',
#  '없단',
#  '그리워서',
#  '없나',
#  '행복해',
#  '없이도',
#  '어떻게',
#  '있을까',
#  '그리워서',
#  '없잖아']

# %%
# 불용어 추가
# 실행해보면서 추가하면서 바꿔야함.
stop_words3 = ["그리워하다","있게","선명히","있나요","이런","있네요","깉","그런","길은","없었으니까",\
               "있어","그래","수많은","있었잖아","말라","없게","같","같은","없어","없는","어떻게","아프게",\
               "아닌","아니","있으니","뒤늦게","있다","없을꺼야","같아","없는게","같아서","같다면","없잖아",\
               "안되나","없나","많은","완벽히","없어서","있니","없었지만","없을꺼야","그랬어","힘들기","힘들어",\
               "아픈가","깊게","같던","아팠고","그리워도","없으니까","있기를","있을까","없었던"
            ]
token_ko3 = [each_word for each_word in adjective_list if each_word not in stop_words3]
print(token_ko3)
# Out:
# ['마른', '원했고', '미안해', '미워해', '원했고', '미안해', '미워해', '차가운', '원했고', '미안해', '미워해', '미워해도', '아름다웠던', '뜨겁게', '서툴게', '짧은', '미치도록', '짧은', '미치도록', '두려워', '미친', '두려워', '작은', '두려워', '울적해진', '낯설기만', '뜨겁게', '뜨겁게', '뜨겁게', '하얀', '붉어진', '같은데', '어색한', '분명히', '좋았어', '좋아서', '아프죠', '아프다', '반갑게', '아파오더라', '좋은', '아니었더라', '미안했어야만', '들떴었나', '우스웠던', '좋은', '좁은', '괜찮다', '완전히', '벅차도록', '행복했던', '아플', '충분히', '그러니', '벅차도록', '행복했던', '아플', '없었고', '벅차도록', '행복했던', '아플', '고마웠어', '서툰', '아련한', '따스한', '그리운', '싫어져', '아파', '서툰', '많았어', '따스한', '그리운', '싫어져', '아파', '같은데', '아파', '조용히', '여전히', '아닐', '아쉬울', '날카로울', '좋아했었던', '생생한', '힘들게', '없지만', '행복한', '있었던', '아파야', '차가웠던', '따스한', '같았어', '아무렇지', '차가운', '무서워', '있다면', '그리워해', '같다고', '아파서', '행복하면', '좋겠어', '슬픈', '까마득해', '두려워', '싫던', '아파', '까마득해', '많은데', '없던', '그리워', '없지만', '그럴', '싫지', '영원한', '미안해서', '미안해서', '아파', '없는데', '미안해서', '미안해서', '아파', '슬픈', '영원히', '그리워', '안될것', '좋았어', '없을거야', '고마워', '힘들었겠지', '없었니', '없니', '좋은', '좋았어', '없을거야', '고마워', '아파서', '편해', '아파도', '아파도', '괜찮아', '그리워', '아파', '슬퍼도', '소용없는', '소용없는', '뜨겁고', '치열했는데', '괜찮아', '소중했었고', '힘든', '좋겠어', '미안한', '편할거', '있다는게', '낯설어', '서운함은', '소중했었고', '그랬나', '솔직한', '좋은', '행복하겠지', '설레이겠지', '없이도', '확실히', '행복하지', '좋은', '힘들게', '좋은', '이상해', '미안하지만', '궁금한데', '행복하길', '예쁜', '힘들', '고맙게', '나쁜', '행복하길', '예쁜', '행복하게', '예쁜', '작은', '힘든가', '노랠', '힘든', '아픈', '행복했었어', '좋았나', '먼', '좋았어', '궁금해', '싫어서', '궁금해', '예뻐져도', '세련되져도', '바쁘다며', '변해가는', '무심한', '다급했던', '아름답게', '없다고', '미칠', '아픈데', '있나', '없단', '그리워서', '있는', '있나', '없단', '그리워서', '행복해', '없이도', '그리워서']

# %%
# 상위 50개 단어 확인
# 이걸보면서 불용어 지우는게 편해 전체는 힘들어
ko3 = nltk.Text(token_ko3)
ko3.vocab().most_common(50)
# Out:
# [('아파', 7),
#  ('좋은', 6),
#  ('뜨겁게', 4),
#  ('두려워', 4),
#  ('좋았어', 4),
#  ('미안해서', 4),
#  ('원했고', 3),
#  ('미안해', 3),
#  ('미워해', 3),
#  ('벅차도록', 3),
#  ('행복했던', 3),
#  ('아플', 3),
#  ('따스한', 3),
#  ('그리워', 3),
#  ('예쁜', 3),
#  ('그리워서', 3),
#  ('차가운', 2),
#  ('짧은', 2),
#  ('미치도록', 2),
#  ('작은', 2),
#  ('같은데', 2),
#  ('서툰', 2),
#  ('그리운', 2),
#  ('싫어져', 2),
#  ('힘들게', 2),
#  ('없지만', 2),
#  ('아파서', 2),
#  ('좋겠어', 2),
#  ('슬픈', 2),
#  ('까마득해', 2),
#  ('없을거야', 2),
#  ('고마워', 2),
#  ('아파도', 2),
#  ('괜찮아', 2),
#  ('소용없는', 2),
#  ('소중했었고', 2),
#  ('힘든', 2),
#  ('없이도', 2),
#  ('행복하길', 2),
#  ('궁금해', 2),
#  ('있나', 2),
#  ('없단', 2),
#  ('마른', 1),
#  ('미워해도', 1),
#  ('아름다웠던', 1),
#  ('서툴게', 1),
#  ('미친', 1),
#  ('울적해진', 1),
#  ('낯설기만', 1),
#  ('하얀', 1)]

# %%
# 상위 50개의 빈도수 차트 만들기
plt.figure(figsize=(12,6))
ko3.plot(50)
plt.show()

# %%
# 상위 50개만 wordcloud로 그리기
# 구한데이터로 그리기
data3 = ko3.vocab().most_common(50)

# 딕셔너리로 만들기
tmp_data3 = dict(data3)

wordcloud3 = WordCloud(
    background_color='White',
    relative_scaling=0.8,
    font_path="AppleGothic" # 윈도우 => 'c:/Windows/Fonts/malgun.ttf'
).generate_from_frequencies(tmp_data3)

# %%
plt.figure(figsize=(16,8))
plt.imshow(wordcloud3, interpolation='bilinear')
plt.axis('off')
plt.show()
