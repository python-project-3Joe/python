# %% [markdown]
# ---
# ## ballad_sad에서 20개 데이터 추출하기

# %%
import pandas as pd
import numpy as np
import random

# %%
sad = pd.read_csv("../../Data/ballad_sad.csv")
len(sad)
# Out:
# 30

# %%
index_list = range(0,30)

# %%
index = random.sample(index_list,20)
index
# Out:
# [14, 15, 4, 2, 20, 1, 27, 10, 18, 17, 16, 21, 12, 13, 28, 26, 23, 7, 24, 5]

# %%
sad20 = sad.iloc[index,:]

# %%
sad20.reset_index(drop=True,inplace=True)

# %%
sad20.to_csv("../../Data/ballad_sad20.csv",index=False)

# %%
sad20 = pd.read_csv("../../Data/ballad_sad20.csv")
sad20
# Out:
#               가수명                      노래제목         발매일  \
# 0   MSG워너비(M.O.M)                    바라만 본다  2021-06-26
# 1             전상근             오늘따라 더 미운 그대가  2021-06-13
# 2       나비 (Navi)                   잘 된 일이야  2011-01-19
# 3     헤이즈 (Heize)           비가 오는 날엔 (2021)  2021-08-04
# 4             김나영  널 미워하지 않길 (Prod. By 하동균)  2016-12-30
# 5             주보라       네가 없다 (Without You)  2013-02-19
# 6             정효빈                     처음이라서  2019-04-16
# 7             빅마마                     하루만 더  2021-06-24
# 8             이소정       함께 했는데 이별은 나 혼자인 거야  2021-02-19
# 9       포맨 (4MEN)               눈 떠보니 이별이더라  2017-10-24
# 10            윤토벤     서툰 이별을 하려해 (Feat.전상근)  2019-08-01
# 11            다비치   마치 우린 없었던 사이 (Prod. 정키)  2018-07-12
# 12       사이로(415)                  우리 둘 사이로  2019-08-29
# 13             이우                      내 안부  2019-07-16
# 14            아이유                나만 몰랐던 이야기  2011-02-17
# 15      강민경 (다비치)                   사랑해서 그래  2019-02-27
# 16            권진아                     이별 뒷면  2018-02-02
# 17     펀치 (Punch)                    이 밤의 끝  2018-05-31
# 18            아이유                 첫 이별 그날 밤  2010-12-09
# 19     펀치 (Punch)               안녕 내 전부였던 너  2021-03-10
#
#                                                    가사    좋아요수
# 0   내가 너라면 다 알아볼 텐데 널 위할 사람 찾아낼 텐데 지난 오랜 시간 너의 그 곁...  179238
# 1   조금은 괜찮다 생각했는데 이제는 잊혀질 때도 됐는데 아무렇지 않다가도 그대가 없단 ...   25819
# 2   Hello Hello Hello Hello Hello Don't cry Don't ...   42209
# 3   세상이 어두워지고 조용히 비가 내리면 여전히 그대로 오늘도 어김없이 난 벗어나질 못...   73229
# 4   그게 또 그래 이별이란 게 생각과는 늘 다르게 우리 좋았던 기억만 전부 지우고 나타...   21897
# 5   서툰 작별이었는지 아련한 슬픔 속에 눈물이 멈추질 않아 너무나 어렸던 걸까 내 이기...    2948
# 6   떨어질 줄 몰랐던 너의 품도 잡은 손에 스치던 봄바람도 떨리던 입맞춤도 맞춰 걷던 ...   58777
# 7   하루만 더 우리 이별을 늦춘다면 어땠을까 그럴 일 없다는 걸 나는 알면서도 아직 널...   58506
# 8   이젠 누군갈 만나는 게 난 아직은 힘이 들것 같아 다시는 믿고 싶지 않아 왜 난 사...   47706
# 9   분명 나는 꿈을 꾼 거다 눈 떠보니 이별이더라 휴대폰을 확인해 봤더니 다시 봐도 이...  115695
# 10  우리 이제 헤어지기로해 너도 알잖아 우린 충분했다는걸 이별이 무서워 자꾸 피해보지만...   81248
# 11  비 내리는 날 창가에 앉아 서두르던 일상을 달래다 울적해진 마음잡고 써 내려가다 울...   50062
# 12  Forget me close your eyes Forget me close your...    5998
# 13  내 소식 들었지 너와 헤어지고 참 많이 울고 힘들게 버티다 이해심이 많은 좋은 사람...   64527
# 14  정말 넌 다 잊었더라 반갑게 날 보는 너의 얼굴 보니 그제야 어렴풋이 아파오더라 새...  110805
# 15  잘 있니 잘 지내니 나는 요즘 부쩍 네가 보고 싶어 그래 알아 너는 다신 내가 보기...   32146
# 16  좁은 골목길은 또 하염없이 멀어져 마주앉은 탁자 반대편마저도 뻗어봐도 맞닿을 수가 ...   58856
# 17  널 보면 나와 달라 이렇게 난 네 생각뿐인데 널 사랑했던 만큼 아파야 하는 걸까 난...   47764
# 18  멍하니 아무 일도 할 일이 없어 이게 이별인 거니 전화기 가득 찬 너와의 메시지만 ...   93381
# 19  안녕 안녕 이제 인사를 해야지 너와 나의 이별인데 아니 아니 나는 그게 안될것 같아...   14135

# %% [markdown]
# ---
# # sad20 wordcloud만들기

# %%
import nltk # national language tool kit
from konlpy.tag import Okt
import matplotlib.pyplot as plt
from wordcloud import WordCloud

t = Okt()

# %%
t.nouns(sad20.loc[0,'가사'])
# Out:
# ['내',
#  '라면',
#  '널',
#  '위',
#  '사람',
#  '지난',
#  '시간',
#  '너',
#  '그',
#  '곁',
#  '온',
#  '나라',
#  '걸',
#  '내',
#  '너',
#  '사람',
#  '바보',
#  '눈치',
#  '그',
#  '사랑',
#  '너',
#  '왜',
#  '너',
#  '네',
#  '이름',
#  '보고',
#  '맘',
#  '너',
#  '향',
#  '그',
#  '발걸음',
#  '네',
#  '곁',
#  '맴',
#  '오늘',
#  '눈물',
#  '멀리',
#  '만',
#  '또',
#  '네',
#  '보고',
#  '네',
#  '나라',
#  '더',
#  '역할',
#  '내',
#  '모습',
#  '보이',
#  '내',
#  '볼',
#  '수',
#  '너',
#  '네',
#  '이름',
#  '보고',
#  '맘',
#  '너',
#  '향',
#  '그',
#  '발걸음',
#  '네',
#  '곁',
#  '맴',
#  '오늘',
#  '눈물',
#  '멀리',
#  '만',
#  '또',
#  '네',
#  '보고',
#  '걸음',
#  '더',
#  '더',
#  '가까이',
#  '네',
#  '어제',
#  '더',
#  '내일',
#  '더',
#  '널',
#  '사랑',
#  '혼자',
#  '그리움',
#  '바보',
#  '맘',
#  '못',
#  '그',
#  '한마디',
#  '널',
#  '사랑',
#  '말',
#  '얼마나',
#  '내',
#  '맘',
#  '너',
#  '곁',
#  '매일',
#  '하루',
#  '종일',
#  '너',
#  '생각',
#  '보고']

# %%
total20 = ""

# %%
for i in range(0, 20):
    total20 += (" " + sad20['가사'][i])

# %%
# 명사 분리
token_ko1 = t.nouns(total20)

# %%
token_ko1
# Out:
# ['내',
#  '라면',
#  '널',
#  '위',
#  '사람',
#  '지난',
#  '시간',
#  '너',
#  '그',
#  '곁',
#  '온',
#  '나라',
#  '걸',
#  '내',
#  '너',
#  '사람',
#  '바보',
#  '눈치',
#  '그',
#  '사랑',
#  '너',
#  '왜',
#  '너',
#  '네',
#  '이름',
#  '보고',
#  '맘',
#  '너',
#  '향',
#  '그',
#  '발걸음',
#  '네',
#  '곁',
#  '맴',
#  '오늘',
#  '눈물',
#  '멀리',
#  '만',
#  '또',
#  '네',
#  '보고',
#  '네',
#  '나라',
#  '더',
#  '역할',
#  '내',
#  '모습',
#  '보이',
#  '내',
#  '볼',
#  '수',
#  '너',
#  '네',
#  '이름',
#  '보고',
#  '맘',
#  '너',
#  '향',
#  '그',
#  '발걸음',
#  '네',
#  '곁',
#  '맴',
#  '오늘',
#  '눈물',
#  '멀리',
#  '만',
#  '또',
#  '네',
#  '보고',
#  '걸음',
#  '더',
#  '더',
#  '가까이',
#  '네',
#  '어제',
#  '더',
#  '내일',
#  '더',
#  '널',
#  '사랑',
#  '혼자',
#  '그리움',
#  '바보',
#  '맘',
#  '못',
#  '그',
#  '한마디',
#  '널',
#  '사랑',
#  '말',
#  '얼마나',
#  '내',
#  '맘',
#  '너',
#  '곁',
#  '매일',
#  '하루',
#  '종일',
#  '너',
#  '생각',
#  '보고',
#  '조금',
#  '생각',
#  '이제',
#  '때',
#  '그대',
#  '게',
#  '나',
#  '그때',
#  '추억',
#  '거릴',
#  '혼자',
#  '걸',
#  '때',
#  '자꾸만',
#  '눈앞',
#  '그대',
#  '그',
#  '왜',
#  '내',
#  '맘속',
#  '살',
#  '지금',
#  '그대',
#  '나',
#  '조금',
#  '그대',
#  '나',
#  '하나요',
#  '난',
#  '이별',
#  '투',
#  '하나',
#  '오늘',
#  '더',
#  '그대',
#  '보고',
#  '애',
#  '외면',
#  '추억',
#  '더욱',
#  '온',
#  '시간',
#  '더욱더',
#  '아픔',
#  '그',
#  '왜',
#  '내',
#  '맘속',
#  '살',
#  '지금',
#  '그대',
#  '나',
#  '조금',
#  '그대',
#  '나',
#  '하나요',
#  '난',
#  '이별',
#  '투',
#  '하나',
#  '오늘',
#  '더',
#  '그대',
#  '보고',
#  '길',
#  '이',
#  '마음',
#  '난',
#  '그',
#  '사랑',
#  '지금',
#  '그대',
#  '알',
#  '하루하루',
#  '추억',
#  '속',
#  '살',
#  '난',
#  '모든',
#  '게',
#  '투',
#  '오늘',
#  '더',
#  '그대',
#  '보고',
#  '오늘',
#  '그대',
#  '가슴',
#  '널',
#  '안',
#  '계속',
#  '너',
#  '잡고',
#  '안',
#  '먼저',
#  '뒤',
#  '거',
#  '면서',
#  '왜',
#  '사랑',
#  '해',
#  '눈물',
#  '대체',
#  '무슨',
#  '죄',
#  '차라리',
#  '일이',
#  '상처',
#  '줄',
#  '라면',
#  '더',
#  '전',
#  '전',
#  '지금',
#  '좀',
#  '더',
#  '가슴',
#  '더',
#  '사랑',
#  '난',
#  '너',
#  '내',
#  '가라',
#  '내',
#  '사랑',
#  '안녕',
#  '생각',
#  '나',
#  '정말',
#  '마르지',
#  '눈물',
#  '나',
#  '거',
#  '면서',
#  '왜',
#  '보고',
#  '해',
#  '두',
#  '눈',
#  '대체',
#  '무슨',
#  '죄',
#  '차라리',
#  '일이',
#  '상처',
#  '줄',
#  '라면',
#  '더',
#  '전',
#  '전',
#  '지금',
#  '좀',
#  '더',
#  '가슴',
#  '더',
#  '사랑',
#  '난',
#  '너',
#  '내',
#  '가라',
#  '내',
#  '사랑',
#  '안녕',
#  '사랑',
#  '널',
#  '그냥',
#  '걸',
#  '아마',
#  '나',
#  '곁',
#  '너',
#  '날',
#  '가슴',
#  '더',
#  '사랑',
#  '난',
#  '너',
#  '내',
#  '가라',
#  '내',
#  '사랑',
#  '안녕',
#  '세상',
#  '비',
#  '그대로',
#  '오늘',
#  '난',
#  '너',
#  '생각',
#  '안',
#  '이제',
#  '끝',
#  '걸',
#  '알',
#  '미련',
#  '걸',
#  '알',
#  '이제',
#  '걸',
#  '알',
#  '그까짓',
#  '자존심',
#  '널',
#  '잡지',
#  '내',
#  '조금',
#  '뿐',
#  '비',
#  '날',
#  '밤',
#  '비',
#  '너',
#  '따라서',
#  '서서히',
#  '취했',
#  '것',
#  '애',
#  '비',
#  '것',
#  '애',
#  '뭐',
#  '네',
#  '보고',
#  '건',
#  '다만',
#  '우리',
#  '시간',
#  '좀',
#  '뿐',
#  '기억',
#  '추억',
#  '덫',
#  '일부러',
#  '발',
#  '발버둥',
#  '치',
#  '이제',
#  '너',
#  '모두',
#  '비',
#  '너',
#  '모든',
#  '기억',
#  '다시',
#  '널',
#  '비',
#  '날',
#  '밤',
#  '비',
#  '너',
#  '따라서',
#  '서서히',
#  '너',
#  '젠',
#  '지금',
#  '너',
#  '난',
#  '볼',
#  '널',
#  '잡',
#  '수',
#  '힘',
#  '내겐',
#  '어차피',
#  '걸',
#  '이제',
#  '어쩌겠어',
#  '후회',
#  '거지',
#  '덜',
#  '애',
#  '항상',
#  '오',
#  '계속',
#  '반복',
#  '그',
#  '제',
#  '항상',
#  '오',
#  '계속',
#  '반복',
#  '그',
#  '제',
#  '그게',
#  '또',
#  '이별',
#  '게',
#  '생각',
#  '늘',
#  '우리',
#  '기억',
#  '전부',
#  '그땐',
#  '또',
#  '마음',
#  '게',
#  '생각',
#  '우리',
#  '기억',
#  '또',
#  '전부',
#  '가지',
#  '마음',
#  '욕',
#  '한참',
#  '해',
#  '날',
#  '수',
#  '밤',
#  '우리',
#  '기억',
#  '위로',
#  '우린',
#  '사랑',
#  '그게',
#  '널',
#  '게',
#  '생각',
#  '우리',
#  '사랑',
#  '기억',
#  '또',
#  '자꾸',
#  '내',
#  '맘',
#  '한참',
#  '동안',
#  '아무',
#  '일',
#  '내',
#  '맘',
#  '해',
#  '너',
#  '남아',
#  '널',
#  '수',
#  '밤',
#  '우리',
#  '기억',
#  '위로',
#  '날',
#  '기억',
#  '끝',
#  '왜',
#  '우린',
#  '서로',
#  '왜',
#  '사랑',
#  '끝',
#  '왜',
#  '우린',
#  '서로',
#  '또',
#  '이별',
#  '끝',
#  '왜',
#  '우린',
#  '서로',
#  '왜',
#  '우린',
#  '아파해',
#  '하나',
#  '날',
#  '수',
#  '밤',
#  '우리',
#  '기억',
#  '위로',
#  '날',
#  '기억',
#  '끝',
#  '곳',
#  '우린',
#  '사랑',
#  '기억',
#  '만',
#  '새',
#  '어쩌면',
#  '우린',
#  '서로',
#  '우린',
#  '사랑',
#  '지금',
#  '우린',
#  '끝',
#  '작별',
#  '슬픔',
#  '속',
#  '눈물',
#  '내',
#  '적임',
#  '너',
#  '우리',
#  '헤어지자',
#  '말',
#  '한지',
#  '하루',
#  '뒤',
#  '잠깐',
#  '실수',
#  '걸',
#  '깨달',
#  '순간',
#  '아침',
#  '네',
#  '목소리',
#  '네',
#  '품',
#  '벌써',
#  '내',
#  '바보',
#  '너',
#  '내',
#  '왜',
#  '이제',
#  '눈물',
#  '내',
#  '마음',
#  '알',
#  '수',
#  '더',
#  '사랑',
#  '나',
#  '항상',
#  '너',
#  '사람',
#  '때',
#  '우리',
#  '헤어지자',
#  '말',
#  '한지',
#  '하루',
#  '뒤',
#  '잠깐',
#  '실수',
#  '걸',
#  '깨달',
#  '순간',
#  '아침',
#  '네',
#  '목소리',
#  '네',
#  '품',
#  '벌써',
#  '내',
#  '바보',
#  '너',
#  '내',
#  '왜',
#  '이제',
#  '눈물',
#  '내',
#  '마음',
#  '알',
#  '수',
#  '더',
#  '작별인사',
#  '안',
#  '우리',
#  '사랑',
#  '그',
#  '기억',
#  '아침',
#  '네',
#  '목',
#  '소린',
#  '이제',
#  '어제',
#  '오늘',
#  '나',
#  '널',
#  '사랑',
#  '것',
#  '바보',
#  '너',
#  '내',
#  '왜',
#  '이제',
#  '눈물',
#  '내',
#  '마음',
#  '알',
#  '수',
#  '더',
#  '줄',
#  '너',
#  '손',
#  '봄바람',
#  '입맞춤',
#  '걸음',
#  '내겐',
#  '모두',
#  '처음',
#  '고',
#  '하루',
#  '끝',
#  '준',
#  '것',
#  '편지',
#  '눈물',
#  '준',
#  '것',
#  '벚꽃',
#  '여름',
#  '바다',
#  '단풍',
#  '함박눈',
#  '처음',
#  '나',
#  '첫',
#  '사람',
#  '내',
#  '첫사랑',
#  '너',
#  '처음',
#  '시간',
#  '무뎌',
#  '날',
#  '그때',
#  '더',
#  '아파해',
#  '볼',
#  '누군가',
#  '위',
#  '것',
#  '세상',
#  '누군가',
#  '자랑',
#  '것',
#  '너',
#  '게',
#  '게',
#  '나',
#  '첫',
#  '사람',
#  '내',
#  '첫사랑',
#  '너',
#  '처음',
#  '시간',
#  '널',
#  '날',
#  '그때',
#  '더',
#  '아파해',
#  '볼',
#  '사실',
#  '겁',
#  '나',
#  '젠',
#  '가도',
#  '너',
#  '추억',
#  '처음',
#  '거',
#  '더',
#  '거',
#  '처음',
#  '거',
#  '고생',
#  '너',
#  '너',
#  '시간',
#  '추억',
#  '젠',
#  '네',
#  '내',
#  '처음',
#  '하루',
#  '더',
#  '우리',
#  '이별',
#  '일',
#  '걸',
#  '나',
#  '널',
#  '수가',
#  '한번',
#  '나',
#  '널',
#  '볼',
#  '오늘',
#  '끝',
#  '보이지',
#  '내',
#  '사랑',
#  '가슴',
#  '깊이',
#  '이별',
#  '흉터',
#  '또',
#  '다시',
#  '너',
#  '내',
#  '전부',
#  '널',
#  '단',
#  '하루',
#  '더',
#  '너',
#  '사랑',
#  '단',
#  '한순간',
#  '못',
#  '너',
#  '세상',
#  '다시',
#  '시간',
#  '이별',
#  '왜',
#  '계속',
#  '내란',
#  '인사',
#  '것',
#  '오늘',
#  '눈물',
#  '혼자',
#  '내',
#  '맘',
#  '이해',
#  '네',
#  '흔적',
#  '그대로',
#  '남아',
#  '내',
#  '입술',
#  '추억',
#  '너',
#  '사랑',
#  '내',
#  '전부',
#  '널',
#  '단',
#  '하루',
#  '더',
#  '너',
#  '사랑',
#  '단',
#  '한순간',
#  '못',
#  '너',
#  '세상',
#  '다시',
#  '시간',
#  '이별',
#  '왜',
#  '계속',
#  '우리',
#  '이별',
#  '끝',
#  '지금',
#  '네',
#  '픈',
#  '말',
#  '널',
#  '사랑',
#  '단',
#  '한순간',
#  '못',
#  '너',
#  '세상',
#  '목',
#  '정말',
#  '그때',
#  '우린',
#  '추억',
#  '젠',
#  '누',
#  '게',
#  '난',
#  '은',
#  '힘',
#  '들것',
#  '왜',
#  '난',
#  '사랑',
#  '뭐',
#  '리도',
#  '홀로',
#  '또',
#  '날',
#  '사랑',
#  '절대',
#  '안',
#  '너',
#  '사랑',
#  '모든',
#  '걸',
#  '이별',
#  '나',
#  '혼자',
#  '왜',
#  '거',
#  '고',
#  '잠시',
#  '내',
#  '거',
#  '라면',
#  '수',
#  '네',
#  '때',
#  '날',
#  '말',
#  '날',
#  '위',
#  '척',
#  '너',
#  '그',
#  '표정',
#  '네',
#  '맘',
#  '끝',
#  '착각',
#  '말',
#  '맘',
#  '것',
#  '너',
#  '사랑',
#  '모든',
#  '걸',
#  '이별',
#  '나',
#  '혼자',
#  '왜',
#  '거',
#  '고',
#  '잠시',
#  '내',
#  '거',
#  '라면',
#  '수',
#  '네',
#  '때',
#  '날',
#  '말',
#  '나',
#  '너',
#  '네',
#  '모든',
#  '걸',
#  '사랑',
#  '내',
#  '널',
#  '내',
#  '탓',
#  '정말',
#  '사랑',
#  '네',
#  '품',
#  '다시',
#  '널',
#  '내',
#  '다시',
#  '나',
#  '울',
#  '그땐',
#  '내',
#  '곁',
#  '날',
#  '말',
#  '분명',
#  '나',
#  '꿈',
#  '꾼',
#  '거',
#  '눈',
#  '이별',
#  '더',
#  '휴대폰',
#  '확인',
#  '다시',
#  '이별',
#  '더',
#  '헛웃음',
#  '두',
#  '문득',
#  '네',
#  '얼굴',
#  '눈물',
#  '대체',
#  '무슨',
#  '짓',
#  '엎',
#  '물',
#  '난',
#  '채',
#  '꼼짝',
#  '못',
#  '그',
#  '이별',
#  '뒤',
#  '넌',
#  '사랑',
#  '정말',
#  '내',
#  '옆',
#  '늘',
#  '여기',
#  '네',
#  '날',
#  '그냥',
#  '식이',
#  '나',
#  '눈',
#  '이별',
#  '더',
#  '이건',
#  '절대',
#  '현실',
#  '눈',
#  '꿈',
#  '부정',
#  '이별',
#  '눈물',
#  '네',
#  '이름',
#  '움직',
#  '못',
#  '채',
#  '너',
#  '외치',
#  '그',
#  '이별',
#  '뒤',
#  '넌',
#  '사랑',
#  '정말',
#  '내',
#  '옆',
#  '늘',
#  '여기',
#  '네',
#  '날',
#  '그냥',
#  '식이',
#  '나',
#  '꿈',
#  '사랑',
#  '이별',
#  '현실',
#  '알람',
#  '하나',
#  '번만',
#  '더',
#  '기회',
#  '다시',
#  '내',
#  '바보',
#  '화가',
#  '나',
#  '수가',
#  '그',
#  '이별',
#  '뒤',
#  '이별',
#  '정말',
#  '가슴',
#  '네',
#  '날',
#  '나',
#  '사람과',
#  '평생',
#  '사랑',
#  '나',
#  '너',
#  '평생',
#  '나',
#  '너',
#  '안',
#  '눈',
#  '이별',
#  '더',
#  '우리',
#  '이제',
#  '해',
#  '너',
#  '우린',
#  '이별',
#  '자꾸',
#  '피',
#  '젠',
#  '정말',
#  '끝',
#  '우리',
#  '사랑',
#  '우리',
#  '추억',
#  '젠',
#  '기억',
#  '내',
#  '끝',
#  '걸',
#  '알',
#  '끝',
#  '눈',
#  '네',
#  '모습',
#  '날',
#  ...]

# %%
# 불용어 추가
# 실행해보면서 추가하면서 바꿔야함.
stop_words1 = ["손","고","준","것","첫","더","볼","위","것","게","겁","나","젠","거","줄",\
    "꾼", "거", "눈", "두", "짓", "엎", "물", "채", "뒤", "옆", "늘", "식이", "울", "해심", "척", "왜",\
          "해", "알", "이", "번", "때", "전", "걸", "롤", "굴지", "바", "적임", "수", "듯이", "래야", "쉬", "살", "자리"]
token_ko1 = [each_word for each_word in token_ko1 if each_word not in stop_words1]
print(token_ko1)
# Out:
# ['내', '라면', '널', '사람', '지난', '시간', '너', '그', '곁', '온', '나라', '내', '너', '사람', '바보', '눈치', '그', '사랑', '너', '너', '네', '이름', '보고', '맘', '너', '향', '그', '발걸음', '네', '곁', '맴', '오늘', '눈물', '멀리', '만', '또', '네', '보고', '네', '나라', '역할', '내', '모습', '보이', '내', '너', '네', '이름', '보고', '맘', '너', '향', '그', '발걸음', '네', '곁', '맴', '오늘', '눈물', '멀리', '만', '또', '네', '보고', '걸음', '가까이', '네', '어제', '내일', '널', '사랑', '혼자', '그리움', '바보', '맘', '못', '그', '한마디', '널', '사랑', '말', '얼마나', '내', '맘', '너', '곁', '매일', '하루', '종일', '너', '생각', '보고', '조금', '생각', '이제', '그대', '그때', '추억', '거릴', '혼자', '자꾸만', '눈앞', '그대', '그', '내', '맘속', '지금', '그대', '조금', '그대', '하나요', '난', '이별', '투', '하나', '오늘', '그대', '보고', '애', '외면', '추억', '더욱', '온', '시간', '더욱더', '아픔', '그', '내', '맘속', '지금', '그대', '조금', '그대', '하나요', '난', '이별', '투', '하나', '오늘', '그대', '보고', '길', '마음', '난', '그', '사랑', '지금', '그대', '하루하루', '추억', '속', '난', '모든', '투', '오늘', '그대', '보고', '오늘', '그대', '가슴', '널', '안', '계속', '너', '잡고', '안', '먼저', '면서', '사랑', '눈물', '대체', '무슨', '죄', '차라리', '일이', '상처', '라면', '지금', '좀', '가슴', '사랑', '난', '너', '내', '가라', '내', '사랑', '안녕', '생각', '정말', '마르지', '눈물', '면서', '보고', '대체', '무슨', '죄', '차라리', '일이', '상처', '라면', '지금', '좀', '가슴', '사랑', '난', '너', '내', '가라', '내', '사랑', '안녕', '사랑', '널', '그냥', '아마', '곁', '너', '날', '가슴', '사랑', '난', '너', '내', '가라', '내', '사랑', '안녕', '세상', '비', '그대로', '오늘', '난', '너', '생각', '안', '이제', '끝', '미련', '이제', '그까짓', '자존심', '널', '잡지', '내', '조금', '뿐', '비', '날', '밤', '비', '너', '따라서', '서서히', '취했', '애', '비', '애', '뭐', '네', '보고', '건', '다만', '우리', '시간', '좀', '뿐', '기억', '추억', '덫', '일부러', '발', '발버둥', '치', '이제', '너', '모두', '비', '너', '모든', '기억', '다시', '널', '비', '날', '밤', '비', '너', '따라서', '서서히', '너', '지금', '너', '난', '널', '잡', '힘', '내겐', '어차피', '이제', '어쩌겠어', '후회', '거지', '덜', '애', '항상', '오', '계속', '반복', '그', '제', '항상', '오', '계속', '반복', '그', '제', '그게', '또', '이별', '생각', '우리', '기억', '전부', '그땐', '또', '마음', '생각', '우리', '기억', '또', '전부', '가지', '마음', '욕', '한참', '날', '밤', '우리', '기억', '위로', '우린', '사랑', '그게', '널', '생각', '우리', '사랑', '기억', '또', '자꾸', '내', '맘', '한참', '동안', '아무', '일', '내', '맘', '너', '남아', '널', '밤', '우리', '기억', '위로', '날', '기억', '끝', '우린', '서로', '사랑', '끝', '우린', '서로', '또', '이별', '끝', '우린', '서로', '우린', '아파해', '하나', '날', '밤', '우리', '기억', '위로', '날', '기억', '끝', '곳', '우린', '사랑', '기억', '만', '새', '어쩌면', '우린', '서로', '우린', '사랑', '지금', '우린', '끝', '작별', '슬픔', '속', '눈물', '내', '너', '우리', '헤어지자', '말', '한지', '하루', '잠깐', '실수', '깨달', '순간', '아침', '네', '목소리', '네', '품', '벌써', '내', '바보', '너', '내', '이제', '눈물', '내', '마음', '사랑', '항상', '너', '사람', '우리', '헤어지자', '말', '한지', '하루', '잠깐', '실수', '깨달', '순간', '아침', '네', '목소리', '네', '품', '벌써', '내', '바보', '너', '내', '이제', '눈물', '내', '마음', '작별인사', '안', '우리', '사랑', '그', '기억', '아침', '네', '목', '소린', '이제', '어제', '오늘', '널', '사랑', '바보', '너', '내', '이제', '눈물', '내', '마음', '너', '봄바람', '입맞춤', '걸음', '내겐', '모두', '처음', '하루', '끝', '편지', '눈물', '벚꽃', '여름', '바다', '단풍', '함박눈', '처음', '사람', '내', '첫사랑', '너', '처음', '시간', '무뎌', '날', '그때', '아파해', '누군가', '세상', '누군가', '자랑', '너', '사람', '내', '첫사랑', '너', '처음', '시간', '널', '날', '그때', '아파해', '사실', '가도', '너', '추억', '처음', '처음', '고생', '너', '너', '시간', '추억', '네', '내', '처음', '하루', '우리', '이별', '일', '널', '수가', '한번', '널', '오늘', '끝', '보이지', '내', '사랑', '가슴', '깊이', '이별', '흉터', '또', '다시', '너', '내', '전부', '널', '단', '하루', '너', '사랑', '단', '한순간', '못', '너', '세상', '다시', '시간', '이별', '계속', '내란', '인사', '오늘', '눈물', '혼자', '내', '맘', '이해', '네', '흔적', '그대로', '남아', '내', '입술', '추억', '너', '사랑', '내', '전부', '널', '단', '하루', '너', '사랑', '단', '한순간', '못', '너', '세상', '다시', '시간', '이별', '계속', '우리', '이별', '끝', '지금', '네', '픈', '말', '널', '사랑', '단', '한순간', '못', '너', '세상', '목', '정말', '그때', '우린', '추억', '누', '난', '은', '힘', '들것', '난', '사랑', '뭐', '리도', '홀로', '또', '날', '사랑', '절대', '안', '너', '사랑', '모든', '이별', '혼자', '잠시', '내', '라면', '네', '날', '말', '날', '너', '그', '표정', '네', '맘', '끝', '착각', '말', '맘', '너', '사랑', '모든', '이별', '혼자', '잠시', '내', '라면', '네', '날', '말', '너', '네', '모든', '사랑', '내', '널', '내', '탓', '정말', '사랑', '네', '품', '다시', '널', '내', '다시', '그땐', '내', '곁', '날', '말', '분명', '꿈', '이별', '휴대폰', '확인', '다시', '이별', '헛웃음', '문득', '네', '얼 ...

# %%
# 상위 50개 단어 확인
# 이걸보면서 불용어 지우는게 편해 전체는 힘들어
ko1 = nltk.Text(token_ko1)
ko1.vocab().most_common(50)
# Out:
# [('너', 93),
#  ('내', 60),
#  ('사랑', 59),
#  ('네', 40),
#  ('이별', 39),
#  ('날', 39),
#  ('널', 38),
#  ('우리', 35),
#  ('이제', 30),
#  ('난', 28),
#  ('끝', 22),
#  ('그', 21),
#  ('말', 20),
#  ('눈물', 19),
#  ('또', 18),
#  ('기억', 18),
#  ('우린', 17),
#  ('못', 16),
#  ('시간', 14),
#  ('맘', 14),
#  ('생각', 14),
#  ('밤', 14),
#  ('다시', 14),
#  ('사람', 12),
#  ('보고', 12),
#  ('그대', 12),
#  ('추억', 12),
#  ('정말', 12),
#  ('혼자', 11),
#  ('지금', 11),
#  ('넌', 11),
#  ('오늘', 10),
#  ('하루', 10),
#  ('그때', 10),
#  ('곁', 9),
#  ('안녕', 8),
#  ('비', 8),
#  ('서로', 8),
#  ('사이', 8),
#  ('조금', 7),
#  ('가슴', 7),
#  ('안', 7),
#  ('그냥', 7),
#  ('세상', 7),
#  ('건', 7),
#  ('전부', 7),
#  ('그땐', 7),
#  ('처음', 7),
#  ('나라', 6),
#  ('바보', 6)]

# %%
# 한글 폰트 문제 해결 
# matplotlib은 한글 폰트를 지원하지 않음
# os정보
import platform

# font_manager : 폰트 관리 모듈
# rc : 폰트 변경 모듈
from matplotlib import font_manager, rc
# unicode 설정
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic') # os가 macos
elif platform.system() == 'Windows':
    path = 'c:/Windows/Fonts/malgun.ttf' # os가 windows
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print("Unknown System")

# %%
# Warning무시
import warnings
warnings.filterwarnings('ignore')

# %%
# 상위 50개의 빈도수 차트 만들기
plt.figure(figsize=(12,6))
ko1.plot(50)
plt.show()

# %%
# 상위 50개만 wordcloud로 그리기
# 구한데이터로 그리기
data = ko1.vocab().most_common(50)

# 딕셔너리로 만들기
tmp_data1 = dict(data)

wordcloud1 = WordCloud(
    background_color='White',
    relative_scaling=0.8,
    font_path="AppleGothic" # 윈도우 => 'c:/Windows/Fonts/malgun.ttf'
).generate_from_frequencies(tmp_data1)

# %%
plt.figure(figsize=(16,8))
plt.imshow(wordcloud1, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
test = total20

# %%
verb_list = []
for i in range(len(t.pos(test))):
    if t.pos(test)[i][1] == 'Verb':
        verb_list.append(t.pos(test)[i][0])

# %%
verb_list
# Out:
# ['알아볼',
#  '할',
#  '찾아낼',
#  '지켜',
#  '였다면',
#  '참',
#  '한',
#  '가졌으니까',
#  '챌',
#  '모르니',
#  '바라만',
#  '바라만',
#  '본다',
#  '외쳐',
#  '부른다',
#  '싶은',
#  '는데',
#  '애써',
#  '참았던',
#  '흘러',
#  '바라보다',
#  '소리쳐',
#  '싶다',
#  '참',
#  '맡을게',
#  '웃는',
#  '살아가',
#  '줘',
#  '바라만',
#  '바라만',
#  '본다',
#  '외쳐',
#  '부른다',
#  '싶은',
#  '는데',
#  '애써',
#  '참았던',
#  '흘러',
#  '바라보다',
#  '소리쳐',
#  '싶다',
#  '한',
#  '다가갈까',
#  '갈까',
#  '해',
#  '바라고',
#  '바라만',
#  '보다',
#  '솟는다',
#  '하지',
#  '해야',
#  '닿게',
#  '될까',
#  '사무쳐',
#  '싶다',
#  '했는데',
#  '잊혀질',
#  '됐는데',
#  '않다가도',
#  '걸까',
#  '녹아든',
#  '보이네요',
#  '댄',
#  '않네요',
#  '따라',
#  '미운',
#  '싶죠',
#  '지워',
#  '보려',
#  '쓰고',
#  '해도',
#  '짙어져',
#  '가네요',
#  '견뎌',
#  '커지네요',
#  '댄',
#  '않네요',
#  '따라',
#  '미운',
#  '싶죠',
#  '달랠',
#  '댈',
#  '하는데',
#  '나를',
#  '않아요',
#  '따라',
#  '미운',
#  '싶죠',
#  '따라',
#  '미워요',
#  '놔줘',
#  '떼어내도',
#  '놔줘',
#  '잘라내도',
#  '돌아설',
#  '하게',
#  '잘',
#  '됐어',
#  '된',
#  '미워지기',
#  '나을지도',
#  '몰라',
#  '하지',
#  '말아줘',
#  '웃고',
#  '싶은데',
#  '잊고',
#  '싶은데',
#  '보내줄게',
#  '잘',
#  '웃으며',
#  '질리지도',
#  '않나',
#  '봐',
#  '않나',
#  '봐',
#  '떠나',
#  '버릴',
#  '싶게',
#  '잘',
#  '됐어',
#  '된',
#  '미워지기',
#  '나을지도',
#  '몰라',
#  '하지',
#  '말아줘',
#  '웃고',
#  '싶은데',
#  '잊고',
#  '싶은데',
#  '보내줄게',
#  '잘',
#  '웃으며',
#  '나를',
#  '떠나도',
#  '웃으며',
#  '놓아줄게',
#  '줬으니',
#  '됐어',
#  '됐어',
#  '는',
#  '올',
#  '우는',
#  '올',
#  '하지',
#  '말아줘',
#  '웃고',
#  '싶은데',
#  '잊고',
#  '싶은데',
#  '보내줄게',
#  '잘',
#  '웃으며',
#  '어두워지고',
#  '내리면',
#  '벗어나질',
#  '하네',
#  '했던',
#  '오는',
#  '나를',
#  '찾아와',
#  '새워',
#  '괴롭히다',
#  '그쳐가면',
#  '그쳐가겠지',
#  '봐',
#  '마셔야',
#  '될',
#  '떨어지니까',
#  '나도',
#  '떨어질',
#  '싶다거나',
#  '아냐',
#  '가진',
#  '참',
#  '날이면',
#  '꺼내놓고',
#  '들여놔',
#  '벗어나려고',
#  '않아',
#  '지워',
#  '냈지만',
#  '비워',
#  '냈지만',
#  '내리면',
#  '숨겨놨던',
#  '돌아와',
#  '찾나',
#  '봐',
#  '오는',
#  '나를',
#  '찾아와',
#  '새워',
#  '괴롭히다',
#  '그쳐가면',
#  '그쳐가겠지',
#  '돌아갈',
#  '보며',
#  '웃어',
#  '끝나',
#  '버린',
#  '와',
#  '하는',
#  '떨어진',
#  '비는',
#  '되겠지',
#  '나면',
#  '서야',
#  '나도',
#  '그치겠지',
#  '비는',
#  '되겠지',
#  '나면',
#  '서야',
#  '나도',
#  '그치겠지',
#  '지우고',
#  '나타나',
#  '되질',
#  '않고',
#  '나타나',
#  '퍼붓게',
#  '않길',
#  '잊지',
#  '않길',
#  '빛나는',
#  '되',
#  '기를',
#  '했고',
#  '잘',
#  '돼',
#  '잊는단',
#  '보다',
#  '쉽지',
#  '않아',
#  '들어와',
#  '내게',
#  '않길',
#  '잊지',
#  '않길',
#  '빛나는',
#  '되',
#  '기를',
#  '않길',
#  '멈춰서',
#  '멈춰서',
#  '멈춰서',
#  '않길',
#  '잊지',
#  '않길',
#  '빛나는',
#  '되',
#  '기를',
#  '않길',
#  '멈춰서',
#  '했던',
#  '내게서',
#  '달아나고',
#  '남이었을까',
#  '했고',
#  '이었는지',
#  '멈추질',
#  '않아',
#  '어렸던',
#  '걸까',
#  '보내고',
#  '말았던',
#  '걸까',
#  '였단',
#  '버린',
#  '듣던',
#  '버린',
#  '서',
#  '흘리는지',
#  '이었을까',
#  '느껴질',
#  '였단',
#  '버린',
#  '듣던',
#  '버린',
#  '서',
#  '흘리는지',
#  '뱉어',
#  '버린',
#  '했던',
#  '듣던',
#  '한다',
#  '할',
#  '들리지',
#  '않아',
#  '버린',
#  '서',
#  '흘리는걸',
#  '까',
#  '떨어질',
#  '몰랐던',
#  '품도',
#  '잡은',
#  '스치던',
#  '떨리던',
#  '맞춰',
#  '걷던',
#  '된',
#  '토닥여',
#  '큰',
#  '봐',
#  '봐',
#  '지나면',
#  '오겠지',
#  '부른',
#  '떠올리는',
#  '나를',
#  '떠올리는',
#  '되는',
#  '익숙해져',
#  '버려서',
#  '봐',
#  '지나면',
#  '보며',
#  '웃는',
#  '오겠지',
#  '봐',
#  '했어',
#  '봐',
#  '지나면',
#  '되어',
#  '웃겠지',
#  '참',
#  '늦춘다면',
#  '알면서도',
#  '보낼',
#  '봐',
#  '불러',
#  '할게',
#  '않아',
#  '남기고',
#  '되어도',
#  '할게',
#  '잊어',
#  '무너져가',
#  '돌아와줘',
#  '기대어',
#  '애써',
#  '봐도',
#  '까',
#  '잘',
#  '할',
#  '흘릴게',
#  '남은',
#  '해줘',
#  '부르고',
#  '한다',
#  '할게',
#  '잊어',
#  '무너져가',
#  '돌아와줘',
#  '기대어',
#  '애써',
#  '봐도',
#  '까',
#  '서있어',
#  '하고',
#  '한다고',
#  '보내',
#  '메어와',
#  '끝난거니',
#  '참',
#  '사라지고',
#  '갈',
#  '만나는',
#  '다시는',
#  '믿고',
#  '싶지',
#  '않아',
#  '하면',
#  '할수록',
#  '건지',
#  '남겨질',
#  '내게',
#  '한다며',
#  '떠나겠다며',
#  '했는데',
#  '했었는데',
#  '미워진',
#  '기다릴',
#  '돌아올',
#  '놓지',
#  '줘',
#  '애써',
#  '해주는',
#  '하는',
#  '봤어',
#  '이길',
#  '바랐어',
#  '이러지',
#  '줘',
#  '찢어질',
#  '했는데',
#  '했었는데',
#  '기다릴',
#  '돌아올',
#  '놓지',
#  '줘',
#  '바라보겠단',
#  '믿고',
#  '주고',
#  '했었어',
#  '보내야겠지',
#  '일까',
#  '했는데',
#  '안기고',
#  '싶은데',
#  '기다리는',
#  '참',
#  '보여',
#  '내게',
#  '돌아와',
#  '준다면',
#  '않을게',
#  '놓지',
#  '줘',
#  '떠보니',
#  '해',
#  '봤더니',
#  '봐도',
#  '흘러나왔고',
#  '다리는',
#  '풀려',
#  '버렸고',
#  '스친',
#  '생각나',
#  '쏟아지는데',
#  '한',
#  '질러진',
#  '젖은',
#  '이었다',
#  '떠나가면',
#  '가버리면',
#  '떠보니',
#  '감으면',
#  '될',
#  '애써',
#  '해봐도',
#  '맞잖아',
#  '버리고',
#  '중얼거리고',
#  '웅크린',
#  '이었다',
#  '떠나가면',
#  '가버리면',
#  '하면',
#  '깨어나',
#  '한',
#  '줘',
#  '하면',
#  '할',
#  '참을',
#  '온다',
#  '찢어',
#  '놔도',
#  '밟아도',
#  '딴',
#  '해도',
#  '되는데',
#  '떠보니',
#  '헤어지기로',
#  '알잖아',
#  '해보지만',
#  '끝나가지만',
#  '함께한',
#  '가져갈게',
#  '할게',
#  '비친',
#  '만들어',
#  '하려해',
#  '지려해',
#  '견디기',
#  '나도',
#  '부르게',
#  '되면',
#  '지나쳐줘',
#  '했더라면',
#  '달라졌을까',
#  '서',
#  '이러는',
#  '봐',
#  '비친',
#  '만들어',
#  '하려해',
#  '지려해',
#  '견디기',
#  '나도',
#  '부르게',
#  '되면',
#  '지나쳐줘',
#  '보낼게',
#  '보내줘야해',
#  '애써',
#  '웃으며',
#  '않게',
#  '보낼게',
#  '하려해',
#  '만나게',
#  '되는',
#  '다가오면',
#  '안아줘',
#  '보고싶었다고',
#  '해줘',
#  '내리는',
#  '앉아',
#  '서두르던',
#  '달래다',
#  '마음잡고',
#  '써',
#  '내려가다',
#  '헤어진단',
#  '버티다가',
#  '내게',
#  '어두워지면',
#  '헤매다',
#  '잊었던',
#  '드는',
#  '만난다면',
#  '바랄게',
#  '하길',
#  '했던',
#  '지우고',
#  '어두워지면',
#  '헤매다',
#  '잊었던',
#  '드는',
#  '만난다면',
#  '바랄게',
#  '하길',
#  '했던',
#  '지우고',
#  '뱉어놓은',
#  '만난다면',
#  '바랄게',
#  '하길',
#  '했던',
#  '지우고',
#  '돌아보지',
#  '않을',
#  '돌아보지',
#  '않을',
#  '않을',
#  '보낼',
#  '돼',
#  '버린',
#  '걸까',
#  '헤매이는',
#  '잠들',
#  '미워지지만',
#  '해',
#  '할',
#  '나를',
#  '괴롭히는',
#  '지워',
#  '버려야지',
#  '잊을',
#  '돌아보지',
#  '않을거야',
#  '몰라',
#  '나도',
#  '모르게',
#  '흘러가는',
#  '않아도',
#  '되는',
#  '해',
#  '할',
#  '하는',
#  '걸까',
#  '지워',
#  '낸',
#  '겠지',
#  '잊을',
#  '돌아보지',
#  '않을',
#  '그립겠지만',
#  '잊을',
#  '됐지만',
#  '돌이킬',
#  '됐지만',
#  '흘러가겠지',
#  '나눈',
#  '감으면',
#  '잊혀질까',
#  '들었지',
#  '헤어지고',
#  '참',
#  '버티다',
#  '만나서',
#  '잘',
#  '지내고',
#  '들으니',
#  '돼',
#  '생각나',
#  '지내',
#  '참',
#  '잊고',
#  '하기를',
#  '잘해주지',
#  '잊지',
#  '하니',
#  '들려오는',
#  '들은',
#  '지나갈',
#  '돼',
#  '와',
#  '지워',
#  '줬어',
#  '가봐',
#  '뛰고',
#  '잊고',
#  '하기를',
#  '잘해주지',
#  '잊지',
#  '하니',
#  '들려오는',
#  '들은',
#  '지나갈',
#  '헤어짐을',
#  '미워도',
#  '하고',
#  '하며',
#  '지내기를',
#  '잊고',
#  '잘',
#  '살았는데',
#  '했는데',
#  '잊었다',
#  '지내',
#  '왔는데',
#  '들려오는',
#  '무너졌어',
#  '잊었더라',
#  '보는',
#  '보니',
#  '차오르지',
#  '흐르질',
#  '않더라',
#  '하는',
#  '해서',
#  '보잘',
#  '알았다면',
#  '울어',
#  '이었다는',
#  '몰랐었던',
#  '머물던',
#  '이었을',
#  '했는지',
#  '봐',
#  '떠나는',
#  '했었다니',
#  '알았다면',
#  '울어',
#  '이었다는',
#  '몰랐었던',
#  '잘',
#  '잘',
#  '지내니',
#  '싶어',
#  '다신',
#  '그리',
#  '났었는지',
#  '바라던',
#  '막혔어',
#  '어려서',
#  '몰랐었어',
#  '돌아가지',
#  '하는',
#  '만나면',
#  '멀어질',
#  '참을',
#  '잊지',
#  '해',
#  '잊어',
#  '보내지도',
#  '하는',
#  '알아줘',
#  '바뀌지',
#  '않을',
#  '할',
#  '웃어주던',
#  '미운',
#  '안아주던',
#  '놓칠',
#  '하겠어',
#  '돌아가지',
#  '하는',
#  '만나면',
#  '멀어질',
#  '참을',
#  '잊지',
#  '해',
#  '잊어',
#  '보내지도',
#  '하는',
#  '알아줘',
#  '바뀌지',
#  '않을',
#  '할',
#  '붙잡아줘',
#  '잡아줘',
#  '했었어',
#  '해서',
#  '알기에',
#  '참을',
#  '해서',
#  '해서',
#  '하지',
#  '하는',
#  '지나가도',
#  '않는',
#  '할',
#  '멀어져',
#  '앉은',
#  '뻗어',
#  '봐도',
#  '맞닿을',
#  '가',
#  '긴',
#  '드리워',
#  '하는데',
#  '돌아갈',
#  '감았다',
#  '떠보니',
#  '와있어',
#  '서있는',
#  '내게',
#  '넘겨야겠어',
#  '는',
#  '해야겠지',
#  '찾는',
#  '말아요',
#  '할',
#  '했는걸',
#  '말아줘',
#  '보면서',
#  '웃어줘',
#  '서있는',
#  '내게',
#  '넘겨야겠어',
#  '는',
#  '해야겠지',
#  '하지',
#  '나눈',
#  '한',
#  '내게',
#  '넘겨야겠어',
#  '는',
#  '해야겠지',
#  '보면',
#  '나와',
#  '했던',
#  '하는',
#  '걸까',
#  '지나가면',
#  '비춰',
#  '줄까',
#  '끝난',
#  '돌아올',
#  '보면',
#  '나와',
#  '않던',
#  '잦',
#  '떠나고',
#  '나잖아',
#  '않을까',
#  '불어오는',
#  '할',
#  '지워가지만',
#  '보면',
#  '나와',
#  '나와',
#  '않던',
#  '잦',
#  '했던',
#  '지울래',
#  '보면',
#  '나와',
#  '봐',
#  '흐르는데',
#  '할',
#  '읽다',
#  '읽다',
#  '들린',
#  '둘러보면',
#  '했어',
#  '했지',
#  '했던',
#  '했단',
#  '믿을게',
#  '그리우면',
#  '한',
#  '사라질',
#  '봤어',
#  '떠나면',
#  '들썩여',
#  '우는',
#  '했어',
#  '했지',
#  '했던',
#  '했단',
#  '믿을게',
#  '그리우면',
#  '한',
#  '하지',
#  '나를',
#  '놓친',
#  '딴',
#  '만나면',
#  '내게',
#  '들리도록',
#  '해줘',
#  '서야',
#  '끝낼게',
#  '내게',
#  '돌아올지',
#  '모를',
#  '꿈꾸는',
#  '할말',
#  '해야지',
#  '보내는',
#  '먹는',
#  '걷는',
#  '나를',
#  '만드는',
#  '였던',
#  '해',
#  '다신',
#  '잘가',
#  '하기',
#  '참을',
#  '하지',
#  '했어',
#  '사라질까봐',
#  '였던',
#  '해',
#  '다신',
#  '잘가',
#  '잊겠니',
#  '듣고',
#  '가',
#  '했단',
#  '잊으라는',
#  '해']

# %%
# 불용어 추가
# 실행해보면서 추가하면서 바꿔야함.
stop_words2 = ["할","참","한","챌","는제","참","줘","걸까","댄","따라","된","잘","된","는","올","되",\
    "기를","까","큰","갈","건지","하는","이길","딴","서","써","내게","나를","나도"]
token_ko2 = [each_word for each_word in verb_list if each_word not in stop_words2]
print(token_ko2)
# Out:
# ['알아볼', '찾아낼', '지켜', '였다면', '가졌으니까', '모르니', '바라만', '바라만', '본다', '외쳐', '부른다', '싶은', '는데', '애써', '참았던', '흘러', '바라보다', '소리쳐', '싶다', '맡을게', '웃는', '살아가', '바라만', '바라만', '본다', '외쳐', '부른다', '싶은', '는데', '애써', '참았던', '흘러', '바라보다', '소리쳐', '싶다', '다가갈까', '갈까', '해', '바라고', '바라만', '보다', '솟는다', '하지', '해야', '닿게', '될까', '사무쳐', '싶다', '했는데', '잊혀질', '됐는데', '않다가도', '녹아든', '보이네요', '않네요', '미운', '싶죠', '지워', '보려', '쓰고', '해도', '짙어져', '가네요', '견뎌', '커지네요', '않네요', '미운', '싶죠', '달랠', '댈', '하는데', '않아요', '미운', '싶죠', '미워요', '놔줘', '떼어내도', '놔줘', '잘라내도', '돌아설', '하게', '됐어', '미워지기', '나을지도', '몰라', '하지', '말아줘', '웃고', '싶은데', '잊고', '싶은데', '보내줄게', '웃으며', '질리지도', '않나', '봐', '않나', '봐', '떠나', '버릴', '싶게', '됐어', '미워지기', '나을지도', '몰라', '하지', '말아줘', '웃고', '싶은데', '잊고', '싶은데', '보내줄게', '웃으며', '떠나도', '웃으며', '놓아줄게', '줬으니', '됐어', '됐어', '우는', '하지', '말아줘', '웃고', '싶은데', '잊고', '싶은데', '보내줄게', '웃으며', '어두워지고', '내리면', '벗어나질', '하네', '했던', '오는', '찾아와', '새워', '괴롭히다', '그쳐가면', '그쳐가겠지', '봐', '마셔야', '될', '떨어지니까', '떨어질', '싶다거나', '아냐', '가진', '날이면', '꺼내놓고', '들여놔', '벗어나려고', '않아', '지워', '냈지만', '비워', '냈지만', '내리면', '숨겨놨던', '돌아와', '찾나', '봐', '오는', '찾아와', '새워', '괴롭히다', '그쳐가면', '그쳐가겠지', '돌아갈', '보며', '웃어', '끝나', '버린', '와', '떨어진', '비는', '되겠지', '나면', '서야', '그치겠지', '비는', '되겠지', '나면', '서야', '그치겠지', '지우고', '나타나', '되질', '않고', '나타나', '퍼붓게', '않길', '잊지', '않길', '빛나는', '했고', '돼', '잊는단', '보다', '쉽지', '않아', '들어와', '않길', '잊지', '않길', '빛나는', '않길', '멈춰서', '멈춰서', '멈춰서', '않길', '잊지', '않길', '빛나는', '않길', '멈춰서', '했던', '내게서', '달아나고', '남이었을까', '했고', '이었는지', '멈추질', '않아', '어렸던', '보내고', '말았던', '였단', '버린', '듣던', '버린', '흘리는지', '이었을까', '느껴질', '였단', '버린', '듣던', '버린', '흘리는지', '뱉어', '버린', '했던', '듣던', '한다', '들리지', '않아', '버린', '흘리는걸', '떨어질', '몰랐던', '품도', '잡은', '스치던', '떨리던', '맞춰', '걷던', '토닥여', '봐', '봐', '지나면', '오겠지', '부른', '떠올리는', '떠올리는', '되는', '익숙해져', '버려서', '봐', '지나면', '보며', '웃는', '오겠지', '봐', '했어', '봐', '지나면', '되어', '웃겠지', '늦춘다면', '알면서도', '보낼', '봐', '불러', '할게', '않아', '남기고', '되어도', '할게', '잊어', '무너져가', '돌아와줘', '기대어', '애써', '봐도', '흘릴게', '남은', '해줘', '부르고', '한다', '할게', '잊어', '무너져가', '돌아와줘', '기대어', '애써', '봐도', '서있어', '하고', '한다고', '보내', '메어와', '끝난거니', '사라지고', '만나는', '다시는', '믿고', '싶지', '않아', '하면', '할수록', '남겨질', '한다며', '떠나겠다며', '했는데', '했었는데', '미워진', '기다릴', '돌아올', '놓지', '애써', '해주는', '봤어', '바랐어', '이러지', '찢어질', '했는데', '했었는데', '기다릴', '돌아올', '놓지', '바라보겠단', '믿고', '주고', '했었어', '보내야겠지', '일까', '했는데', '안기고', '싶은데', '기다리는', '보여', '돌아와', '준다면', '않을게', '놓지', '떠보니', '해', '봤더니', '봐도', '흘러나왔고', '다리는', '풀려', '버렸고', '스친', '생각나', '쏟아지는데', '질러진', '젖은', '이었다', '떠나가면', '가버리면', '떠보니', '감으면', '될', '애써', '해봐도', '맞잖아', '버리고', '중얼거리고', '웅크린', '이었다', '떠나가면', '가버리면', '하면', '깨어나', '하면', '참을', '온다', '찢어', '놔도', '밟아도', '해도', '되는데', '떠보니', '헤어지기로', '알잖아', '해보지만', '끝나가지만', '함께한', '가져갈게', '할게', '비친', '만들어', '하려해', '지려해', '견디기', '부르게', '되면', '지나쳐줘', '했더라면', '달라졌을까', '이러는', '봐', '비친', '만들어', '하려해', '지려해', '견디기', '부르게', '되면', '지나쳐줘', '보낼게', '보내줘야해', '애써', '웃으며', '않게', '보낼게', '하려해', '만나게', '되는', '다가오면', '안아줘', '보고싶었다고', '해줘', '내리는', '앉아', '서두르던', '달래다', '마음잡고', '내려가다', '헤어진단', '버티다가', '어두워지면', '헤매다', '잊었던', '드는', '만난다면', '바랄게', '하길', '했던', '지우고', '어두워지면', '헤매다', '잊었던', '드는', '만난다면', '바랄게', '하길', '했던', '지우고', '뱉어놓은', '만난다면', '바랄게', '하길', '했던', '지우고', '돌아보지', '않을', '돌아보지', '않을', '않을', '보낼', '돼', '버린', '헤매이는', '잠들', '미워지지만', '해', '괴롭히는', '지워', '버려야지', '잊을', '돌아보지', '않을거야', '몰라', '모르게', '흘러가는', '않아도', '되는', '해', '지워', '낸', '겠지', '잊을', '돌아보지', '않을', '그립겠지만', '잊을', '됐지만', '돌이킬', '됐지만', '흘러가겠지', '나눈', '감으면', '잊혀질까', '들었지', '헤어지고', '버티다', '만나서', '지내고', '들으니', '돼', '생각나', '지내', '잊고', '하기를', '잘해주지', '잊지', '하니', '들려오는', '들은', '지나갈', '돼', '와', '지워', '줬어', '가봐', '뛰고', '잊고', '하기를', '잘해주지', '잊지', '하니', '들려오는', '들은', '지나갈', '헤어짐을', '미워도', '하고', '하며', '지내기를', '잊고', '살았는데', '했는데', '잊었다', '지내', '왔는데', '들려오는', '무너졌어', '잊었더라', '보는', '보니', '차오르지', '흐르질', '않더라', '해서', '보잘', '알았다면', '울어', '이었다는', '몰랐었던', '머물던', '이었을', '했는지', '봐', '떠나는', '했었다니', '알았다면', '울어', '이었다는', '몰랐었던', '지내니', '싶어', '다신', '그리', '났었는지', '바라던', '막혔어', '어려서', '몰랐었어', '돌아가지', '만나면', '멀어질', '참을', '잊지', '해', '잊어', '보내지도', '알아줘', '바뀌지', '않을', '웃어주던', ' ...

# %%
# 상위 50개 단어 확인
# 이걸보면서 불용어 지우는게 편해 전체는 힘들어
ko2 = nltk.Text(token_ko2)
ko2.vocab().most_common(50)
# Out:
# [('봐', 13),
#  ('했던', 10),
#  ('해', 9),
#  ('하지', 8),
#  ('버린', 8),
#  ('않길', 8),
#  ('애써', 7),
#  ('싶은데', 7),
#  ('잊지', 7),
#  ('잊고', 6),
#  ('않아', 6),
#  ('않을', 6),
#  ('바라만', 5),
#  ('했는데', 5),
#  ('지워', 5),
#  ('웃으며', 5),
#  ('참을', 5),
#  ('나와', 5),
#  ('미운', 4),
#  ('됐어', 4),
#  ('말아줘', 4),
#  ('지우고', 4),
#  ('돼', 4),
#  ('멈춰서', 4),
#  ('했어', 4),
#  ('할게', 4),
#  ('잊어', 4),
#  ('봐도', 4),
#  ('떠보니', 4),
#  ('돌아보지', 4),
#  ('해서', 4),
#  ('보면', 4),
#  ('싶다', 3),
#  ('싶죠', 3),
#  ('몰라', 3),
#  ('웃고', 3),
#  ('보내줄게', 3),
#  ('서야', 3),
#  ('빛나는', 3),
#  ('듣던', 3),
#  ('지나면', 3),
#  ('되는', 3),
#  ('해줘', 3),
#  ('하면', 3),
#  ('돌아올', 3),
#  ('놓지', 3),
#  ('하려해', 3),
#  ('만난다면', 3),
#  ('바랄게', 3),
#  ('하길', 3)]

# %%
# 상위 50개의 빈도수 차트 만들기
plt.figure(figsize=(12,6))
ko2.plot(50)
plt.show()

# %%
# 상위 50개만 wordcloud로 그리기
# 구한데이터로 그리기
data2 = ko2.vocab().most_common(50)

# 딕셔너리로 만들기
tmp_data2 = dict(data2)

wordcloud2 = WordCloud(
    background_color='White',
    relative_scaling=0.8,
    font_path="AppleGothic" # 윈도우 => 'c:/Windows/Fonts/malgun.ttf'
).generate_from_frequencies(tmp_data2)

# %%
plt.figure(figsize=(16,8))
plt.imshow(wordcloud2, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
test1 = total20

# %%
t.pos(test1)
# Out:
# [('내', 'Noun'),
#  ('가', 'Josa'),
#  ('너', 'Modifier'),
#  ('라면', 'Noun'),
#  ('다', 'Adverb'),
#  ('알아볼', 'Verb'),
#  ('텐데', 'Eomi'),
#  ('널', 'Noun'),
#  ('위', 'Noun'),
#  ('할', 'Verb'),
#  ('사람', 'Noun'),
#  ('찾아낼', 'Verb'),
#  ('텐데', 'Eomi'),
#  ('지난', 'Noun'),
#  ('오랜', 'Adverb'),
#  ('시간', 'Noun'),
#  ('너', 'Noun'),
#  ('의', 'Josa'),
#  ('그', 'Noun'),
#  ('곁', 'Noun'),
#  ('을', 'Josa'),
#  ('지켜', 'Verb'),
#  ('온', 'Noun'),
#  ('나라', 'Noun'),
#  ('는', 'Josa'),
#  ('걸', 'Noun'),
#  ('내', 'Noun'),
#  ('가', 'Josa'),
#  ('너', 'Noun'),
#  ('였다면', 'Verb'),
#  ('참', 'Verb'),
#  ('행복할', 'Adjective'),
#  ('텐데', 'Eomi'),
#  ('한', 'Verb'),
#  ('사람', 'Noun'),
#  ('을', 'Josa'),
#  ('다', 'Adverb'),
#  ('가졌으니까', 'Verb'),
#  ('둔한', 'Adjective'),
#  ('바보', 'Noun'),
#  ('도', 'Josa'),
#  ('눈치', 'Noun'),
#  ('챌', 'Verb'),
#  ('그', 'Noun'),
#  ('사랑', 'Noun'),
#  ('을', 'Josa'),
#  ('너', 'Noun'),
#  ('만', 'Josa'),
#  ('왜', 'Noun'),
#  ('모르니', 'Verb'),
#  ('너', 'Noun'),
#  ('를', 'Josa'),
#  ('바라만', 'Verb'),
#  ('바라만', 'Verb'),
#  ('본다', 'Verb'),
#  ('외쳐', 'Verb'),
#  ('네', 'Noun'),
#  ('이름', 'Noun'),
#  ('만', 'Josa'),
#  ('부른다', 'Verb'),
#  ('보고', 'Noun'),
#  ('싶은', 'Verb'),
#  ('맘', 'Noun'),
#  ('에', 'Josa'),
#  ('너', 'Noun'),
#  ('를', 'Josa'),
#  ('향', 'Noun'),
#  ('한', 'Josa'),
#  ('그', 'Noun'),
#  ('발걸음', 'Noun'),
#  ('네', 'Noun'),
#  ('곁', 'Noun'),
#  ('을', 'Josa'),
#  ('맴', 'Noun'),
#  ('도', 'Josa'),
#  ('는데', 'Verb'),
#  ('오늘', 'Noun'),
#  ('도', 'Josa'),
#  ('그리고', 'Conjunction'),
#  ('그리워하다', 'Adjective'),
#  ('애써', 'Verb'),
#  ('참았던', 'Verb'),
#  ('눈물', 'Noun'),
#  ('이', 'Josa'),
#  ('흘러', 'Verb'),
#  ('그저', 'Adverb'),
#  ('멀리', 'Noun'),
#  ('서', 'Josa'),
#  ('만', 'Noun'),
#  ('바라보다', 'Verb'),
#  ('또', 'Noun'),
#  ('소리쳐', 'Verb'),
#  ('네', 'Noun'),
#  ('가', 'Josa'),
#  ('보고', 'Noun'),
#  ('싶다', 'Verb'),
#  ('네', 'Noun'),
#  ('가', 'Josa'),
#  ('나라', 'Noun'),
#  ('면', 'Josa'),
#  ('더', 'Noun'),
#  ('참', 'Verb'),
#  ('아팠을', 'Adjective'),
#  ('텐데', 'Eomi'),
#  ('슬픈', 'Adjective'),
#  ('역할', 'Noun'),
#  ('은', 'Josa'),
#  ('내', 'Noun'),
#  ('가', 'Josa'),
#  ('맡을게', 'Verb'),
#  ('웃는', 'Verb'),
#  ('모습', 'Noun'),
#  ('만', 'Josa'),
#  ('보이', 'Noun'),
#  ('며', 'Josa'),
#  ('살아가', 'Verb'),
#  ('줘', 'Verb'),
#  ('내', 'Noun'),
#  ('가', 'Josa'),
#  ('볼', 'Noun'),
#  ('수', 'Noun'),
#  ('있게', 'Adjective'),
#  ('너', 'Noun'),
#  ('를', 'Josa'),
#  ('바라만', 'Verb'),
#  ('바라만', 'Verb'),
#  ('본다', 'Verb'),
#  ('외쳐', 'Verb'),
#  ('네', 'Noun'),
#  ('이름', 'Noun'),
#  ('만', 'Josa'),
#  ('부른다', 'Verb'),
#  ('보고', 'Noun'),
#  ('싶은', 'Verb'),
#  ('맘', 'Noun'),
#  ('에', 'Josa'),
#  ('너', 'Noun'),
#  ('를', 'Josa'),
#  ('향', 'Noun'),
#  ('한', 'Josa'),
#  ('그', 'Noun'),
#  ('발걸음', 'Noun'),
#  ('네', 'Noun'),
#  ('곁', 'Noun'),
#  ('을', 'Josa'),
#  ('맴', 'Noun'),
#  ('도', 'Josa'),
#  ('는데', 'Verb'),
#  ('오늘', 'Noun'),
#  ('도', 'Josa'),
#  ('그리고', 'Conjunction'),
#  ('그리워하다', 'Adjective'),
#  ('애써', 'Verb'),
#  ('참았던', 'Verb'),
#  ('눈물', 'Noun'),
#  ('이', 'Josa'),
#  ('흘러', 'Verb'),
#  ('그저', 'Adverb'),
#  ('멀리', 'Noun'),
#  ('서', 'Josa'),
#  ('만', 'Noun'),
#  ('바라보다', 'Verb'),
#  ('또', 'Noun'),
#  ('소리쳐', 'Verb'),
#  ('네', 'Noun'),
#  ('가', 'Josa'),
#  ('보고', 'Noun'),
#  ('싶다', 'Verb'),
#  ('한', 'Verb'),
#  ('걸음', 'Noun'),
#  ('더', 'Noun'),
#  ('다가갈까', 'Verb'),
#  ('더', 'Noun'),
#  ('가까이', 'Noun'),
#  ('네', 'Noun'),
#  ('게', 'Josa'),
#  ('갈까', 'Verb'),
#  ('OH', 'Alpha'),
#  ('어제', 'Noun'),
#  ('보다', 'Josa'),
#  ('더', 'Noun'),
#  ('내일', 'Noun'),
#  ('더', 'Noun'),
#  ('널', 'Noun'),
#  ('사랑', 'Noun'),
#  ('해', 'Verb'),
#  ('I', 'Alpha'),
#  ('’', 'Punctuation'),
#  ('ll', 'Alpha'),
#  ('make', 'Alpha'),
#  ('you', 'Alpha'),
#  ('love', 'Alpha'),
#  ('me', 'Alpha'),
#  ('someday', 'Alpha'),
#  ('혼자', 'Noun'),
#  ('바라고', 'Verb'),
#  ('바라만', 'Verb'),
#  ('보다', 'Verb'),
#  ('울컥', 'Adverb'),
#  ('그리움', 'Noun'),
#  ('이', 'Josa'),
#  ('솟는다', 'Verb'),
#  ('바보', 'Noun'),
#  ('같은', 'Adjective'),
#  ('맘', 'Noun'),
#  ('에', 'Josa'),
#  ('하지', 'Verb'),
#  ('못', 'Noun'),
#  ('한', 'Josa'),
#  ('그', 'Noun'),
#  ('한마디', 'Noun'),
#  ('널', 'Noun'),
#  ('사랑', 'Noun'),
#  ('한다는', 'Modifier'),
#  ('말', 'Noun'),
#  ('얼마나', 'Noun'),
#  ('그리고', 'Conjunction'),
#  ('그리워', 'Adjective'),
#  ('해야', 'Verb'),
#  ('내', 'Noun'),
#  ('맘', 'Noun'),
#  ('너', 'Noun'),
#  ('의', 'Josa'),
#  ('곁', 'Noun'),
#  ('에', 'Josa'),
#  ('닿게', 'Verb'),
#  ('될까', 'Verb'),
#  ('매일', 'Noun'),
#  ('하루', 'Noun'),
#  ('종일', 'Noun'),
#  ('너', 'Noun'),
#  ('의', 'Josa'),
#  ('생각', 'Noun'),
#  ('에', 'Josa'),
#  ('사무쳐', 'Verb'),
#  ('너무', 'Adverb'),
#  ('보고', 'Noun'),
#  ('싶다', 'Verb'),
#  ('조금', 'Noun'),
#  ('은', 'Josa'),
#  ('괜찮다', 'Adjective'),
#  ('생각', 'Noun'),
#  ('했는데', 'Verb'),
#  ('이제', 'Noun'),
#  ('는', 'Josa'),
#  ('잊혀질', 'Verb'),
#  ('때', 'Noun'),
#  ('도', 'Josa'),
#  ('됐는데', 'Verb'),
#  ('아무렇지', 'Adjective'),
#  ('않다가도', 'Verb'),
#  ('그대', 'Noun'),
#  ('가', 'Josa'),
#  ('없단', 'Adjective'),
#  ('게', 'Noun'),
#  ('아직', 'Adverb'),
#  ('나', 'Noun'),
#  ('에겐', 'Josa'),
#  ('어색한', 'Adjective'),
#  ('걸까', 'Verb'),
#  ('벅차도록', 'Adjective'),
#  ('행복했던', 'Adjective'),
#  ('그때', 'Noun'),
#  ('가', 'Josa'),
#  ('그리워서', 'Adjective'),
#  ('추억', 'Noun'),
#  ('이', 'Josa'),
#  ('녹아든', 'Verb'),
#  ('거릴', 'Noun'),
#  ('혼자', 'Noun'),
#  ('걸', 'Noun'),
#  ('을', 'Josa'),
#  ('때', 'Noun'),
#  ('면', 'Josa'),
#  ('자꾸만', 'Noun'),
#  ('눈앞', 'Noun'),
#  ('에', 'Josa'),
#  ('그대', 'Noun'),
#  ('가', 'Josa'),
#  ('선명히', 'Adjective'),
#  ('보이네요', 'Verb'),
#  ('그', 'Noun'),
#  ('댄', 'Verb'),
#  ('아직도', 'Adverb'),
#  ('왜', 'Noun'),
#  ('내', 'Noun'),
#  ('맘속', 'Noun'),
#  ('에', 'Josa'),
#  ('살', 'Noun'),
#  ('고', 'Josa'),
#  ('있나요', 'Adjective'),
#  ('지금', 'Noun'),
#  ('그대', 'Noun'),
#  ('는', 'Josa'),
#  ('나', 'Noun'),
#  ('없이도', 'Adjective'),
#  ('행복하나요', 'Adjective'),
#  ('조금', 'Noun'),
#  ('은', 'Josa'),
#  ('그대', 'Noun'),
#  ('도', 'Josa'),
#  ('나', 'Noun'),
#  ('처럼', 'Josa'),
#  ('아프긴', 'Adjective'),
#  ('하나요', 'Noun'),
#  ('아직', 'Adverb'),
#  ('난', 'Noun'),
#  ('이별', 'Noun'),
#  ('이', 'Josa'),
#  ('서', 'Modifier'),
#  ('투', 'Noun'),
#  ('네', 'Suffix'),
#  ('요', 'Josa'),
#  ('하나', 'Noun'),
#  ('도', 'Josa'),
#  ('괜찮지가', 'Adjective'),
#  ('않네요', 'Verb'),
#  ('오늘', 'Noun'),
#  ('따라', 'Verb'),
#  ('더', 'Noun'),
#  ('미운', 'Verb'),
#  ('그대', 'Noun'),
#  ('가', 'Josa'),
#  ('너무', 'Adverb'),
#  ('보고', 'Noun'),
#  ('싶죠', 'Verb'),
#  ('지워', 'Verb'),
#  ('보려', 'Verb'),
#  ('애', 'Noun'),
#  ('를', 'Josa'),
#  ('쓰고', 'Verb'),
#  ('아무리', 'Adverb'),
#  ('외면', 'Noun'),
#  ('해도', 'Verb'),
#  ('추억', 'Noun'),
#  ('은', 'Josa'),
#  ('더욱', 'Noun'),
#  ('아름답게', 'Adjective'),
#  ('짙어져', 'Verb'),
#  ('가네요', 'Verb'),
#  ('견뎌', 'Verb'),
#  ('온', 'Noun'),
#  ('시간', 'Noun'),
#  ('만큼', 'Josa'),
#  ('더욱더', 'Noun'),
#  ('아픔', 'Noun'),
#  ('이', 'Josa'),
#  ('커지네요', 'Verb'),
#  ('그', 'Noun'),
#  ('댄', 'Verb'),
#  ('아직도', 'Adverb'),
#  ('왜', 'Noun'),
#  ('내', 'Noun'),
#  ('맘속', 'Noun'),
#  ('에', 'Josa'),
#  ('살', 'Noun'),
#  ('고', 'Josa'),
#  ('있나요', 'Adjective'),
#  ('지금', 'Noun'),
#  ('그대', 'Noun'),
#  ('는', 'Josa'),
#  ('나', 'Noun'),
#  ('없이도', 'Adjective'),
#  ('행복하나요', 'Adjective'),
#  ('조금', 'Noun'),
#  ('은', 'Josa'),
#  ('그대', 'Noun'),
#  ('도', 'Josa'),
#  ('나', 'Noun'),
#  ('처럼', 'Josa'),
#  ('아프긴', 'Adjective'),
#  ('하나요', 'Noun'),
#  ('아직', 'Adverb'),
#  ('난', 'Noun'),
#  ('이별', 'Noun'),
#  ('이', 'Josa'),
#  ('서', 'Modifier'),
#  ('투', 'Noun'),
#  ('네', 'Suffix'),
#  ('요', 'Josa'),
#  ('하나', 'Noun'),
#  ('도', 'Josa'),
#  ('괜찮지가', 'Adjective'),
#  ('않네요', 'Verb'),
#  ('오늘', 'Noun'),
#  ('따라', 'Verb'),
#  ('더', 'Noun'),
#  ('미운', 'Verb'),
#  ('그대', 'Noun'),
#  ('가', 'Josa'),
#  ('너무', 'Adverb'),
#  ('보고', 'Noun'),
#  ('싶죠', 'Verb'),
#  ('달랠', 'Verb'),
#  ('길', 'Noun'),
#  ('없는', 'Adjective'),
#  ('이', 'Noun'),
#  ('마음', 'Noun'),
#  ('을', 'Josa'),
#  ('어떡하나요', 'Adjective'),
#  ('난', 'Noun'),
#  ('아직도', 'Adverb'),
#  ('그', 'Noun'),
#  ('댈', 'Verb'),
#  ('사랑', 'Noun'),
#  ('하는데', 'Verb'),
#  ('지금', 'Noun'),
#  ('그대', 'Noun'),
#  ('는', 'Josa'),
#  ('이런', 'Adjective'),
#  ('나를', 'Verb'),
#  ('알', 'Noun'),
#  ('고', 'Josa'),
#  ('있나요', 'Adjective'),
#  ('하루하루', 'Noun'),
#  ('를', 'Josa'),
#  ('추억', 'Noun'),
#  ('속', 'Noun'),
#  ('에', 'Josa'),
#  ('살', 'Noun'),
#  ('고', 'Josa'),
#  ('있네요', 'Adjective'),
#  ('아직', 'Adverb'),
#  ('난', 'Noun'),
#  ('모든', 'Noun'),
#  ('게', 'Noun'),
#  ('서', 'Modifier'),
#  ('투', 'Noun'),
#  ('네', 'Suffix'),
#  ('요', 'Josa'),
#  ('괜찮지가', 'Adjective'),
#  ('않아요', 'Verb'),
#  ('오늘', 'Noun'),
#  ('따라', 'Verb'),
#  ('더', 'Noun'),
#  ('미운', 'Verb'),
#  ('그대', 'Noun'),
#  ('가', 'Josa'),
#  ('너무', 'Adverb'),
#  ('보고', 'Noun'),
#  ('싶죠', 'Verb'),
#  ('오늘', 'Noun'),
#  ('따라', 'Verb'),
#  ('행복할', 'Adjective'),
#  ('그대', 'Noun'),
#  ('가', 'Josa'),
#  ('너무', 'Adverb'),
#  ('미워요', 'Verb'),
#  ('Hello', 'Alpha'),
#  ('Hello', 'Alpha'),
#  ('Hello', 'Alpha'),
#  ('Hello', 'Alpha'),
#  ('Hello', 'Alpha'),
#  ('Don', 'Alpha'),
#  ("'", 'Punctuation'),
#  ('t', 'Alpha'),
#  ('cry', 'Alpha'),
#  ('Don', 'Alpha'),
#  ("'", 'Punctuation'),
#  ('t', 'Alpha'),
#  ('cry', 'Alpha'),
#  ('Don', 'Alpha'),
#  ("'", 'Punctuation'),
#  ('t', 'Alpha'),
#  ('cry', 'Alpha'),
#  ('Don', 'Alpha'),
#  ("'", 'Punctuation'),
#  ('t', 'Alpha'),
#  ('Hello', 'Alpha'),
#  ('가슴', 'Noun'),
#  ('이', 'Josa'),
#  ('널', 'Noun'),
#  ('안', 'Noun'),
#  ('놔줘', 'Verb'),
#  ('아무리', 'Adverb'),
#  ('떼어내도', 'Verb'),
#  ('계속', 'Noun'),
#  ('너', 'Noun'),
#  ('를', 'Josa'),
#  ('잡고', 'Noun'),
#  ('안', 'Noun'),
#  ('놔줘', 'Verb'),
#  ('아무리', 'Adverb'),
#  ('잘라내도', 'Verb'),
#  ('먼저', 'Noun'),
#  ('뒤', 'Noun'),
#  ('돌아설', 'Verb'),
#  ('거', 'Noun'),
#  ('면서', 'Noun'),
#  ('왜', 'Noun'),
#  ('사랑', 'Noun'),
#  ('하게', 'Verb'),
#  ('해', 'Noun'),
#  ('눈물', 'Noun'),
#  ('이', 'Josa'),
#  ('대체', 'Noun'),
#  ('무슨', 'Noun'),
#  ('죄', 'Noun'),
#  ('야', 'Josa'),
#  ('차라리', 'Noun'),
#  ('잘', 'Verb'),
#  ('됐어', 'Verb'),
#  ('잘', 'VerbPrefix'),
#  ('된', 'Verb'),
#  ('일이', 'Noun'),
#  ('야', 'Josa'),
#  ('아프게', 'Adjective'),
#  ('상처', 'Noun'),
#  ('만', 'Josa'),
#  ('줄', 'Noun'),
#  ('너', 'Modifier'),
#  ('라면', 'Noun'),
#  ('더', 'Noun'),
#  ('힘들기', 'Adjective'),
#  ('전', 'Noun'),
#  ('에', 'Josa'),
#  ('미워지기', 'Verb'),
#  ('전', 'Noun'),
#  ('에', 'Josa'),
#  ('지금', 'Noun'),
#  ('이', 'Josa'),
#  ('좀', 'Noun'),
#  ('더', 'Noun'),
#  ('나을지도', 'Verb'),
#  ('몰라', 'Verb'),
#  ('가슴', 'Noun'),
#  ('아', 'Josa'),
#  ('더', 'Noun'),
#  ('사랑', 'Noun'),
#  ('하지', 'Verb'),
#  ('말아줘', 'Verb'),
#  ('난', 'Noun'),
#  ('웃고', 'Verb'),
#  ('싶은데', 'Verb'),
#  ('너', 'Noun'),
#  ('를', 'Josa'),
#  ('잊고', 'Verb'),
#  ('싶은데', 'Verb'),
#  ('내', 'Noun'),
#  ('가', 'Josa'),
#  ('보내줄게', 'Verb'),
#  ('잘', 'Verb'),
#  ('가라', 'Noun'),
#  ('내', 'Noun'),
#  ('사랑', 'Noun'),
#  ('아', 'Josa'),
#  ('아파도', 'Adjective'),
#  ('웃으며', 'Verb'),
#  ('안녕', 'Noun'),
#  ('질리지도', 'Verb'),
#  ('않나', 'Verb'),
#  ('봐', 'Verb'),
#  ('한없이', 'Adverb'),
#  ('생각', 'Noun'),
#  ('이', 'Josa'),
#  ('나', 'Noun'),
#  ('정말', 'Noun'),
#  ('마르지', 'Noun'),
#  ('도', 'Josa'),
#  ('않나', 'Verb'),
#  ('봐', 'Verb'),
#  ('한없이', 'Adverb'),
#  ('눈물', 'Noun'),
#  ('이', 'Josa'),
#  ('나', 'Noun'),
#  ('결국', 'Adverb'),
#  ('떠나', 'Verb'),
#  ('버릴', 'Verb'),
#  ('거', 'Noun'),
#  ('면서', 'Noun'),
#  ('왜', 'Noun'),
#  ('보고', 'Noun'),
#  ('싶게', 'Verb'),
#  ('해', 'Noun'),
#  ('두', 'Noun'),
#  ('눈', 'Noun'),
#  ('이', 'Josa'),
#  ('대체', 'Noun'),
#  ('무슨', 'Noun'),
#  ('죄', 'Noun'),
#  ('야', 'Josa'),
#  ('차라리', 'Noun'),
#  ('잘', 'Verb'),
#  ('됐어', 'Verb'),
#  ('잘', 'VerbPrefix'),
#  ('된', 'Verb'),
#  ('일이', 'Noun'),
#  ('야', 'Josa'),
#  ('아프게', 'Adjective'),
#  ('상처', 'Noun'),
#  ('만', 'Josa'),
#  ('줄', 'Noun'),
#  ('너', 'Modifier'),
#  ('라면', 'Noun'),
#  ('더', 'Noun'),
#  ('힘들기', 'Adjective'),
#  ('전', 'Noun'),
#  ('에', 'Josa'),
#  ('미워지기', 'Verb'),
#  ('전', 'Noun'),
#  ('에', 'Josa'),
#  ('지금', 'Noun'),
#  ('이', 'Josa'),
#  ('좀', 'Noun'),
#  ('더', 'Noun'),
#  ('나을지도', 'Verb'),
#  ('몰라', 'Verb'),
#  ('가슴', 'Noun'),
#  ('아', 'Josa'),
#  ('더', 'Noun'),
#  ('사랑', 'Noun'),
#  ('하지', 'Verb'),
#  ('말아줘', 'Verb'),
#  ('난', 'Noun'),
#  ('웃고', 'Verb'),
#  ('싶은데', 'Verb'),
#  ('너', 'Noun'),
#  ('를', 'Josa'),
#  ('잊고', 'Verb'),
#  ('싶은데', 'Verb'),
#  ('내', 'Noun'),
#  ('가', 'Josa'),
#  ('보내줄게', 'Verb'),
#  ('잘', 'Verb'),
#  ('가라', 'Noun'),
#  ('내', 'Noun'),
#  ('사랑', 'Noun'),
#  ('아', 'Josa'),
#  ('아파도', 'Adjective'),
#  ('웃으며', 'Verb'),
#  ('안녕', 'Noun'),
#  ('Hello', 'Alpha'),
#  ('Hello', 'Alpha'),
#  ('Hello', 'Alpha'),
#  ('Hello', 'Alpha'),
#  ('Hello', 'Alpha'),
#  ('Don', 'Alpha'),
#  ("'", 'Punctuation'),
#  ('t', 'Alpha'),
#  ('cry', 'Alpha'),
#  ('Don', 'Alpha'),
#  ("'", 'Punctuation'),
#  ('t', 'Alpha'),
#  ('cry', 'Alpha'),
#  ('Don', 'Alpha'),
#  ("'", 'Punctuation'),
#  ('t', 'Alpha'),
#  ('cry', 'Alpha'),
#  ('Don', 'Alpha'),
#  ("'", 'Punctuation'),
#  ('t', 'Alpha'),
#  ('Hello', 'Alpha'),
#  ('괜찮아', 'Adjective'),
#  ('사랑', 'Noun'),
#  ('아', 'Josa'),
#  ('나를', 'Verb'),
#  ('떠나도', 'Verb'),
#  ('웃으며', 'Verb'),
#  ('널', 'Noun'),
#  ('놓아줄게', 'Verb'),
#  ('다', 'Adverb'),
#  ('줬으니', 'Verb'),
#  ('됐어', 'Verb'),
#  ('그냥', 'Noun'),
#  ('그', 'Determiner'),
#  ('걸', 'Noun'),
#  ('로', 'Josa'),
#  ('됐어', 'Verb'),
#  ('아마', 'Noun'),
#  ('언젠가', 'Adverb'),
#  ('는', 'Verb'),
#  ('나', 'Noun'),
#  ('의', 'Josa'),
#  ('곁', 'Noun'),
#  ('이', 'Josa'),
#  ('그리워', 'Adjective'),
#  ('너', 'Noun'),
#  ('도', 'Josa'),
#  ('아파', 'Adjective'),
#  ('올', 'Verb'),
#  ('거야', 'Eomi'),
#  ('우는', 'Verb'),
#  ('날', 'Noun'),
#  ('이', 'Josa'),
#  ('올', 'Verb'),
#  ('거야', 'Eomi'),
#  ('(', 'Punctuation'),
#  ('가슴', 'Noun'),
#  ('아', 'Josa'),
#  (')', 'Punctuation'),
#  ('(', 'Punctuation'),
#  ('더', 'Noun'),
#  ('사랑', 'Noun'),
#  ('하지', 'Verb'),
#  ('말아줘', 'Verb'),
#  (')', 'Punctuation'),
#  ('난', 'Noun'),
#  ('웃고', 'Verb'),
#  ('싶은데', 'Verb'),
#  ('(', 'Punctuation'),
#  ('너', 'Noun'),
#  ('를', 'Josa'),
#  ('잊고', 'Verb'),
#  ('싶은데', 'Verb'),
#  (')', 'Punctuation'),
#  ('(', 'Punctuation'),
#  ('내', 'Noun'),
#  ('가', 'Josa'),
#  ('보내줄게', 'Verb'),
#  (')', 'Punctuation'),
#  ('(', 'Punctuation'),
#  ('잘', 'Verb'),
#  ('가라', 'Noun'),
#  ('내', 'Noun'),
#  ('사랑', 'Noun'),
#  ('아', 'Josa'),
#  (')', 'Punctuation'),
#  ('슬퍼도', 'Adjective'),
#  ('웃으며', 'Verb'),
#  ('안녕', 'Noun'),
#  ('세상', 'Noun'),
#  ('이', 'Josa'),
#  ('어두워지고', 'Verb'),
#  ('조용히', 'Adjective'),
#  ('비', 'Noun'),
#  ('가', 'Josa'),
#  ('내리면', 'Verb'),
#  ('여전히', 'Adjective'),
#  ('그대로', 'Noun'),
#  ('오늘', 'Noun'),
#  ('도', 'Josa'),
#  ('어김없이', 'Adverb'),
#  ('난', 'Noun'),
#  ('벗어나질', 'Verb'),
#  ('못', 'VerbPrefix'),
#  ('하네', 'Verb'),
#  ('너', 'Noun'),
#  ('의', 'Josa'),
#  ('생각', 'Noun'),
#  ('안', 'Noun'),
#  ('에서', 'Josa'),
#  ('이제', 'Noun'),
#  ('끝', 'Noun'),
#  ('이라는', 'Josa'),
#  ('걸', 'Noun'),
#  ('알', 'Noun'),
#  ('지만', 'Josa'),
#  ('미련', 'Noun'),
#  ('이란', 'Josa'),
#  ('걸', 'Noun'),
#  ('알', 'Noun'),
#  ('지만', 'Josa'),
#  ('이제', 'Noun'),
#  ('아닐', 'Adjective'),
#  ('걸', 'Noun'),
#  ('알', 'Noun'),
#  ('지만', 'Josa'),
#  ('그까짓', 'Noun'),
#  ('자존심', 'Noun'),
#  ('에', 'Josa'),
#  ('널', 'Noun'),
#  ('잡지', 'Noun'),
#  ('못', 'VerbPrefix'),
#  ('했던', 'Verb'),
#  ('내', 'Noun'),
#  ('가', 'Josa'),
#  ('조금', 'Noun'),
#  ('아쉬울', 'Adjective'),
#  ('뿐', 'Noun'),
#  ('이니까', 'Josa'),
#  ('비', 'Noun'),
#  ('가', 'Josa'),
#  ('오는', 'Verb'),
#  ('날', 'Noun'),
#  ('엔', 'Josa'),
#  ('나를', 'Verb'),
#  ('찾아와', 'Verb'),
#  ('밤', 'Noun'),
#  ('을', 'Josa'),
#  ('새워', 'Verb'),
#  ('괴롭히다', 'Verb'),
#  ('비', 'Noun'),
#  ('가', 'Josa'),
#  ('그쳐가면', 'Verb'),
#  ('너', 'Noun'),
#  ('도', 'Josa'),
#  ('따라서', 'Noun'),
#  ('서서히', 'Noun'),
#  ('조금씩', 'Adverb'),
#  ('그쳐가겠지', 'Verb'),
#  ('취했', 'Noun'),
#  ('나', 'Josa'),
#  ('봐', 'Verb'),
#  ('그만', 'Adverb'),
#  ('마셔야', 'Verb'),
#  ('될', 'Verb'),
#  ('것', 'Noun'),
#  ('같', 'Adjective'),
#  ('애', 'Noun'),
#  ('비', 'Noun'),
#  ('가', 'Josa'),
#  ('떨어지니까', 'Verb'),
#  ('나도', 'Verb'),
#  ('떨어질', 'Verb'),
#  ('것', 'Noun'),
#  ('같', 'Adjective'),
#  ('애', 'Noun'),
#  ('뭐', 'Noun'),
#  ('네', 'Noun'),
#  ('가', 'Josa'),
#  ('보고', 'Noun'),
#  ('싶다거나', 'Verb'),
#  ('그런', 'Adjective'),
#  ('건', 'Noun'),
#  ('아냐', 'Verb'),
#  ('다만', 'Noun'),
#  ('우리', 'Noun'),
#  ('가', 'Josa'),
#  ('가진', 'Verb'),
#  ('시간', 'Noun'),
#  ('이', 'Josa'),
#  ('좀', 'Noun'),
#  ('날카로울', 'Adjective'),
#  ('뿐', 'Noun'),
#  ('참', 'Verb'),
#  ('좋아했었던', 'Adjective'),
#  ('이런', 'Adjective'),
#  ('날이면', 'Verb'),
#  ('아직', 'Adverb'),
#  ('너무', 'Adverb'),
#  ('생생한', 'Adjective'),
#  ('기억', 'Noun'),
#  ('을', 'Josa'),
#  ('꺼내놓고', 'Verb'),
#  ('추억', 'Noun'),
#  ('이란', 'Josa'),
#  ('덫', 'Noun'),
#  ('에', 'Josa'),
#  ('일부러', 'Noun'),
#  ('발', 'Noun'),
#  ('을', 'Josa'),
#  ('들여놔', 'Verb'),
#  ('벗어나려고', 'Verb'),
#  ('발버둥', 'Noun'),
#  ('조차', 'Josa'),
#  ('치', 'Noun'),
#  ('지', 'Josa'),
#  ('않아', 'Verb'),
#  ('이제', 'Noun'),
#  ('너', 'Noun'),
#  ('를', 'Josa'),
#  ('다', 'Adverb'),
#  ('지워', 'Verb'),
#  ('냈지만', 'Verb'),
#  ('모두', 'Noun'),
#  ('다', 'Adverb'),
#  ('비워', 'Verb'),
#  ('냈지만', 'Verb'),
#  ('또다시', 'Adverb'),
#  ('비', 'Noun'),
#  ('가', 'Josa'),
#  ('내리면', 'Verb'),
#  ('힘들게', 'Adjective'),
#  ('숨겨놨던', 'Verb'),
#  ('너', 'Noun'),
#  ('의', 'Josa'),
#  ('모든', 'Noun'),
#  ('기억', 'Noun'),
#  ('들', 'Suffix'),
#  ('이', 'Josa'),
#  ('다시', 'Noun'),
#  ('돌아와', 'Verb'),
#  ('널', 'Noun'),
#  ('찾나', 'Verb'),
#  ('봐', 'Verb'),
#  ('비', 'Noun'),
#  ('가', 'Josa'),
#  ('오는', 'Verb'),
#  ('날', 'Noun'),
#  ('엔', 'Josa'),
#  ('나를', 'Verb'),
#  ('찾아와', 'Verb'),
#  ('밤', 'Noun'),
#  ('을', 'Josa'),
#  ('새워', 'Verb'),
#  ('괴롭히다', 'Verb'),
#  ('비', 'Noun'),
#  ('가', 'Josa'),
#  ('그쳐가면', 'Verb'),
#  ('너', 'Noun'),
#  ('도', 'Josa'),
#  ('따라서', 'Noun'),
#  ('서서히', 'Noun'),
#  ('조금씩', 'Adverb'),
#  ('그쳐가겠지', 'Verb'),
#  ('너', 'Noun'),
#  ('에게로', 'Josa'),
#  ('이', 'Determiner'),
#  ('젠', 'Noun'),
#  ('돌아갈', 'Verb'),
#  ('길은', 'Adjective'),
#  ('없지만', 'Adjective'),
#  ('지금', 'Noun'),
#  ('행복한', 'Adjective'),
#  ('너', 'Noun'),
#  ('를', 'Josa'),
#  ('보며', 'Verb'),
#  ('난', 'Noun'),
#  ('그래도', 'Adverb'),
#  ('웃어', 'Verb'),
#  ('볼', 'Noun'),
#  ('게', 'Josa'),
#  ('널', 'Noun'),
#  ('잡', 'Noun'),
#  ('을', 'Josa'),
#  ('수', 'Noun'),
#  ('있었던', 'Adjective'),
#  ('힘', 'Noun'),
#  ('이', 'Josa'),
#  ('내겐', 'Noun'),
#  ('없었으니까', 'Adjective'),
#  ('어차피', 'Noun'),
#  ('끝나', 'Verb'),
#  ('버린', 'Verb'),
#  ('걸', 'Noun'),
#  ('이제', 'Noun'),
#  ('와', 'Verb'),
#  ('어쩌겠어', 'Noun'),
#  ('뒤늦게', 'Adjective'),
#  ('후회', 'Noun'),
#  ('나', 'Josa'),
#  ('하는', 'Verb'),
#  ('거지', 'Noun'),
#  ('덜', 'Noun'),
#  ('떨어진', 'Verb'),
#  ('애', 'Noun'),
#  ('처럼', 'Josa'),
#  ('비는', 'Verb'),
#  ('항상', 'Noun'),
#  ('오', 'Noun'),
#  ('니까', 'Josa'),
#  ('계속', 'Noun'),
#  ('반복', 'Noun'),
#  ('되겠지', 'Verb'),
#  ('그', 'Noun'),
#  ('치고', 'Josa'),
#  ('나면', 'Verb'),
#  ('그', 'Determiner'),
#  ('제', 'Noun'),
#  ('서야', 'Verb'),
#  ('나도', 'Verb'),
#  ('그치겠지', 'Verb'),
#  ('비는', 'Verb'),
#  ('항상', 'Noun'),
#  ('오', 'Noun'),
#  ('니까', 'Josa'),
#  ('계속', 'Noun'),
#  ('반복', 'Noun'),
#  ('되겠지', 'Verb'),
#  ('그', 'Noun'),
#  ('치고', 'Josa'),
#  ('나면', 'Verb'),
#  ('그', 'Determiner'),
#  ('제', 'Noun'),
#  ('서야', 'Verb'),
#  ('나도', 'Verb'),
#  ('그치겠지', 'Verb'),
#  ('그게', 'Noun'),
#  ('또', 'Noun'),
#  ('그래', 'Adjective'),
#  ('이별', 'Noun'),
#  ('이란', 'Josa'),
#  ('게', 'Noun'),
#  ('생각', 'Noun'),
#  ('과는', 'Josa'),
#  ('늘', 'Noun'),
#  ('다르게', 'Adjective'),
#  ('우리', 'Noun'),
#  ('좋았던', 'Adjective'),
#  ('기억', 'Noun'),
#  ('만', 'Josa'),
#  ('전부', 'Noun'),
#  ('지우고', 'Verb'),
#  ('나타나', 'Verb'),
#  ('그땐', 'Noun'),
#  ('또', 'Noun'),
#  ('그래', 'Adjective'),
#  ('마음', 'Noun'),
#  ('이란', 'Josa'),
#  ('게', 'Noun'),
#  ('생각', 'Noun'),
#  ('처럼', 'Josa'),
#  ('되질', 'Verb'),
#  ('않고', 'Verb'),
#  ('우리', 'Noun'),
#  ('아프던', 'Adjective'),
#  ('기억', 'Noun'),
#  ('만', 'Josa'),
#  ('또', 'Noun'),
#  ('전부', 'Noun'),
#  ...]

# %%
adjective_list = []
for i in range(len(t.pos(test1))):
    if t.pos(test1)[i][1] == 'Adjective':
        adjective_list.append(t.pos(test1)[i][0])

# %%
adjective_list
# Out:
# ['행복할',
#  '둔한',
#  '그리워하다',
#  '아팠을',
#  '슬픈',
#  '있게',
#  '그리워하다',
#  '같은',
#  '그리워',
#  '괜찮다',
#  '아무렇지',
#  '없단',
#  '어색한',
#  '벅차도록',
#  '행복했던',
#  '그리워서',
#  '선명히',
#  '있나요',
#  '없이도',
#  '행복하나요',
#  '아프긴',
#  '괜찮지가',
#  '아름답게',
#  '있나요',
#  '없이도',
#  '행복하나요',
#  '아프긴',
#  '괜찮지가',
#  '없는',
#  '어떡하나요',
#  '이런',
#  '있나요',
#  '있네요',
#  '괜찮지가',
#  '행복할',
#  '아프게',
#  '힘들기',
#  '아파도',
#  '아프게',
#  '힘들기',
#  '아파도',
#  '괜찮아',
#  '그리워',
#  '아파',
#  '슬퍼도',
#  '조용히',
#  '여전히',
#  '아닐',
#  '아쉬울',
#  '같',
#  '같',
#  '그런',
#  '날카로울',
#  '좋아했었던',
#  '이런',
#  '생생한',
#  '힘들게',
#  '길은',
#  '없지만',
#  '행복한',
#  '있었던',
#  '없었으니까',
#  '뒤늦게',
#  '그래',
#  '다르게',
#  '좋았던',
#  '그래',
#  '아프던',
#  '없었던',
#  '미워하지',
#  '많은',
#  '아름다웠어',
#  '없던',
#  '힘들게',
#  '미워하지',
#  '많은',
#  '미워하지',
#  '미워하지',
#  '많은',
#  '미워하지',
#  '아닌',
#  '서툰',
#  '아련한',
#  '뒤늦게',
#  '따스한',
#  '그리운',
#  '싫어져',
#  '없는게',
#  '아파',
#  '서툰',
#  '없는',
#  '많았어',
#  '뒤늦게',
#  '따스한',
#  '그리운',
#  '싫어져',
#  '없는게',
#  '아파',
#  '같은데',
#  '없는게',
#  '아파',
#  '작은',
#  '힘든가',
#  '아픈가',
#  '노랠',
#  '아픈가',
#  '있을까',
#  '힘든',
#  '아픈',
#  '그런',
#  '행복했었어',
#  '좋았나',
#  '먼',
#  '좋았어',
#  '어땠을까',
#  '그럴',
#  '없다는',
#  '없나',
#  '그리워',
#  '새까맣게',
#  '그리워해',
#  '없는',
#  '아파서',
#  '선명해질',
#  '같아',
#  '여전히',
#  '없는',
#  '아파서',
#  '선명해질',
#  '뜨겁게',
#  '없는',
#  '아파',
#  '행복했었던',
#  '있잖아',
#  '같아',
#  '어려운',
#  '미안해',
#  '이런',
#  '있어',
#  '뻔한',
#  '같아',
#  '이런',
#  '싫어진',
#  '있어',
#  '그래',
#  '부족한',
#  '비참해',
#  '있어줘',
#  '수많은',
#  '분명히',
#  '있었잖아',
#  '있었잖아',
#  '이런',
#  '곤란한데',
#  '아니야',
#  '말라',
#  '수많은',
#  '분명히',
#  '있었잖아',
#  '있었잖아',
#  '이런',
#  '곤란한데',
#  '같던',
#  '같아',
#  '없다',
#  '수많은',
#  '당연하게',
#  '아닌',
#  '아니면',
#  '곤란한데',
#  '아니면',
#  '충분했다는걸',
#  '무서워',
#  '나쁘게',
#  '서툰',
#  '아프겠지만',
#  '힘들어',
#  '서툰',
#  '그래',
#  '나쁘게',
#  '서툰',
#  '아프겠지만',
#  '힘들어',
#  '서툰',
#  '그래',
#  '같아',
#  '많았어',
#  '같은',
#  '아무렇지',
#  '아프겠지만',
#  '힘들겠지만',
#  '울적해진',
#  '낯설기만',
#  '뜨겁게',
#  '없었던',
#  '없었던',
#  '뜨겁게',
#  '없었던',
#  '많은',
#  '없어',
#  '없었던',
#  '뜨겁게',
#  '없었던',
#  '없었던',
#  '아무렇지',
#  '있을까',
#  '두려워',
#  '괜찮아',
#  '없을',
#  '있을까',
#  '없는',
#  '어떨진',
#  '힘들게',
#  '행복하길',
#  '있을',
#  '아프게',
#  '있을까',
#  '없게',
#  '없는',
#  '같은',
#  '그리워하며',
#  '힘들게',
#  '많은',
#  '좋은',
#  '있어',
#  '이상해',
#  '힘들어',
#  '미안하지만',
#  '어떻게',
#  '궁금한데',
#  '행복하길',
#  '예쁜',
#  '힘들',
#  '고맙게',
#  '나쁜',
#  '행복하길',
#  '예쁜',
#  '행복하게',
#  '예쁜',
#  '반갑게',
#  '아파오더라',
#  '없어서',
#  '좋은',
#  '없는',
#  '아니었더라',
#  '같아',
#  '미안했어야만',
#  '들떴었나',
#  '우스웠던',
#  '좋은',
#  '없는',
#  '있니',
#  '그래',
#  '싫지',
#  '영원한',
#  '미안해서',
#  '미안해서',
#  '이런',
#  '같은',
#  '있어',
#  '어떻게',
#  '이런',
#  '같은',
#  '아파',
#  '있으니',
#  '없는데',
#  '미안해서',
#  '미안해서',
#  '이런',
#  '같은',
#  '있어',
#  '어떻게',
#  '이런',
#  '같은',
#  '아파',
#  '있으니',
#  '슬픈',
#  '같은',
#  '영원히',
#  '그리워',
#  '같아',
#  '좁은',
#  '없어서',
#  '괜찮다',
#  '완전히',
#  '없는',
#  '벅차도록',
#  '행복했던',
#  '아플',
#  '같은',
#  '충분히',
#  '그러니',
#  '벅차도록',
#  '행복했던',
#  '아플',
#  '없는',
#  '없었고',
#  '벅차도록',
#  '행복했던',
#  '아플',
#  '고마웠어',
#  '아파야',
#  '차가웠던',
#  '따스한',
#  '같았어',
#  '아무렇지',
#  '차가운',
#  '무서워',
#  '있다면',
#  '없는',
#  '아프게',
#  '그리워해',
#  '그래',
#  '같다고',
#  '아파서',
#  '그래',
#  '행복하면',
#  '좋겠어',
#  '있니',
#  '없어',
#  '같아',
#  '궁금해',
#  '싫어서',
#  '궁금해',
#  '예뻐져도',
#  '세련되져도',
#  '아니',
#  '아니',
#  '안될것',
#  '같아',
#  '좋았어',
#  '같은',
#  '없을거야',
#  '고마워',
#  '힘들었겠지',
#  '없었니',
#  '없니',
#  '좋은',
#  '좋았어',
#  '같은',
#  '없을거야',
#  '고마워',
#  '아파서',
#  '없어',
#  '어떻게',
#  '편해']

# %%
# 불용어 추가
# 실행해보면서 추가하면서 바꿔야함.
stop_words3 = ["그리워하다","있게","선명히","있나요","이런","있네요","깉","그런","길은","없었으니까",\
               "있어","그래","수많은","있었잖아","말라","없게","같","같은"]
token_ko3 = [each_word for each_word in adjective_list if each_word not in stop_words3]
print(token_ko3)
# Out:
# ['행복할', '둔한', '아팠을', '슬픈', '그리워', '괜찮다', '아무렇지', '없단', '어색한', '벅차도록', '행복했던', '그리워서', '없이도', '행복하나요', '아프긴', '괜찮지가', '아름답게', '없이도', '행복하나요', '아프긴', '괜찮지가', '없는', '어떡하나요', '괜찮지가', '행복할', '아프게', '힘들기', '아파도', '아프게', '힘들기', '아파도', '괜찮아', '그리워', '아파', '슬퍼도', '조용히', '여전히', '아닐', '아쉬울', '날카로울', '좋아했었던', '생생한', '힘들게', '없지만', '행복한', '있었던', '뒤늦게', '다르게', '좋았던', '아프던', '없었던', '미워하지', '많은', '아름다웠어', '없던', '힘들게', '미워하지', '많은', '미워하지', '미워하지', '많은', '미워하지', '아닌', '서툰', '아련한', '뒤늦게', '따스한', '그리운', '싫어져', '없는게', '아파', '서툰', '없는', '많았어', '뒤늦게', '따스한', '그리운', '싫어져', '없는게', '아파', '같은데', '없는게', '아파', '작은', '힘든가', '아픈가', '노랠', '아픈가', '있을까', '힘든', '아픈', '행복했었어', '좋았나', '먼', '좋았어', '어땠을까', '그럴', '없다는', '없나', '그리워', '새까맣게', '그리워해', '없는', '아파서', '선명해질', '같아', '여전히', '없는', '아파서', '선명해질', '뜨겁게', '없는', '아파', '행복했었던', '있잖아', '같아', '어려운', '미안해', '뻔한', '같아', '싫어진', '부족한', '비참해', '있어줘', '분명히', '곤란한데', '아니야', '분명히', '곤란한데', '같던', '같아', '없다', '당연하게', '아닌', '아니면', '곤란한데', '아니면', '충분했다는걸', '무서워', '나쁘게', '서툰', '아프겠지만', '힘들어', '서툰', '나쁘게', '서툰', '아프겠지만', '힘들어', '서툰', '같아', '많았어', '아무렇지', '아프겠지만', '힘들겠지만', '울적해진', '낯설기만', '뜨겁게', '없었던', '없었던', '뜨겁게', '없었던', '많은', '없어', '없었던', '뜨겁게', '없었던', '없었던', '아무렇지', '있을까', '두려워', '괜찮아', '없을', '있을까', '없는', '어떨진', '힘들게', '행복하길', '있을', '아프게', '있을까', '없는', '그리워하며', '힘들게', '많은', '좋은', '이상해', '힘들어', '미안하지만', '어떻게', '궁금한데', '행복하길', '예쁜', '힘들', '고맙게', '나쁜', '행복하길', '예쁜', '행복하게', '예쁜', '반갑게', '아파오더라', '없어서', '좋은', '없는', '아니었더라', '같아', '미안했어야만', '들떴었나', '우스웠던', '좋은', '없는', '있니', '싫지', '영원한', '미안해서', '미안해서', '어떻게', '아파', '있으니', '없는데', '미안해서', '미안해서', '어떻게', '아파', '있으니', '슬픈', '영원히', '그리워', '같아', '좁은', '없어서', '괜찮다', '완전히', '없는', '벅차도록', '행복했던', '아플', '충분히', '그러니', '벅차도록', '행복했던', '아플', '없는', '없었고', '벅차도록', '행복했던', '아플', '고마웠어', '아파야', '차가웠던', '따스한', '같았어', '아무렇지', '차가운', '무서워', '있다면', '없는', '아프게', '그리워해', '같다고', '아파서', '행복하면', '좋겠어', '있니', '없어', '같아', '궁금해', '싫어서', '궁금해', '예뻐져도', '세련되져도', '아니', '아니', '안될것', '같아', '좋았어', '없을거야', '고마워', '힘들었겠지', '없었니', '없니', '좋은', '좋았어', '없을거야', '고마워', '아파서', '없어', '어떻게', '편해']

# %%
# 상위 50개 단어 확인
# 이걸보면서 불용어 지우는게 편해 전체는 힘들어
ko3 = nltk.Text(token_ko3)
ko3.vocab().most_common(50)
# Out:
# [('없는', 12),
#  ('같아', 9),
#  ('아파', 7),
#  ('없었던', 7),
#  ('서툰', 6),
#  ('미워하지', 5),
#  ('많은', 5),
#  ('그리워', 4),
#  ('아무렇지', 4),
#  ('벅차도록', 4),
#  ('행복했던', 4),
#  ('아프게', 4),
#  ('힘들게', 4),
#  ('있을까', 4),
#  ('아파서', 4),
#  ('뜨겁게', 4),
#  ('좋은', 4),
#  ('어떻게', 4),
#  ('미안해서', 4),
#  ('괜찮지가', 3),
#  ('뒤늦게', 3),
#  ('따스한', 3),
#  ('없는게', 3),
#  ('좋았어', 3),
#  ('곤란한데', 3),
#  ('아프겠지만', 3),
#  ('힘들어', 3),
#  ('없어', 3),
#  ('행복하길', 3),
#  ('예쁜', 3),
#  ('아플', 3),
#  ('행복할', 2),
#  ('슬픈', 2),
#  ('괜찮다', 2),
#  ('없이도', 2),
#  ('행복하나요', 2),
#  ('아프긴', 2),
#  ('힘들기', 2),
#  ('아파도', 2),
#  ('괜찮아', 2),
#  ('여전히', 2),
#  ('아닌', 2),
#  ('그리운', 2),
#  ('싫어져', 2),
#  ('많았어', 2),
#  ('아픈가', 2),
#  ('그리워해', 2),
#  ('선명해질', 2),
#  ('분명히', 2),
#  ('아니면', 2)]

# %%
# 상위 50개의 빈도수 차트 만들기
plt.figure(figsize=(12,6))
ko3.plot(50)
plt.show()

# %%
# 상위 50개만 wordcloud로 그리기
# 구한데이터로 그리기
data3 = ko3.vocab().most_common(50)

# 딕셔너리로 만들기
tmp_data3 = dict(data3)

wordcloud3 = WordCloud(
    background_color='White',
    relative_scaling=0.8,
    font_path="AppleGothic" # 윈도우 => 'c:/Windows/Fonts/malgun.ttf'
).generate_from_frequencies(tmp_data3)

# %%
plt.figure(figsize=(16,8))
plt.imshow(wordcloud3, interpolation='bilinear')
plt.axis('off')
plt.show()
