# %% [markdown]
# # 후회 WordCloud 만들기
# ---

# %%
import pandas as pd
import nltk # national language tool kit
from konlpy.corpus import kolaw
from konlpy.tag import Okt
import matplotlib.pyplot as plt
from wordcloud import WordCloud

t = Okt()

# %%
ballad_regret20 = pd.read_csv("../../Data/ballad_regret20.csv")
ballad_regret20.head()
# Out:
#      가수명               노래제목         발매일  \
# 0  어반자카파       아직도 나를 사랑한다면  2016-05-27
# 1     수지     I Love You Boy  2017-10-11
# 2    박새별  사랑이 우릴 다시 만나게 한다면  2013-05-28
# 3     폴킴         사랑 알 수 없나봐  2018-12-16
# 4   길구봉구             다시, 우리  2018-05-24
#
#                                                   가사   좋아요수
# 0  노래를 불러요 우릴 헤어지게 만든 그 노래를 이 일만 끝나면 더 잘할 수 있다고 그...   7655
# 1  그댈 보기 위해 먼 길을 건너왔네요 힘든 길인걸 알면서도 그저 걸었죠 I fly f...  33264
# 2  사랑이 우릴 다시 만나게 해준다면 나 그대에게 해주고 싶은 말이 너무 많아요 그댈 ...  12564
# 3  사랑 알 수 없나 봐 어떤 마음인지 자꾸 의심하게 돼 청개구리처럼 반대로 하게 되는...  41914
# 4  뚜루루 온종일 비가 내렸지 눅눅히 젖은 신발을 보다가 엉겨 붙어버린 기억의 먼지 한...  33582

# %% [markdown]
# ---
# ### 후회 wordcloud 생성

# %%
regret20 = ""

# %%
for i in range(0, 20):
    regret20 += (" " + ballad_regret20['가사'][i])
print(regret20)
# Out:
#  노래를 불러요 우릴 헤어지게 만든 그 노래를 이 일만 끝나면 더 잘할 수 있다고 그댈 괴롭히던 그 노래를 불안한 우리가 더 좋은 얘길 만들어 주겠죠 이런 거 싫지만 그댈 더 원하지만 결국 만들었네요 이 노래를 아직도 나를 사랑한다면 혹시 아직 나를 기다리면 전활 걸어줘요 아직도 나를 사랑한다면 혹시 아직 나를 기다리면 아직도 나를 사랑한다면 혹시 아직 나를 기다리면 전활 걸어줘요 아직도 나를 사랑한다면 혹시 아직 나를 기다리면  그댈 보기 위해 먼 길을 건너왔네요 힘든 길인걸 알면서도 그저 걸었죠 I fly for you 눈감아도 보이지 않던 내 맘에 니가 다가와 Because i love you boy 내 곁으로 다가와요 Because i need you boy 꿈에서도 그리운걸 Remember i love you boy 다신 볼 수 없다 해도 Because i love you boy Because i love you boy 사랑해요 사랑해요 너와 함께한 기억들이 바람에 날려 지친 내 맘에 내려앉아 나를 웃게 해 안개 속을 헤메이던 전하지 못한 내 맘이 네게 다가가 Because i love you boy 내 곁으로 다가와요 Because i need you boy 꿈에서도 그리운걸 내 차가운 맘을 움직였던 가슴을 울게 했던 그 사람이 그댄걸요 정말 잊으려고 해도 지워내려 해도 내 사랑은 그대죠 I fly for you Because i love you boy 내 곁으로 다가와요 Because i need you boy 꿈에서도 그리운걸 Remember i love you boy 다신 볼 수 없다 해도 Because i love you bo
다시 나의 별이 되어줘 주머니 속 내 손을 꼭 잡고 형편없는 나의 말에 웃어주던 그리운 밤 아무 일 없는 듯이 전화를 걸고 있어 나 여기서 두 팔 벌려 힘껏 달려와 내게 입 맞추던 그 눈빛을 그 사랑을 기다리고 있어 나였다면 언젠가 돌아본 그곳에 너를 바라보던 그 하늘이 나였다면 내가 너의 밤이 돼 줄게 어느 멋진 날 너에게 줄 노래  후회는 없을거라고 그만큼 사랑했다고지금 흔들리는 목소리로이별을 얘기하는거니사랑한 순간이야 그래 나도 기억하니까니 말대로 후회는 없을꺼야잊을순 없겠지만그게 정말이니 너 돌아서는모습이 정말 마지막이니아무말 없이 너를 보내고 난 뒤에후회하면 어떡하니어쩌면 너의 말처럼 조금씩 잊혀진대도아직까지는 나 단 하루도 너 없인 안되는데그게 정말이니 너 돌아서는모습이 정말 마지막이니아무말 없이 너를 보내고 난 뒤에 후회하면 어떡하니지금이라도 널 품에 안고괜찮아 하면 돌아올꺼니지나간 날에 이쁜추억 하나로이렇게 너 남는거니이렇게 멀어져 가는 그대그저 힘없이 바라볼 뿐소리쳐 불러봐도 잡을수 없기에이건 안 된다고 가지 말라고제발 내곁에 있어 달라고마음속으로 너를 한없이 불러도아 ...

# %%
# 명사 분리
token_regret = t.nouns(regret20)

# %%
# 후회테마 20곡의 상위 50개 단어 확인
# 이걸 보면서 불용어 선택하기
token_regret50 = nltk.Text(token_regret)
token_regret50.vocab().most_common(50)
# Out:
# [('사랑', 65),
#  ('너', 65),
#  ('내', 59),
#  ('나', 47),
#  ('말', 46),
#  ('그', 40),
#  ('수', 29),
#  ('네', 28),
#  ('날', 28),
#  ('다시', 25),
#  ('널', 25),
#  ('그대', 23),
#  ('우리', 22),
#  ('못', 19),
#  ('시간', 18),
#  ('더', 17),
#  ('생각', 17),
#  ('혹시', 16),
#  ('니', 16),
#  ('맘', 15),
#  ('정말', 15),
#  ('이', 14),
#  ('그때', 14),
#  ('후회', 13),
#  ('햇살', 13),
#  ('밤', 12),
#  ('모습', 12),
#  ('매일', 12),
#  ('걸', 11),
#  ('보고', 11),
#  ('꼭', 11),
#  ('눈물', 11),
#  ('것', 11),
#  ('그녀', 11),
#  ('노래', 10),
#  ('볼', 10),
#  ('거', 9),
#  ('가슴', 9),
#  ('그땐', 9),
#  ('난', 9),
#  ('게', 9),
#  ('처음', 9),
#  ('우릴', 8),
#  ('길', 8),
#  ('기억', 8),
#  ('해', 8),
#  ('사람', 8),
#  ('혼자', 8),
#  ('지금', 8),
#  ('마음', 8)]

# %%
# 불용어 추가
# 실행해보면서 추가하면서 바꿔야함.
stop_words20 = ['내','말','그','수','네','날','널','그대','니','햇살','해','이','걸','것','볼','거','난','꼭','게','길','길','알','안','눈','줄','척','속','때','손','늘','꿈','전','만큼','뒤','젠']
token_regret50 = [each_word for each_word in token_regret if each_word not in stop_words20]

# %%
# 후회테마 20곡의 상위 50개 단어 확인
# 불용어 처리후
token_regret50 = nltk.Text(token_regret50)
token_regret50.vocab().most_common(50)
# Out:
# [('사랑', 65),
#  ('너', 65),
#  ('나', 47),
#  ('다시', 25),
#  ('우리', 22),
#  ('못', 19),
#  ('시간', 18),
#  ('더', 17),
#  ('생각', 17),
#  ('혹시', 16),
#  ('맘', 15),
#  ('정말', 15),
#  ('그때', 14),
#  ('후회', 13),
#  ('밤', 12),
#  ('모습', 12),
#  ('매일', 12),
#  ('보고', 11),
#  ('눈물', 11),
#  ('그녀', 11),
#  ('노래', 10),
#  ('가슴', 9),
#  ('그땐', 9),
#  ('처음', 9),
#  ('우릴', 8),
#  ('기억', 8),
#  ('사람', 8),
#  ('혼자', 8),
#  ('지금', 8),
#  ('마음', 8),
#  ('왜', 8),
#  ('오늘', 8),
#  ('그날', 8),
#  ('곁', 7),
#  ('하나', 7),
#  ('이제', 7),
#  ('이별', 6),
#  ('하늘', 6),
#  ('또', 6),
#  ('해도', 5),
#  ('하루', 5),
#  ('그게', 5),
#  ('마', 5),
#  ('만날', 5),
#  ('바보', 5),
#  ('마지막', 5),
#  ('아주', 5),
#  ('손길', 4),
#  ('자꾸', 4),
#  ('아무', 4)]

# %%
# 한글 폰트 문제 해결 
# matplotlib은 한글 폰트를 지원하지 않음
# os정보
import platform

# font_manager : 폰트 관리 모듈
# rc : 폰트 변경 모듈
from matplotlib import font_manager, rc
# unicode 설정
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic') # os가 macos
elif platform.system() == 'Windows':
    path = 'c:/Windows/Fonts/malgun.ttf' # os가 windows
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print("Unknown System")

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# 상위 50개의 빈도수 차트 만들기
plt.figure(figsize=(12,6))
token_regret50.plot(50)
plt.show()

# %%
# 상위 50개만 wordcloud로 그리기
# 구한데이터로 그리기
data50 = token_regret50.vocab().most_common(50)

# 딕셔너리로 만들기
tmp_data50 = dict(data50)

wordcloud50 = WordCloud(
    background_color='White',
    relative_scaling=0.2,
    font_path="AppleGothic" # 윈도우 => 'c:/Windows/Fonts/malgun.ttf'
).generate_from_frequencies(tmp_data50)

# %%
plt.figure(figsize=(8,8))
plt.imshow(wordcloud50, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# 상위 500개만 wordcloud로 그리기
# 구한데이터로 그리기
data100 = ko100.vocab().most_common(50)

# 딕셔너리로 만들기
tmp_data100 = dict(data100)

wordcloud100 = WordCloud(
    background_color='White',
    relative_scaling=0.2,
    font_path="AppleGothic" # 윈도우 => 'c:/Windows/Fonts/malgun.ttf'
).generate_from_frequencies(tmp_data100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/51/xmc_l6t13wv1nc5z6qmyg58r0000gn/T/ipykernel_39295/1980976654.py in <module>
#       1 # 상위 500개만 wordcloud로 그리기
#       2 # 구한데이터로 그리기
# ----> 3 data100 = ko100.vocab().most_common(50)
#       4
#       5 # 딕셔너리로 만들기
#
# NameError: name 'ko100' is not defined
