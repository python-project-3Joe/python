# %%
import pandas as pd
import nltk # national language tool kit
from konlpy.corpus import kolaw
from konlpy.tag import Okt
import matplotlib.pyplot as plt
from wordcloud import WordCloud

t = Okt()

# %%
ballad_indifference20 = pd.read_csv("../../Data/ballad_indifference20.csv")
ballad_indifference20.head()
# Out:
#                         가수명       노래제목         발매일  \
# 0          백예린 (Yerin Baek)      그럴때마다  2021-09-10
# 1  Collective Arts (콜렉티브아츠)      나의 그늘  2017-07-27
# 2                    Sondia  Moonlight  2019-12-31
# 3                       윤현상     잊는다는 게  2015-03-13
# 4                       윤종신        말꼬리  2011-05-31
#
#                                                   가사   좋아요수
# 0  반복된 하루 사는 일에 지칠 때면 내게 말해요 항상 그대의 지쳐있는 마음에 조그만 ...  33255
# 1  나의 그늘이 좋다고 하는 너에게 무슨 말을 해야 좋을까 이 순간에도 가난한 나의 마...   4344
# 2  Moonlight 나를 감싸안아 데려다줘 그럼 너의 온기를 간직하겠어 내가 어디에 ...   4461
# 3  잊는다는 게 참 그래요 사랑하다가 이별하게 되면 그때서야 못해줬던 게 생각이 나요 ...  29999
# 4  비는 오고 너는 가려 하고 내 마음 눅눅하게 잠기고 낡은 흑백영화 한 장면처럼 내 ...  46043

# %% [markdown]
# ---
# ### 무관심 wordcloud 생성

# %%
indifference20 = ""

# %%
for i in range(0, 20):
    indifference20 += (" " + ballad_indifference20['가사'][i])
print(indifference20)
# Out:
#  반복된 하루 사는 일에 지칠 때면 내게 말해요 항상 그대의 지쳐있는 마음에 조그만 위로 돼줄게요 요즘 유행하는 영화 보고플 땐 내게 말해요 내겐 그대의 작은 부탁조차도 조그만 행복이죠 아무런 약속도 없는 일요일 오후 늦게 잠에서 깨 이유 없이 괜히 서글퍼질 땐 그대 곁엔 세상 누구보다 그댈 이해하는 내 자신보다 그댈 먼저 생각하는 사람이 있죠 오랫동안 항상 지켜왔죠 그대 빈자리 이젠 들어와 편히 쉬어요  혼자서 밥 먹기 싫을 땐 다른 사람 찾지 말아요 내겐 그대의 짜증 섞인 투정도 조그만 기쁨이죠 아무런 약속도 없는 일요일 오후 누군가 만나서 하루 종일 거릴 걷고 싶을 땐 그대 곁엔 세상 누구보다 그댈 이해하는 내 자신보다 그댈 먼저 생각하는 사람이 있죠  오랫동안 항상 지켜왔죠 그대 빈자리 이젠 들어와 편히 쉬어요 나의 그늘이 좋다고 하는 너에게 무슨 말을 해야 좋을까 이 순간에도 가난한 나의 마음인데도 넌 왜 웃어 보일까 미운 말을 쏟아내 상처 주긴 쉬운데 넌 왜 아직 거기 서 있는데 해는 뜨지 않는데 내게 기댄 너는 나의 그늘이 좋대 어둠이 내리고 모두 떠나가도 가깝지 않은 곳 어디에서 너는 나의 믿음이 되어 미운 말을 쏟아내 상처 주긴 쉬운데 넌 왜 아직 거기 서 있는데 해는 뜨지 않는데 내게 기댄 너는 나의 그늘이 좋대 아 나의 그늘이 나의 그늘이 아 나의 그늘이 나의 그늘이  Moonlight 나를 감싸안아 데려다줘 그럼 너의 온기를 간직하겠어 내가 어디에 숨어있든 다시 날 찾아줘 보기좋게 비껴나온 날 너의 빛으로 비춰줘 내 모든 발자욱과 내 창문 밖에 남은 너와 나의 흔적들 내 모든 것들이 다 그대로 남아 다시 날 채우네 Moonlight 내가 힘이 들 때 찾아와줘 그럼 네 빛을 따라 걸어가겠어 내가 어디에 숨어있든 다시 날 찾아줘 보기좋게 비껴나온 날 너의 빛으로 비춰줘 내 모든 발자욱과 내 창문 밖에 남은 너와 나의 흔적들 내 모든 것들이 다 그대로 남아 다시 날 채우네  잊는다는 게 참 그래요 사랑하다가 이별하게 되면 그때서야 못해줬던 
# ...

# %%
# 명사 분리
token_indifference = t.nouns(indifference20)

# %%
# 무관심테마 20곡의 상위 100개 단어 확인
# 이걸 보면서 불용어 선택하기
token_indifference50 = nltk.Text(token_indifference)
token_indifference50.vocab().most_common(100)
# Out:
# [('사랑', 69),
#  ('너', 59),
#  ('나', 44),
#  ('내', 42),
#  ('말', 38),
#  ('수', 37),
#  ('우리', 36),
#  ('날', 31),
#  ('더', 29),
#  ('게', 28),
#  ('것', 26),
#  ('이별', 26),
#  ('그', 25),
#  ('그대', 24),
#  ('알', 20),
#  ('시간', 16),
#  ('젠', 15),
#  ('왜', 15),
#  ('속', 15),
#  ('널', 15),
#  ('난', 15),
#  ('일', 14),
#  ('다시', 13),
#  ('걸', 13),
#  ('서로', 13),
#  ('때', 12),
#  ('생각', 12),
#  ('아무', 12),
#  ('그때', 11),
#  ('사람', 10),
#  ('해', 10),
#  ('또', 10),
#  ('멀리', 10),
#  ('마음', 9),
#  ('네', 9),
#  ('이제', 9),
#  ('손', 9),
#  ('맘', 9),
#  ('거', 9),
#  ('하루', 8),
#  ('혼자', 8),
#  ('곳', 8),
#  ('비', 8),
#  ('모든', 8),
#  ('추억', 8),
#  ('우린', 8),
#  ('그늘', 7),
#  ('끝', 7),
#  ('만큼', 7),
#  ('모습', 7),
#  ('오늘', 7),
#  ('바람', 7),
#  ('그날', 7),
#  ('건', 6),
#  ('길', 6),
#  ('이상', 6),
#  ('노력', 6),
#  ('눈', 6),
#  ('그게', 6),
#  ('그것', 6),
#  ('시절', 6),
#  ('번호', 6),
#  ('영화', 5),
#  ('약속', 5),
#  ('상처', 5),
#  ('어디', 5),
#  ('남아', 5),
#  ('못', 5),
#  ('기억', 5),
#  ('좀', 5),
#  ('덜', 5),
# ...

# %%
# 불용어 추가
# 실행해보면서 추가하면서 바꿔야함.
stop_words20 = ['내','말','수','네','날','더','게','것','그','알','젠','속','널','난','일','걸','만큼','해','거','곳','비','좀','덜','뒤','눈','건','손','길','스산','그게','방','무','창','빗','그것','으','두','이','못','넌','땐']
token_indifference100 = [each_word for each_word in token_indifference if each_word not in stop_words20]

# %%
# 무관심테마 20곡의 상위 50개 단어 확인
# 불용어 처리후
token_indifference100 = nltk.Text(token_indifference100)
token_indifference100.vocab().most_common(100)
# Out:
# [('사랑', 69),
#  ('너', 59),
#  ('나', 44),
#  ('우리', 36),
#  ('이별', 26),
#  ('그대', 24),
#  ('시간', 16),
#  ('왜', 15),
#  ('다시', 13),
#  ('서로', 13),
#  ('때', 12),
#  ('생각', 12),
#  ('아무', 12),
#  ('그때', 11),
#  ('사람', 10),
#  ('또', 10),
#  ('멀리', 10),
#  ('마음', 9),
#  ('이제', 9),
#  ('맘', 9),
#  ('하루', 8),
#  ('혼자', 8),
#  ('모든', 8),
#  ('추억', 8),
#  ('우린', 8),
#  ('그늘', 7),
#  ('끝', 7),
#  ('모습', 7),
#  ('오늘', 7),
#  ('바람', 7),
#  ('그날', 7),
#  ('이상', 6),
#  ('노력', 6),
#  ('시절', 6),
#  ('번호', 6),
#  ('영화', 5),
#  ('약속', 5),
#  ('상처', 5),
#  ('어디', 5),
#  ('남아', 5),
#  ('기억', 5),
#  ('가슴', 5),
#  ('소리', 5),
#  ('가기', 5),
#  ('노래', 5),
#  ('마지막', 5),
#  ('안녕', 5),
#  ('항상', 4),
#  ('보고', 4),
#  ('내겐', 4),
#  ('혹시', 4),
#  ('조금', 4),
#  ('사실', 4),
#  ('저기', 4),
#  ('여기', 4),
#  ('점점', 4),
#  ('아픔', 4),
#  ('조그만', 3),
#  ('행복', 3),
#  ('이유', 3),
#  ('누구', 3),
#  ('모두', 3),
#  ('빛', 3),
#  ('어제', 3),
#  ('지금', 3),
#  ('어쩌면', 3),
#  ('오지', 3),
#  ('가끔', 3),
#  ('숲', 3),
#  ('척', 3),
# ...

# %%
# 한글 폰트 문제 해결 
# matplotlib은 한글 폰트를 지원하지 않음
# os정보
import platform

# font_manager : 폰트 관리 모듈
# rc : 폰트 변경 모듈
from matplotlib import font_manager, rc
# unicode 설정
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic') # os가 macos
elif platform.system() == 'Windows':
    path = 'c:/Windows/Fonts/malgun.ttf' # os가 windows
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print("Unknown System")

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# 상위 100개의 빈도수 차트 만들기
plt.figure(figsize=(12,6))
token_indifference50.plot(100)
plt.show()

# %%
# 상위 100개만 wordcloud로 그리기
# 구한데이터로 그리기
data100 = token_indifference100.vocab().most_common(100)

# 딕셔너리로 만들기
tmp_data100 = dict(data100)

wordcloud100 = WordCloud(
    background_color='White',
    relative_scaling=0.2,
    font_path="AppleGothic" # 윈도우 => 'c:/Windows/Fonts/malgun.ttf'
).generate_from_frequencies(tmp_data100)

# %%
plt.figure(figsize=(8,8))
plt.imshow(wordcloud100, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
from wordcloud import WordCloud 
import matplotlib.pyplot as plt
import numpy as np
from PIL import *

# %%
#워드클라우드의 모양 설정. 후회모양의 이미지를 그대로 가져와 만들도록 하였음.
cand_mask=np.array(Image.open('../../Data/image/무관심1.png'))

# %%
wordcloud = WordCloud(
    background_color='white', # 배경색은 흰색으로 
    colormap= 'ocean', # 글씨색은 ('copper','ocean','summer')
    mask=cand_mask, # 워드클라우드 모양 설정
    font_path="AppleGothic" # 한글 글씨체 설정 # 윈도우 => 'c:/Windows/Fonts/malgun.ttf'
).generate_from_frequencies(tmp_data100)

# %%
#사이즈 설정 및 출력
plt.figure(figsize=(16,8))
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis('off') # 차트로 나오지 않게
# Out:
# (-0.5, 1003.5, 381.5, -0.5)

# %% [markdown]
# ---
# ## 무관심 워드클라우드 - 동사

# %%
test = indifference20

# %%
verb_list = []
for i in range(len(t.pos(test))):
    if t.pos(test)[i][1] == 'Verb':
        verb_list.append(t.pos(test)[i][0])

# %%
verb_list
# Out:
# ['된',
#  '사는',
#  '지칠',
#  '내게',
#  '해요',
#  '지쳐있는',
#  '돼줄게요',
#  '하는',
#  '내게',
#  '해요',
#  '늦게',
#  '서글퍼질',
#  '댈',
#  '하는',
#  '댈',
#  '하는',
#  '지켜',
#  '왔죠',
#  '들어와',
#  '쉬어요',
#  '찾지',
#  '말아요',
#  '섞인',
#  '만나서',
#  '걷고',
#  '싶을',
#  '댈',
#  '하는',
#  '댈',
#  '하는',
#  '지켜',
#  '왔죠',
#  '들어와',
#  '쉬어요',
#  '하는',
#  '해야',
#  '웃어',
#  '보일까',
#  '미운',
#  '쏟아내',
#  '주긴',
#  '서',
#  '뜨지',
#  '않는데',
#  '내게',
#  '기댄',
#  '내리고',
#  '떠나가도',
#  '않은',
#  '되어',
#  '미운',
#  '쏟아내',
#  '주긴',
#  '서',
#  '뜨지',
#  '않는데',
#  '내게',
#  '기댄',
#  '나를',
#  '감싸안아',
#  '데려다줘',
#  '하겠어',
#  '숨어있든',
#  '찾아줘',
#  '껴',
#  '나온',
#  '비춰줘',
#  '남은',
#  '채우네',
#  '들',
#  '찾아와줘',
#  '따라',
#  '걸어가겠어',
#  '숨어있든',
#  '찾아줘',
#  '껴',
#  '나온',
#  '비춰줘',
#  '남은',
#  '채우네',
#  '잊는다는',
#  '참',
#  '하다가',
#  '하게',
#  '되면',
#  '서야',
#  '해줬던',
#  '참',
#  '남아있는데',
#  '지나가면',
#  '버리는',
#  '잊는다는',
#  '했었던',
#  '일까',
#  '만나서',
#  '되는',
#  '그리',
#  '잊는다는',
#  '참',
#  '지키지',
#  '내게',
#  '돼',
#  '버린단',
#  '돼',
#  '버리니까',
# ...

# %%
# 불용어 추가
# 실행해보면서 추가하면서 바꿔야함.
stop_words2 = ["할","참","한","챌","는제","참","줘","걸까","댄","따라","된","잘","된","는","올","되",\
    "기를","까","큰","갈","건지","하는","이길","딴","서","써","내게","나를","나도",'해서','댈','봐','하며',\
    '해','했죠','해요','했어','본','밝아서','줬던','돼','되는','않을','갔','뜨고','가','했고','와']
token_ko2 = [each_word for each_word in verb_list if each_word not in stop_words2]
print(token_ko2)
# Out:
# ['사는', '지칠', '지쳐있는', '돼줄게요', '늦게', '서글퍼질', '지켜', '왔죠', '들어와', '쉬어요', '찾지', '말아요', '섞인', '만나서', '걷고', '싶을', '지켜', '왔죠', '들어와', '쉬어요', '해야', '웃어', '보일까', '미운', '쏟아내', '주긴', '뜨지', '않는데', '기댄', '내리고', '떠나가도', '않은', '되어', '미운', '쏟아내', '주긴', '뜨지', '않는데', '기댄', '감싸안아', '데려다줘', '하겠어', '숨어있든', '찾아줘', '껴', '나온', '비춰줘', '남은', '채우네', '들', '찾아와줘', '걸어가겠어', '숨어있든', '찾아줘', '껴', '나온', '비춰줘', '남은', '채우네', '잊는다는', '하다가', '하게', '되면', '서야', '해줬던', '남아있는데', '지나가면', '버리는', '잊는다는', '했었던', '일까', '만나서', '그리', '잊는다는', '지키지', '버린단', '버리니까', '잊는다는', '했었던', '일까', '만나서', '그리', '잊는다는', '생각나는', '다시는', '묻힌', '잊어야겠지', '잊어야겠지', '만나서', '만나도', '잊지', '말아요', '그리', '그리', '잊는다는', '비는', '오고', '가려', '하고', '끊기고', '하기에', '보낸다고', '하지', '않았었나', '보내', '떠나간', '빌어줄', '하면', '머물러줘', '하면', '하지', '않았었나', '보내', '떠나간', '빌어줄', '보일', '메말라', '갈라질', '쓰고', '남은', '만들지', '주고', '걷는다', '걷는다', '걷는다', '쳐다만', '보는', '도망치는', '떠올라서', '지우고', '지워도', '걷는다', '채운다', '걷는다', '걷는다', '끝났어', '해본다', '돌아가', '달려가', '싶지만', '잊었겠지', '걷는다', '싶단', '걷는다', '걷는다', '잊혀진', '만
# ...

# %%
# 상위 100개 단어 확인
# 이걸보면서 불용어 지우는게 편해 전체는 힘들어
ko2 = nltk.Text(token_ko2)
ko2.vocab().most_common(100)
# Out:
# [('걷는다', 9),
#  ('남은', 6),
#  ('잊는다는', 6),
#  ('만나서', 5),
#  ('하게', 5),
#  ('그리', 5),
#  ('하지', 5),
#  ('될까', 4),
#  ('견딜', 4),
#  ('만나게', 4),
#  ('이뤄져', 4),
#  ('머문', 4),
#  ('했지', 4),
#  ('끝난', 4),
#  ('말아요', 3),
#  ('해야', 3),
#  ('하겠어', 3),
#  ('해도', 3),
#  ('멀어지는', 3),
#  ('잡아도', 3),
#  ('돌아와', 3),
#  ('들려오는', 3),
#  ('느껴지는', 3),
#  ('해줘', 3),
#  ('커져가던', 3),
#  ('갇혀', 3),
#  ('잃고', 3),
#  ('울리던', 3),
#  ('들리지', 3),
#  ('작아져', 3),
#  ('가는', 3),
#  ('엇갈린', 3),
#  ('지나쳐', 3),
#  ('맞는', 3),
#  ('알아요', 3),
#  ('누르고', 3),
#  ('채우다', 3),
#  ('지우며', 3),
#  ('덜어내', 3),
#  ('몰랐을까', 3),
#  ('이뤄질', 3),
#  ('가봐', 3),
#  ('지킬', 3),
#  ('감추려', 3),
#  ('달래며', 3),
#  ('돌아', 3),
#  ('걷지', 3),
#  ('되돌릴', 3),
#  ('잖아', 3),
#  ('지켜', 2),
#  ('왔죠', 2),
#  ('들어와', 2),
#  ('쉬어요', 2),
#  ('미운', 2),
#  ('쏟아내', 2),
#  ('주긴', 2),
#  ('뜨지', 2),
#  ('않는데', 2),
#  ('기댄', 2),
#  ('않은', 2),
#  ('숨어있든', 2),
#  ('찾아줘', 2),
#  ('껴', 2),
#  ('나온', 2),
#  ('비춰줘', 2),
#  ('채우네', 2),
#  ('들', 2),
#  ('해줬던', 2),
# ...

# %%
# 상위 100개만 wordcloud로 그리기
# 구한데이터로 그리기
data2 = ko2.vocab().most_common(100)

# 딕셔너리로 만들기
tmp_data2 = dict(data2)

wordcloud2 = WordCloud(
    background_color='White',
    relative_scaling=0.8,
    font_path="AppleGothic" # 윈도우 => 'c:/Windows/Fonts/malgun.ttf'
).generate_from_frequencies(tmp_data2)

# %%
plt.figure(figsize=(20,8))
plt.imshow(wordcloud2, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
from wordcloud import WordCloud 
import matplotlib.pyplot as plt
import numpy as np
from PIL import *

# %%
#워드클라우드의 모양 설정. 후회모양의 이미지를 그대로 가져와 만들도록 하였음.
cand_mask=np.array(Image.open('../../Data/image/무관심.png'))

# %%
wordcloud = WordCloud(
    background_color='white', # 배경색은 흰색으로 
    colormap= 'ocean', # 글씨색은 ('copper','ocean','summer')
    mask=cand_mask, # 워드클라우드 모양 설정
    font_path="AppleGothic" # 한글 글씨체 설정 # 윈도우 => 'c:/Windows/Fonts/malgun.ttf'
).generate_from_frequencies(tmp_data2)

# %%
#사이즈 설정 및 출력
plt.figure(figsize=(20,20))
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis('off') # 차트로 나오지 않게
#plt.savefig('test.png')
# Out:
# (-0.5, 1063.5, 391.5, -0.5)
