# %% [markdown]
# # 기쁨 가사 20개 Markov Chain 하기

# %%
import pandas as pd

# %%
ballad = pd.read_csv("../../Data/ballad_train60.csv")

# %%
ballad_lyrics_happy = ballad[ballad.감정 == 'happy'].가사

# %%
ballad_lyrics_happy= pd.DataFrame(ballad_lyrics_happy)
ballad_lyrics_happy.to_csv("../../Data/ballad_lyrics_happy.csv",index=False)

# %%
import markov
from konlpy.tag import Okt
import json

# %%
ballad_file = "../../Note/Markov/ballad.txt"
dict_file = "../../Note/Markov/markov_ballad.json"

# %%
file = open("../../Data/ballad_lyrics_happy.csv",encoding='UTF-8')
text = str(file.readlines())
text
# Out:
# '[\'가사\\n\', \'Oh darling 처음 널 만나면 수줍은 대화들로 사랑에 빠질 거야 My darling 아마도 우린 손을 마주 잡고서 도시를 거닐 거야 비라도 오면 골목 어귀에 발을 멈추고서 바라보다가 입을 맞출지도 몰라 어둠이 오면 밝게 빛나는 별빛들 아래서 음악에 취해 서로에게 기대어 Darling My darling 멈춰버린 시간 속에서 우리 둘이서 영원토록 Darling My darling 함께 할 거야 너의 곁에서 눈을 감을 때까지 Oh darling 잊지 못할 거야 서로를 품에 안고 온기를 느끼던 날 My darling 따스할 거야 함께 잠이 들 때면 비추는 햇살들이 가끔씩 우린 아쉬울 거야 다른 모습들에 말을 멈추고 어색한 침묵이 올 때면 서운한 마음에 다투다 보면 오직 둘만 아는 그런 말들로 가벼운 미소가 될 거야 Darling My darling 멈춰버린 시간 속에서 우리 둘이서 영원토록 Darling My darling 함께 할 거야 너의 곁에서 눈을 감을 때까지 널 처음 마주한 순간 알 수 있었어 나를 보며 지었던 그 미소 그게 내 전부란 걸 Darling My darling 설레이는 내 마음을 담아 너에게 고백할게 영원토록 Darling My darling 나를 안아줘 너의 곁에서 눈을 감을 때까지 눈을 감을 때까지 눈을 감을 때까지 \\n\', \'당신은 날 설레게 만들어 조용한 내 마음 자꾸만 춤추게 해 얼마나 얼마나 날 떨리게 하는지 당신이 이 밤을 항상 잠 못 들게 해 매일 같은 밤 너를 생각하면서 유치한 노랠 들으며 심장이 춤을 추면서 오오 난 너를 기다리면서 유치한 노랠 부르며 심장이 춤을 추면서 워 나를 떨리게 하나요 그대 왜 나를 설레게 하나요 자꾸만 오늘도 잠 못 이루는 이 밤 아름다운 그대 나를 아프게 하나요 웃는 그대 왜 자꾸 설레게 하나요 하염없이 오늘 밤 잠이 오질 않네요 보고 싶은 그대여 당신이 날 힘들게 만들어 갑자기 내 마음 자꾸만 멍들게 해 얼마나 얼마나 잠 못 들게 하는지 고요한 내 마음 항
# ...

# %%
text = text.split(",")[1:]

# %%
text
# Out:
# [" 'Oh darling 처음 널 만나면 수줍은 대화들로 사랑에 빠질 거야 My darling 아마도 우린 손을 마주 잡고서 도시를 거닐 거야 비라도 오면 골목 어귀에 발을 멈추고서 바라보다가 입을 맞출지도 몰라 어둠이 오면 밝게 빛나는 별빛들 아래서 음악에 취해 서로에게 기대어 Darling My darling 멈춰버린 시간 속에서 우리 둘이서 영원토록 Darling My darling 함께 할 거야 너의 곁에서 눈을 감을 때까지 Oh darling 잊지 못할 거야 서로를 품에 안고 온기를 느끼던 날 My darling 따스할 거야 함께 잠이 들 때면 비추는 햇살들이 가끔씩 우린 아쉬울 거야 다른 모습들에 말을 멈추고 어색한 침묵이 올 때면 서운한 마음에 다투다 보면 오직 둘만 아는 그런 말들로 가벼운 미소가 될 거야 Darling My darling 멈춰버린 시간 속에서 우리 둘이서 영원토록 Darling My darling 함께 할 거야 너의 곁에서 눈을 감을 때까지 널 처음 마주한 순간 알 수 있었어 나를 보며 지었던 그 미소 그게 내 전부란 걸 Darling My darling 설레이는 내 마음을 담아 너에게 고백할게 영원토록 Darling My darling 나를 안아줘 너의 곁에서 눈을 감을 때까지 눈을 감을 때까지 눈을 감을 때까지 \\n'",
# ...

# %%
total = ""
for i in range(len(text)):
     total += " " + text[i] + "."

# %%
# 텍스트를 한 줄씩 처리하기
twitter = Okt()
lines = total.split("\n")
for line in lines:
    malist = twitter.pos(line,norm=True,stem=False)
    words = []
    for word in malist:
        if not word[1] in ['Alpha','Punctuation']: # .(마침표)제외한 ? "" ! 를 사용하지 않음
            words.append(word[0])
        if word[0] == ".":
            words.append(word[0])

# %%
# 딕셔너리 생성
dic = markov.make_dic(words)
json.dump(dic,open(dict_file,"w",encoding="utf-8"))

# %%
dic = json.load(open(dict_file,"r"))

# %%
dic
# Out:
# {'@': {'처음': {'널': 1}, '널': {'기다리던': 1}, '내': {'가': 1}},
#  '처음': {'널': {'만나면': 1},
#   '마주': {'한': 1},
#   '본': {'날': 1},
#   '에': {'약속': 1},
#   '이니까': {'초록': 1},
#   '내민': {'너': 1},
#   '만난': {'날': 1},
#   '조차': {'기억나지': 1}},
#  '널': {'만나면': {'수줍은': 1},
#   '처음': {'마주': 1, '만난': 1},
#   '볼': {'때': 1, '수': 1},
#   '떠올렸던': {'밤': 1},
#   '울리고': {'말았어': 1},
#   '위': {'한': 2},
#   '품고': {'달려': 1},
#   '보면': {'나': 1},
#   '우연히': {'봤고': 1},
#   '기다리던': {'밤': 1},
#   '잊으려고': {'노력': 3},
#   '미워하는': {'건': 3},
#   '그리워하는': {'날': 1},
#   '좋아하는': {'내': 1},
#   '사랑': {'해': 5},
#   '정말': {'좋아하게': 1},
#   '향': {'한': 1}},
#  '만나면': {'수줍은': {'대화': 1}},
#  '수줍은': {'대화': {'들': 1}},
#  '대화': {'들': {'로': 1}},
#  '들': {'로': {'사랑': 1, '가벼운': 1},
#   '아래': {'서': 1},
#   '때': {'면': 1},
#   '이': {'가끔': 1,
#    '모두': 3,
#    '반짝': 1,
#    '눈': 1,
#    '이제야': 1,
#    '내게': 2,
#    '이제': 1,
#    '너무': 1},
#   '에': {'말': 1, '긴': 1},
#   '게': {'해': 1},
#   '은': {'내게': 1, '계속': 1},
#   '왜': {'이리': 1},
# ...

# %%
# 문장 만들기
for i in range(3):
    s = markov.make_sentence(dic)
    print(s)
    print("-------")
# Out:
# 널 기다리던 밤 처럼 길고 어둡던 우리 사이 공백 은 너무 길고 어떤 단어 보다 너 가 더 멀어져 가며 흘러가는 어색했던 오늘 하루 가 즐거워져 이대로 함께 그대 와 함께하고 싶은 게 참 많은걸요 익숙해질 즘 그 댈 기다리는 게 왠지 마주칠 것 만 같아 마음 이 그대 머문 자리 에 천천히 다 말 해봐요 매일 나 귀 기울여요 차갑던 계절 지나면 또 피어 날 거란 걸 알아요 듣고 있죠 두 눈 혼자 서 숨겼던 널 향 한 마음 은 알 게 하진 않을 거야 널 볼 때 면 불안할 때 나를 강해지게 만드는 한 사람 아껴줄게 세상 의 행복 을 위해 나를 다 주겠단 그 약속 왜 이리 힘든 걸까 이 모든 게 그림 인 걸 내게 가까이 와줘 한 손 엔 널 품고 달려 너무나도 특별한 널 위 한 너 의 행복해하는 모습 을 보고 있으면 나도 모르게 따라 웃는데 이 정도 면 알아줄 만 하잖아 너 도 용기 낼 만 하잖아 나 만 이런 게 아니라면 우리 만 나볼 만 하잖아 너 도 이렇게 대답 해줘 너 라서 좋아 니 가 내 곁 에 그대 가 있겠죠 멈춘 가슴 이 뛰어요 우리 처음 본 날 처럼 문득 스쳐 지나는 기억 에 습관 처럼 웃어요 어디 라도 난 느낄 수 있죠 내게 사랑 이란 한 번 뿐이겠죠 혹시 내 옆 에 다른 사람 있어도 사랑 은 아니죠 언제 부터 였을까 맘 이 타 들어가 대체 왜 이러는거야 서로 원하고 있잖아 애써 외면 하는 우리 둘 만의 첫 겨울 이니까 뭐 가 좋을까 로 즈 골드 빛 목 걸인 어떨까 언젠가 풀 반지 곱 게 엮어 고백 을 할 땐 눈 이 내리면 크리스마스 온 세상 환희 반짝 이네 크리스마스 그중 제일 반짝이는 숨막히게 예쁜 너 와 하고 싶은 일 들 을 기다려 왔던 내 맘 전 할래 간지럽게만 느껴지던 눈 빛 이 이제 는 익숙 하단 듯이 웃음 짓지 그 쪽 으로 걸어가기만 하면 돼 라고 친구 들 은 계속 해서 날 부추기지만 아직 은 무거운 구두 의 뒷 굽 차라리 벗어 버리고 싶은 이 밤 을 항상 잠 못 이루는 이 밤 을 항상 잠 못 이루고 널 떠올렸던 밤 별 들 이 가끔 씩 우
# ...

# %%
import os
import codecs
from bs4 import BeautifulSoup
from konlpy.tag import Twitter
import urllib.request
import os, re, json, random

# 마르코프 체인 딕셔너리 만들기 --- (※1)
def make_dic(words):
    tmp = ["@"]
    dic = {}
    for word in words:
        tmp.append(word)
        if len(tmp) < 3: continue
        if len(tmp) > 3: tmp = tmp[1:]
        set_word3(dic, tmp)
        if word == ".":
            tmp = ["@"]
            continue
    return dic
# 딕셔너리에 데이터 등록하기 --- (※2)
def set_word3(dic, s3):
    w1, w2, w3 = s3
    if not w1 in dic: dic[w1] = {}
    if not w2 in dic[w1]: dic[w1][w2] = {}
    if not w3 in dic[w1][w2]: dic[w1][w2][w3] = 0
    dic[w1][w2][w3] += 1
# 문장 만들기 --- (※3)
def make_sentence(dic):
    ret = []
    if not "@" in dic: return "no dic" 
    top = dic["@"]
    w1 = word_choice(top)
    w2 = word_choice(top[w1])
    ret.append(w1)
    ret.append(w2)
    while True:
        try:
            w3 = word_choice(dic[w1][w2])
            ret.append(w3)
        except:
            continue
        # if w3 == ".": break
        if len(ret) >= 200: break
        w1, w2 = w2, w3
    ret = "".join(ret)
    # 띄어쓰기
    params = urllib.parse.urlencode({
        "_callback": "",
        "q": ret
    })
    # 네이버 맞춤법 검사기를 사용합니다.
    # data = urllib.request.urlopen("https://m.search.naver.com/p/csearch/ocontent/util/SpellerProxy?" + params)
    data = urllib.request.urlopen("https://m.search.naver.com/p/csearch/ocontent/spellchecker.nhn?" + params)
    data = data.read().decode("utf-8")[1:-2]
    data = json.loads(data)
    data = data["message"]["result"]["html"]
    data = soup = BeautifulSoup(data, "html.parser").getText()
    # 리턴
    return data

def word_choice(sel):
    keys = sel.keys()
    return random.choice(list(keys))
# 문장 읽어 들이기 --- (※4)
toji_file = "../../Note/Markov/ballad.txt"
dict_file = "../../Note/Markov/markov_ballad.json"
if not os.path.exists(dict_file):
    # 텍스트 파일 읽어 들이기
    with open(toji_file, 'r', encoding='utf-8') as f:
        text = str(f.readlines())

    text = text.replace("…", "") # 현재 koNLPy가 …을 구두점으로 잡지 못하는 문제 임시 해결
    text = text.replace("n", "")
    # 형태소 분석
   # twitter = Twitter()
    twitter=Twitter()
    malist = twitter.pos(text, norm=True)
    words = []
    for word in malist:
        # 구두점 등은 대상에서 제외(단 마침표는 포함)
        if not word[1] in ["Punctuation"]:
            words.append(word[0])
        if word[0] == ".":
            words.append(word[0])
    # 딕셔너리 생성
    dic = make_dic(words)
    json.dump(dic, open(dict_file,"w", encoding="utf-8"))
else:
    dic = json.load(open(dict_file,"r"))
# 문장 만들기 — (※6)
for i in range(5):
    s = make_sentence(dic)
    print(s)
    print("—")
# Out:
# 처음 널 만나면 수줍은 대화들로 사랑에 눈처럼 가득히 날리고 영원토록 녹지 않아 우리의 부드럽고 예쁜 스토리 오늘은 유난히 멋 좀 부리고 제일 먼저 네게 전활 걸어 지금 어디야 오늘 뭐 할래 퉁명스러운 너의 행복해하는 모습을 보고 있으면 자연스레 따라 웃고 있는 걸 너 땜에 아파하는 걸 널 잊으려고 노력해봐도 잘 안돼 널 미워하는 건 너무 어려워 날 몰라주는 너도 용기 낼만하잖아 아무래도 사랑인가 봐 점점 너와 난 이젠 돌아갈 순 없지만 낡아진 서랍 속에서 어둡게 피어난 미움들 왜 이리 멀쩡해 보이는 건지 눈치도 없는 둘만이 알던 곳 함께 걷던 거리에 서서 아무 말도 하지 못한 채 한참을 너 생각했어 그날 그때 우리 떨리던 목소리 여전히 들리는지 이런 내 맘을 설레게 해 항상 어두웠던 것들이 내게 일어나고 있어 나에게만 준비된 선물 같아 자그마한 모든 게 커져만 가 항상 평범했던 일상도 특별해지는 이 순간이 영원하길 난 정말 행복해 밤하늘의 별을 따서 너에게 가고 있나 봐 부는 바람에 흘려보내봐도 다시 꽃 피는 이 사랑을
# —
# ...

# %% [markdown]
# ---
# # 후회 가사 20개 Markov Chain 하기

# %%
ballad_lyrics_regret = ballad[ballad.감정 == 'regret'].가사

# %%
ballad_lyrics_regret= pd.DataFrame(ballad_lyrics_regret)
ballad_lyrics_regret.to_csv("../../Data/ballad_lyrics_regret.csv",index=False)

# %%
ballad_file = "../../Note/Markov/ballad_regret.txt"
dict_file = "../../Note/Markov/markov_ballad_regret.json"

# %%
file = open("../../Data/ballad_lyrics_regret.csv",encoding='UTF-8')
text = str(file.readlines())
text
# Out:
# "['가사\\n', '노래를 불러요 우릴 헤어지게 만든 그 노래를 이 일만 끝나면 더 잘할 수 있다고 그댈 괴롭히던 그 노래를 불안한 우리가 더 좋은 얘길 만들어 주겠죠 이런 거 싫지만 그댈 더 원하지만 결국 만들었네요 이 노래를 아직도 나를 사랑한다면 혹시 아직 나를 기다리면 전활 걸어줘요 아직도 나를 사랑한다면 혹시 아직 나를 기다리면 아직도 나를 사랑한다면 혹시 아직 나를 기다리면 전활 걸어줘요 아직도 나를 사랑한다면 혹시 아직 나를 기다리면 \\n', '그댈 보기 위해 먼 길을 건너왔네요 힘든 길인걸 알면서도 그저 걸었죠 I fly for you 눈감아도 보이지 않던 내 맘에 니가 다가와 Because i love you boy 내 곁으로 다가와요 Because i need you boy 꿈에서도 그리운걸 Remember i love you boy 다신 볼 수 없다 해도 Because i love you boy Because i love you boy 사랑해요 사랑해요 너와 함께한 기억들이 바람에 날려 지친 내 맘에 내려앉아 나를 웃게 해 안개 속을 헤메이던 전하지 못한 내 맘이 네게 다가가 Because i love you boy 내 곁으로 다가와요 Because i need you boy 꿈에서도 그리운걸 내 차가운 맘을 움직였던 가슴을 울게 했던 그 사람이 그댄걸요 정말 잊으려고 해도 지워내려 해도 내 사랑은 그대죠 I fly for you Because i love you boy 내 곁으로 다가와요 Because i need you boy 꿈에서도 그리운걸 Remember i love you boy 다신 볼 수 없다 해도 Because i love you boy Because i love you boy 사랑해요 사랑해요 \\n', '사랑이 우릴 다시 만나게 해준다면 나 그대에게 해주고 싶은 말이 너무 많아요 그댈 보내고 내가 얼마나 많은 밤들을 혼자 그리워하는지 그댄 그댄 모르죠 사랑이 우릴 다시 만나게 해준다면 나 그땐 좀 더 온전히 그대를
# ...

# %%
text = text.split(",")[1:]

# %%
text
# Out:
# [" '노래를 불러요 우릴 헤어지게 만든 그 노래를 이 일만 끝나면 더 잘할 수 있다고 그댈 괴롭히던 그 노래를 불안한 우리가 더 좋은 얘길 만들어 주겠죠 이런 거 싫지만 그댈 더 원하지만 결국 만들었네요 이 노래를 아직도 나를 사랑한다면 혹시 아직 나를 기다리면 전활 걸어줘요 아직도 나를 사랑한다면 혹시 아직 나를 기다리면 아직도 나를 사랑한다면 혹시 아직 나를 기다리면 전활 걸어줘요 아직도 나를 사랑한다면 혹시 아직 나를 기다리면 \\n'",
#  " '그댈 보기 위해 먼 길을 건너왔네요 힘든 길인걸 알면서도 그저 걸었죠 I fly for you 눈감아도 보이지 않던 내 맘에 니가 다가와 Because i love you boy 내 곁으로 다가와요 Because i need you boy 꿈에서도 그리운걸 Remember i love you boy 다신 볼 수 없다 해도 Because i love you boy Because i love you boy 사랑해요 사랑해요 너와 함께한 기억들이 바람에 날려 지친 내 맘에 내려앉아 나를 웃게 해 안개 속을 헤메이던 전하지 못한 내 맘이 네게 다가가 Because i love you boy 내 곁으로 다가와요 Because i need you boy 꿈에서도 그리운걸 내 차가운 맘을 움직였던 가슴을 울게 했던 그 사람이 그댄걸요 정말 잊으려고 해도 지워내려 해도 내 사랑은 그대죠 I fly for you Because i love you boy 내 곁으로 다가와요 Because i need you boy 꿈에서도 그리운걸 Remember i love you boy 다신 볼 수 없다 해도 Because i love you boy Because i love you boy 사랑해요 사랑해요 \\n'",
# ...

# %%
total = ""
for i in range(len(text)):
     total += " " + text[i] + "."

# %%
len(total)
# Out:
# 9685

# %%
# 텍스트를 한 줄씩 처리하기
twitter = Okt()
lines = total.split("\n")
for line in lines:
    malist = twitter.pos(line,norm=True,stem=False)
    words = []
    for word in malist:
        if not word[1] in ['Alpha','Punctuation']: # .(마침표)제외한 ? "" ! 를 사용하지 않음
            words.append(word[0])
        if (word[0] == ".") | (word[0] == "돌아가고")| (word[0] == "싶어서"):
            words.append(word[0])

# %%
# 딕셔너리 생성
dic = markov.make_dic(words)
json.dump(dic,open(dict_file,"w",encoding="utf-8"))

# %%
dic
# Out:
# {'@': {'노래': {'를': 1}},
#  '노래': {'를': {'불러요': 1, '이': 1, '불안한': 1, '아직도': 1},
#   '해': {'내게로': 3},
#   '는': {'너': 1},
#   '의': {'의미': 1},
#   '후회': {'는': 1}},
#  '를': {'불러요': {'우릴': 1},
#   '이': {'일만': 1},
#   '불안한': {'우리': 1},
#   '아직도': {'나를': 1},
#   '사랑': {'할게요': 1, '이': 3, '해서': 4},
#   '돌려': {'바': 1},
#   '지': {'운': 1},
#   '쳐': {'낼': 1},
#   '기다려': {'네': 1},
#   '맞으며': {'서': 1},
#   '지울': {'수': 3},
#   '붙잡고': {'후회': 2},
#   '찾고': {'있어': 1},
#   '바라보던': {'그': 2},
#   '걸고': {'있어': 1},
#   '보내고': {'난': 2},
#   '한없이': {'불러도': 1},
#   '소리쳐': {'부른다': 2},
#   '위해': {'기도': 1},
#   '할께': {'부디': 1},
#   '만나서': {'세상': 2, '그냥': 1, '너': 2},
#   '알아서': {'내': 2},
#   '보내며': {'나를': 2},
#   '탓': {'하며': 1},
#   '지우면': {'그게': 1},
#   '놓았을까': {'나': 1},
#   '만들어줄게': {'미안한': 1},
#   '보낼': {'준비': 1},
#   '준다면': {'내': 1},
#   '볼': {'수': 3},
#   '주고받고': {'엉엉': 1},
#   '한': {'번': 1},
#   '다': {'끝낸': 1},
#   '외우듯이': {'시간': 1}},
#  '불러요': {'우릴': {'헤어지게': 1}},
#  '우릴': {'헤어지게': {'만든': 1},
# ...

# %%
# 문장 만들기
for i in range(3):
    s = markov.make_sentence(dic)
    print(s)
    print("-------")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7268/3363405284.py in <module>
#       1 # 문장 만들기
#       2 for i in range(3):
# ----> 3     s = markov.make_sentence(dic)
#       4     print(s)
#       5     print("-------")
#
# c:\Users\yejin\Desktop\python\Note\Markov\markov.py in make_sentence(dic)
#      40     ret.append(w2)
#      41     while True:
# ---> 42         w3 = word_choice(dic[w1][w2])
#      43         ret.append(w3)
#      44         if w3 == ".": break
#
# c:\Users\yejin\Desktop\python\Note\Markov\markov.py in word_choice(sel)
#      49 def word_choice(sel):
#      50     keys = sel.keys()
# ---> 51     return random.choice(list(keys))
#
# c:\Users\yejin\anaconda3\lib\random.py in choice(self, seq)
#     341     ## -------------------- sequence methods  -------------------
#     342
# --> 343     def choice(self, seq):
# ...
