# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import urllib.request as request

from selenium.webdriver.chrome.options import Options
from fake_useragent import UserAgent

# %%
options = Options()
ua = UserAgent(verify_ssl=False)
userAgent = ua.random
print(userAgent)
# Out:
# Mozilla/5.0 (Windows NT 6.2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/28.0.1467.0 Safari/537.36

# %%
options.add_argument(f'user-agent={userAgent}')
# chrome_options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)
driver.get('https://www.melon.com/mymusic/dj/mymusicdjplaylistview_inform.htm?plylstSeq=497292073')

# %%
page_source = driver.page_source
soup = BeautifulSoup(page_source, "html.parser")

# %%
import time

total_lists = []

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)
driver.get('https://www.melon.com/mymusic/dj/mymusicdjplaylistview_inform.htm?plylstSeq=497292073')

time.sleep(1)

page_source = driver.page_source
soup = BeautifulSoup(page_source, "html.parser")

time.sleep(1)

songIds = soup.select("#frm > div > table > tbody td:nth-child(4) > div > a")
total_lists = total_lists + songIds

time.sleep(1)
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 103.0.5060
# [WDM] - Get LATEST chromedriver version for 103.0.5060 google-chrome
# [WDM] - Driver [/Users/tj/.wdm/drivers/chromedriver/mac64/103.0.5060.134/chromedriver] found in cache

# %%
test = []
for i in range(len(total_lists)):
    test.append(total_lists[i]['href'])

# %%
test1 = []
for i in range(len(test)):
    test1.append(str(test[i]).split('.')[2].split("(")[1].split(")")[0])

# %%
test2 = []
for i in range(len(test1)):
    test2.append(str(test1[i]).strip("''"))

# %%
test2
# Out:
# ['32225055',
#  '4037360',
#  '32028531',
#  '33759183',
#  '33751633',
#  '5610945',
#  '30290011',
#  '3110148',
#  '33339576',
#  '31993173',
#  '33453317',
#  '32955381',
#  '4654324',
#  '31107239',
#  '33720891',
#  '33013877',
#  '33722559',
#  '30172476',
#  '9646572',
#  '33618271',
#  '30642146',
#  '32711048',
#  '32142272',
#  '32018045',
#  '31929663',
#  '4854490',
#  '33625988',
#  '33572275',
#  '31960759',
#  '31453551',
#  '30690674',
#  '33295747',
#  '32080223',
#  '31840635',
#  '3136470',
#  '30939454',
#  '30177184',
#  '31181342',
#  '31788850',
#  '30869144',
#  '9620473',
#  '3053257',
#  '3899275',
#  '30132701',
#  '30879719',
#  '31636358',
#  '31740215',
#  '3143550',
#  '31709526',
#  '2425271']

# %%
# 가수명, 노래제목, 발매일, 가사, 좋아요 수 리스트 변수 생성

singer_list = []
singName_list = []
date_list = []
genre_list = []
lyrics_list = []
like_list = []

# %%
# for문으로 가수명, 노래제목, 발매일, 가사, 좋아요 수 리스트 변수에 내용 담고 저장하기

chrome_options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)

for songId in test2:
    
    driver.get(f'https://www.melon.com/song/detail.htm?songId={songId}')

    page_source = driver.page_source
    soup = BeautifulSoup(page_source, "html.parser")

    time.sleep(2)

    try:
    
        # 가수명 가져오기
        artist_name = soup.select_one('#downloadfrm > div > div > div.entry > div.info > div.artist > a > span:nth-child(1) ')
        singer_list.append(artist_name.string)

        # 노래제목 가져오기
        song_name = soup.select_one("#downloadfrm > div > div > div.entry > div.info > div.song_name ")
        singName_list.append(song_name.text.strip().split('\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t')[1])

        # 발매일 가져오기
        date = soup.select_one('#downloadfrm > div > div > div.entry > div.meta > dl > dd:nth-child(4)')
        date_list.append(date.string)

        # 장르 가져오기
        genre = soup.select_one('#downloadfrm > div > div > div.entry > div.meta > dl > dd:nth-child(6)')
        genre_list.append(genre.string)

        # 가사 가져오기
        lyric = str(soup.select_one('#d_video_summary')).replace('<br/>', ' ').replace(
            '<div class="lyric" id="d_video_summary"><!-- height:auto; 로 변경시, 확장됨 -->', '').replace('</div>', '').replace('\t', '').replace('\n', '')
        lyric = lyric.replace('  ', ' ')
        lyrics_list.append(lyric)

        # 좋아요수 가져오기
        like = soup.select_one("#d_like_count")
        like_list.append(like.text)

        time.sleep(2)
    except:
        singer_list.append(0)
        singName_list.append(0)
        date_list.append(0)
        lyrics_list.append(0)
        like_list.append(0)

        time.sleep(1)
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 103.0.5060
# [WDM] - Get LATEST chromedriver version for 103.0.5060 google-chrome
# [WDM] - Driver [/Users/tj/.wdm/drivers/chromedriver/mac64/103.0.5060.134/chromedriver] found in cache

# %%
ballad = {'가수명':singer_list, '노래제목':singName_list, '발매일':date_list, '장르':genre_list, '가사':lyrics_list, '좋아요수':like_list}

# %%
import pandas as pd

# %%
ballad_sad= pd.DataFrame(ballad)
ballad_sad.head()
# Out:
#                 가수명                 노래제목         발매일          장르  \
# 0             V.O.S              잘 살고 있다  2019.12.02         발라드
# 1               주보라  네가 없다 (Without You)  2013.02.19         발라드
# 2      휘인 (Whee In)      헤어지자 (Prod. 정키)  2019.09.04         발라드
# 3       헤이즈 (Heize)      비가 오는 날엔 (2021)  2021.08.04  발라드, 국내드라마
# 4  스트레이 (The Stray)           그냥, 묻고 싶었어  2021.08.04   발라드, 인디음악
#
#                                                   가사     좋아요수
# 0  한잔 술에 잊자 그만나도 숨 좀 쉬자 제발마치 주문처럼매일 읊조렸던넌 모르는내 슬픈...   38,511
# 1  서툰 작별이었는지 아련한 슬픔 속에 눈물이멈추질 않아너무나 어렸던 걸까내 이기적임에...    2,949
# 2  그럴 수도 있지 생각했어잊어 보려 했어지난 날의 모든 걸 노력했어다시 시작해 보려고...  115,651
# 3  세상이 어두워지고조용히 비가 내리면여전히 그대로오늘도 어김없이 난벗어나질 못하네너의...   73,204
# 4  외로운 내 마음의 불꽃은아픔으로 가득 찬 과거를 불태워차디찬 이곳에서 벗어나게 해줄...    1,759

# %%
ballad_sad = ballad_sad[ballad_sad.장르 != 'R&B/Soul']

# %%
ballad_sad = ballad_sad[ballad_sad.장르 != 'R&B/Soul, 국내드라마']

# %%
ballad_sad = ballad_sad[ballad_sad != 'R&B/Soul, 인디음악']

# %%
ballad_sad = ballad_sad[ballad_sad.장르 != '인디음악, 포크/블루스']

# %%
ballad_sad = ballad_sad[ballad_sad.장르 != '랩/힙합']

# %%
ballad_sad = ballad_sad[ballad_sad.장르 != 'NaN']

# %%
ballad_sad.장르= ballad_sad.장르.replace('발라드, 국내드라마','발라드')

# %%
ballad_sad.장르= ballad_sad.장르.replace('발라드, 인디음악','발라드')

# %%
ballad_sad.reset_index(drop=True,inplace=True)

# %%
ballad_sad['좋아요수'] = ballad_sad['좋아요수'].str.replace(',','')

# %%
ballad_sad['발매일'] = ballad_sad['발매일'].str.replace('.', '-')
# Out:
# /var/folders/51/xmc_l6t13wv1nc5z6qmyg58r0000gn/T/ipykernel_9634/1511717123.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   ballad_sad['발매일'] = ballad_sad['발매일'].str.replace('.', '-')

# %%
ballad_sad['발매일'] = pd.to_datetime(ballad_sad['발매일'])

# %%
ballad_sad.drop(columns='장르',inplace=True)

# %%
ballad_sad
# Out:
#                  가수명                      노래제목        발매일  \
# 0              V.O.S                   잘 살고 있다 2019-12-02
# 1                주보라       네가 없다 (Without You) 2013-02-19
# 2       휘인 (Whee In)           헤어지자 (Prod. 정키) 2019-09-04
# 3        헤이즈 (Heize)           비가 오는 날엔 (2021) 2021-08-04
# 4   스트레이 (The Stray)                그냥, 묻고 싶었어 2021-08-04
# 5                 정키   부담이 돼 (Feat. 휘인 Of 마마무) 2017-03-08
# 6          나비 (Navi)                   잘 된 일이야 2011-01-19
# 7         펀치 (Punch)               안녕 내 전부였던 너 2021-03-10
# 8         펀치 (Punch)               Done For Me 2019-08-18
# 9         펀치 (Punch)                    이 밤의 끝 2018-05-31
# 10               전상근                   너무 보고싶어 2021-07-25
# 11               장범준                 잠이 오질 않네요 2020-10-24
# 12               강고은       같은 시간 속 우린 여기까지인 거야 2021-07-24
# 13               권진아                         끝 2016-09-19
# 14               빅마마                     하루만 더 2021-06-24
# 15    그리즐리 (Grizzly)                        달라 2017-09-21
# 16               황인욱                       이별주 2019-11-01
# 17          사이로(415)                  우리 둘 사이로 2019-08-29
# 18                이우                      내 안부 2019-07-16
# 19     MSG워너비(M.O.M)                    바라만 본다 2021-06-26
# 20               전상근             오늘따라 더 미운 그대가 2021-06-13
# 21               윤토벤     서툰 이별을 하려해 (Feat.전상근) 2019-08-01
# 22                허각                     흔한 이별 2018-11-28
# 23         포맨 (4MEN)               눈 떠보니 이별이더라 2017-10-24
# 24               이소정       함께 했는데 이별은 나 혼자인 거야 2021-02-19
# 25                이우                      이별행동 2019-10-06
# 26               김나영  널 미워하지 않길 (Prod. By 하동균) 2016-12-30
# 27               다비치   마치 우린 없었던 사이 (Prod. 정키) 2018-07-12
# 28               송하예                      니 소식 2019-05-11
# 29               권진아                     이별 뒷면 2018-02-02
# 30               아이유                 첫 이별 그날 밤 2010-12-09
# 31            스웨덴세탁소                 우리가 있던 시간 2012-09-07
# 32         강민경 (다비치)                   사랑해서 그래 2019-02-27
# 33               정효빈                     처음이라서 2019-04-16
# 34               아이유                나만 몰랐던 이야기 2011-02-17
# 35       윤하 (YOUNHA)                  오늘 헤어졌어요 2009-12-11
#
#                                                    가사    좋아요수
# 0   한잔 술에 잊자 그만나도 숨 좀 쉬자 제발마치 주문처럼매일 읊조렸던넌 모르는내 슬픈...   38511
# 1   서툰 작별이었는지 아련한 슬픔 속에 눈물이멈추질 않아너무나 어렸던 걸까내 이기적임에...    2949
# 2   그럴 수도 있지 생각했어잊어 보려 했어지난 날의 모든 걸 노력했어다시 시작해 보려고...  115651
# 3   세상이 어두워지고조용히 비가 내리면여전히 그대로오늘도 어김없이 난벗어나질 못하네너의...   73204
# 4   외로운 내 마음의 불꽃은아픔으로 가득 찬 과거를 불태워차디찬 이곳에서 벗어나게 해줄...    1759
# 5   더는 할 말이 없어다른 이유도어떤 변명도 난의미 없단 걸 알아끝이란 게 다 그렇잖아...  134027
# 6   Hello Hello Hello Hello HelloDon't cry Don't c...   42204
# 7   안녕 안녕이제 인사를 해야지너와 나의 이별인데아니 아니나는 그게 안될것 같아너를 보...   14131
# 8   지울게 너에게 남겨줬던 추억까지도바랄게 너와의 기억도 남지 못하게더는 다가갈 수 없...  100916
# 9   널 보면 나와 달라이렇게 난 네 생각뿐인데널 사랑했던 만큼 아파야 하는 걸까난 이 ...   47764
# 10  혼자 이별을 하고가버리면 난 어떡하라고너 없는 하루를 살아보고너 없는 채로 잠들어본...   18720
# 11  당신은 날 설레게 만들어조용한 내 마음 자꾸만 춤추게 해얼마나 얼마나 날 떨리게 하...  159019
# 12  어떻게 말을 꺼 내야 할까내 하루 속엔 없어 네가떨어지지 않는 내 마른 입술 끝에이...    4474
# 13  한참을 아무 말도 없었다 어색한 공기만 우릴 감싸고 있다너는 고개를 돌린 채로한숨만...  140297
# 14  하루만 더 우리 이별을늦춘다면 어땠을까그럴 일 없다는 걸 나는 알면서도아직 널 보낼...   58503
# 15  니가 나와 다르다는 걸인정하는 것과는 달라현실에 안주하려는 너와낭만적인 삶을 살길 ...   11082
# 16  오늘이 지나면 널 지워야겠지흔들리는 이 술잔이너의 마음 같아서아무 말 안 해도 난 ...   60815
# 17  Forget me close your eyesForget me close your ...    5997
# 18  내 소식 들었지 너와 헤어지고참 많이 울고 힘들게 버티다이해심이 많은 좋은 사람을만...   64521
# 19  내가 너라면 다 알아볼 텐데널 위할 사람 찾아낼 텐데지난 오랜 시간 너의 그 곁을지...  179223
# 20  조금은 괜찮다 생각했는데이제는 잊혀질 때도 됐는데아무렇지 않다가도 그대가 없단 게아...   25817
# 21  우리 이제 헤어지기로해 너도 알잖아 우린 충분했다는걸이별이 무서워 자꾸 피해보지만 ...   81227
# 22  매일 집으로 돌아가는 익숙한 골목 거리 사이불어온 볼 스치는 차가워진 이 바람을 따...   81840
# 23  분명 나는 꿈을 꾼 거다눈 떠보니 이별이더라휴대폰을 확인해 봤더니다시 봐도 이별이더...  115681
# 24  이젠 누군갈 만나는 게 난아직은 힘이 들것 같아다시는 믿고 싶지 않아왜 난 사랑을 ...   47705
# 25  자꾸만 연락을 피하고 바쁘다며 약속을 미루고점점 변해가는 네 모습 무심한 말투 조금...   58640
# 26  그게 또 그래 이별이란 게생각과는 늘 다르게우리 좋았던 기억만전부 지우고 나타나그땐...   21895
# 27  비 내리는 날 창가에 앉아서두르던 일상을 달래다울적해진 마음잡고 써 내려가다울컥 눈...   50059
# 28  그때의 우리 사랑뜨겁고 치열했는데끝나보니 남는건 미움뿐몇번의 계절을 더보내야 괜찮아...  195082
# 29  좁은 골목길은 또 하염없이 멀어져마주앉은 탁자 반대편마저도뻗어봐도 맞닿을 수가 없어...   58835
# 30  멍하니 아무 일도 할 일이 없어이게 이별인 거니전화기 가득 찬 너와의 메시지만한참 ...   93388
# 31  생각한다 지난 날들눈이 부시도록 아름다웠던사라진다 뜨겁게 안아주던네 손 끝 향기가들...   26461
# 32  잘 있니 잘 지내니나는 요즘 부쩍네가 보고 싶어그래 알아 너는 다신내가 보기 싫지 ...   32144
# 33  떨어질 줄 몰랐던 너의 품도잡은 손에 스치던 봄바람도떨리던 입맞춤도 맞춰 걷던 걸음...   58756
# 34  정말 넌 다 잊었더라반갑게 날 보는 너의 얼굴 보니그제야 어렴풋이 아파오더라새 살 ...  110811
# 35  새하얀 머플러에 얼굴을 묻고붉어진 눈을 깜빡이며 널 기다렸어무슨 얘길 하고 픈지 그...   82624

# %%
ballad_sad.to_csv("../Data/ballad_sad.csv",index=False)

# %%
pd.read_csv("../Data/ballad_sad.csv")
# Out:
#                  가수명                      노래제목         발매일  \
# 0              V.O.S                   잘 살고 있다  2019-12-02
# 1                주보라       네가 없다 (Without You)  2013-02-19
# 2       휘인 (Whee In)           헤어지자 (Prod. 정키)  2019-09-04
# 3        헤이즈 (Heize)           비가 오는 날엔 (2021)  2021-08-04
# 4   스트레이 (The Stray)                그냥, 묻고 싶었어  2021-08-04
# 5                 정키   부담이 돼 (Feat. 휘인 Of 마마무)  2017-03-08
# 6          나비 (Navi)                   잘 된 일이야  2011-01-19
# 7         펀치 (Punch)               안녕 내 전부였던 너  2021-03-10
# 8         펀치 (Punch)               Done For Me  2019-08-18
# 9         펀치 (Punch)                    이 밤의 끝  2018-05-31
# 10               전상근                   너무 보고싶어  2021-07-25
# 11               장범준                 잠이 오질 않네요  2020-10-24
# 12               강고은       같은 시간 속 우린 여기까지인 거야  2021-07-24
# 13               권진아                         끝  2016-09-19
# 14               빅마마                     하루만 더  2021-06-24
# 15    그리즐리 (Grizzly)                        달라  2017-09-21
# 16               황인욱                       이별주  2019-11-01
# 17          사이로(415)                  우리 둘 사이로  2019-08-29
# 18                이우                      내 안부  2019-07-16
# 19     MSG워너비(M.O.M)                    바라만 본다  2021-06-26
# 20               전상근             오늘따라 더 미운 그대가  2021-06-13
# 21               윤토벤     서툰 이별을 하려해 (Feat.전상근)  2019-08-01
# 22                허각                     흔한 이별  2018-11-28
# 23         포맨 (4MEN)               눈 떠보니 이별이더라  2017-10-24
# 24               이소정       함께 했는데 이별은 나 혼자인 거야  2021-02-19
# 25                이우                      이별행동  2019-10-06
# 26               김나영  널 미워하지 않길 (Prod. By 하동균)  2016-12-30
# 27               다비치   마치 우린 없었던 사이 (Prod. 정키)  2018-07-12
# 28               송하예                      니 소식  2019-05-11
# 29               권진아                     이별 뒷면  2018-02-02
# 30               아이유                 첫 이별 그날 밤  2010-12-09
# 31            스웨덴세탁소                 우리가 있던 시간  2012-09-07
# 32         강민경 (다비치)                   사랑해서 그래  2019-02-27
# 33               정효빈                     처음이라서  2019-04-16
# 34               아이유                나만 몰랐던 이야기  2011-02-17
# 35       윤하 (YOUNHA)                  오늘 헤어졌어요  2009-12-11
#
#                                                    가사    좋아요수
# 0   한잔 술에 잊자 그만나도 숨 좀 쉬자 제발마치 주문처럼매일 읊조렸던넌 모르는내 슬픈...   38511
# 1   서툰 작별이었는지 아련한 슬픔 속에 눈물이멈추질 않아너무나 어렸던 걸까내 이기적임에...    2949
# 2   그럴 수도 있지 생각했어잊어 보려 했어지난 날의 모든 걸 노력했어다시 시작해 보려고...  115651
# 3   세상이 어두워지고조용히 비가 내리면여전히 그대로오늘도 어김없이 난벗어나질 못하네너의...   73204
# 4   외로운 내 마음의 불꽃은아픔으로 가득 찬 과거를 불태워차디찬 이곳에서 벗어나게 해줄...    1759
# 5   더는 할 말이 없어다른 이유도어떤 변명도 난의미 없단 걸 알아끝이란 게 다 그렇잖아...  134027
# 6   Hello Hello Hello Hello HelloDon't cry Don't c...   42204
# 7   안녕 안녕이제 인사를 해야지너와 나의 이별인데아니 아니나는 그게 안될것 같아너를 보...   14131
# 8   지울게 너에게 남겨줬던 추억까지도바랄게 너와의 기억도 남지 못하게더는 다가갈 수 없...  100916
# 9   널 보면 나와 달라이렇게 난 네 생각뿐인데널 사랑했던 만큼 아파야 하는 걸까난 이 ...   47764
# 10  혼자 이별을 하고가버리면 난 어떡하라고너 없는 하루를 살아보고너 없는 채로 잠들어본...   18720
# 11  당신은 날 설레게 만들어조용한 내 마음 자꾸만 춤추게 해얼마나 얼마나 날 떨리게 하...  159019
# 12  어떻게 말을 꺼 내야 할까내 하루 속엔 없어 네가떨어지지 않는 내 마른 입술 끝에이...    4474
# 13  한참을 아무 말도 없었다 어색한 공기만 우릴 감싸고 있다너는 고개를 돌린 채로한숨만...  140297
# 14  하루만 더 우리 이별을늦춘다면 어땠을까그럴 일 없다는 걸 나는 알면서도아직 널 보낼...   58503
# 15  니가 나와 다르다는 걸인정하는 것과는 달라현실에 안주하려는 너와낭만적인 삶을 살길 ...   11082
# 16  오늘이 지나면 널 지워야겠지흔들리는 이 술잔이너의 마음 같아서아무 말 안 해도 난 ...   60815
# 17  Forget me close your eyesForget me close your ...    5997
# 18  내 소식 들었지 너와 헤어지고참 많이 울고 힘들게 버티다이해심이 많은 좋은 사람을만...   64521
# 19  내가 너라면 다 알아볼 텐데널 위할 사람 찾아낼 텐데지난 오랜 시간 너의 그 곁을지...  179223
# 20  조금은 괜찮다 생각했는데이제는 잊혀질 때도 됐는데아무렇지 않다가도 그대가 없단 게아...   25817
# 21  우리 이제 헤어지기로해 너도 알잖아 우린 충분했다는걸이별이 무서워 자꾸 피해보지만 ...   81227
# 22  매일 집으로 돌아가는 익숙한 골목 거리 사이불어온 볼 스치는 차가워진 이 바람을 따...   81840
# 23  분명 나는 꿈을 꾼 거다눈 떠보니 이별이더라휴대폰을 확인해 봤더니다시 봐도 이별이더...  115681
# 24  이젠 누군갈 만나는 게 난아직은 힘이 들것 같아다시는 믿고 싶지 않아왜 난 사랑을 ...   47705
# 25  자꾸만 연락을 피하고 바쁘다며 약속을 미루고점점 변해가는 네 모습 무심한 말투 조금...   58640
# 26  그게 또 그래 이별이란 게생각과는 늘 다르게우리 좋았던 기억만전부 지우고 나타나그땐...   21895
# 27  비 내리는 날 창가에 앉아서두르던 일상을 달래다울적해진 마음잡고 써 내려가다울컥 눈...   50059
# 28  그때의 우리 사랑뜨겁고 치열했는데끝나보니 남는건 미움뿐몇번의 계절을 더보내야 괜찮아...  195082
# 29  좁은 골목길은 또 하염없이 멀어져마주앉은 탁자 반대편마저도뻗어봐도 맞닿을 수가 없어...   58835
# 30  멍하니 아무 일도 할 일이 없어이게 이별인 거니전화기 가득 찬 너와의 메시지만한참 ...   93388
# 31  생각한다 지난 날들눈이 부시도록 아름다웠던사라진다 뜨겁게 안아주던네 손 끝 향기가들...   26461
# 32  잘 있니 잘 지내니나는 요즘 부쩍네가 보고 싶어그래 알아 너는 다신내가 보기 싫지 ...   32144
# 33  떨어질 줄 몰랐던 너의 품도잡은 손에 스치던 봄바람도떨리던 입맞춤도 맞춰 걷던 걸음...   58756
# 34  정말 넌 다 잊었더라반갑게 날 보는 너의 얼굴 보니그제야 어렴풋이 아파오더라새 살 ...  110811
# 35  새하얀 머플러에 얼굴을 묻고붉어진 눈을 깜빡이며 널 기다렸어무슨 얘길 하고 픈지 그...   82624

# %%
import time

total_lists = []

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)
driver.get('https://www.melon.com/mymusic/dj/mymusicdjplaylistview_inform.htm?plylstSeq=497292073#params%5BplylstSeq%5D=497292073&po=pageObj&startIndex=51')

time.sleep(1)

page_source = driver.page_source
soup = BeautifulSoup(page_source, "html.parser")

time.sleep(1)

songIds = soup.select("#frm > div > table > tbody td:nth-child(4) > div > a")
total_lists = total_lists + songIds

time.sleep(1)

# %%
test = []
for i in range(len(total_lists)):
    test.append(total_lists[i]['href'])

test1 = []
for i in range(len(test)):
    test1.append(str(test[i]).split('.')[2].split("(")[1].split(")")[0])

test2 = []
for i in range(len(test1)):
    test2.append(str(test1[i]).strip("''"))

test2
# Out:
# ['30963466',
#  '31589633',
#  '30646587',
#  '31815490',
#  '30043160',
#  '30973237',
#  '5637411',
#  '8259473',
#  '31703498',
#  '31438601',
#  '7893048',
#  '31181605',
#  '5462209',
#  '5694905',
#  '31326215',
#  '4073176',
#  '31524309',
#  '30378163',
#  '31524320',
#  '30859639',
#  '4268444',
#  '5831542',
#  '30043162',
#  '30859637',
#  '30299276',
#  '3893169',
#  '31584295',
#  '30257677',
#  '30043157',
#  '7998349',
#  '30859638',
#  '31469826',
#  '5466962',
#  '4281352',
#  '31477685',
#  '30693104',
#  '31426934',
#  '31455159',
#  '30939453',
#  '9646576',
#  '8298724',
#  '3593078',
#  '30859641',
#  '31426935',
#  '2930971',
#  '3053254',
#  '4709050',
#  '31469825',
#  '30043155',
#  '30675647']

# %%
# 가수명, 노래제목, 발매일, 가사, 좋아요 수 리스트 변수 생성

singer_list = []
singName_list = []
date_list = []
genre_list = []
lyrics_list = []
like_list = []

# for문으로 가수명, 노래제목, 발매일, 가사, 좋아요 수 리스트 변수에 내용 담고 저장하기

chrome_options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)

for songId in test2:
    
    driver.get(f'https://www.melon.com/song/detail.htm?songId={songId}')

    page_source = driver.page_source
    soup = BeautifulSoup(page_source, "html.parser")

    time.sleep(2)

    try:
    
        # 가수명 가져오기
        artist_name = soup.select_one('#downloadfrm > div > div > div.entry > div.info > div.artist > a > span:nth-child(1) ')
        singer_list.append(artist_name.string)

        # 노래제목 가져오기
        song_name = soup.select_one("#downloadfrm > div > div > div.entry > div.info > div.song_name ")
        singName_list.append(song_name.text.strip().split('\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t')[1])

        # 발매일 가져오기
        date = soup.select_one('#downloadfrm > div > div > div.entry > div.meta > dl > dd:nth-child(4)')
        date_list.append(date.string)

        # 장르 가져오기
        genre = soup.select_one('#downloadfrm > div > div > div.entry > div.meta > dl > dd:nth-child(6)')
        genre_list.append(genre.string)

        # 가사 가져오기
        lyric = soup.select_one('#d_video_summary')
        lyrics_list.append(lyric.text.strip())

        # 좋아요수 가져오기
        like = soup.select_one("#d_like_count")
        like_list.append(like.text)

        time.sleep(2)
    except:
        singer_list.append(0)
        singName_list.append(0)
        date_list.append(0)
        lyrics_list.append(0)
        like_list.append(0)

        time.sleep(1)

# %%
ballad = {'가수명':singer_list, '노래제목':singName_list, '발매일':date_list, '장르':genre_list, '가사':lyrics_list, '좋아요수':like_list}

# %%
import pandas as pd
ballad_sad2 = pd.DataFrame(ballad)
ballad_sad2.head()
# Out:
#           가수명                  노래제목         발매일    장르  \
# 0        선우정아                     남  2018.03.20   발라드
# 1  로시 (Rothy)                 다 핀 꽃  2019.01.30   발라드
# 2         아이유                   개여울  2017.09.22   발라드
# 3        기리보이      교통정리 (Feat. 헤이즈)  2019.05.21  랩/힙합
# 4         김나영  마음 (Prod. by MAKTUB)  2016.10.18   발라드
#
#                                                   가사     좋아요수
# 0  누구도 잘못한 건 없어모르겠어 우린 최선을 다 했어발버둥 쳐 사랑하기 위해 but사...   20,416
# 1  다 핀 어느 이름 모를 꽃 한송이의떠나기 전의 끝모습처럼하필 모든 것이 너무 눈부셨...   30,531
# 2  당신은 무슨 일로 그리합니까 홀로이 개여울에 주저앉아서 파릇한 풀 포기가 돋아 나오...   43,323
# 3  우리가 자주 걸었던 이 길거리에만약 우리 마주치면그냥 모른척해 줘요우리가 자주 걸었...  113,732
# 4  잠깐의 긴 꿈처럼 어제의 바람처럼 어느새 또 찾아온 너의 기억 사랑만으로는 부족한 ...    6,694

# %%
ballad_sad2.장르.unique()
# Out:
# array(['발라드', '랩/힙합', '발라드, 국내드라마', '인디음악, 포크/블루스', '발라드, 인디음악',
#        'R&B/Soul', '록/메탈', '국내드라마', '인디음악, 록/메탈'], dtype=object)

# %%
list = ['발라드, 국내드라마','발라드, 인디음악','발라드']
ballad_sad2 = ballad_sad2[ballad_sad2['장르'].isin(list)]

# %%
ballad_sad2.reset_index(drop=True, inplace=True)

# %%
ballad_sad2['좋아요수'] = ballad_sad2['좋아요수'].str.replace(',','')

# %%
ballad_sad2['발매일'] = ballad_sad2['발매일'].str.replace('.', '-')
# Out:
# /var/folders/51/xmc_l6t13wv1nc5z6qmyg58r0000gn/T/ipykernel_1449/3538400742.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   ballad_sad2['발매일'] = ballad_sad2['발매일'].str.replace('.', '-')

# %%
ballad_sad2['발매일'] = pd.to_datetime(ballad_sad2['발매일'])

# %%
ballad_sad2.drop(columns='장르',inplace=True)

# %%
ballad_sad2.to_csv("../Data/ballad_sad2.csv",index=False)

# %%
pd.read_csv("../Data/ballad_sad2.csv")
# Out:
#             가수명                                 노래제목         발매일  \
# 0          선우정아                                    남  2018-03-20
# 1    로시 (Rothy)                                다 핀 꽃  2019-01-30
# 2           아이유                                  개여울  2017-09-22
# 3           김나영                 마음 (Prod. by MAKTUB)  2016-10-18
# 4             벤                          Love Recipe  2018-03-23
# 5           김나영                                그럴 리가  2015-03-27
# 6           김나영                               가슴이 말해  2016-07-08
# 7    HYNN (박혜원)                          시든 꽃에 물을 주듯  2019-03-31
# 8           백아연                              마음아 미안해  2018-11-21
# 9           안예은                              Re-feet  2018-07-12
# 10      소심한 오빠들                  이별맛집 (Feat. 볼빨간사춘기)  2014-11-17
# 11  CHEEZE (치즈)                              Romance  2015-05-13
# 12          스무살                       미안 (Feat. 안지연)  2018-09-27
# 13          김나영               오답 (Feat. 이민혁 of BTOB)  2018-12-30
# 14          아이유                              그렇게 사랑은  2017-04-21
# 15  케이시 (Kassy)                              그때가 좋았어  2018-12-31
# 16          다비치                             사랑하지 말아요  2018-01-25
# 17          김나영                                 어땠을까  2016-10-18
# 18          다비치                              알아서 앓아요  2018-01-25
# 19           정키                       홀로 (Feat. 김나영)  2012-08-31
# 20          윤딴딴                                남은 기억  2019-01-28
# 21   swai (스와이)                       짝사랑 (Feat. 폴킴)  2017-02-17
# 22          김나영                                 꺼내본다  2016-10-18
# 23          김나영                                 어땠을까  2015-12-30
# 24          다비치                               그래도 우리  2018-01-25
# 25           정키                       그래서 (Feat. 민서)  2018-12-05
# 26            벤                                 180도  2018-12-07
# 27       스탠딩 에그                바보야 (With 이해리 of 다비치)  2017-10-25
# 28          김나영                             널 떠올리는 밤  2018-11-15
# 29           윤건                       너도 그냥 날 놓아주면 돼  2018-11-29
# 30          권진아                               그녀가 되길  2016-09-19
# 31          이소라                슬픔 속에 그댈 지워야만 해 (이현우)  2011-10-30
# 32          다비치                          내가 더 사랑하는 일  2018-01-25
# 33          김나영                                그 한마디  2018-11-15
# 34         2NE1                            아파 (Slow)  2010-09-09
# 35          아이유                             느리게 하는 일  2010-12-09
# 36          김나영                                가끔 내가  2014-06-27
# 37           정키  니가 내 곁에 머물렀던 시간 (Feat. 육성재 of BTOB)  2018-12-05
# 38          김나영                                그래 그래  2016-10-18
# 39          김나영                             헤어질 수 밖에  2017-10-20
#
#                                                    가사    좋아요수
# 0   누구도 잘못한 건 없어모르겠어 우린 최선을 다 했어발버둥 쳐 사랑하기 위해 but사...   20416
# 1   다 핀 어느 이름 모를 꽃 한송이의떠나기 전의 끝모습처럼하필 모든 것이 너무 눈부셨...   30531
# 2   당신은 무슨 일로 그리합니까 홀로이 개여울에 주저앉아서 파릇한 풀 포기가 돋아 나오...   43323
# 3   잠깐의 긴 꿈처럼 어제의 바람처럼 어느새 또 찾아온 너의 기억 사랑만으로는 부족한 ...    6694
# 4   늦은 일요일 잠에서 깨고여느 때처럼 세수를 하죠 머릴 묶죠텅 빈 방 안에 우연 한 ...    5162
# 5   사실은 나 다 지운 줄 알았어한참 동안 니 생각이 안 나서우연히 나 친구에게 들었어...   15950
# 6   나를 기억하나요나를 알아보나요이렇게 또 마주하네요흔들리는 눈빛이 떨리는 내 입술이또...   25786
# 7   아무말도 아무것도여전히 넌 여기 없고널 원하고 널 원해도 난 외롭고꽃이 피고 진 그...  204751
# 8   마음아 미안해 또 아프게 하네나 왜 그랬을까 고작 그런 사람에게너를 연 걸까바보라 ...   10458
# 9   우리 함께 사랑했던 날들 어떻게 발 밑 낙엽처럼 바스라트릴 수 있나요우리 같이 행복...    1483
# 10  오늘 우연히 들렀어 그 집그러고 보니 우리참 많이도 찾아다녔다가는 동네 집집마다 우...    7867
# 11  빨간 풍선에 가득 담긴꽃잎에 짙은 향기 품고서무표정으로 내게 다가와귓가에 깊이 색을...   54481
# 12  미안 널 생각해미안 아직도 널 생각해마침 지금 창밖에비가 내리고 있어저 비를 핑계 ...    6783
# 13  이유가 되잖아아무 이유가 없는 것도그냥 좋았잖아 다른 이유 없이도다 그런 거잖아다들...   14773
# 14  그렇게 사랑은 간절히 불러보지만아무런 대답이 없는그렇게 사랑은 아무리 다가갈수록멀어...   47043
# 15  이젠 내가 편하니작은 설렘조차 욕심이겠지항상 곁에 있어서계속 함께 있을 줄 알았나 ...  232601
# 16  맘 졸이다 그댈 기다리다혼자 그렇게 지새운 많은 날오랜 시간을 나만 그랬네요전부를 ...    6649
# 17  지내봐도 다시 너였고 숨어있던 너를 찾고오늘도 난 눈을 감아 봐도 또 네가 보여마주...    6027
# 18  내 맘 부서지는 소리 들으며이젠 떠나 줄게요저벅 저벅 밟혀지는우리의 사랑과 또 울음...    4950
# 19  아침에 눈을 떴을 때텅 빈 방안에 나 홀로 니 빈자리 거닐면서많은 생각들에 잠겨지워...  150108
# 20  어디서부터 이 긴 얘기를 시작할지가끔 비추는 너의 소식이 좋아보여네가 없으면 참 걱...   21647
# 21  한참을 혼자서 맴돌았지나만의 생각인 줄 모르고하루하루가 너의 생각으로가득한 나만의 ...   16691
# 22  널 지워 내 가슴에 묻고 꼭 잊겠다 다짐해 놓고 또 난 울어 또 난 울어 긴 시간이...   35270
# 23  지내봐도 다시 너였고숨어있던 너를 찾고오늘도 난눈을 감아 봐도또 네가 보여마주했던 ...   76963
# 24  아마도 그때쯤 일 거야헤어짐을 느꼈던 거우리 같은 일로 매번 싸우던 그 즈음항상 똑...    4476
# 25  잠깐 기다려너에게 할 말이 있어가끔씩 이상한 기분이 들어서나도 모르게사소한 너의 모...   10499
# 26  사랑 다 비슷해 그래 다 비슷해너는 다르길 바랐는데넌 뭐가 미안해 왜 맨날 미안해헤...  165996
# 27  제발 다가오지 마 더 이상은나를 사랑한다는 그런 말은 하지 마제발 날 내버려 둬 더...   24585
# 28  너였던 날들도 지나갔나 봐이렇게 혼자인걸 보니우리 마지막 그날도바람마저 쓸쓸했던오늘...    5793
# 29  반복돼 오늘도 이렇게 힘겨운 스물네 시간반복돼 오늘도 머리속엔온통 너라는 사람또 반...  132245
# 30  나 알고 싶어요 알고 싶어요너를 오늘보다 오늘보다 더 사랑하는 법너무 어려워요 어려...    8070
# 31  창가에 불어오는 가을바람은텅빈 마음을 스쳐 가는데차가워진 벽에 기대어 멀리 밝아오는...    6877
# 32  네가 곁에 없는 것보다 날 외롭게 하는 건우리 이제 멀어진 걸 아는데 혼자 여전히 ...    6053
# 33  내가 이 길의 끝에 선 이유한마디도 못하고 와있던 나아무 데도 닿지 못할 걸알아서 ...   23973
# 34  내가 준 신발을 신고그녀와 길을 걷고아무렇지 않게 그녀와 kiss하고내가 준 향수 ...   42228
# 35  느리게 느리게 느리게그대를 잊으려 해요빠르게 빠르게 가는 시간보다 더천천히 잊으려 ...   48842
# 36  무슨 말이라도 좀 해봐잘못 나온 말이 였다고헤어지잔 너의 그 말에털석 주저 앉은 날...   49080
# 37  무슨 말이든 해 봐울고만 있지 말고또 짓궂은 장난이라고자주 다퉜긴 해도요즘 괜찮았잖...   27569
# 38  그래 그래 헤어지자그래 우리 헤어지자내 사랑이 니 마음에들지 않다면 그래 그래나도 ...   17024
# 39  밤하늘 속 별처럼너와 내가 눈부셨던기억 추억 너무 많아서우리 사랑도 별빛 같았어영원...   47230
