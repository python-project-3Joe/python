# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import urllib.request as request

from selenium.webdriver.chrome.options import Options
from fake_useragent import UserAgent

# %%
options = Options()
ua = UserAgent(verify_ssl=False)
userAgent = ua.random
print(userAgent)
# Out:
# Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/27.0.1453.93 Safari/537.36

# %%
options.add_argument(f'user-agent={userAgent}')
# chrome_options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)
driver.get('https://www.melon.com/mymusic/dj/mymusicdjplaylistview_inform.htm?plylstSeq=497292073')
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 103.0.5060
# [WDM] - Get LATEST chromedriver version for 103.0.5060 google-chrome
# [WDM] - Driver [/Users/tj/.wdm/drivers/chromedriver/mac64/103.0.5060.134/chromedriver] found in cache

# %%
page_source = driver.page_source
soup = BeautifulSoup(page_source, "html.parser")

# %%
import time

total_lists = []

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)
driver.get('https://www.melon.com/mymusic/dj/mymusicdjplaylistview_inform.htm?plylstSeq=497292073')

time.sleep(1)

page_source = driver.page_source
soup = BeautifulSoup(page_source, "html.parser")

time.sleep(1)

songIds = soup.select("#frm > div > table > tbody td:nth-child(4) > div > a")
total_lists = total_lists + songIds

time.sleep(1)
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 103.0.5060
# [WDM] - Get LATEST chromedriver version for 103.0.5060 google-chrome
# [WDM] - Driver [/Users/tj/.wdm/drivers/chromedriver/mac64/103.0.5060.134/chromedriver] found in cache

# %%
test = []
for i in range(len(total_lists)):
    test.append(total_lists[i]['href'])

# %%
test1 = []
for i in range(len(test)):
    test1.append(str(test[i]).split('.')[2].split("(")[1].split(")")[0])

# %%
test2 = []
for i in range(len(test1)):
    test2.append(str(test1[i]).strip("''"))

# %%
test2
# Out:
# ['32225055',
#  '4037360',
#  '32028531',
#  '33759183',
#  '33751633',
#  '5610945',
#  '30290011',
#  '3110148',
#  '33339576',
#  '31993173',
#  '33453317',
#  '32955381',
#  '4654324',
#  '31107239',
#  '33720891',
#  '33013877',
#  '33722559',
#  '30172476',
#  '9646572',
#  '33618271',
#  '30642146',
#  '32711048',
#  '32142272',
#  '32018045',
#  '31929663',
#  '4854490',
#  '33625988',
#  '33572275',
#  '31960759',
#  '31453551',
#  '30690674',
#  '33295747',
#  '32080223',
#  '31840635',
#  '3136470',
#  '30939454',
#  '30177184',
#  '31181342',
#  '31788850',
#  '30869144',
#  '9620473',
#  '3053257',
#  '3899275',
#  '30132701',
#  '30879719',
#  '31636358',
#  '31740215',
#  '3143550',
#  '31709526',
#  '2425271']

# %%
# # songId 가져오기
# songId_list = []
# for songId in test2:
#     songId_list.append(songId['href'].split('\'')[1])

# len(songId_list)

# %%
# song_title = []
# for i in range(len(test2)):
#     song_title.append(total_lists[i]['title'].replace(" 곡정보",""))

# %%
# song_title

# %%
# 가수명, 노래제목, 발매일, 가사, 좋아요 수 리스트 변수 생성

singer_list = []
singName_list = []
date_list = []
genre_list = []
lyrics_list = []
like_list = []

# %%
# for문으로 가수명, 노래제목, 발매일, 가사, 좋아요 수 리스트 변수에 내용 담고 저장하기

chrome_options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)

for songId in test2:
    
    driver.get(f'https://www.melon.com/song/detail.htm?songId={songId}')

    page_source = driver.page_source
    soup = BeautifulSoup(page_source, "html.parser")

    time.sleep(2)

    try:
    
        # 가수명 가져오기
        artist_name = soup.select_one('#downloadfrm > div > div > div.entry > div.info > div.artist > a > span:nth-child(1) ')
        singer_list.append(artist_name.string)

        # 노래제목 가져오기
        song_name = soup.select_one("#downloadfrm > div > div > div.entry > div.info > div.song_name ")
        singName_list.append(song_name.text.strip().split('\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t')[1])

        # 발매일 가져오기
        date = soup.select_one('#downloadfrm > div > div > div.entry > div.meta > dl > dd:nth-child(4)')
        date_list.append(date.string)

        # 장르 가져오기
        genre = soup.select_one('#downloadfrm > div > div > div.entry > div.meta > dl > dd:nth-child(6)')
        genre_list.append(genre.string)

        # 가사 가져오기
        lyric = soup.select_one('#d_video_summary')
        lyrics_list.append(lyric.text.strip())

        # 좋아요수 가져오기
        like = soup.select_one("#d_like_count")
        like_list.append(like.text)

        time.sleep(2)
    except:
        singer_list.append(0)
        singName_list.append(0)
        date_list.append(0)
        lyrics_list.append(0)
        like_list.append(0)

        time.sleep(1)
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 103.0.5060
# [WDM] - Get LATEST chromedriver version for 103.0.5060 google-chrome
# [WDM] - Driver [/Users/tj/.wdm/drivers/chromedriver/mac64/103.0.5060.134/chromedriver] found in cache

# %%
ballad = {'가수명':singer_list, '노래제목':singName_list, '발매일':date_list, '장르':genre_list, '가사':lyrics_list, '좋아요수':like_list}

# %%
import pandas as pd

# %%
ballad_sad= pd.DataFrame(ballad)
ballad_sad.head()
# Out:
#                 가수명                 노래제목         발매일          장르  \
# 0             V.O.S              잘 살고 있다  2019.12.02         발라드
# 1               주보라  네가 없다 (Without You)  2013.02.19         발라드
# 2      휘인 (Whee In)      헤어지자 (Prod. 정키)  2019.09.04         발라드
# 3       헤이즈 (Heize)      비가 오는 날엔 (2021)  2021.08.04  발라드, 국내드라마
# 4  스트레이 (The Stray)           그냥, 묻고 싶었어  2021.08.04   발라드, 인디음악
#
#                                                   가사     좋아요수
# 0  한잔 술에 잊자 그만나도 숨 좀 쉬자 제발마치 주문처럼매일 읊조렸던넌 모르는내 슬픈...   38,511
# 1  서툰 작별이었는지 아련한 슬픔 속에 눈물이멈추질 않아너무나 어렸던 걸까내 이기적임에...    2,949
# 2  그럴 수도 있지 생각했어잊어 보려 했어지난 날의 모든 걸 노력했어다시 시작해 보려고...  115,651
# 3  세상이 어두워지고조용히 비가 내리면여전히 그대로오늘도 어김없이 난벗어나질 못하네너의...   73,204
# 4  외로운 내 마음의 불꽃은아픔으로 가득 찬 과거를 불태워차디찬 이곳에서 벗어나게 해줄...    1,759

# %%
ballad_sad = ballad_sad[ballad_sad.장르 != 'R&B/Soul']

# %%
ballad_sad = ballad_sad[ballad_sad.장르 != 'R&B/Soul, 국내드라마']

# %%
ballad_sad = ballad_sad[ballad_sad != 'R&B/Soul, 인디음악']

# %%
ballad_sad = ballad_sad[ballad_sad.장르 != '인디음악, 포크/블루스']

# %%
ballad_sad = ballad_sad[ballad_sad.장르 != '랩/힙합']

# %%
ballad_sad = ballad_sad[ballad_sad.장르 != 'NaN']

# %%
ballad_sad.장르= ballad_sad.장르.replace('발라드, 국내드라마','발라드')

# %%
ballad_sad.장르= ballad_sad.장르.replace('발라드, 인디음악','발라드')

# %%
ballad_sad.reset_index(drop=True,inplace=True)

# %%
ballad_sad.to_csv("../Data/ballad_sad.csv",index=False)

# %%
pd.read_csv("../Data/ballad_sad.csv")
# Out:
#                  가수명                      노래제목         발매일   장르  \
# 0              V.O.S                   잘 살고 있다  2019.12.02  발라드
# 1                주보라       네가 없다 (Without You)  2013.02.19  발라드
# 2       휘인 (Whee In)           헤어지자 (Prod. 정키)  2019.09.04  발라드
# 3        헤이즈 (Heize)           비가 오는 날엔 (2021)  2021.08.04  발라드
# 4   스트레이 (The Stray)                그냥, 묻고 싶었어  2021.08.04  발라드
# 5                 정키   부담이 돼 (Feat. 휘인 Of 마마무)  2017.03.08  발라드
# 6          나비 (Navi)                   잘 된 일이야  2011.01.19  발라드
# 7         펀치 (Punch)               안녕 내 전부였던 너  2021.03.10  발라드
# 8         펀치 (Punch)               Done For Me  2019.08.18  발라드
# 9         펀치 (Punch)                    이 밤의 끝  2018.05.31  발라드
# 10               전상근                   너무 보고싶어  2021.07.25  발라드
# 11               장범준                 잠이 오질 않네요  2020.10.24  발라드
# 12               강고은       같은 시간 속 우린 여기까지인 거야  2021.07.24  발라드
# 13               권진아                         끝  2016.09.19  발라드
# 14               빅마마                     하루만 더  2021.06.24  발라드
# 15    그리즐리 (Grizzly)                        달라  2017.09.21  NaN
# 16               황인욱                       이별주  2019.11.01  발라드
# 17          사이로(415)                  우리 둘 사이로  2019.08.29  발라드
# 18                이우                      내 안부  2019.07.16  발라드
# 19     MSG워너비(M.O.M)                    바라만 본다  2021.06.26  발라드
# 20               전상근             오늘따라 더 미운 그대가  2021.06.13  발라드
# 21               윤토벤     서툰 이별을 하려해 (Feat.전상근)  2019.08.01  발라드
# 22                허각                     흔한 이별  2018.11.28  발라드
# 23         포맨 (4MEN)               눈 떠보니 이별이더라  2017.10.24  발라드
# 24               이소정       함께 했는데 이별은 나 혼자인 거야  2021.02.19  발라드
# 25                이우                      이별행동  2019.10.06  발라드
# 26               김나영  널 미워하지 않길 (Prod. By 하동균)  2016.12.30  발라드
# 27               다비치   마치 우린 없었던 사이 (Prod. 정키)  2018.07.12  발라드
# 28               송하예                      니 소식  2019.05.11  발라드
# 29               권진아                     이별 뒷면  2018.02.02  발라드
# 30               아이유                 첫 이별 그날 밤  2010.12.09  발라드
# 31            스웨덴세탁소                 우리가 있던 시간  2012.09.07  발라드
# 32         강민경 (다비치)                   사랑해서 그래  2019.02.27  발라드
# 33               정효빈                     처음이라서  2019.04.16  발라드
# 34               아이유                나만 몰랐던 이야기  2011.02.17  발라드
# 35       윤하 (YOUNHA)                  오늘 헤어졌어요  2009.12.11  발라드
#
#                                                    가사     좋아요수
# 0   한잔 술에 잊자 그만나도 숨 좀 쉬자 제발마치 주문처럼매일 읊조렸던넌 모르는내 슬픈...   38,511
# 1   서툰 작별이었는지 아련한 슬픔 속에 눈물이멈추질 않아너무나 어렸던 걸까내 이기적임에...    2,949
# 2   그럴 수도 있지 생각했어잊어 보려 했어지난 날의 모든 걸 노력했어다시 시작해 보려고...  115,651
# 3   세상이 어두워지고조용히 비가 내리면여전히 그대로오늘도 어김없이 난벗어나질 못하네너의...   73,204
# 4   외로운 내 마음의 불꽃은아픔으로 가득 찬 과거를 불태워차디찬 이곳에서 벗어나게 해줄...    1,759
# 5   더는 할 말이 없어다른 이유도어떤 변명도 난의미 없단 걸 알아끝이란 게 다 그렇잖아...  134,027
# 6   Hello Hello Hello Hello HelloDon't cry Don't c...   42,204
# 7   안녕 안녕이제 인사를 해야지너와 나의 이별인데아니 아니나는 그게 안될것 같아너를 보...   14,131
# 8   지울게 너에게 남겨줬던 추억까지도바랄게 너와의 기억도 남지 못하게더는 다가갈 수 없...  100,916
# 9   널 보면 나와 달라이렇게 난 네 생각뿐인데널 사랑했던 만큼 아파야 하는 걸까난 이 ...   47,764
# 10  혼자 이별을 하고가버리면 난 어떡하라고너 없는 하루를 살아보고너 없는 채로 잠들어본...   18,720
