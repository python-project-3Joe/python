# %% [markdown]
# # 나이브 베이즈 정리 모델로 발라드 노래 감정 분류
# ---

# %%
# 
from bayes import BayesianFilter
import pandas as pd

# %%
# 학습시킬 데이터 셋 불러오기
train_ballad60_0 = pd.read_csv("../../Data/train_data.csv", index_col="Unnamed: 0")
train_ballad60_1 = train_ballad60_0.iloc[:40,:]
train_ballad60_2 = train_ballad60_0.iloc[60:,:]
train_ballad60 = pd.concat([train_ballad60_1,train_ballad60_2], axis=0, ignore_index=True)
train_ballad60
# Out:
#                          가수명                          노래제목         발매일  \
# 0                        양다일                       Darling  2020-11-23
# 1                        장범준                     잠이 오질 않네요  2020-10-24
# 2                        백아연                          어디라도  2020-11-18
# 3                        김제훈                    Love Again  2017-02-06
# 4                        김제훈                            잠잠  2020-03-17
# 5                         죠지                         바라봐줘요  2019-02-21
# 6                        김제훈                       너만 생각하면  2018-01-29
# 7                 웬디 (WENDY)                          두 글자  2020-11-15
# 8                        김제훈                     Love Road  2017-07-24
# 9               태연 (TAEYEON)           겨울나무 (I'm all ears)  2017-12-12
# 10                       성시경                       첫 겨울이니까  2019-12-09
# 11                        로꼬                       Say Yes  2016-08-29
# 12                긱스 (Geeks)   Officially Missing You, Too  2012-11-01
# 13                 비비 (BIBI)                       아주, 천천히  2022-02-20
# 14                        경서                 밤하늘의 별을(2020)  2020-11-14
# 15               CHEEZE (치즈)              이렇게 좋아해 본 적이 없어요  2021-03-14
# 16                      멜로망스                            선물  2017-07-10
# 17                       정준일                     있잖아 널 사랑해  2016-12-29
# 18                      멜로망스                        사랑인가 봐  2022-02-18
# 19                      10CM                            서랍  2021-12-07
# 20                       정효빈                         처음이라서  2019-04-16
# 21                 포맨 (4MEN)                   눈 떠보니 이별이더라  2017-10-24
# 22                        이우                          내 안부  2019-07-16
# 23                       윤토벤         서툰 이별을 하려해 (Feat.전상근)  2019-08-01
# 24                  사이로(415)                      우리 둘 사이로  2019-08-29
# 25                펀치 (Punch)                   안녕 내 전부였던 너  2021-03-10
# 26                       주보라           네가 없다 (Without You)  2013-02-19
# 27                펀치 (Punch)                   Done For Me  2019-08-18
# 28                       송하예                          니 소식  2019-05-11
# 29                     V.O.S                       잘 살고 있다  2019-12-02
# 30                       황인욱                           이별주  2019-11-01
# 31             MSG워너비(M.O.M)                        바라만 본다  2021-06-26
# 32                        이우                          이별행동  2019-10-06
# 33                       다비치       마치 우린 없었던 사이 (Prod. 정키)  2018-07-12
# 34                       전상근                       너무 보고싶어  2021-07-25
# 35                        정키       부담이 돼 (Feat. 휘인 Of 마마무)  2017-03-08
# 36                펀치 (Punch)                        이 밤의 끝  2018-05-31
# 37                       아이유                     첫 이별 그날 밤  2010-12-09
# 38                       빅마마                         하루만 더  2021-06-24
# 39                       전상근                 오늘따라 더 미운 그대가  2021-06-13
# 40          백예린 (Yerin Baek)                         그럴때마다  2021-09-10
# 41  Collective Arts (콜렉티브아츠)                         나의 그늘  2017-07-27
# 42                    Sondia                     Moonlight  2019-12-31
# 43                       윤현상                        잊는다는 게  2015-03-13
# 44                       윤종신                           말꼬리  2011-05-31
# 45                       정승환                       숲으로 걷는다  2016-11-29
# 46                        문빛                           끝자락  2017-11-02
# 47                      드림캐쳐                          괜찮아!  2017-07-27
# 48                       아이유                          싫은 날  2013-12-20
# 49                       손동운                   Decrescendo  2019-04-22
# 50                       홍민정                        아마도 그건  2008-11-28
# 51      스윗소로우 (SWEET SORROW)                         서울은 비  2015-10-15
# 52                      멜로망스  그게 더 편할 것 같아 (N번째 연애 X 멜로망스)  2021-11-26
# 53                        김필         다시 사랑한다면 (니글니글 버터플라이)  2016-02-21
# 54                 AKMU (악뮤)     어떻게 이별까지 사랑하겠어, 널 사랑하는 거지  2019-09-25
# 55                       #안녕       너의 번호를 누르고 (Prod. 영화처럼)  2019-11-30
# 56                        부활            Never Ending Story  2002-09-01
# 57         Chocolat.D (쇼콜라디)                        그날에 우리  2016-02-05
# 58                       정승수                되돌릴 수 없는 이별을 해  2021-01-10
# 59                펀치 (Punch)                        헤어지는 중  2018-09-12
#
#                                                    가사    좋아요수            감정
# 0   Oh darling 처음 널 만나면 수줍은 대화들로 사랑에 빠질 거야 My darl...   10907         happy
# 1   당신은 날 설레게 만들어 조용한 내 마음 자꾸만 춤추게 해 얼마나 얼마나 날 떨리게...  159018         happy
# 2   우연의 다른 이름은 운명이란 걸 배웠죠 우리 사랑의 끝이 없는 걸 이제서야 알았죠 ...    1622         happy
# 3   언제부터였을까 따뜻한 휴식을 찾고 있을 때 찾고 있을 때 그때부터였을까 맘이 포근해...     980         happy
# 4   오랜만에 거길 가봤어 아무도 없는 둘만이 알던 곳 함께 걷던 거리에 서서 아무 말도...     548         happy
# 5   그대를 다시 볼 수 있다는 생각을 해요 아마도 우린 끝없이 멀리 돌아만 왔죠 엊그제...   70395         happy
# 6   오늘도 어김없이 빗나가는 말투들에 긴 싸움 끝에 결국 널 울리고 말았어 처음에 약속...     375         happy
# 7   그대 아무 말 없어도 나의 눈빛은 그대만 봐요 눈망울에 숨겨놓은 그대 이야기 이젠 ...   12288         happy
# 8   매일 마다 만드는 우리의 부드럽고 예쁜 스토리 오늘은 유난히 멋 좀 부리고 제일 먼...     150         happy
# 9   어제보다 많이 지쳐 보이는 그대의 표정 만져 보곤 알죠 바람이 또 아프게 했나요 왜...   17817         happy
# 10  무얼 고를까 추운 겨울이니까 캐시미어 스웨터는 어떨까 처음이니까 초록이 날까 다홍색...   58622         happy
# 11  니 눈앞에 왔잖아 내가 여기 있잖아 너의 입술로 말을 해줘 say yes say y...   89514         happy
# 12  애써 너에게 건냈던 말 good bye 이젠 혼자 남게된 이 밤 without yo...  123533         happy
# 13  눈빛만으로 알 수가 있지 어떤 세상을 살아왔는지 처음 내민 너의 따뜻한 손길에 내 ...   35147         happy
# 14  밤하늘의 별을 따서 너에게 줄래 너는 내가 사랑하니까 더 소중하니까 오직 너 아니면...  197543         happy
# 15  따스한 바람이 불어오는 날엔 포근한 미소로 나를 또 반겨주던 그대란 사람 설레는 이...   67373         happy
# 16  빛이 들어오면 자연스레 뜨던 눈 그렇게 너의 눈빛을 보곤 사랑에 눈을 떴어 항상 알...  334594         happy
# 17  따뜻한 봄바람처럼 상냥하게 내게 불어오던 너 찬란하게 피어나던 여름의 꽃처럼 반짝이...   25523         happy
# 18  너와 함께 하고 싶은 일들을 상상하는 게 요즘 내 일상이 되고 너의 즐거워하는 모습...  147178         happy
# 19  어린 햇살 아래서 뛰어놀곤 했었던 가쁜 숨결 굽이진 골목 지나 길을 따라가보면 같은...   65760         happy
# 20  떨어질 줄 몰랐던 너의 품도 잡은 손에 스치던 봄바람도 떨리던 입맞춤도 맞춰 걷던 ...   58777           sad
# 21  분명 나는 꿈을 꾼 거다 눈 떠보니 이별이더라 휴대폰을 확인해 봤더니 다시 봐도 이...  115695           sad
# 22  내 소식 들었지 너와 헤어지고 참 많이 울고 힘들게 버티다 이해심이 많은 좋은 사람...   64527           sad
# 23  우리 이제 헤어지기로해 너도 알잖아 우린 충분했다는걸 이별이 무서워 자꾸 피해보지만...   81248           sad
# 24  Forget me close your eyes Forget me close your...    5998           sad
# 25  안녕 안녕 이제 인사를 해야지 너와 나의 이별인데 아니 아니 나는 그게 안될것 같아...   14135           sad
# 26  서툰 작별이었는지 아련한 슬픔 속에 눈물이 멈추질 않아 너무나 어렸던 걸까 내 이기...    2948           sad
# 27  지울게 너에게 남겨줬던 추억까지도 바랄게 너와의 기억도 남지 못하게 더는 다가갈 수...  100916           sad
# 28  그때의 우리 사랑 뜨겁고 치열했는데 끝나보니 남는건 미움뿐 몇번의 계절을 더 보내야...  195103           sad
# 29  한잔 술에 잊자 그만 나도 숨 좀 쉬자 제발 마치 주문처럼 매일 읊조렸던 넌 모르는...   38512           sad
# 30  오늘이 지나면 널 지워야겠지 흔들리는 이 술잔이 너의 마음 같아서 아무 말 안 해도...   60822           sad
# 31  내가 너라면 다 알아볼 텐데 널 위할 사람 찾아낼 텐데 지난 오랜 시간 너의 그 곁...  179238           sad
# 32  자꾸만 연락을 피하고 바쁘다며 약속을 미루고 점점 변해가는 네 모습 무심한 말투 조...   58649           sad
# 33  비 내리는 날 창가에 앉아 서두르던 일상을 달래다 울적해진 마음잡고 써 내려가다 울...   50062           sad
# 34  혼자 이별을 하고 가버리면 난 어떡하라고 너 없는 하루를 살아보고 너 없는 채로 잠...   18728           sad
# 35  더는 할 말이 없어 다른 이유도 어떤 변명도 난 의미 없단 걸 알아 끝이란 게 다 ...  134029           sad
# 36  널 보면 나와 달라 이렇게 난 네 생각뿐인데 널 사랑했던 만큼 아파야 하는 걸까 난...   47764           sad
# 37  멍하니 아무 일도 할 일이 없어 이게 이별인 거니 전화기 가득 찬 너와의 메시지만 ...   93381           sad
# 38  하루만 더 우리 이별을 늦춘다면 어땠을까 그럴 일 없다는 걸 나는 알면서도 아직 널...   58506           sad
# 39  조금은 괜찮다 생각했는데 이제는 잊혀질 때도 됐는데 아무렇지 않다가도 그대가 없단 ...   25819           sad
# 40  반복된 하루 사는 일에 지칠 때면 내게 말해요 항상 그대의 지쳐있는 마음에 조그만 ...   33255  indifference
# 41  나의 그늘이 좋다고 하는 너에게 무슨 말을 해야 좋을까 이 순간에도 가난한 나의 마...    4344  indifference
# 42  Moonlight 나를 감싸안아 데려다줘 그럼 너의 온기를 간직하겠어 내가 어디에 ...    4461  indifference
# 43  잊는다는 게 참 그래요 사랑하다가 이별하게 되면 그때서야 못해줬던 게 생각이 나요 ...   29999  indifference
# 44  비는 오고 너는 가려 하고 내 마음 눅눅하게 잠기고 낡은 흑백영화 한 장면처럼 내 ...   46043  indifference
# 45  숲으로 걷는다 미안하단 말 대신 천천히 걷는다 기억의 너와 나란히 걷는다 아무 말 ...    7894  indifference
# 46  다 알고 있었어 저 별이 지고 나면 말이야 애써 아무렇지 않은 척 또 난 예전 같진...    1773  indifference
# 47  아직도 난 길을 잃어서 어디로 갈지 몰라 조금도 나아지지가 않아 사실은 나 아직 어...    4281  indifference
# 48  키 큰 전봇대 조명 아래 나 혼자 집에 돌아가는 길 가기 싫다 쓸쓸한 대사 한 마디...   49488  indifference
# 49  내게 주던 사랑이갈수록 익숙해져 편하게 생각했나 봐날 떠나 가벼워진 사랑은 이제야 ...    3906  indifference
# 50  아마도 그건 사랑이었을거야 희미하게 떠오르는 기억이 이제야 그 마음을 알아버렸네 그...   27493  indifference
# 51  오늘 따라 내리는 이 비는 좀처럼 그치질 않네요 혹시 그대 있는 곳에도 지금처럼 비...    3226  indifference
# 52  너를 위해 해줬었던 말들은 부담을 줬고 네가 내게 해줬던 위로에 나 상처 입었죠 사...   36203  indifference
# 53  다시 태어난다면 다시 사랑한다면 그때는 우리 이러지 말아요 조금 덜 만나고 조금 덜...   81524  indifference
# 54  일부러 몇 발자국 물러나 내가 없이 혼자 걷는 널 바라본다 옆자리 허전한 너의 풍경...  386623  indifference
# 55  우연히 너를 만나서 너의 옆자리에 앉아 그렇게 우린 친해졌어 짧은 시간에 그렇게 가...  109930  indifference
# 56  손 닿을 수 없는 저기 어딘가 오늘도 난 숨쉬고 있지만 너와 머물던 작은 의자 위에...   70543  indifference
# 57  그날에 우리 예감했었지 끊어질 것 같은 우리의 사랑 차마 말하지 못했지 마지막 그 ...      61  indifference
# 58  혼자 집에 걸어가는 길이 어색해 우리 예전처럼 함께 걷던 그 날이 무색해질 만큼 변...     878  indifference
# 59  나를 사랑하나요 같은 곳을 보나요 이미 알고 있어요 아닌 걸 알죠 배우지 않았어도 ...  125919  indifference

# %% [markdown]
# ---
# ### 감정분류가 되어있는 발라드 60 곡의 정보

# %%
train_ballad60.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   가수명     60 non-null     object
#  1   노래제목    60 non-null     object
#  2   발매일     60 non-null     object
#  3   가사      60 non-null     object
#  4   좋아요수    60 non-null     int64
#  5   감정      60 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 2.9+ KB

# %%
# 첫번째 노래 추출하기
train_ballad60.iloc[0]
# Out:
# 가수명                                                   양다일
# 노래제목                                              Darling
# 발매일                                            2020-11-23
# 가사      Oh darling 처음 널 만나면 수줍은 대화들로 사랑에 빠질 거야 My darl...
# 좋아요수                                                10907
# 감정                                                  happy
# Name: 0, dtype: object

# %%
# train_ballad80의 첫번째 노래의 가사
str(train_ballad60.iloc[0].가사)
# Out:
# 'Oh darling 처음 널 만나면 수줍은 대화들로 사랑에 빠질 거야 My darling 아마도 우린 손을 마주 잡고서 도시를 거닐 거야 비라도 오면 골목 어귀에 발을 멈추고서 바라보다가 입을 맞출지도 몰라 어둠이 오면 밝게 빛나는 별빛들 아래서 음악에 취해 서로에게 기대어 Darling My darling 멈춰버린 시간 속에서 우리 둘이서 영원토록 Darling My darling 함께 할 거야 너의 곁에서 눈을 감을 때까지 Oh darling 잊지 못할 거야 서로를 품에 안고 온기를 느끼던 날 My darling 따스할 거야 함께 잠이 들 때면 비추는 햇살들이 가끔씩 우린 아쉬울 거야 다른 모습들에 말을 멈추고 어색한 침묵이 올 때면 서운한 마음에 다투다 보면 오직 둘만 아는 그런 말들로 가벼운 미소가 될 거야 Darling My darling 멈춰버린 시간 속에서 우리 둘이서 영원토록 Darling My darling 함께 할 거야 너의 곁에서 눈을 감을 때까지 널 처음 마주한 순간 알 수 있었어 나를 보며 지었던 그 미소 그게 내 전부란 걸 Darling My darling 설레이는 내 마음을 담아 너에게 고백할게 영원토록 Darling My darling 나를 안아줘 너의 곁에서 눈을 감을 때까지 눈을 감을 때까지 눈을 감을 때까지 '

# %%
# train_ballad80의 첫번째 노래의 감정
str(train_ballad60.iloc[0].감정)
# Out:
# 'happy'

# %% [markdown]
# ---
# ### 나이브베이즈 정리 모델 불러와 60곡 bf model에 학습시키기

# %%
bf = BayesianFilter()

# %%
# for 문을 이용하여 텍스트 학습 시키기
for i in range(len(train_ballad60)):
    bf.fit(str(train_ballad60.iloc[i].가사),str(train_ballad60.iloc[i].감정))
# Out:
# [0.003s][warning][os,thread] Attempt to protect stack guard pages failed (0x000000016b480000-0x000000016b48c000).
# [0.003s][warning][os,thread] Attempt to deallocate stack guard pages failed.

# %%
# 예측 해보기
pre, scorelist = bf.predict("다신 사랑하지 않아 보고 싶지 않아 나를 떠나간 너를 내가 싫다고 했잖아 헤어지기 싫다고 옆에 있어달라고 눈물이 멈추질 않아 이렇게 끝이라면 다신 널 볼 수 없으니까 우리 사랑했던 추억을 아직 잊지 말아요 다시 돌아갈 수 없다며 단정 지었던 네가 너무 그립고 그리워서 보고 싶어 눈물이 나서 그대 생각하며 이렇게 조금만 더 아플게요 그대 행복해야 해요 아프지도 말고 내가 없었단 듯이 사실 아파했음 좋겠어 내 생각을 하면서 매일 밤마다 날 그리워해 주길 우리 사랑했던 추억을 아직 잊지 말아요 다시 돌아갈 수 없다며 단정 지었던 네가 너무 그립고 그리워서 보고 싶어 눈물이 나서 그대 생각하며 이렇게 조금만 더 아플게요 너와 걷던 길을 혼자 걸어요 그대 추억을 두고 오려 해 미안하다고 내가 보고 싶었다고 말 한마디면 난 충분한데 우리 사랑했던 추억을 아직 잊지 말아요 다시 돌아갈 수 없다며 단정 지었던 네가 너무 그립고 그리워서 눈물이 멈추질 않아서 그댈 생각하며 이렇게 나 조금만 더 아플게요 ")
print("결과 =", pre)
print(scorelist)
# Out:
# 결과 = sad
# [('happy', -947.3209143496434), ('sad', -881.4227828689841), ('indifference', -907.2984709108819)]

# %%
# 예측 해보기
pre, scorelist = bf.predict("오늘 한잔할까요 늘 만나던 그곳에서 찬바람이 불면 생각이 나던 골목집에서 추억 한잔할까요 긴 하루의 끝에서 아름다웠던 우리의 시절 다시 돌아갈까요 어떤 누구보다 날 사랑했던 그 사람 한잔하고 싶을 때마다 떠오르는 그리움 혼자서 마시는 술에 홀로 남겨진 슬픔에 잊으려고 하면 할수록 더 그대가 보고 싶어요 나 많이 취한 것처럼 우는 것처럼 보여도 괜찮아요 그대 온다면 못 알아볼 리가 없죠 언제인지 몰라도 술 버릇이 생겼네요 테이블 위에다 흘린 술로 난 그대를 그리죠 오늘만은 내 잔을 뺏어가면 안 돼요 못 이기는 건 술이 아니라 아픈 이별이니까 돌아와야 하는 그대는 안 돌아오고 그대 떠난 그때 겨울만 혼자 돌아왔네요 혼자서 마시는 술에 홀로 남겨진 슬픔에 잊으려고 하면 할수록 더 그대가 보고 싶어요 나 많이 취한 것처럼 우는 것처럼 보여도 괜찮아요 그대 온다면 못 알아볼 리가 없죠 이렇게 있다간 나도 모르게 소리 내서 울 것 같아서 나 일어날래요 나 그만 갈래요 이제 자꾸 사람들이 쳐다보니까 나 항상 그대뿐이죠 그래 난 그대뿐이죠 헤어지고 나서 이제서야 그대란 걸 알아요 나 많이 취한 것처럼 우는 것처럼 보여도 내일에도 이 곳에 와서 그대를 기다릴게요")
print("결과 =", pre)
print(scorelist)
# Out:
# 결과 = indifference
# [('happy', -1180.0305223109456), ('sad', -1150.549088461802), ('indifference', -1140.9743927533016)]

# %%
# 예측 해보기
pre, scorelist = bf.predict("그댄 내가 바라던 Romance 오랫동안 헤맨듯해 꿈만 같은 그대 품에 Deep inside Hmm 이토록 많이 사랑하게 된 이유 저 파도처럼 내게 밀려왔었지 우린 좀 달라도 어딘가 특별해 그댄 내게 전부가 된 거죠 Oh oh 그댄 내가 바라던 Romance 오랫동안 헤맨듯해 꿈만 같은 그대 품에 Deep inside Hmm 그렇게 우린 서로에게 기대어 그 누구에게도 못한 이야기까지도 커다란 그 품속에 잠들 때면 모든 게 편해진 거죠 우린 서로의 밤이 되어요 Oh oh 그댄 내가 바라던 Romance 오랫동안 헤맨듯해 꿈만 같은 그대 품에 Deep inside Woo 그대와 난 내일을 그려가요 영원히 둘이서 사랑이라 부를게요 My romance ")
print("결과 =", pre)
print(scorelist)
# Out:
# 결과 = sad
# [('happy', -694.8372886071193), ('sad', -685.656604272049), ('indifference', -686.1544803089199)]

# %% [markdown]
# ---
# ### 발라드 2000곡(베이즈 정리 모델 곡 제외)를 학습시키기

# %%
# 학습시킬 데이터 셋 불러오기
train_ballad2000 = pd.read_csv("../../Data/ballad_test.csv")
train_ballad2000.head(10)
# Out:
#              가수명                          노래제목         발매일  \
# 0   WSG워너비 (가야G)             그때 그 순간 그대로 (그그그)  2022-07-09
# 1             경서                        나의 X에게  2022-04-24
# 2             주호                       내가 아니라도  2022-03-25
# 3     김민석 (멜로망스)                          취중고백  2021-12-19
# 4            임영웅                      우리들의 블루스  2022-05-02
# 5           경서예지                 다정히 내 이름을 부르면  2021-05-19
# 6            이석훈  바보에게 바보가 (웹툰 '연애의 발견' X 이석훈)  2022-07-11
# 7  MSG워너비(M.O.M)                        듣고 싶을까  2022-02-26
# 8    케이시 (Kassy)              늦은 밤 헤어지긴 너무 아쉬워  2022-05-19
# 9            임영웅                   다시 만날 수 있을까  2022-05-02
#
#                                                   가사    좋아요수  \
# 0   잘 지냈지? 조금은 어색해 요즘 좋아 보여 인사 나누며 사실 궁금한 게 너무 많았...   88589
# 1   우리 다시 만날래 예쁘게 빛나던 모든 추억들이 너무 그리워 너의 품에 안길래 이 ...  105034
# 2   사랑이었다 별거 없던 내 하루에 빛이 돼준 단한 사람 나보다 나를 더 아껴 주던 ...   52955
# 3   뭐하고 있었니 늦었지만 잠시 나올래 너의 집 골목에 있는 놀이터에 앉아 있어 친구...  137934
# 4   잊지는 말아요 함께 했던 날들 눈물이 날 때면 그대 뒤를 돌아보면 돼요 아프지 말...   71880
# 5   끝없이 별빛이 내리던 밤 기분 좋은 바람이 두 빰을 스치고 새벽 바다 한곳을 보는...  144360
# 6   너무 걱정하지는 마 보란 듯이 살아 볼 거야 후회는 사치일 뿐이야 다시 시작해 볼...   16170
# 7   우리 함께 듣던 그 노랠 듣고 싶을까 듣고 나서 잠시 날 생각은 할까 아주 혹시라...   79001
# 8   어쩌면 너도 나와 같은 꿈 꿀까 매일 마주 보며 눈뜨는 하루 늦은 밤 헤어지긴 너...   39685
# 9   너를 위해 해 줄 것이 하나 없어서 보낼 수밖에 없었고 네가 없이 사는 법을 알지...   56804
#
#                                                 앨범사진    songId  순위
# 0  https://cdnimg.melon.co.kr/cm2/album/images/11...  35383397   1
# 1  https://cdnimg.melon.co.kr/cm2/album/images/10...  34943312   2
# 2  https://cdnimg.melon.co.kr/cm2/album/images/10...  34787226   4
# 3  https://cdnimg.melon.co.kr/cm2/album/images/10...  34431086   6
# 4  https://cdnimg.melon.co.kr/cm2/album/images/10...  34908740   7
# 5  https://cdnimg.melon.co.kr/cm2/album/images/10...  33496587   8
# 6  https://cdnimg.melon.co.kr/cm2/album/images/11...  35388184   9
# 7  https://cdnimg.melon.co.kr/cm2/album/images/10...  34701627  10
# 8  https://cdnimg.melon.co.kr/cm2/album/images/10...  35177030  11
# 9  https://cdnimg.melon.co.kr/cm2/album/images/10...  35008524  12

# %%
train_ballad2000.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1913 entries, 0 to 1912
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   가수명     1913 non-null   object
#  1   노래제목    1913 non-null   object
#  2   발매일     1913 non-null   object
#  3   가사      1913 non-null   object
#  4   좋아요수    1913 non-null   object
#  5   앨범사진    1913 non-null   object
#  6   songId  1913 non-null   int64
#  7   순위      1913 non-null   int64
# dtypes: int64(2), object(6)
# memory usage: 119.7+ KB

# %%
train_ballad2000.iloc[1]
# Out:
# 가수명                                                      경서
# 노래제목                                                 나의 X에게
# 발매일                                              2022-04-24
# 가사         우리 다시 만날래 예쁘게 빛나던 모든 추억들이 너무 그리워 너의 품에 안길래 이 ...
# 좋아요수                                                 105034
# 앨범사진      https://cdnimg.melon.co.kr/cm2/album/images/10...
# songId                                             34943312
# 순위                                                        2
# Name: 1, dtype: object

# %% [markdown]
# ---
# ### 예시] 30곡을 추출해서 감정분류 후 감정리스트 추가하기

# %%
emotion = []
for i in range(0,30):
    pre, scorelist = bf.predict(str(train_ballad2000.iloc[i].가사))
    print("결과 =", pre)
    print(scorelist)
    print('-------------------------------------------')
    emotion.append(pre)
# Out:
# 결과 = sad
# [('happy', -1298.7762631897315), ('sad', -1235.1918789090873), ('indifference', -1238.675004258135)]
# -------------------------------------------
# 결과 = sad
# [('happy', -964.7618737931717), ('sad', -945.9808225098034), ('indifference', -981.6623060199992)]
# -------------------------------------------
# 결과 = sad
# [('happy', -948.647234536125), ('sad', -910.9115843010925), ('indifference', -933.4303810593238)]
# -------------------------------------------
# 결과 = sad
# [('happy', -1012.4517170671978), ('sad', -1003.3839982123916), ('indifference', -1013.5404081728325)]
# -------------------------------------------
# 결과 = indifference
# [('happy', -799.7458989773952), ('sad', -797.140711879668), ('indifference', -764.8704755820412)]
# -------------------------------------------
# 결과 = happy
# [('happy', -1361.6021847622867), ('sad', -1403.912137430925), ('indifference', -1389.0267812057557)]
# -------------------------------------------
# 결과 = sad
# [('happy', -936.4693134664373), ('sad', -872.733353822688), ('indifference', -907.1245282093304)]
# -------------------------------------------
# 결과 = happy
# [('happy', -1173.3689977901815), ('sad', -1175.0800260602016), ('indifference', -1214.9116441115123)]
# -------------------------------------------
# 결과 = sad
# [('happy', -781.1032572155029), ('sad', -778.3752043496929), ('indifference', -805.0684626343066)]
# -------------------------------------------
# 결과 = sad
# [('happy', -975.7110830466493), ('sad', -947.0074717766512), ('indifference', -950.5948672498411)]
# -------------------------------------------
# 결과 = sad
# [('happy', -863.8452282028752), ('sad', -858.440818158268), ('indifference', -867.62642017794)]
# -------------------------------------------
# 결과 = happy
# [('happy', -1293.5817098740463), ('sad', -1323.8897617977211), ('indifference', -1312.8880936204248)]
# -------------------------------------------
# 결과 = sad
# [('happy', -1007.174623904763), ('sad', -1005.5969535395694), ('indifference', -1039.032140266469)]
# -------------------------------------------
# 결과 = happy
# [('happy', -622.3597739784198), ('sad', -624.4762398931871), ('indifference', -624.1862390544343)]
# -------------------------------------------
# 결과 = sad
# [('happy', -902.7412427108366), ('sad', -895.3377290954978), ('indifference', -901.6344846292774)]
# -------------------------------------------
# 결과 = happy
# [('happy', -1018.5959942087043), ('sad', -1039.7069561670085), ('indifference', -1038.6907828716844)]
# -------------------------------------------
# 결과 = happy
# [('happy', -1179.6116423104336), ('sad', -1201.5799941854668), ('indifference', -1191.410847818691)]
# -------------------------------------------
# 결과 = happy
# [('happy', -843.7748991860192), ('sad', -855.1482297802107), ('indifference', -861.0639991761707)]
# -------------------------------------------
# 결과 = sad
# [('happy', -1289.2760096743082), ('sad', -1250.0486945210596), ('indifference', -1282.466384334803)]
# -------------------------------------------
# 결과 = sad
# [('happy', -956.4406461440057), ('sad', -881.9960622171815), ('indifference', -924.7358121156936)]
# -------------------------------------------
# 결과 = indifference
# [('happy', -663.1065965499495), ('sad', -655.7998447963033), ('indifference', -643.7061359100179)]
# -------------------------------------------
# 결과 = indifference
# [('happy', -1421.1657901513292), ('sad', -1414.141100684544), ('indifference', -1397.9869068663647)]
# -------------------------------------------
# 결과 = happy
# [('happy', -1349.3012722882972), ('sad', -1440.415140175594), ('indifference', -1485.90409275533)]
# -------------------------------------------
# 결과 = indifference
# [('happy', -1625.3613950259642), ('sad', -1639.998830451302), ('indifference', -1601.0103572611652)]
# -------------------------------------------
# 결과 = happy
# [('happy', -974.9302318776063), ('sad', -981.6096501535741), ('indifference', -982.222204771021)]
# -------------------------------------------
# 결과 = indifference
# [('happy', -557.8864221939115), ('sad', -553.5604372549324), ('indifference', -551.1930352970104)]
# -------------------------------------------
# 결과 = sad
# [('happy', -2076.0981685957877), ('sad', -2050.6609435279474), ('indifference', -2065.5328829717355)]
# -------------------------------------------
# 결과 = sad
# [('happy', -952.3063657782315), ('sad', -943.9577731258474), ('indifference', -951.2906699532994)]
# -------------------------------------------
# 결과 = indifference
# [('happy', -1842.5466277195314), ('sad', -1855.4416924809955), ('indifference', -1803.8988050608816)]
# -------------------------------------------
# 결과 = sad
# [('happy', -1197.3353068310707), ('sad', -1176.7287548625343), ('indifference', -1208.7570196652853)]
# -------------------------------------------

# %%
emotion[1]
# Out:
# 'sad'

# %% [markdown]
# ---
# ### 1913곡을 추출해서 베이즈 정리 모델에 학습시키고 감정분류 후 감정리스트 추가하기

# %% [markdown]
# > 30곡씩 가사를 추출하여 bf에 돌려 pre 값을 emotion List에 합치며
# > 그 가사와 pre값을 다시 bf에 합쳐서 학습시킨다.

# %%
range(1913//30+1)
# Out:
# range(0, 64)

# %%
emotion = [] # 감정 리스트 선언
for j in range(1913//30 + 1): # 범위 0~64번 돌게 범위 지정
    for i in range(j*30, j*30+30): # 30곡씩 학습 시켜야됨
        if (i == 1913): # 마지막 1913곡일때 for문을 빠져나오게 함.
            break
        pre, scorelist = bf.predict(str(train_ballad2000.iloc[i].가사))
        emotion.append(pre)
        bf.fit(str(train_ballad2000.iloc[i].가사),pre)

# %%
len(emotion)
# Out:
# 1913

# %%
emotion
# Out:
# ['sad',
#  'sad',
#  'sad',
#  'sad',
#  'indifference',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'happy',
#  'sad',
#  'happy',
#  'happy',
#  'happy',
#  'sad',
#  'sad',
#  'indifference',
#  'indifference',
#  'happy',
#  'indifference',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'indifference',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'indifference',
#  'happy',
#  'sad',
#  'sad',
#  'happy',
#  'happy',
#  'sad',
#  'sad',
#  'happy',
#  'happy',
#  'happy',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'indifference',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'indifference',
#  'sad',
#  'sad',
#  'indifference',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'indifference',
#  'happy',
#  'sad',
#  'sad',
#  'indifference',
#  'indifference',
#  'happy',
#  'happy',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'indifference',
#  'sad',
#  'sad',
#  'sad',
#  'indifference',
#  'indifference',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'indifference',
#  'sad',
#  'sad',
#  'sad',
#  'indifference',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'indifference',
#  'sad',
#  'sad',
#  'sad',
#  'indifference',
#  'indifference',
#  'sad',
#  'happy',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'indifference',
#  'sad',
#  'indifference',
#  'sad',
#  'indifference',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'indifference',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'indifference',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'happy',
#  'indifference',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'indifference',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'indifference',
#  'happy',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'happy',
#  'indifference',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'indifference',
#  'indifference',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'indifference',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'indifference',
#  'sad',
#  'sad',
#  'sad',
#  'indifference',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'indifference',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'indifference',
#  'sad',
#  'happy',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'indifference',
#  'sad',
#  'sad',
#  'indifference',
#  'sad',
#  'happy',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'indifference',
#  'happy',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'indifference',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'happy',
#  'sad',
#  'happy',
#  'indifference',
#  'indifference',
#  'sad',
#  'happy',
#  'happy',
#  'sad',
#  'indifference',
#  'happy',
#  'sad',
#  'indifference',
#  'sad',
#  'indifference',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'indifference',
#  'sad',
#  'indifference',
#  'sad',
#  'happy',
#  'sad',
#  'indifference',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'indifference',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'indifference',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'indifference',
#  'sad',
#  'sad',
#  'sad',
#  'indifference',
#  'sad',
#  'indifference',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'indifference',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'indifference',
#  'happy',
#  'indifference',
#  'sad',
#  'sad',
#  'indifference',
#  'sad',
#  'sad',
#  'indifference',
#  'sad',
#  'indifference',
#  'happy',
#  'sad',
#  'sad',
#  'indifference',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'indifference',
#  'sad',
#  'sad',
#  'indifference',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'indifference',
#  'sad',
#  'happy',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'happy',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'indifference',
#  'sad',
#  'sad',
#  'indifference',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'indifference',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'happy',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'indifference',
#  'sad',
#  'sad',
#  'sad',
#  'indifference',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'indifference',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'indifference',
#  'indifference',
#  'sad',
#  'sad',
#  'sad',
#  'indifference',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'indifference',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'indifference',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'indifference',
#  'indifference',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'indifference',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'indifference',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'indifference',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'happy',
#  'sad',
#  'indifference',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'indifference',
#  'sad',
#  'indifference',
#  'happy',
#  'happy',
#  'indifference',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'happy',
#  'sad',
#  'happy',
#  'sad',
#  'indifference',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'indifference',
#  'sad',
#  'happy',
#  'sad',
#  'indifference',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'indifference',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'indifference',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'indifference',
#  'indifference',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'indifference',
#  'sad',
#  'sad',
#  'indifference',
#  'sad',
#  'sad',
#  'sad',
#  'indifference',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'indifference',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'indifference',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'indifference',
#  'happy',
#  'sad',
#  'sad',
#  'happy',
#  'indifference',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'indifference',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'indifference',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'indifference',
#  'sad',
#  'sad',
#  'sad',
#  'indifference',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'happy',
#  ...]

# %% [markdown]
# ---
# ### emotion 리스트를 Naive Bayes_ballad2000에 추가하기

# %%
Bayes_ballad2000 = pd.read_csv("../../Data/ballad_test.csv")

# %%
Bayes_ballad2000
# Out:
#                가수명                      노래제목         발매일  \
# 0     WSG워너비 (가야G)         그때 그 순간 그대로 (그그그)  2022-07-09
# 1               경서                    나의 X에게  2022-04-24
# 2               주호                   내가 아니라도  2022-03-25
# 3       김민석 (멜로망스)                      취중고백  2021-12-19
# 4              임영웅                  우리들의 블루스  2022-05-02
# ...            ...                       ...         ...
# 1908            터보             회상 (December)  1997-01-01
# 1909           이석훈                        고백  2011-06-02
# 1910           다비치                    나의 첫사랑  2022-05-16
# 1911          미스에스  이 나이 먹고 뭐했길래 (Feat. 정슬기)  2010-09-10
# 1912       하은 (포맨)             혼코노 (Honkono)  2019-10-17
#
#                                                      가사    좋아요수  \
# 0      잘 지냈지? 조금은 어색해 요즘 좋아 보여 인사 나누며 사실 궁금한 게 너무 많았...   88589
# 1      우리 다시 만날래 예쁘게 빛나던 모든 추억들이 너무 그리워 너의 품에 안길래 이 ...  105034
# 2      사랑이었다 별거 없던 내 하루에 빛이 돼준 단한 사람 나보다 나를 더 아껴 주던 ...   52955
# 3      뭐하고 있었니 늦었지만 잠시 나올래 너의 집 골목에 있는 놀이터에 앉아 있어 친구...  137934
# 4      잊지는 말아요 함께 했던 날들 눈물이 날 때면 그대 뒤를 돌아보면 돼요 아프지 말...   71880
# ...                                                 ...     ...
# 1908  겨울 오면은 우리 둘이서 항상 왔었던 바닷가 시린 바람과 하얀 파도는 예전 그대로였...   12742
# 1909  좋은 사람 만나 행복해야 해 너는 웃고 있지만 나는 웃을 수가 없는걸 그래 난 알고...   18569
# 1910  그때의 나는 너를 만나서 하나부터 열까지 모든 순간들이 소중했어 내 첫사랑 잊고 싶...     925
# 1911  다시 처음으로 돌아갈 수 있다면 아마 너를 사랑하는 일은 안했을텐데 그 날밤 그 카...   10416
# 1912  이 동전 하나로 뭘 할 수 있을까 고민 고민하다가 나 혼자 이곳에 왔어 익숙한 번호...   15260
#
#                                                    앨범사진    songId    순위
# 0     https://cdnimg.melon.co.kr/cm2/album/images/11...  35383397     1
# 1     https://cdnimg.melon.co.kr/cm2/album/images/10...  34943312     2
# 2     https://cdnimg.melon.co.kr/cm2/album/images/10...  34787226     4
# 3     https://cdnimg.melon.co.kr/cm2/album/images/10...  34431086     6
# 4     https://cdnimg.melon.co.kr/cm2/album/images/10...  34908740     7
# ...                                                 ...       ...   ...
# 1908  https://cdnimg.melon.co.kr/cm/album/images/003...   1606413  1996
# 1909  https://cdnimg.melon.co.kr/cm/album/images/012...   3426230  1997
# 1910  https://cdnimg.melon.co.kr/cm2/album/images/10...  35145139  1998
# 1911  https://cdnimg.melon.co.kr/cm/album/images/010...   2933662  1999
# 1912  https://cdnimg.melon.co.kr/cm2/album/images/10...  32104350  2000
#
# [1913 rows x 8 columns]

# %%
감정 = pd.DataFrame(emotion)
감정
# Out:
#                  0
# 0              sad
# 1              sad
# 2              sad
# 3              sad
# 4     indifference
# ...            ...
# 1908           sad
# 1909           sad
# 1910           sad
# 1911           sad
# 1912           sad
#
# [1913 rows x 1 columns]

# %%
Bayes_ballad2000 = pd.concat([Bayes_ballad2000,감정], axis=1)

# %%
Bayes_ballad2000
# Out:
#                가수명                      노래제목         발매일  \
# 0     WSG워너비 (가야G)         그때 그 순간 그대로 (그그그)  2022-07-09
# 1               경서                    나의 X에게  2022-04-24
# 2               주호                   내가 아니라도  2022-03-25
# 3       김민석 (멜로망스)                      취중고백  2021-12-19
# 4              임영웅                  우리들의 블루스  2022-05-02
# ...            ...                       ...         ...
# 1908            터보             회상 (December)  1997-01-01
# 1909           이석훈                        고백  2011-06-02
# 1910           다비치                    나의 첫사랑  2022-05-16
# 1911          미스에스  이 나이 먹고 뭐했길래 (Feat. 정슬기)  2010-09-10
# 1912       하은 (포맨)             혼코노 (Honkono)  2019-10-17
#
#                                                      가사    좋아요수  \
# 0      잘 지냈지? 조금은 어색해 요즘 좋아 보여 인사 나누며 사실 궁금한 게 너무 많았...   88589
# 1      우리 다시 만날래 예쁘게 빛나던 모든 추억들이 너무 그리워 너의 품에 안길래 이 ...  105034
# 2      사랑이었다 별거 없던 내 하루에 빛이 돼준 단한 사람 나보다 나를 더 아껴 주던 ...   52955
# 3      뭐하고 있었니 늦었지만 잠시 나올래 너의 집 골목에 있는 놀이터에 앉아 있어 친구...  137934
# 4      잊지는 말아요 함께 했던 날들 눈물이 날 때면 그대 뒤를 돌아보면 돼요 아프지 말...   71880
# ...                                                 ...     ...
# 1908  겨울 오면은 우리 둘이서 항상 왔었던 바닷가 시린 바람과 하얀 파도는 예전 그대로였...   12742
# 1909  좋은 사람 만나 행복해야 해 너는 웃고 있지만 나는 웃을 수가 없는걸 그래 난 알고...   18569
# 1910  그때의 나는 너를 만나서 하나부터 열까지 모든 순간들이 소중했어 내 첫사랑 잊고 싶...     925
# 1911  다시 처음으로 돌아갈 수 있다면 아마 너를 사랑하는 일은 안했을텐데 그 날밤 그 카...   10416
# 1912  이 동전 하나로 뭘 할 수 있을까 고민 고민하다가 나 혼자 이곳에 왔어 익숙한 번호...   15260
#
#                                                    앨범사진    songId    순위  \
# 0     https://cdnimg.melon.co.kr/cm2/album/images/11...  35383397     1
# 1     https://cdnimg.melon.co.kr/cm2/album/images/10...  34943312     2
# 2     https://cdnimg.melon.co.kr/cm2/album/images/10...  34787226     4
# 3     https://cdnimg.melon.co.kr/cm2/album/images/10...  34431086     6
# 4     https://cdnimg.melon.co.kr/cm2/album/images/10...  34908740     7
# ...                                                 ...       ...   ...
# 1908  https://cdnimg.melon.co.kr/cm/album/images/003...   1606413  1996
# 1909  https://cdnimg.melon.co.kr/cm/album/images/012...   3426230  1997
# 1910  https://cdnimg.melon.co.kr/cm2/album/images/10...  35145139  1998
# 1911  https://cdnimg.melon.co.kr/cm/album/images/010...   2933662  1999
# 1912  https://cdnimg.melon.co.kr/cm2/album/images/10...  32104350  2000
#
#                  0
# 0              sad
# 1              sad
# 2              sad
# 3              sad
# 4     indifference
# ...            ...
# 1908           sad
# 1909           sad
# 1910           sad
# 1911           sad
# 1912           sad
#
# [1913 rows x 9 columns]

# %% [markdown]
# ---
# ### 감정 컬럼 만들기

# %%
Bayes_ballad2000.rename(columns={0:'감정'},inplace=True)

# %%
Bayes_ballad2000
# Out:
#                가수명                      노래제목         발매일  \
# 0     WSG워너비 (가야G)         그때 그 순간 그대로 (그그그)  2022-07-09
# 1               경서                    나의 X에게  2022-04-24
# 2               주호                   내가 아니라도  2022-03-25
# 3       김민석 (멜로망스)                      취중고백  2021-12-19
# 4              임영웅                  우리들의 블루스  2022-05-02
# ...            ...                       ...         ...
# 1908            터보             회상 (December)  1997-01-01
# 1909           이석훈                        고백  2011-06-02
# 1910           다비치                    나의 첫사랑  2022-05-16
# 1911          미스에스  이 나이 먹고 뭐했길래 (Feat. 정슬기)  2010-09-10
# 1912       하은 (포맨)             혼코노 (Honkono)  2019-10-17
#
#                                                      가사    좋아요수  \
# 0      잘 지냈지? 조금은 어색해 요즘 좋아 보여 인사 나누며 사실 궁금한 게 너무 많았...   88589
# 1      우리 다시 만날래 예쁘게 빛나던 모든 추억들이 너무 그리워 너의 품에 안길래 이 ...  105034
# 2      사랑이었다 별거 없던 내 하루에 빛이 돼준 단한 사람 나보다 나를 더 아껴 주던 ...   52955
# 3      뭐하고 있었니 늦었지만 잠시 나올래 너의 집 골목에 있는 놀이터에 앉아 있어 친구...  137934
# 4      잊지는 말아요 함께 했던 날들 눈물이 날 때면 그대 뒤를 돌아보면 돼요 아프지 말...   71880
# ...                                                 ...     ...
# 1908  겨울 오면은 우리 둘이서 항상 왔었던 바닷가 시린 바람과 하얀 파도는 예전 그대로였...   12742
# 1909  좋은 사람 만나 행복해야 해 너는 웃고 있지만 나는 웃을 수가 없는걸 그래 난 알고...   18569
# 1910  그때의 나는 너를 만나서 하나부터 열까지 모든 순간들이 소중했어 내 첫사랑 잊고 싶...     925
# 1911  다시 처음으로 돌아갈 수 있다면 아마 너를 사랑하는 일은 안했을텐데 그 날밤 그 카...   10416
# 1912  이 동전 하나로 뭘 할 수 있을까 고민 고민하다가 나 혼자 이곳에 왔어 익숙한 번호...   15260
#
#                                                    앨범사진    songId    순위  \
# 0     https://cdnimg.melon.co.kr/cm2/album/images/11...  35383397     1
# 1     https://cdnimg.melon.co.kr/cm2/album/images/10...  34943312     2
# 2     https://cdnimg.melon.co.kr/cm2/album/images/10...  34787226     4
# 3     https://cdnimg.melon.co.kr/cm2/album/images/10...  34431086     6
# 4     https://cdnimg.melon.co.kr/cm2/album/images/10...  34908740     7
# ...                                                 ...       ...   ...
# 1908  https://cdnimg.melon.co.kr/cm/album/images/003...   1606413  1996
# 1909  https://cdnimg.melon.co.kr/cm/album/images/012...   3426230  1997
# 1910  https://cdnimg.melon.co.kr/cm2/album/images/10...  35145139  1998
# 1911  https://cdnimg.melon.co.kr/cm/album/images/010...   2933662  1999
# 1912  https://cdnimg.melon.co.kr/cm2/album/images/10...  32104350  2000
#
#                 감정
# 0              sad
# 1              sad
# 2              sad
# 3              sad
# 4     indifference
# ...            ...
# 1908           sad
# 1909           sad
# 1910           sad
# 1911           sad
# 1912           sad
#
# [1913 rows x 9 columns]

# %% [markdown]
# ---
# ### csv 저장하기

# %%
Bayes_ballad2000.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1913 entries, 0 to 1912
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   가수명     1913 non-null   object
#  1   노래제목    1913 non-null   object
#  2   발매일     1913 non-null   object
#  3   가사      1913 non-null   object
#  4   좋아요수    1913 non-null   object
#  5   앨범사진    1913 non-null   object
#  6   songId  1913 non-null   int64
#  7   순위      1913 non-null   int64
#  8   감정      1913 non-null   object
# dtypes: int64(2), object(7)
# memory usage: 134.6+ KB

# %%
Bayes_ballad2000.to_csv('../../Data/Bayes_ballad2000_emotion3.csv', index=None)

# %%
import pandas as pd

# %%
pd.read_csv("../../Data/Bayes_ballad2000_emotion3.csv")['감정'].value_counts()
# Out:
# sad             1485
# happy            255
# indifference     173
# Name: 감정, dtype: int64

# %%
Bayes_ballad2000 = pd.read_csv("../../Data/Bayes_ballad2000_emotion3.csv")
Bayes_ballad2000.head()
# Out:
#             가수명               노래제목         발매일  \
# 0  WSG워너비 (가야G)  그때 그 순간 그대로 (그그그)  2022-07-09
# 1            경서             나의 X에게  2022-04-24
# 2            주호            내가 아니라도  2022-03-25
# 3    김민석 (멜로망스)               취중고백  2021-12-19
# 4           임영웅           우리들의 블루스  2022-05-02
#
#                                                   가사    좋아요수  \
# 0   잘 지냈지? 조금은 어색해 요즘 좋아 보여 인사 나누며 사실 궁금한 게 너무 많았...   88589
# 1   우리 다시 만날래 예쁘게 빛나던 모든 추억들이 너무 그리워 너의 품에 안길래 이 ...  105034
# 2   사랑이었다 별거 없던 내 하루에 빛이 돼준 단한 사람 나보다 나를 더 아껴 주던 ...   52955
# 3   뭐하고 있었니 늦었지만 잠시 나올래 너의 집 골목에 있는 놀이터에 앉아 있어 친구...  137934
# 4   잊지는 말아요 함께 했던 날들 눈물이 날 때면 그대 뒤를 돌아보면 돼요 아프지 말...   71880
#
#                                                 앨범사진    songId  순위  \
# 0  https://cdnimg.melon.co.kr/cm2/album/images/11...  35383397   1
# 1  https://cdnimg.melon.co.kr/cm2/album/images/10...  34943312   2
# 2  https://cdnimg.melon.co.kr/cm2/album/images/10...  34787226   4
# 3  https://cdnimg.melon.co.kr/cm2/album/images/10...  34431086   6
# 4  https://cdnimg.melon.co.kr/cm2/album/images/10...  34908740   7
#
#              감정
# 0           sad
# 1           sad
# 2           sad
# 3           sad
# 4  indifference

# %%
1485 + 255 + 173
# Out:
# 1913
